# %%
# -*- coding:utf-8 -*-
import tensorflow as tf
from tensorflow.python.layers.core import Dense
import tensorflow.contrib.keras as keras
from keras.preprocessing.sequence import pad_sequences
import os
import numpy as np
import pandas as pd
from pandas import DataFrame
import time
import random
from PIL import Image
# from trec_eval import trec_eval
import nltk
import copy
from keras.models import load_model

# %%
# !pip install -r requirements.txt
# !rm -rf checkpoint4

# %%
# from zipfile import ZipFile
# filename = "checkpoint.zip"
# with ZipFile(filename,'r') as zip:
#   zip.extractall()

# filename1 = "dataset.zip"
# with ZipFile(filename1,'r') as zip:
#   zip.extractall()
  
# filename = "checkpoint2.zip"
# with ZipFile(filename,'r') as zip:
#   zip.extractall()
  
# filename3 = "img.zip"
# with ZipFile(filename3,'r') as zip:
#   zip.extractall()

# print('Done')

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

# %%
random.seed(1)
np.random.seed(1)

# %% [markdown]
# # Useful Functions

# %%
def read_comments(file_name):
    with open(file_name,'r') as f:
        file_content = f.readlines()
    comments = []
    for line in file_content:
        comments.append(line[:-1].split())
    return comments

# %%
def build_vocab(file_name,min_num):
    with open(file_name,'r') as f:
        file_content = f.readlines()
    word_to_int = {}
    int_to_word = {}
    words_num = 0
    for line in file_content:
        line = line[:-1].split('\t')
        if int(line[2]) >= min_num:
            word_to_int[line[1]] = int(line[0])
            int_to_word[int(line[0])] = line[1] 
            words_num += 1
        else:
            break
    word_to_int['<PAD>'] = 0
    word_to_int['<UNK>'] = words_num+1
    word_to_int['<GO>'] = words_num+2
    word_to_int['<EOS>'] = words_num+3
    int_to_word[0] = '<PAD>'
    int_to_word[words_num+1] = '<UNK>'
    int_to_word[words_num+2] = '<GO>'
    int_to_word[words_num+3] = '<EOS>'
    return word_to_int,int_to_word

# %%
# vocab_path = 'dataset/vocab.dat'

# min_num=5
# word_to_int,int_to_word = build_vocab(vocab_path,min_num)
# vocab_size = len(word_to_int)
# print(vocab_size)
# Out:
# 16519

# %%
def convert_comments(comments,word_to_int,int_to_word):
    comments_to_int = []
    for comment in comments:
        comment_to_int = [word_to_int[word] if word_to_int.get(word) != None else word_to_int['<UNK>'] for word in comment]  
        comment_to_int.insert(0,word_to_int['<GO>'])
        comment_to_int.append(word_to_int['<EOS>'])
        comments_to_int.append(comment_to_int)
    return comments_to_int

# %%
def negative_samples(num_samples,toplist,downlist,combinationlist):
    sampledata = []
    num = 0
    while num < num_samples:
        top = random.sample(toplist,1)[0]
        down = random.sample(downlist,1)[0]
        if top+down not in combinationlist:
            sampledata.append((top,down,-1))
            num += 1
    return sampledata

# %%
def pad_batch(batch,pad_int):
    max_length = max([len(comment) for comment in batch])
    pad_batch = pad_sequences(batch,maxlen=max_length,value=pad_int,padding='post')
    return pad_batch

# %%
def get_img(imgidlist):
    result=[]
    for img_idx in imgidlist:
        img = Image.open('img/'+img_idx+'.jpg')
        img = np.array(img)
        img = img/255.0
        result.append(img)
    return result

# %%
def batch_to_input(batch,comments,topidlist,downidlist,pad_int):
    img1 = []#for top
    img2 = []#for down
    img1id = []
    img2id = []
    label = []
    sequence = []
    sequence_length = []
    weight = []
    
    for instance in batch:
        img1.append(instance[0])
        img2.append(instance[1])
#         img1=instance[0]
#         img2=instance[1]
        img1id.append(topidlist[instance[0]])
        img2id.append(downidlist[instance[1]])
        commentid = instance[2]
        if commentid == -1:
            label.append([1,0])
            weight.append(0)
        else:
            label.append([0,1])
            weight.append(1)
        sequence.append(comments[commentid])
        sequence_length.append(len(comments[commentid])-1)
    sequence = pad_batch(sequence,pad_int)
    sequence_input = sequence[:,:-1]
    sequence_output = sequence[:,1:]
    max_sequence_length = np.max(sequence_length)
#     np.array(img1),np.array(img2),
    return np.array(img1),np.array(img2),np.array(img1id),np.array(img2id),np.array(label),sequence_input,sequence_output,sequence_length,max_sequence_length,np.array(weight)

# %%
def get_batches(data,batch_size,comments,toplist,downlist,combinationlist,topidlist,downidlist,pad_int):
    datacopy = copy.copy(data)
    datacopy.extend(negative_samples(len(datacopy),toplist,downlist,combinationlist))
    random.shuffle(datacopy)
    for batch_i in range(0,len(datacopy)//batch_size+1):
        start_i = batch_i*batch_size
        batch = datacopy[start_i:start_i+batch_size]          
        yield batch_to_input(batch,comments,topidlist,downidlist,pad_int)

# %%
def build_evaluation_batch(fixitem,itemlist,state,topidlist,downidlist):
    img1 = []
    img2 = []
    img1id = []
    img2id = []
    if state == 0:#top,downs
        for item in itemlist:
            img1.append(fixitem)
            img2.append(item)
            img1id.append(topidlist[fixitem])
            img2id.append(downidlist[item])
    if state == 1:#down,tops
        for item in itemlist:
            img1.append(item)
            img2.append(fixitem)
            img1id.append(topidlist[item])
            img2id.append(downidlist[fixitem])
    return np.array(img1),np.array(img2),np.array(img1id),np.array(img2id)

# %%
****************************************************************

def id_seq_to_word_seq(id_seq,id_vocab,eos):
    index = 0
    while index < len(id_seq):
        if id_seq[index] == eos:
            break
        index += 1
    valid_id_seq = id_seq[:index+1]
    return ' '.join([id_vocab[id] for id in valid_id_seq])

# %%
def accuracy(label,prediction):
    return (label.argmax(axis=1) == prediction.argmax(axis=1)).sum()/float(len(label))

# %%
def prepare_evaluation(data_path,comments,int_to_word,word_to_int):
    with open(data_path,'r') as f:
        content = f.readlines()
    data = {}
    orderlist = []
    model_comments = {}
    labellist = {}
    query_number = 0
    for line in content:
        line = line[:-1].split('\t')
        if data.get(line[0]) != None:
            data[line[0]].append(line[1])
        else:
            data[line[0]] = [line[1]] 
            labellist[query_number] = {}
            query_number += 1
            orderlist.append(line[0])
        if int(line[2]) == 1:
            model_comments[(line[0],line[1])] = [id_seq_to_word_seq(comments[int(comment)],int_to_word,word_to_int['<EOS>']).split()[1:-1] for comment in line[3].split('|')]
            labellist[query_number-1][line[1]] = 1
        else:
            labellist[query_number-1][line[1]] = 0
    return data,orderlist,model_comments,labellist

# %%
def trec_evaluation(qrel_file_path,trec_file_path,trec):
    with open(trec_file_path,'w') as f:
        i = 0
        while i < len(trec):
            j = 0 
            while j < len(trec[i]):
                f.write(str(i)+' '+'Q0 '+trec[i][j][0]+' '+str(j+1)+' '+str(trec[i][j][1])+' '+'Exp'+'\n')
                j += 1
            i += 1   
    result = trec_eval(qrel_file_path,trec_file_path)
    print(result)
    return result

# %%
def bleu_evalaution(model_comments,system_comments,beamsearch):
    select = {}
    bleus = []
    if beamsearch:
        for combination,comments in system_comments.items():
            scores = []
            for comment in comments:
                scores.append(nltk.translate.bleu_score.sentence_bleu(model_comments[combination],comment,weights=[1.0]))
            scores = np.array(scores)
            bleus.append(scores.max())
            select[combination] = scores.argmax()#we only select the best for evaluation
    else:
        for combination,comment in system_comments.items():
            bleus.append(nltk.translate.bleu_score.sentence_bleu(model_comments[combination],comment,weights=[1.0]))  
    bleus = np.array(bleus)
    print(bleus.mean())
    return bleus.mean(),select

# %%
def auc_evaluation(labellist,trec):
    query_number = 0
    record = []
    while query_number < len(trec):
        negative = 0
        temp = []
        for combination in trec[query_number]:
            if labellist[query_number][combination[0]] == 1:
                temp.append(negative)
            else:
                negative += 1
        record.extend([(negative-val)/float(negative) for val in temp])
        query_number += 1
    auc = np.array(record).mean()
    print(auc)
    return auc

# %% [markdown]
# # Prepare Datasets

# %%
comments_path = 'dataset/text.dat'
vocab_path = 'dataset/vocab.dat'
min_num = 5

# %%
comments = read_comments(comments_path)
comments.append([])
comments
# Out:
# [['congrats', 'on', 'your', 'ts', '!'],
#  ['thank', 'you', '!', '...', 'xoxo', '.'],
#  ['thank', 'you', '!', 'xoxo', '.'],
#  ['congrats', 'on', 'ts', '!', 'your', 'sets', 'are', 'amazing', '!'],
#  ['absolutely', 'fabulous', 'congrats', 'on', 'tfs', '.'],
#  ['congrats', 'on', 'this', 'amazing', 'top', 'set', '~', '.'],
#  ['nice', '!', 'ts', 'congrats', '!'],
#  ['outstanding',
#   'casual',
#   'outfit',
#   'and',
#   'stunning',
#   'clothes',
#   'congrats',
#   'on',
#   'fab',
#   'top',
#   'set',
#   '.'],
#  ['congratulations',
#   'on',
#   'your',
#   'very',
#   'pretty',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['simple', '&', 'fab', '!', '<', '333', '.'],
#  ['splendid', '!', 'congratulations', '!'],
#  ['so', 'chic', 'yet', 'so', 'simplecongratzz', '.'],
#  ['too', 'fashionista', 'for', 'me', '!'],
#  ['adore', 'your', 'comments', ',', 'thank', 'you', '!', 'xoxo', '.'],
#  ['thank',
#   'you',
#   'so',
#   'much',
#   'to',
#   'everyone',
#   '!',
#   'i',
#   'appreciate',
#   'every',
#   'comment',
#   'and',
#   'beautiful',
#   'comment',
#   'xoxo',
#   ':',
#   '.'],
#  ['amazing',
#   '!',
#   'congrats',
#   'girl',
#   '!',
#   'i',
#   'will',
#   'follow',
#   'back',
#   '.',
#   ':',
#   ')',
#   '.'],
#  ['wonderful', '!', 'congratulations', 'dear', 'on', 'ts', '!'],
#  ['bellissimo', ',', 'congratulazioni', '.'],
#  ['congratulations',
#   'on',
#   'being',
#   '#',
#   '1',
#   'top',
#   'set',
#   'today',
#   ',',
#   'so',
#   'happy',
#   'for',
#   'you',
#   '.',
#   'hope',
#   'you',
#   'get',
#   'tons',
#   'of',
#   'likes',
#   '&',
#   'follows',
#   '.'],
#  ['felicidades', 'linda', 'por', 'tu', 'tfs', 'y', 'el', 'primero', '!'],
#  ['congrats',
#   'on',
#   'being',
#   '#',
#   '3',
#   'in',
#   'the',
#   'picnic',
#   'in',
#   'the',
#   'park',
#   'sets',
#   'collection',
#   '.'],
#  ['color', 'scheme', 'goals', '!', 'love', 'it', '.'],
#  ['amazing', 'dear.congrats', '.'],
#  ['congrats', 'on', 'tfs', '.', 'amazing', '.'],
#  ['yay',
#   '!',
#   'nawzajem',
#   ',',
#   'gratulacje',
#   ',',
#   'w',
#   'pelni',
#   'zasluzony',
#   '!'],
#  ['lovely', '!', 'ts', 'congrats', '!'],
#  ['woow', 'adore', '...', '.congrats', 'on', 'ts', '.'],
#  ['so', 'summery', '!', 'love', 'it', '.', 'congrats', '.'],
#  ['u', 'know', 'this', 'is', 'amazing', ',', 'congrats', '!'],
#  ['so',
#   'gorgeous',
#   'and',
#   'beautiful',
#   '!',
#   'congratulations',
#   'on',
#   'ts',
#   '.'],
#  ['congratulations', 'on', 'your', 'gorgeous', 'ts', '!'],
#  ['congratulations', 'on', 'ts', '!'],
#  ['splendid', ',', 'congratulations', '!'],
#  ['lovely', ',', 'congratulations', 'hun', '.'],
#  ['amazing',
#   '!',
#   'congrats',
#   '!',
#   ':',
#   ')',
#   'i',
#   'will',
#   'follow',
#   'back',
#   '.',
#   '<',
#   '3',
#   '.'],
#  ['oh', 'awesome', '!'],
#  ['great',
#   'look',
#   'great',
#   'set',
#   'great',
#   'color',
#   'n',
#   "'",
#   'nice',
#   'pants',
#   '.'],
#  ['pretty', 'mix', '!'],
#  ['its', 'soo', 'sweet', '!'],
#  ['no',
#   'problem',
#   '!',
#   'this',
#   'is',
#   'definitely',
#   'one',
#   'of',
#   'my',
#   'fave',
#   'sets',
#   '!'],
#  ['you', "'re", 'too', 'sweet', ',', 'tysm', '<', '33', '.'],
#  ['ikrrr',
#   'i',
#   'didnt',
#   'even',
#   'notice',
#   '!',
#   'this',
#   'set',
#   'completely',
#   'deserves',
#   'it',
#   'tho',
#   '!'],
#  ['haha',
#   'ikr',
#   '!',
#   'i',
#   "'ve",
#   'never',
#   'even',
#   'gotten',
#   'over',
#   '300',
#   'before',
#   'lol',
#   '.',
#   'thanks',
#   'so',
#   'much',
#   'girlie',
#   '!'],
#  ['dang',
#   'girl',
#   'thats',
#   'alot',
#   'of',
#   'likes',
#   '!',
#   'congrats',
#   'girly',
#   '!'],
#  ['thanks', 'lauren', ',', 'i', 'agree', ';', '-', ')', '.'],
#  ['no',
#   'need',
#   'to',
#   'be',
#   'rude',
#   ',',
#   'please',
#   'keep',
#   'your',
#   'negative',
#   'opinions',
#   'to',
#   'yourself',
#   '.',
#   'and',
#   'apparently',
#   '2.6k+',
#   'people',
#   'think',
#   'it',
#   'works',
#   'and',
#   'decided',
#   'to',
#   'like',
#   'the',
#   'set',
#   'sooooo',
#   '.'],
#  ['i', 'think', 'it', 'works', 'great', '.'],
#  ['i',
#   'like',
#   'the',
#   'color',
#   'but',
#   'those',
#   'jeans',
#   'just',
#   'do',
#   "n't",
#   'work',
#   'with',
#   'it',
#   '.'],
#  ['i', 'am', 'sorry', 'that', 'was', 'my', 'cousin', '.'],
#  ['liking', 'this', 'for', 'the', 'title', '<', '3', '.'],
#  ['thanks',
#   'a',
#   'million',
#   'lauren',
#   '!',
#   'you',
#   "'re",
#   'too',
#   'sweet',
#   'haha',
#   'xx',
#   '.'],
#  ['yesss',
#   'lorde',
#   'is',
#   'the',
#   'queen',
#   '!',
#   'and',
#   'thanks',
#   'annaya',
#   '!',
#   '<',
#   '33',
#   '.'],
#  ['your',
#   'style',
#   'is',
#   'totally',
#   'amazing',
#   '!',
#   'and',
#   'congratulations',
#   '!',
#   'you',
#   'really',
#   'deserve',
#   'it',
#   '!'],
#  ['wooww',
#   '!',
#   'wonderful',
#   '.',
#   'i',
#   'adore',
#   'your',
#   'style',
#   'congratulations',
#   'baby',
#   '.'],
#  ['yes',
#   ',',
#   'lorde',
#   'my',
#   'queen',
#   '.',
#   'and',
#   'wow',
#   ',',
#   'congratulations',
#   '!',
#   'i',
#   'know',
#   'someone',
#   'famous',
#   ';',
#   ')',
#   'xoxo',
#   '.'],
#  ['thank',
#   'you',
#   'so',
#   'much',
#   '!',
#   'it',
#   'means',
#   'a',
#   'lot',
#   '<',
#   '33',
#   '.'],
#  ['i', 'see', 'red', ';', ')', '.'],
#  ['nice', '!', 'ts', 'congrats', '!'],
#  ['amazing',
#   'set',
#   'dear',
#   '!',
#   'congratulations',
#   '!',
#   'you',
#   'deserve',
#   'it',
#   '!',
#   ':',
#   ')',
#   '.'],
#  ['me', 'too', 'until', 'the', '26th', 'gurllllll', '.'],
#  ['thanks', 'a', 'billion', 'sariah', '!', '<', '33', '.'],
#  ['congrats',
#   'on',
#   'top',
#   'set',
#   '!',
#   'you',
#   'deserve',
#   'it',
#   '!',
#   '<',
#   '3',
#   '.'],
#  ['awesome', 'look', '!', 'congrats', 'on', 'ts', 'dear', '!'],
#  ['omg', 'omg', 'thank', 'you', 'all', 'so', 'much', '!', '<', '33', '.'],
#  ['congratssss', '!', 'you', 'deserve', 'it', '!'],
#  ['god', 'this', 'is', '<', '3', '.'],
#  ['tell',
#   'me',
#   'how',
#   'do',
#   'you',
#   'get',
#   'views',
#   'or',
#   'promote',
#   'your',
#   'page',
#   '.'],
#  ['congrats', '!', 'you', 'totally', 'deserve', 'it', '!'],
#  ['yass',
#   ',',
#   'this',
#   'set',
#   'is',
#   'on',
#   'fire',
#   '!',
#   'haha',
#   'congrats',
#   ':',
#   ')',
#   '.'],
#  ['congrats', 'bby', 'you', 'really', 'deserve', 'it', '!', '<', '3', '.'],
#  ['omg', 'bby', 'congrats', '!', '<', '33', '.'],
#  ['thanks', 'a', 'million', 'baby', '<', '3', 'and', 'ilysm', '!'],
#  ['aww',
#   'no',
#   'problem',
#   'babe',
#   '!',
#   'thanks',
#   'so',
#   'much',
#   'and',
#   'ily',
#   'so',
#   'much',
#   '<',
#   '33',
#   '.'],
#  ['omg',
#   'girl',
#   'i',
#   'would',
#   'love',
#   'to',
#   'see',
#   'that',
#   '!',
#   'and',
#   'good',
#   'luck',
#   'at',
#   'high',
#   'school',
#   ',',
#   'ily',
#   'a',
#   'lot',
#   '.'],
#  ['aw',
#   'thanks',
#   'so',
#   'much',
#   'rachel',
#   '!',
#   'and',
#   'of',
#   'course',
#   ',',
#   'only',
#   'the',
#   'best',
#   'for',
#   'you',
#   'haha',
#   ':',
#   "'",
#   ')',
#   'omg',
#   'you',
#   "'re",
#   'too',
#   'sweet',
#   ',',
#   'ly',
#   'more',
#   '<',
#   '333',
#   '.'],
#  ['yay',
#   ',',
#   'glad',
#   'to',
#   'hear',
#   'it',
#   '!',
#   'thanks',
#   'so',
#   'much',
#   'mia',
#   ',',
#   'and',
#   'no',
#   'problem',
#   '<',
#   '3',
#   '.'],
#  ['oh', 'lucky', '!', 'haha', ',', 'thanks', ':', '-', ')', '.'],
#  ['omg',
#   'i',
#   'love',
#   'this',
#   'set',
#   '!',
#   'the',
#   'colors',
#   'are',
#   'gorgeous',
#   '!'],
#  ['so', 'pretty', 'babe', '!'],
#  ['i',
#   'do',
#   "n't",
#   'go',
#   'back',
#   'for',
#   'another',
#   'month',
#   '.',
#   'i',
#   'would',
#   'really',
#   'enjoy',
#   'you',
#   'listing',
#   'your',
#   'looks',
#   '.'],
#  ['thanks', 'ally', '!', 'xx', '.'],
#  ['it',
#   'does',
#   'actually',
#   'haha',
#   '!',
#   'thanks',
#   'so',
#   'much',
#   'elle',
#   '!',
#   'xx',
#   '.'],
#  ['thanks',
#   'hailee',
#   '!',
#   'ooh',
#   'that',
#   "'s",
#   'a',
#   'good',
#   'idea',
#   ',',
#   'i',
#   'actually',
#   'just',
#   'checked',
#   'out',
#   'your',
#   'collections',
#   'for',
#   'that',
#   'and',
#   'your',
#   'outfits',
#   'are',
#   'so',
#   'cute',
#   '!',
#   '<',
#   '3',
#   '.'],
#  ['but',
#   'painting',
#   'nails',
#   'and',
#   'watching',
#   'tv',
#   'makes',
#   'for',
#   'a',
#   'phenomenal',
#   'day',
#   '!',
#   'haha',
#   '.',
#   'this',
#   'set',
#   'is',
#   'really',
#   'nice',
#   '<',
#   '3',
#   'love',
#   'the',
#   'red',
#   '.',
#   'good',
#   'luck',
#   'with',
#   'school',
#   'and',
#   'things',
#   'in',
#   'your',
#   'life',
#   ':',
#   ')',
#   '.'],
#  ['yay',
#   'i',
#   "'m",
#   'glad',
#   'you',
#   "'re",
#   'interested',
#   '!',
#   'and',
#   'thanks',
#   ';',
#   '-',
#   ')',
#   '.'],
#  ['the',
#   'outfits',
#   'of',
#   'the',
#   'week',
#   'would',
#   'actually',
#   'be',
#   'a',
#   'really',
#   'cool',
#   'idea',
#   '!',
#   'id',
#   'love',
#   'to',
#   'see',
#   'it',
#   '!',
#   'also',
#   'good',
#   'luck',
#   'going',
#   'back',
#   'to',
#   'school',
#   '.'],
#  ['thanks',
#   'so',
#   'much',
#   '!',
#   'yay',
#   ',',
#   'i',
#   "'m",
#   'glad',
#   'you',
#   "'d",
#   'like',
#   'to',
#   'see',
#   'that',
#   ';',
#   '-',
#   ')',
#   '.'],
#  ['this',
#   'is',
#   'so',
#   'gorgeous',
#   '!',
#   'and',
#   'aww',
#   'the',
#   'school',
#   'thing',
#   'kinda',
#   'sucks',
#   'but',
#   'i',
#   'wish',
#   'you',
#   'good',
#   'luck',
#   '.',
#   'and',
#   'i',
#   'would',
#   'love',
#   'to',
#   'see',
#   'an',
#   'outfits',
#   'of',
#   'the',
#   'week',
#   '!',
#   '#',
#   'ssfavorites',
#   '.'],
#  ['no', 'problem', '!', 'xx', '.'],
#  ['thanks', 'for', 'making', 'me', 'the', 'aotd', '<', '3', '.'],
#  ['congrats', 'on', 'ts', '!'],
#  ['beautiful', 'follow', 'me', 'please', '.'],
#  ['amazing',
#   'set',
#   '!',
#   'congrats',
#   'on',
#   'ts',
#   '!',
#   '<',
#   '3',
#   'if',
#   'you',
#   'guys',
#   'could',
#   'help',
#   'me',
#   'get',
#   'to',
#   '500',
#   'followers',
#   ',',
#   'i',
#   "'d",
#   'be',
#   'very',
#   'grateful',
#   '!',
#   ':',
#   ')',
#   'xoxo~',
#   'sam',
#   '.'],
#  ['cool', '!', 'ts', 'congrats', '!'],
#  ['fun',
#   'combination',
#   '!',
#   'really',
#   'like',
#   'the',
#   'little',
#   'scarf',
#   'with',
#   'the',
#   'shorts',
#   '.',
#   'adds',
#   'a',
#   'fun',
#   'flair',
#   '.'],
#  ['inspired', 'magic', '.'],
#  ['i', 'luv', 'this', 'so', 'much', '.'],
#  ['beautiful',
#   '...',
#   'congrats',
#   'and',
#   'keep',
#   'up',
#   'the',
#   'wonderful',
#   'work',
#   '!'],
#  ['marvelous', '!', 'congrats', '.'],
#  ['this',
#   'set',
#   'is',
#   'actually',
#   'adorable',
#   '!',
#   'it',
#   "'s",
#   'so',
#   'classy',
#   'and',
#   'mature',
#   'x',
#   '.'],
#  ['it',
#   'is',
#   'so',
#   'pretty',
#   '!',
#   'i',
#   'love',
#   'how',
#   'it',
#   'has',
#   'a',
#   'very',
#   'romantic',
#   'feel',
#   'to',
#   'it',
#   '!'],
#  ['its', 'really', 'amazing', '.'],
#  ['love', 'it', '!', 'congrats', 'darling', '.'],
#  ['this', 'is', 'the', 'most', 'gorgeous', 'one', 'ever', '!', 'perfect', '!'],
#  ['this', 'is', 'so', 'beautiful', '!', 'absolutely', 'delightful', '!'],
#  ['lovely', 'design', '.'],
#  ['wow', ',', 'what', 'an', 'amazingly', 'beautiful', 'set', '!'],
#  ['romantic', 'and', 'delightful', 'congrats', '.'],
#  ['you',
#   'spelt',
#   'the',
#   'name',
#   'wrong',
#   'it',
#   "'s",
#   'fairytail',
#   'idiot',
#   '.'],
#  ['so',
#   'gorgeous',
#   '!',
#   'double',
#   'whammy',
#   ',',
#   'congrats',
#   'on',
#   'tfs',
#   'and',
#   'your',
#   'win',
#   '!'],
#  ['congrats', 'on', 'ts', 'dear', '!'],
#  ['this', 'is', 'truly', 'magical', '!'],
#  ['lovely', '!', 'ts', 'congrats', '!'],
#  ['oh', 'gosh', 'that', "'s", 'so', 'pretty', '!'],
#  ['congratulations', 'beautiful', '*.*.*', '.', '*', '.'],
#  ['stunner', '!', 'congrats', '.'],
#  ['how', 'pretty', '.'],
#  ['ooo',
#   ',',
#   'so',
#   'stunning',
#   ',',
#   'certainly',
#   'looks',
#   'like',
#   'a',
#   'fairytale',
#   'congratulations',
#   '.'],
#  ['a',
#   'masterpiece',
#   '!',
#   '``',
#   'nothing',
#   'to',
#   'add',
#   "''",
#   'congrats',
#   ':',
#   ')',
#   '.'],
#  ['wow', '!', 'congratulations', 'on', 'this', 'princess', 'look', '.'],
#  ['sooooo', 'fab', '!'],
#  ['congrats', 'on', 'tfs', '.'],
#  ['stunning',
#   '!',
#   'just',
#   'love',
#   'it',
#   '!',
#   'congrats',
#   '!',
#   'so',
#   'well',
#   'deserved',
#   '!'],
#  ['congrats', 'on', 'your', 'beautiful', 'tfs', '!'],
#  ['wow',
#   'i',
#   "'m",
#   'in',
#   'love',
#   'with',
#   'this',
#   'set',
#   'so',
#   'flawless',
#   'and',
#   'beautiful',
#   'congratulations',
#   'on',
#   'ts',
#   'you',
#   'absolutely',
#   'deserve',
#   'it',
#   '.'],
#  ['congratulations', 'on', '1st', 'place', ',', 'beautiful', 'set', '.'],
#  ['wow', ',', 'wow', ',', 'wow', 'the', 'shoes', '!'],
#  ['follow', 'me', 'and', 'i', 'will', 'follow', 'you', 'too', '!'],
#  ['please', 'join', 'my', 'group', ':', '.'],
#  ['gorgeous',
#   'congrats',
#   'on',
#   'the',
#   'amazing',
#   'set',
#   'beautifully',
#   'designed',
#   '.'],
#  ['lovely', 'scheme', ';', ')', 'gj', '.'],
#  ['fabulous',
#   '!',
#   'congrats',
#   '!',
#   'i',
#   'will',
#   'follow',
#   'back',
#   ':',
#   ')',
#   '.'],
#  ['terrific', '!', 'ts', 'congrats', '!'],
#  ['congrats', 'dear', 'its', 'so', 'beautiful', '.'],
#  ['why', 'is', 'it', 'rebel', '.'],
#  ['nice', 'combination', '.'],
#  ['omgg', 'supaa', 'cutee', '.'],
#  ['congratulations',
#   'on',
#   'your',
#   'well',
#   'deserved',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['congrats', 'dear', 'on', 'this', 'well', 'deserved', 'top', 'set', '!'],
#  ['congratulations', 'on', 'tfs', '!'],
#  ['congratulations', 'on', 'ts', '!'],
#  ['amazing', '!', 'i', 'will', 'follow', 'back', ':', ')', 'congrats', '!'],
#  ['lovely', 'and', 'stylish', 'beautiful', 'look', '~', '.'],
#  ['so', 'feminine', '.'],
#  ['add', 'me', '.'],
#  ['hey', 'can', 'you', 'check', 'my', 'creations', '.'],
#  ['join', 'my', 'group', ',', 'pleas', '.'],
#  ['it', "'s", 'super', 'eye', 'catching', '!', 'loved', 'it', '!'],
#  ['add', 'me', '.'],
#  ['urmariti-ma', '!', 'follow', 'me', '!'],
#  ['omg',
#   'i',
#   'am',
#   'in',
#   'love',
#   'with',
#   'this',
#   'set',
#   '<',
#   '3congratulations',
#   '.'],
#  ['fabulous', '...', 'congrats', 'on', 'your', 'win', '.'],
#  ['congrats',
#   '!',
#   'i',
#   'wish',
#   'my',
#   'sets',
#   'could',
#   'be',
#   'like',
#   'urs',
#   '!'],
#  ['congratulations',
#   'on',
#   '#',
#   '1',
#   'top',
#   'set',
#   ',',
#   'hope',
#   'you',
#   'get',
#   'tons',
#   'of',
#   'follows',
#   '&',
#   'likes',
#   'today',
#   '.'],
#  ['congratulations', 'on', 'top', 'fashion', 'set', '!'],
#  ['i', 'love', 'this', '=', ')', '.'],
#  ['congrats',
#   'on',
#   'ts',
#   '!',
#   'fabulous',
#   'set',
#   '.',
#   ':',
#   ')',
#   'i',
#   'will',
#   'follow',
#   'back.',
#   '<',
#   '3',
#   '.'],
#  ['wow',
#   ',',
#   'this',
#   'set',
#   'is',
#   'so',
#   'great',
#   '!',
#   'i',
#   'love',
#   'de',
#   'colors',
#   'and',
#   'the',
#   'way',
#   'it',
#   'fits',
#   'perfectly',
#   'while',
#   'the',
#   'green',
#   'jeans',
#   'are',
#   'the',
#   'spotlight',
#   '.',
#   'well',
#   'done',
#   '!'],
#  ['outstanding', 'set', '.'],
#  ['very',
#   'beautiful',
#   'styling',
#   '.',
#   'i',
#   'like',
#   'it',
#   'a',
#   'lot',
#   '.',
#   'congratulations',
#   'to',
#   'you',
#   'dear',
#   ':',
#   ')',
#   '.'],
#  ['congrats', 'on', 'ts', '!'],
#  ['yay', '!', 'congrats', '!'],
#  ['i', 'would', 'love', 'to', 'wear', 'this', '.'],
#  ['congrats', 'on', 'fab', 'top', 'set', 'well', 'done', 'sweetie', '.'],
#  ['congrats', 'on', 'a', 'awesome', 'ts', '!'],
#  ['congrats', '!', 'exquisite', 'styling', '!'],
#  ['awesome', 'tfs', '!', 'on', 'point', 'as', 'always', '!'],
#  ['beautiful', 'ts', 'congrats', '.'],
#  ['love', 'congrts', '!'],
#  ['congrats', 'on', 'ts', 'dear', '!'],
#  ['lovely', '!', 'ts', 'congrats', '!'],
#  ['gorgeous', 'look', '!', 'congrats', 'on', 'ts', 'dear', '!'],
#  ['congrats', '.', 'really', 'deserve', 'it', '.', 'its', 'beautiful', '.'],
#  ['stunning', 'styling', '!', 'big', 'congrats', '!'],
#  ['yay', '!', 'congrats', '.'],
#  ['congratulations', 'dear', 'on', 'ts', '!'],
#  ['predivno', '!', 'estitam', '!'],
#  ['lovely', ',', 'congrats', 'dear..'],
#  ['great', '!', 'congrts', '.'],
#  ['great',
#   'set',
#   '!',
#   'congrats',
#   ',',
#   'you',
#   'deserve',
#   'it',
#   '!',
#   ':',
#   ')',
#   'i',
#   'will',
#   'follow',
#   'back',
#   '.'],
#  ['congratulations', 'on', 'your', 'charming', 'top', 'fashion', 'set', '.'],
#  ['cestitam', 'draga', '.'],
#  ['congrats', 'on', 'your', 'wonderful', 'ts', 'dear', 'xx', '.'],
#  ['perfect', 'back', 'to', 'school', 'look', '!'],
#  ['great', 'look', 'great', 'set', 'great', 'mixing', 'w/', 'red', '.'],
#  ['fab', 'bts', 'set', '!'],
#  ['styled', 'to', 'perfection', '.'],
#  ['great', 'look', 'for', 'school', 'love', 'it', 'xx', '.'],
#  ['fabulous', 'outfit', '!', 'love', 'these', 'basics', '!'],
#  ['hi',
#   ',',
#   'i',
#   'invite',
#   'you',
#   'to',
#   'join',
#   'the',
#   'competition',
#   ',',
#   'a',
#   'link',
#   'to',
#   'the',
#   'competition',
#   ':',
#   'thank',
#   'you',
#   '<',
#   '3you',
#   'set',
#   'is',
#   'amazing',
#   '.'],
#  ['congrats', 'on', 'ts', '!'],
#  ['congrats', 'sweetie', '!', 'xxo', '.'],
#  ['eye', 'candy', '.'],
#  ['beautiful', '!', 'congrats', 'on', 'ts', '!'],
#  ['congrats', 'ts', '!', 'awesome', '!'],
#  ['lovely', 'skirt', '.'],
#  ['congratulations', 'on', 'your', 'top', 'fashion', 'set', '!'],
#  ['fabulous',
#   ',',
#   'so',
#   'deserving',
#   'of',
#   'top',
#   'set',
#   '!',
#   'congrats',
#   'xo',
#   '.'],
#  ['gratulere', 'med', 'top', 'fashion', 'p', 'frste', 'side', '.'],
#  ['terrific', '!', 'ts', 'congrats', '!'],
#  ['so', 'lovely', '!', 'congrats', 'on', 'tfs', '!'],
#  ['perfectly', 'amazing', '.'],
#  ['congratulations', 'on', 'ts', '!'],
#  ['congratulations',
#   'on',
#   'your',
#   'well',
#   'deserved',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['stunning',
#   '!',
#   'congrats',
#   'on',
#   'top',
#   'fashion',
#   'set',
#   'and',
#   'top',
#   'slot',
#   '!'],
#  ['outstanding', '!', 'congratulations', 'dear', 'on', 'ts', '!'],
#  ['congrats', 'on', 'your', 'amazing', 'ts', 'dear', '!'],
#  ['congrats',
#   'on',
#   'your',
#   'beautiful',
#   'ts',
#   'on',
#   'cover',
#   'sweetie',
#   'xx',
#   'love',
#   '.'],
#  ['congrats', 'hun', '.'],
#  ['these', 'are', 'colors', 'well', 'blended', '.'],
#  ['congrats', '!', 'fantasic', '!'],
#  ['congrats', 'on', 'ts', '!'],
#  ['congrats', 'on', 'your', 'tfs', 'dear', '!'],
#  ['beautiful', 'ts', 'congrats', '.'],
#  ['congrats', 'on', 'your', 'amazing', 'ts', '!'],
#  ['well', 'done', '!'],
#  ['congrats', 'on', 'this', 'amazing', 'top', 'set', '~', '.'],
#  ['congrats',
#   'on',
#   'top',
#   'set',
#   '.',
#   'such',
#   'a',
#   'gorgeous',
#   'outfit',
#   'you',
#   'put',
#   'together',
#   '&',
#   'very',
#   'well',
#   'deserved',
#   '!'],
#  ['congrats', 'darling', '.'],
#  ['beautifully', 'styled', '!', 'congratulations', '!'],
#  ['congrats', 'on', 'ts', '!'],
#  ['congrats', 'on', 'ts', '!'],
#  ['cool', '...', 'congrats', 'my', 'dear', 'friend', '.'],
#  ['yay', '!', 'congrats', '.'],
#  ['hey', 'congrats', 'on', 'top', 'sets', '.'],
#  ['congrats', 'on', 'ts', '!', 'fab', '!'],
#  ['awesome',
#   'top',
#   'products',
#   'and',
#   'top',
#   'fashion',
#   'set',
#   '!',
#   'congrats',
#   'sweetie',
#   '!'],
#  ['congratulations', 'dear', 'on', 'ts', '!'],
#  ['congrats', '!', 'top', 'pick', '!'],
#  ['prefect', '!', 'congrats', '.'],
#  ['congrats', 'dear', 'fab', 'ts', '.'],
#  ['great', 'ts', 'congrats', 'dear', 'x', '.'],
#  ['congratulations',
#   'on',
#   'being',
#   '#',
#   '1',
#   'top',
#   'set',
#   'today',
#   ',',
#   'way',
#   'to',
#   'go',
#   '!',
#   'so',
#   'happy',
#   'for',
#   'you',
#   '.'],
#  ['finally', ',', 'on', 'top', '.'],
#  ['congrats', 'on', 'ts', 'dear', '!'],
#  ['congratulations',
#   'on',
#   'your',
#   'well',
#   'deserved',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['congrats', 'on', 'amazing', 'cover', 'ts', 'dear', 'xx', 'love', '.'],
#  ['wonderful', 'stripe', 'and', 'great', 'outfit', 'xx', '.'],
#  ['adore', 'this', 'simple', 'chic', '!'],
#  ['rachel', 'what', 'a', 'beautiful', 'set', '!', '（）', '.'],
#  ['love',
#   'definitely',
#   'ai',
#   "n't",
#   'haha',
#   'great',
#   'mix',
#   'of',
#   'colors',
#   '!',
#   'congrats',
#   '.'],
#  ['love', 'this', ',', 'congrats', ',', 'honey', '!'],
#  ['can', 'you', 'follow', 'me', 'please', 'please', '.'],
#  ['awesome', 'c', ':', '.'],
#  ['congrats', 'rach', '!', 'you', 'deserve', 'it', '!', '<', '333', '.'],
#  ['congratulations',
#   'rachel',
#   'on',
#   'top',
#   'set',
#   '.',
#   'hope',
#   'your',
#   'having',
#   'a',
#   'good',
#   'time',
#   'in',
#   'vacation',
#   'xx',
#   '.'],
#  ['lovely', '!', 'check', 'out', 'my', 'sets', '.'],
#  ['pefect', '!', 'love', 'this', '!'],
#  ['congratulations', 'on', 'ts', '!'],
#  ['i', 'love', 'going', 'school', 'shopping', 'lol', '.'],
#  ['congrats', 'on', 'the', 'gorgeous', 'top', 'set', 'hun', '!'],
#  ['does',
#   'buying',
#   'school',
#   'supplies',
#   'count',
#   'i',
#   'have',
#   "n't",
#   'read',
#   'the',
#   'other',
#   'comments',
#   'yet',
#   'so',
#   'i',
#   'dunno',
#   'what',
#   'they',
#   'say',
#   ',',
#   'but',
#   'i',
#   'like',
#   'that',
#   'best',
#   ',',
#   'haha',
#   ':',
#   "'",
#   ')',
#   'love',
#   'this',
#   'set',
#   '!'],
#  ['this',
#   'is',
#   'such',
#   'a',
#   'cute',
#   'set',
#   '!',
#   'my',
#   'favorite',
#   'thing',
#   'about',
#   'school',
#   'is',
#   'getting',
#   'to',
#   'see',
#   'my',
#   'friends',
#   '!'],
#  ['tysm',
#   '!',
#   'you',
#   "'re",
#   'very',
#   'kind',
#   'too',
#   ',',
#   'my',
#   'favorite',
#   'part',
#   'about',
#   'school',
#   'would',
#   'have',
#   'to',
#   'be',
#   'my',
#   'friends',
#   'as',
#   'well',
#   '#',
#   'katsfavorites',
#   '.'],
#  ['love',
#   'this',
#   'so',
#   'much',
#   '!',
#   'amazing',
#   '!',
#   'my',
#   'favourite',
#   'part',
#   'of',
#   'school',
#   'is',
#   'all',
#   'my',
#   'friends',
#   '(',
#   ':',
#   '.'],
#  ['ahhh',
#   'so',
#   'pretty',
#   'rachel',
#   '!',
#   'my',
#   'favorite',
#   'part',
#   'of',
#   'school',
#   'is',
#   'not',
#   'going',
#   'to',
#   'it',
#   'hehe',
#   '.'],
#  ['my',
#   'fave',
#   'thing',
#   'at',
#   'school',
#   'is',
#   'friends',
#   'and',
#   'english',
#   'and',
#   'augh',
#   'i',
#   'love',
#   'this',
#   'setttt',
#   '<',
#   '3333',
#   '.'],
#  ['beautiful',
#   'choice',
#   'of',
#   'ice',
#   'blue',
#   '!',
#   'great',
#   'back',
#   'to',
#   'school',
#   'look',
#   '!'],
#  ['fantastic',
#   'set',
#   '!',
#   'my',
#   'fave',
#   'thing',
#   'about',
#   'school',
#   'is',
#   'getting',
#   'supplies',
#   ':',
#   '(',
#   '.'],
#  ['you',
#   "'re",
#   'super',
#   'kind',
#   'too',
#   '!',
#   'my',
#   'favorite',
#   'thing',
#   'in',
#   'school',
#   'is',
#   'math',
#   '(',
#   'i',
#   "'m",
#   'a',
#   'nerd',
#   ':',
#   'p',
#   ')',
#   '.'],
#  ['stunning', 'and', 'mesmerizing', 'as', 'always', '.'],
#  ['i',
#   'like',
#   'getting',
#   'the',
#   'stationary',
#   'supplies',
#   ',',
#   'and',
#   'also',
#   'my',
#   'friends',
#   '.'],
#  ['this',
#   'is',
#   'so',
#   'pretty',
#   '!',
#   'my',
#   'favorite',
#   'thing',
#   'about',
#   'school',
#   'is',
#   'school',
#   'shopping',
#   '!'],
#  ['my',
#   'favorite',
#   'part',
#   'of',
#   'school',
#   'is',
#   'back',
#   'to',
#   'school',
#   'shopping',
#   '.'],
#  ['this',
#   'is',
#   'so',
#   'pretty',
#   '!',
#   'but',
#   'tbh',
#   'my',
#   'favorite',
#   'part',
#   'of',
#   'school',
#   'is',
#   'going',
#   'home',
#   'at',
#   'the',
#   'end',
#   'of',
#   'the',
#   'day',
#   '.'],
#  ['this',
#   'is',
#   'sooo',
#   'pretty',
#   'rachel',
#   '!',
#   'i',
#   'actually',
#   'love',
#   'everything',
#   'about',
#   'school',
#   ',',
#   'except',
#   'for',
#   'the',
#   'ten',
#   'hours',
#   'of',
#   'hw',
#   'haha',
#   '.',
#   'but',
#   'probably',
#   'hanging',
#   'with',
#   'my',
#   'friends',
#   'or',
#   'doing',
#   'group',
#   'projects',
#   '!'],
#  ['lunch', ';', ')', 'this', 'is', 'really', 'cute', '!'],
#  ['tag', 'o9', '.'],
#  ['tag', 'o8', '.'],
#  ['tag', 'o7', '.'],
#  ['tag', 'o6', '.', '#', 'philosoqhytags', '.'],
#  ['tag', 'o5', '.'],
#  ['tag', 'o4', '.'],
#  ['tag', 'o3', '.'],
#  ['tag', 'o2', '.', '#', 'unicorntags', '.'],
#  ['tag', 'o1', '.'],
#  ['so', 'simple', 'yet', 'stunning', '.'],
#  ['i',
#   'ca',
#   "n't",
#   'even',
#   'take',
#   'all',
#   'of',
#   'you',
#   "'re",
#   'beautiful',
#   'outfits',
#   '.'],
#  ['congrats', 'dear', '!', '#', 'supercute', '.'],
#  ['gratulere', '!', 'here', 'is', 'a', 'copy', 'give', 'report', '!'],
#  ['congrats', 'on', 'ts', '!'],
#  ['can', 'you', 'follow', 'me', 'please', '.'],
#  ['you', "'ve", 'been', 'copied', ':', '.'],
#  ['soo', 'cuteeee', '!', '.', 'congrats', 'babe', '.'],
#  ['ts', 'congrats', '!'],
#  ['supercute', '...', '.', 'congrats', 'on', 'ts', '.'],
#  ['lovely', '!', 'congrats', 'darling', '!'],
#  ['congratulations',
#   'on',
#   'your',
#   'very',
#   'lovely',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['good', 'job', '.'],
#  ['congratulations', 'on', 'ts', '!'],
#  ['congrats', 'again', 'dear', '...'],
#  ['so', 'summery', '!'],
#  ['congrats', 'on', 'ts', '!'],
#  ['idk', 'about', 'pants', '.'],
#  ['i', 'will', 'follow', 'back', ':', ')', '.'],
#  ['congrats', 'on', 'ts', '.'],
#  ['excellent', 'congrats', '!'],
#  ['lovely', '!', 'ts', 'congrats', '!'],
#  ['congrats', 'on', 'ts', '!'],
#  ['congratulations',
#   'on',
#   '#',
#   '1',
#   'top',
#   'set',
#   'today',
#   ',',
#   'way',
#   'to',
#   'go',
#   '.'],
#  ['sooo', 'nice', ',', 'congrats', 'dear', '!'],
#  ['nice', ',', 'congratulations', 'on', 'tfs', '!'],
#  ['just',
#   'now',
#   'at',
#   'penial.late',
#   'for',
#   'my',
#   'ownfucking',
#   'anyone',
#   'want',
#   'to',
#   'waite',
#   '.'],
#  ['congrats', 'on', 'ts', '.'],
#  ['follow', 'for', 'follow', '.'],
#  ['outstanding',
#   'casual',
#   'chic',
#   'look',
#   'congrats',
#   'on',
#   'fab',
#   'top',
#   'set',
#   '.'],
#  ['like',
#   'my',
#   'pretty',
#   'underpinnings',
#   'set',
#   'and',
#   'i',
#   "'ll",
#   'like',
#   '5',
#   'of',
#   'your',
#   'sets',
#   '.'],
#  ['congrats', 'on', 'ts', '!'],
#  ['my',
#   'sister',
#   ':',
#   'is',
#   'going',
#   'to',
#   'college',
#   'too',
#   '!',
#   'good',
#   'job',
#   ',',
#   'for',
#   'doing',
#   'hard',
#   'work',
#   '!',
#   'i',
#   'hope',
#   'you',
#   'got',
#   'into',
#   'a',
#   'good',
#   'university/college',
#   '.'],
#  ['cute', '!', 'ts', 'congrats', '!'],
#  ['congratulations', 'on', 'ts', '.'],
#  ['congrats', 'on', 'ts', '!', 'very', 'nice', 'set', '!'],
#  ['love', 'it', '!', 'congrats', '!', 'you', 'earned', 'it', '.'],
#  ['congrats', 'dear', '!', '#', 'perfectstyling', '.'],
#  ['rlly', 'like', 'it', '.', 'so', 'cute', '.'],
#  ['so', 'pretty', ',', 'and', 'congrats', 'on', 'tfs', '.'],
#  ['oh', 'its', 'fantastic', '!', 'congratulations', '.'],
#  ['phenomenal', '!', 'congrats', '!'],
#  ['so', 'fabulous', '!', 'congrats', 'my', 'friend', '!'],
#  ['so', 'cute', 'but', 'which', 'item', 'has', 'pleats', '...'],
#  ['delightful', 'set', '!', 'congrats', ',', 'dear', '!'],
#  ['congrats', '!', 'how', 'lovely', '!'],
#  ['congrats', 'on', 'your', 'gorgeous', 'ts', 'dear', '!'],
#  ['splendid', '!', 'ts', 'congrats', '!'],
#  ['congratulations', 'on', 'a', 'top', 'set', '!', 'well', 'deserved', '!'],
#  ['gorgeous', '!', 'congrats', 'on', 'tfs', '!'],
#  ['love', 'this', '!', 'congrats', 'on', 'your', 'top', 'fashion', 'set', '!'],
#  ['georgeous', '...', '.congratulations', '!'],
#  ['wonderful', 'top', 'fashion', 'set', '!', 'congrats', '!'],
#  ['delightful', 'congrats', '.'],
#  ['congratulations', 'on', 'your', 'charming', 'top', 'fashion', 'set', '.'],
#  ['yay', ',', 'congrats', 'on', 'top', 'set', '.', 'great', 'style', '.'],
#  ['soo', 'stylish', 'congrats', '.'],
#  ['congrats', 'sweetie', ',', 'i', 'love', 'this', 'set', '!', 'xxo', '.'],
#  ['fabulous..', 'congrats', '.'],
#  ['fantastic', 'outfit', 'in', 'every', 'detail', '!', 'cogratulations', '!'],
#  ['very', 'pretty', 'summer', 'look', '!'],
#  ['adorable',
#   'summer',
#   'fashion',
#   'and',
#   'fab',
#   'outfit',
#   'here',
#   'so',
#   'much',
#   '..sth',
#   'i',
#   "'d",
#   'like',
#   'to',
#   'wear',
#   'and',
#   'stay',
#   'fabulous',
#   'in',
#   'summer',
#   '!'],
#  ['so', 'lovely', 'sweetie', '!', 'xxo', '.'],
#  ['beautiful', 'elegance', '.', 'congratulations', 'to', 'you', '.'],
#  ['incredible',
#   'combination',
#   '!',
#   'very',
#   'stylish',
#   '!',
#   'well',
#   'done',
#   ':',
#   ')',
#   'xx',
#   '.'],
#  ['how',
#   'exquisite',
#   '!',
#   'these',
#   'rich',
#   'jewel',
#   'tones',
#   'and',
#   'chic',
#   'pieces',
#   'are',
#   'stunningly',
#   'together',
#   '.',
#   'big',
#   'congratulations',
#   'to',
#   'you',
#   'xx',
#   '.'],
#  ['very',
#   'stylish',
#   ',',
#   'great',
#   'combination',
#   'of',
#   'the',
#   'outfit',
#   'with',
#   'heels',
#   '&',
#   'clutch',
#   ':',
#   ')',
#   ')',
#   '.'],
#  ['what',
#   'an',
#   'amazing',
#   'style',
#   '!',
#   'gorgeous',
#   'colors',
#   'and',
#   'pieces',
#   '!',
#   'huge',
#   'congrats',
#   '!'],
#  ['pure', 'perfection', '!'],
#  ['unique', '!', 'congratulations', 'on', 'ts', 'dear', '!'],
#  ['congratulations', '!', 'incredible', 'set', '!'],
#  ['marvelous', '!', 'congrats', 'on', 'your', 'well', 'deserved', 'ts', '.'],
#  ['fantastic', '!', 'congrats', 'on', 'your', 'ts', '!'],
#  ['wow', 'absolutely', 'gorgeous', 'congrats', 'on', 'tfs', '.'],
#  ['congrats', 'on', 'ts', '!'],
#  ['lovely', '!', 'congrats', 'on', 'your', 'ts', '.'],
#  ['flawless', '.', 'congrats', '!'],
#  ['follow', 'me', 'and', 'i', 'follow', 'you', 'too', '!'],
#  ['beautiful', '!', 'congrats', 'on', 'ts', '!'],
#  ['how',
#   'gorgeous',
#   '!',
#   'loooove',
#   'it',
#   'my',
#   'friend',
#   '!',
#   'congrats',
#   '!'],
#  ['huge',
#   'congratulations',
#   'my',
#   'precious',
#   'treasure',
#   'on',
#   'your',
#   'most',
#   'magical',
#   '&',
#   'divine',
#   'top',
#   'set',
#   '!',
#   'you',
#   'deserve',
#   'it',
#   '!',
#   'bravo',
#   '!'],
#  ['i',
#   'need',
#   'more',
#   'green',
#   'in',
#   'my',
#   'life',
#   '.',
#   'you',
#   "'ve",
#   'inspired',
#   'me',
#   '.'],
#  ['congrats', '!', 'well', 'deserved', '.'],
#  ['ts', 'congrats', '!'],
#  ['elegant', 'congratulations', '.'],
#  ['congratulations', 'on', 'ts', '.', 'very', 'pretty', '.'],
#  ['beautiful', 'set', 'hun', 'xx', '.'],
#  ['congrats', 'on', 'ts', '!', 'nice', 'job', '!'],
#  ['check', 'mine', '!'],
#  ['amazing', 'work', '.'],
#  ['congrats', 'on', 'ts', '!'],
#  ['congrats', 'on', 'your', 'amazing', 'ts', 'dear', 'xx', '.'],
#  ['such', 'a', 'beautiful', 'look', ',', 'congrats', 'on', 'ts', '!'],
#  ['congrats', 'on', 'ts', 'dear', '.'],
#  ['the',
#   'blouse',
#   'is',
#   'so',
#   'beautiful',
#   'and',
#   'elegant',
#   ',',
#   'congrats',
#   '!'],
#  ['beautiful', '!', 'outstanding', 'look', '!', 'congrats', '!'],
#  ['congratulations',
#   'on',
#   'your',
#   'well',
#   'deserved',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['congrats', 'on', 'your', 'gorgeous', 'ts', 'dear', '!'],
#  ['congrats', 'on', 'tfs', '.', 'well', 'done', 'dear', '.'],
#  ['congratulations', 'dear', 'on', 'tfs', '!'],
#  ['marvelous',
#   'and',
#   'elegant',
#   'style',
#   '!',
#   'love',
#   'it',
#   '!',
#   '\\',
#   '(',
#   ')',
#   '/',
#   '.'],
#  ['just', 'incredible', '!'],
#  ['amazing', 'look', '!', '*', '.'],
#  ['wow..divine', 'styling', 'dear..that', 'jacket', 'is', 'exquisite', '!'],
#  ['adorable', 'modern', 'look', 'dear', '!', '<', '3', '.'],
#  ['absolutely',
#   'nice',
#   'way',
#   'too',
#   'gorgeous',
#   'and',
#   'fab',
#   'this',
#   'style',
#   'too',
#   'great',
#   'set',
#   'dear',
#   'you',
#   'did',
#   'combined',
#   'classic+elegance',
#   'too',
#   'nice',
#   '!'],
#  ['flat', 'out', 'gorgeous', '.'],
#  ['great',
#   'look',
#   'great',
#   'set',
#   'great',
#   'mixing',
#   'w/',
#   'velvet',
#   'n',
#   "'",
#   'nice',
#   'metallic',
#   'bag',
#   '.'],
#  ['perfect', 'outfit', ',', 'love', 'the', 'top', "'", ':', ')', '.'],
#  ['great', 'set', ',', 'that', 'blouse', 'is', 'fab', '!'],
#  ['so', 'lovely', '=d', '.'],
#  ['gorgeous', 'design', 'and', 'outfit', '!'],
#  ['superb',
#   'look',
#   'darling',
#   '!',
#   'love',
#   'the',
#   'color',
#   'and',
#   'textures',
#   '!',
#   'flawless',
#   '!'],
#  ['such', 'a', 'gorgeous', 'summery', 'set', '.'],
#  ['wowsome',
#   ',',
#   'love',
#   'the',
#   'combo',
#   'and',
#   'the',
#   'luxe',
#   'wood',
#   'clutch',
#   'by',
#   'dolce',
#   'and',
#   'gabbana',
#   '!'],
#  ['fabulous', 'sweetie', '!', 'xxo', '.'],
#  ['omg', '!', 'love', 'this', 'outfit', 'ox', '.'],
#  ['great', 'mix', '!', 'love', 'the', 'colors', 'and', 'styling', '.'],
#  ['lovely', 'color', 'combos', '.'],
#  ['absolutely', 'phenomenal', '!'],
#  ['wow', '!', 'fab', 'red', 'and', 'green', 'style', '.', 'love', 'it', '!'],
#  ['very', 'elegant', 'and', 'refined', '!'],
#  ['congrats', 'on', 'ts', '!', 'beautiful', '!'],
#  ['classy', 'af', '.'],
#  ['great', '!', 'congratulations', 'on', 'ts', '.'],
#  ['congrats', 'on', 'this', 'fab', 'top', 'set', '~', '.'],
#  ['nice', '!', 'ts', 'congrats', '!'],
#  ['congratulations', 'on', 'ts', '!'],
#  ['congratulations',
#   'on',
#   'your',
#   'very',
#   'pretty',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['amazing', '!', 'congrats', 'on', 'ts', ':', ')', '.'],
#  ['omg', '!', 'so', 'good', '.'],
#  ['this',
#   'is',
#   'my',
#   'fav',
#   'top',
#   'set',
#   'today',
#   ',',
#   'congratulations',
#   ',',
#   'such',
#   'a',
#   'cool',
#   'set',
#   '&',
#   'exceptional',
#   'design',
#   '.'],
#  ['congrats',
#   'on',
#   'your',
#   'outstanding',
#   'ts',
#   'my',
#   'dear',
#   'xx',
#   'love',
#   '.'],
#  ['congrats', 'on', 'ts', '.'],
#  ['in', 'love', 'with', 'the', 'bag', '!'],
#  ['congrats', '!', 'perfection', '.'],
#  ['have', 'a', 'look', 'at', 'polyvoregrrl', '.'],
#  ['love', 'it', 'girl', '.'],
#  ['você',
#   'no',
#   'conhece',
#   'a',
#   'palavra',
#   'limites',
#   'né',
#   'rs',
#   'lindo',
#   '!'],
#  ['congrats', 'on', 'awesome', 'ts', '!'],
#  ['terrific', '!', 'ts', 'congrats', '!'],
#  ['congratulations', 'on', 'ts', '!'],
#  ['congrats', '.', 'its', 'brilliant', '.'],
#  ['congratulations', 'on', 'top', 'sets', 'darling', '.'],
#  ['wow',
#   'absolutely',
#   'amazing',
#   ',',
#   'well',
#   'deserved',
#   'congrats',
#   'on',
#   'tfs',
#   '.'],
#  ['congratulations', 'on', 'ts', '!'],
#  ['the', 'wine', 'glass', 'tho', '.', 'where', 'issat', '.'],
#  ['outstanding',
#   '!',
#   'congrats',
#   'on',
#   'ts',
#   '.',
#   'i',
#   'will',
#   'follow',
#   'back',
#   '!',
#   ':',
#   ')',
#   '.'],
#  ['cute', 'set', ',', 'congrats', 'on', 'tfs', '!'],
#  ['congrats', 'on', 'ts', 'dear', '!'],
#  ['perfectly', 'amazing', 'congrats', '.'],
#  ['congratulations', '☆☆☆☆☆', '.'],
#  ['great',
#   'look',
#   'great',
#   'set',
#   'great',
#   'mixing',
#   'w/',
#   'clutch',
#   'n',
#   "'",
#   'nice',
#   'pleated',
#   '.'],
#  ['stylish', 'and', 'cool', 'summer', 'fashion', 'fab', 'this', 'style', '!'],
#  ['outstanding', 'set', '!', 'perfect', 'outfit', 'and', 'layout', '.'],
#  ['such', 'a', 'fun', 'set~', '.'],
#  ['``',
#   '...',
#   'i',
#   'suppose',
#   'it',
#   "'s",
#   'old',
#   'partner',
#   'but',
#   'the',
#   'beat',
#   'goes',
#   'on',
#   'da',
#   'da',
#   'dum',
#   'da',
#   'dum',
#   'dum',
#   "''",
#   '(',
#   'with',
#   'title',
#   ')',
#   '.'],
#  ['as',
#   'of',
#   'right',
#   'now',
#   'my',
#   'fave',
#   'song',
#   'is',
#   'hoodie',
#   'by',
#   'hey',
#   'violet',
#   ',',
#   'but',
#   'that',
#   "'s",
#   'guaranteed',
#   'to',
#   'change',
#   'in',
#   'a',
#   'week',
#   '.'],
#  ['nice', '!', 'ts', 'congrats', '!'],
#  ['congrats',
#   'bb',
#   'you',
#   'deserve',
#   'this',
#   'as',
#   'a',
#   'top',
#   'set',
#   'because',
#   'honestly',
#   'it',
#   "'s",
#   'just',
#   'amazing',
#   '!',
#   ':',
#   'd',
#   '.'],
#  ['woow', '!', 'love', '!'],
#  ['sway', 'by', 'phaser', ':', ')', '.'],
#  ['both',
#   'are',
#   'very',
#   'hard',
#   'but',
#   'probably',
#   'alternative',
#   'and',
#   'one',
#   'ok',
#   'rock',
#   ':',
#   ')',
#   'i',
#   'really',
#   'love',
#   'twenty',
#   'one',
#   'pilots',
#   'tho',
#   'even',
#   'tho',
#   'i',
#   'have',
#   "n't",
#   'listened',
#   'to',
#   'everything',
#   '.',
#   'this',
#   'is',
#   'gorgeous',
#   'btw',
#   '!'],
#  ['i',
#   'have',
#   'a',
#   'bunch',
#   'of',
#   'favorite',
#   'bands',
#   'but',
#   'i',
#   'mostly',
#   'listen',
#   'to',
#   'heavy',
#   'metal',
#   'and',
#   'pop',
#   '.',
#   'i',
#   'am',
#   'so',
#   'glad',
#   'i',
#   'do',
#   "n't",
#   'have',
#   'to',
#   'go',
#   'to',
#   'school',
#   'anymore',
#   '.'],
#  ['haha',
#   'the',
#   'back',
#   'to',
#   'school',
#   'thing',
#   "'s",
#   'so',
#   'true',
#   '!',
#   'my',
#   'fave',
#   'band',
#   'is',
#   'thirty',
#   'seconds',
#   'to',
#   'mars',
#   ':',
#   ')',
#   '.'],
#  ['i',
#   'looove',
#   'taylor',
#   'swift',
#   '!',
#   'she',
#   "'s",
#   'my',
#   'all',
#   'time',
#   'fav',
#   'aha',
#   '.'],
#  ['my',
#   'favorite',
#   'genre',
#   'is',
#   'musical',
#   'theater',
#   'and',
#   'my',
#   'favorite',
#   'artist',
#   'is',
#   'either',
#   'taylor',
#   'swift',
#   'or',
#   'lin-manuel',
#   'miranda',
#   '.'],
#  ['lovely', '!', 'ts', 'congrats', '!'],
#  ['congrats',
#   'on',
#   'a',
#   'top',
#   'set',
#   '!',
#   'splendid',
#   'style',
#   'and',
#   'amazinf',
#   'mix',
#   'of',
#   'colors',
#   '.'],
#  ['me', 'encanta', '!'],
#  ['congrats', 'on', 'tfs', '.'],
#  ['i', 'did', '.'],
#  ['congratulations', 'hun', '.'],
#  ['cool', '!', 'ts', 'congrats', '!'],
#  ['love', 'the', 'message', '!'],
#  ['congrats', 'on', 'ts', '.'],
#  ['congratulations',
#   'on',
#   'ts',
#   '!',
#   'this',
#   'set',
#   'deserves',
#   'it',
#   '!',
#   'great',
#   'message',
#   'because',
#   'i',
#   'work',
#   'in',
#   'it',
#   'and',
#   'stem',
#   'is',
#   'so',
#   'important',
#   'for',
#   'that',
#   'field',
#   '!'],
#  ['yes', 'for', 'all', 'things', 'needy', '!'],
#  ['great', 'style', 'dear', '!', 'congrats', 'on', 'ts', '!'],
#  ['congratulations',
#   'on',
#   'your',
#   'very',
#   'pretty',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['cute', 'top', 'fashion', 'set', '!', 'congrats', '!'],
#  ['congratulation', 'dear', '.'],
#  ['congratulations',
#   'on',
#   'your',
#   'tfs',
#   'my',
#   'dear',
#   'friend',
#   'yahoo',
#   'hahaha',
#   'cheers',
#   'and',
#   'hugs',
#   'and',
#   'namaste',
#   'xxxxxxxxxx',
#   '.'],
#  ['congrats', 'on', 'your', 'tfs', '!'],
#  ['congratulations', 'on', 'ts', '!'],
#  ['wow',
#   '!',
#   'this',
#   'one',
#   'is',
#   'so',
#   'stunning',
#   '!',
#   'love',
#   'this',
#   'white',
#   ',',
#   'red',
#   'and',
#   'blue',
#   'look',
#   '!',
#   'outstanding',
#   'combination',
#   '!'],
#  ['great', 'look', 'great', 'set', 'great', 'mixing', 'w/', 'sneakers', '.'],
#  ['this',
#   'set',
#   'rocks',
#   '!',
#   'as',
#   'does',
#   'your',
#   'description',
#   'and',
#   'the',
#   'concept',
#   '!'],
#  ['amazing', 'to', 'look', 'at', '.'],
#  ['agreed', '!', 'cool', '&', 'awesome', 'message', '!'],
#  ['fantastic',
#   'and',
#   'love',
#   'your',
#   'description',
#   '-',
#   'i',
#   'could',
#   "n't",
#   'agree',
#   'more',
#   'my',
#   'dear',
#   'friend',
#   '.',
#   'cheers',
#   'and',
#   'hugs',
#   'and',
#   'namaste',
#   'xxxxxxxxxx',
#   '.'],
#  ['so', 'cool', '!', 'love', 'the', 'jacket', '!', 'amazing', 'set', '!'],
#  ['awesome',
#   '...',
#   'will',
#   'take',
#   'this',
#   'fab',
#   'jacket',
#   'right',
#   'now',
#   '.'],
#  ['super', 'cool', 'outfit', ',', 'fantastic', 'look', 'and', 'mix', '!'],
#  ['this', 'is', 'brilliant', '!', 'hugs', 'my', 'friend', '!'],
#  ['pretty', 'outfit', 'for', 'the', 'school', ':', ')', '.'],
#  ['stylish',
#   'and',
#   'cool',
#   'fashion',
#   'absolutely',
#   'nice',
#   'style',
#   'and',
#   'fab',
#   'outfit',
#   '.'],
#  ['awesome', '!', 'congratulations', 'dear', 'on', 'ts', '!'],
#  ['fabulous', '...', '..congrats', '.'],
#  ['hard',
#   'to',
#   'beat',
#   'light',
#   'denim',
#   ',',
#   'white',
#   ',',
#   'and',
#   'pink',
#   '!'],
#  ['great', 'look', 'great', 'set', 'great', 'mixing', 'w/', 'jeans', '.'],
#  ['follow', 'me', 'and', 'i', 'follow', 'you', 'too', '!'],
#  ['yes', ',', 'awesome', '!', 'congratulations', '.'],
#  ['congrats', 'on', 'tfs', 'dear', '.'],
#  ['ts', 'congrats', '!'],
#  ['congratulations', 'on', 'ts', '.'],
#  ['congrats', 'on', 'your', 'lovely', 'ts', 'my', 'sweetie', '.'],
#  ['awesome', '!', 'congrats', 'on', 'ts', '!'],
#  ['congrats', 'on', 'ts', 'dear', '.'],
#  ['congrats', ',', 'sweetye', '.'],
#  ['congrats', 'on', 'your', 'amazing', 'ts', 'sweetie', '!'],
#  ['congratulations', 'on', 'your', 'lovely', 'top', 'fashion', 'set', '.'],
#  ['lovely', '!', 'congrats', 'on', 'top', 'fashion', 'set', '!'],
#  ['congrats', 'on', 'your', 'amazing', 'ts', '!'],
#  ['congratulations', 'on', 'your', 'tfs', 'x', '.'],
#  ['absolutely',
#   'cheerful',
#   'look',
#   '.',
#   'i',
#   'have',
#   'positive',
#   'thoughts',
#   'just',
#   'looking',
#   'at',
#   'this',
#   'outfit',
#   '!'],
#  ['great', 'attitude', '!'],
#  ['how', 'pretty', '!'],
#  ['beyond', 'beautiful', ',', 'well', 'done', '!'],
#  ['so',
#   'cool',
#   'casual',
#   'fashion',
#   'and',
#   'fab',
#   'this',
#   'style',
#   'too',
#   '.'],
#  ['sophisticated',
#   'and',
#   'beautifully',
#   'designed',
#   'set',
#   'casual',
#   'chic',
#   '.'],
#  ['i',
#   'love',
#   'this',
#   'set',
#   'so',
#   'much',
#   '!',
#   'one',
#   'of',
#   'the',
#   'best',
#   'ones',
#   'i',
#   "'ve",
#   'seen',
#   'in',
#   'a',
#   'while',
#   ',',
#   'so',
#   'pretty',
#   '!'],
#  ['cute', 'outfit', 'dear', '!', 'have', 'a', 'great', 'week', 'ahead', '!'],
#  ['outstanding',
#   'in',
#   'set',
#   'layout',
#   'and',
#   'beautifully',
#   'styled',
#   'dressed',
#   'up',
#   'jeans',
#   'look',
#   '.'],
#  ['simply', 'beautiful', '!'],
#  ['wow',
#   ',',
#   'all',
#   'the',
#   'pieces',
#   'work',
#   'so',
#   'well',
#   'together',
#   '.',
#   'great',
#   'set',
#   '.'],
#  ['cute', 'and', 'lovely', 'wonderful', 'style', '~', '.'],
#  ['nice', '.', 'and', 'i', 'also', 'need', 'a', 'study', 'planner', '.'],
#  ['cool', '!', 'ts', 'congrats', '!'],
#  ['beautiful',
#   '!',
#   'please',
#   'look',
#   'at',
#   'my',
#   'newest',
#   'set',
#   'and',
#   'give',
#   'a',
#   'like',
#   '!',
#   'congrats',
#   '!'],
#  ['love', 'this', '...', 'congratulation', '.'],
#  ['congratulations', 'hun', '.'],
#  ['congrats',
#   'on',
#   'top',
#   'set',
#   '!',
#   'i',
#   'love',
#   'this',
#   'set',
#   'both',
#   'of',
#   'you',
#   'are',
#   'amazing',
#   ':',
#   ')',
#   '.'],
#  ['ahh',
#   'congrats',
#   'rachel',
#   '(',
#   'and',
#   'astrid',
#   'too',
#   '!',
#   ')',
#   'this',
#   'set',
#   'is',
#   'my',
#   'aesthetic',
#   '.'],
#  ['congrats',
#   'both',
#   'of',
#   'you',
#   '!',
#   'dang',
#   'rach',
#   'lol',
#   'so',
#   'many',
#   'collab',
#   'top',
#   'sets',
#   'ahaha',
#   '.'],
#  ['congrats',
#   'omg',
#   'this',
#   'set',
#   'is',
#   'so',
#   'nice',
#   ':',
#   ')',
#   ')',
#   ')',
#   '.'],
#  ['well', 'done', 'on', 'top', 'set', 'bby', '.'],
#  ['congratulations', 'on', 'ts', '!'],
#  ['congrats', 'on', 'ts', 'dear', '!'],
#  ['congrats', 'bby', 'sis', '<', '3', '.'],
#  ['ahh',
#   'this',
#   'turned',
#   'out',
#   'great',
#   '!',
#   'thanks',
#   'so',
#   'much',
#   'for',
#   'the',
#   'collab',
#   '.'],
#  ['such',
#   'a',
#   'cute',
#   'set',
#   'dear',
#   ',',
#   'i',
#   "'m",
#   'obsessed',
#   '!',
#   'congrats',
#   'on',
#   'top',
#   'sets',
#   '!',
#   'x',
#   '.'],
#  ['congrats', 'sweetie', '!', 'xxo', '.'],
#  ['congrats', 'on', 'your', 'wonderful', 'ts', '!'],
#  ['congrats', 'ts', '!', 'fabulous', '!'],
#  ['so', 'cuute', '!'],
#  ['very', 'classy', '.', 'love', 'it', '.'],
#  ['just', 'awsome', '.'],
#  ['terrific', '!', 'ts', 'congrats', '!'],
#  ['add', 'em', '.'],
#  ['congrats', 'on', 'wonderful', 'ts', '!'],
#  ['congrats', 'on', 'this', 'lovely', 'top', 'set', '~', '.'],
#  ['congratulations', 'on', 'ts', '!'],
#  ['congratulations',
#   'on',
#   'your',
#   'very',
#   'pretty',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['wonderful', 'set', 'beautifully', 'designed', '.'],
#  ['just', 'perfect', 'for', 'travel', 'xx', '.'],
#  ['wonderful', 'look', ',', 'love', 'the', 'skirt', '!'],
#  ['perfect', 'travel', 'style', '.'],
#  ['i',
#   'did',
#   "n't",
#   'know',
#   'that',
#   ',',
#   'dear',
#   'what',
#   'an',
#   'awesome',
#   'place',
#   'to',
#   'live',
#   '!'],
#  ['great', 'look', 'great', 'set', 'great', 'mixing', 'outfits', '.'],
#  ['this',
#   'is',
#   'great',
#   'sweetie',
#   ',',
#   'i',
#   'live',
#   'in',
#   'seattle',
#   '!',
#   'xxo',
#   '.'],
#  ['on', 'point', '.'],
#  ['congrats', 'ts', '!', 'awesome', '!'],
#  ['marvelous', '!', 'congratulations', '!'],
#  ['congrats', 'on', 'your', 'amazing', 'ts', 'dear', '!'],
#  ['nice', '!', 'ts', 'congrats', '!'],
#  ['congratulations',
#   'on',
#   'your',
#   'very',
#   'pretty',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['congrats', 'on', 'tfs', '!'],
#  ['congrats', 'on', 'ts', '.'],
#  ['darling', 'outfit', '.', 'congratulations', 'on', 'top', 'set', '!'],
#  ['congrats', 'on', 'this', 'cute', 'top', 'fashion', 'set', '!'],
#  ['congrats', 'on', 'your', 'wonderful', 'ts', 'my', 'dear', 'xx', '.'],
#  ['charming', 'and', 'those', 'chose', 'are', 'fabulous', '.'],
#  ['prekrasni', 'setovi', 'kao', 'i', 'uvijek', 'draga', '!'],
#  ['g8..', 'please', 'like', 'our', 'set', '.'],
#  ['please', 'follow', 'me', 'people', 'i', "'m", 'new', '.'],
#  ['wow', 'amazing', 'congrats', 'on', 'tfs', '.'],
#  ['congratulations', 'on', 'your', 'ts', '!'],
#  ['fantastic', 'style', '!', 'congratulations', 'dear', 'on', 'ts', '!'],
#  ['terrific', '!', 'ts', 'congrats', '!'],
#  ['congratulations',
#   'on',
#   'your',
#   'very',
#   'pretty',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['congrats', 'on', 'your', 'amazing', 'ts', 'dear', 'xx', '.'],
#  ['wonderful', 'set', 'for', 'back', 'to', 'school', '.'],
#  ['thank', 'you', 'very', 'much', 'ladies', '!'],
#  ['congrats', 'on', 'ts', 'dear', '!', 'fabulous', 'set', '!'],
#  ['excellent', ',', 'congrats', '!'],
#  ['thank', 'you', 'very', 'much', 'ladies', '!'],
#  ['thank', 'you', 'very', 'much', 'ladies', '!'],
#  ['congrats', 'e', '.'],
#  ['you',
#   'all',
#   'very',
#   'much',
#   'for',
#   'all',
#   'your',
#   'wonderful',
#   'comments',
#   '&',
#   'support',
#   '!',
#   'have',
#   'a',
#   'great',
#   'weekend',
#   '.'],
#  ['congrats', 'on', 'ts', '!'],
#  ['terrific', '!', 'ts', 'congrats', '!'],
#  ['ooh', 'la', 'la', 'i', 'love', 'this', '.'],
#  ['congrats', 'on', 'ts', 'dear', '!'],
#  ['congrats', 'on', 'ts', '!'],
#  ['congrats', 'on', 'ts', '!'],
#  ['congratulations',
#   'on',
#   'your',
#   'well',
#   'deserved',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['congrats', 'hun', '.'],
#  ['sporty', 'and', 'fun', '.'],
#  ['what',
#   'a',
#   'flawless',
#   'set',
#   '!',
#   'outstanding',
#   'combination',
#   'of',
#   'these',
#   'colors',
#   '!',
#   'incredible',
#   'work',
#   '!'],
#  ['so', 'sophisticated', 'and', 'cool', 'style', '!'],
#  ['effortless', ',', 'stylish', 'and', 'fantastic', '!'],
#  ['you', 'very', 'much', 'for', 'all', 'the', 'wonderful', 'comments', '!'],
#  ['i',
#   'love',
#   'that',
#   'cool',
#   'combo',
#   ',',
#   'fab',
#   'and',
#   'simple',
#   'style',
#   ',',
#   'perfectly',
#   'styled',
#   'dear',
#   '.'],
#  ['beautiful', 'color', '.'],
#  ['terrific', '!', 'love', 'this', 'set', '!'],
#  ['superb', 'hun', 'xx', '.'],
#  ['great', 'job', '!'],
#  ['wish', 'i', 'could', 'achieve', 'this', '.'],
#  ['cure', 'set', 'dear', 'congrats', '.'],
#  ['ts', 'congrats', '!'],
#  ['congrats',
#   '!',
#   'it',
#   "'s",
#   'a',
#   'lovely',
#   'set',
#   '...',
#   'check',
#   'out',
#   'my',
#   'sets',
#   '.'],
#  ['beautiful',
#   '!',
#   'please',
#   'look',
#   'at',
#   'my',
#   'newest',
#   'set',
#   'and',
#   'give',
#   'a',
#   'like',
#   '!',
#   'congrats',
#   '!'],
#  ['soooo', 'nice', '.'],
#  ['not',
#   'my',
#   'style',
#   ',',
#   'but',
#   'very',
#   'cute',
#   '!',
#   'congrats',
#   '^^',
#   '.'],
#  ['terrific', '!', 'ts', 'congrats', '!'],
#  ['congratulations', 'on', 'ts', '!'],
#  ['fabulous', 'styling', '!', 'congratulations', 'on', 'your', 'tfs', '!'],
#  ['congratulations', 'on', 'ts', '!'],
#  ['fabulous', 'set', 'design', '.'],
#  ['congratulations', 'on', 'ts', '!'],
#  ['nice', ',', 'congratulations', 'on', 'tfs', '!'],
#  ['real', 'cute', 'set', ',', 'congrats', 'on', 'tfs', '!'],
#  ['outstanding',
#   'set',
#   '!',
#   'beautiful',
#   'ensemble',
#   'and',
#   'perfect',
#   'layout',
#   '!',
#   'congratulations',
#   '☆☆☆☆☆',
#   '.'],
#  ['congratulations', 'on', 'top', 'sets', 'darling', '.'],
#  ['add', 'me', '.'],
#  ['stunningly', 'chic', '.'],
#  ['hey', 'can', 'you', 'check', 'my', 'creations', '.'],
#  ['add', 'me', '.'],
#  ['ts', 'congrats', '!'],
#  ['congratulations', '!', 'fabulous', 'set', 'hun', 'xx', '.'],
#  ['adorably', 'sweet', '...', '.congratulations', '!'],
#  ['ooooh', ',', 'cool', '!'],
#  ['wonderful', 'ts', '!', 'congrats', '!'],
#  ['congrats', 'on', 'this', 'beautiful', 'tfs', '!'],
#  ['congrats',
#   'on',
#   'a',
#   'top',
#   'set',
#   '!',
#   'i',
#   "'m",
#   'so',
#   'happy',
#   'for',
#   'you',
#   'you',
#   'earned',
#   'it',
#   '!'],
#  ['simply', 'superb', '...', '.love', 'the', 'colour', 'combo', '.'],
#  ['how', 'lovely', 'this', 'is', '.'],
#  ['prekrasno', 'draga', '!'],
#  ['great', 'outfit', ',', 'love', 'the', 'color', 'combo', '.'],
#  ['sophisticated', 'chic', '!'],
#  ['diiivno', '!', 'prekrasne', 'boje', '.', ':', ')', '.'],
#  ['thank',
#   'u',
#   'so',
#   'so',
#   'so',
#   'much',
#   'for',
#   'joining',
#   'my',
#   'group',
#   'and',
#   'adding',
#   'this',
#   'set',
#   'to',
#   'it',
#   '!',
#   'please',
#   'invite',
#   'and',
#   'tell',
#   'others',
#   'to',
#   'join',
#   '.'],
#  ['very',
#   'beautiful',
#   'and',
#   'stylish',
#   'set',
#   '!',
#   'love',
#   'this',
#   'combination',
#   '!'],
#  ['there', "'s", 'no', 'limit', '!'],
#  ['great',
#   'look',
#   'great',
#   'set',
#   'great',
#   'mixing',
#   'w/',
#   'lace-up',
#   'n',
#   "'",
#   'nice',
#   'pleated',
#   '.'],
#  ['i',
#   'just',
#   'saw',
#   'ur',
#   'contest',
#   '!',
#   'how',
#   'many',
#   'times',
#   'am',
#   'i',
#   'allowed',
#   'to',
#   'enter',
#   '.'],
#  ['lovely', 'skirt', 'and', 'top', '!'],
#  ['congrats', 'luv', 'this', 'summer', 'feel', '.'],
#  ['congrats', ',', 'sweetye', '.'],
#  ['thank', 'you', 'very', 'much', ',', 'very', 'much', 'appreciated', '!'],
#  ['big',
#   'congratulations',
#   'dear',
#   'on',
#   'your',
#   'so',
#   'tunning',
#   ',',
#   'trendy',
#   ',',
#   'cool',
#   ',',
#   'awesomeness',
#   ',',
#   'unique',
#   ',',
#   'marvellous',
#   'and',
#   'very',
#   'well',
#   'deserved',
#   'top',
#   'set',
#   '!'],
#  ['you', 'very', 'much', 'ladies', '!'],
#  ['congrats', 'hun', '.'],
#  ['you',
#   'all',
#   'very',
#   'much',
#   'for',
#   'your',
#   'fantastic',
#   'comments',
#   'and',
#   'support',
#   '!',
#   'have',
#   'a',
#   'great',
#   'weekend',
#   '.'],
#  ['congrats', 'on', 'your', 'fantastic', 'ts', 'dear', '!'],
#  ['lovely', '!', 'ts', 'congrats', '!'],
#  ['thank',
#   'you',
#   'all',
#   'very',
#   'much',
#   'for',
#   'all',
#   'your',
#   'support',
#   'and',
#   'wonderful',
#   'comments',
#   '!'],
#  ['yay', '!', 'congrats', '.'],
#  ['thank', 'you', 'ladies', ':', ')', '.'],
#  ['great',
#   'look',
#   'great',
#   'mixing',
#   'w/',
#   'cardigan',
#   'n',
#   "'",
#   'nice',
#   'bag',
#   '.'],
#  ['thank', 'you', 'ladies', '!'],
#  ['great', 'summer', 'look', '!'],
#  ['so', 'damn', 'beautiful', '!'],
#  ['cute', 'and', 'comfy', '.'],
#  ['casual', ',', 'sunny', 'set', '!', 'xx', '.'],
#  ['you',
#   'very',
#   'much',
#   'ladies',
# ...
#   'appreciate',
#   'it',
#   'very',
#   'much',
#   '.'],
#  ['gucci', 'perfection', '!', 'sweet', ',', 'modern', 'femininity', '.'],
#  ['lovely',
#   'and',
#   'girly',
#   'fashion',
#   'fab',
#   'set',
#   'and',
#   'nice',
#   'style',
#   'for',
#   'this',
#   'season',
#   '!'],
#  ['big', 'love', '.'],
#  ['absolutely', 'stunning', '!', 'layout', 'is', 'perfection', '!'],
#  ['simply', 'divine', ',', 'pure', 'perfection', '.'],
#  ['wonderful', '!', 'congrats', '=d', '.'],
#  ['splendid', '!', 'congratulations', 'on', 'ts', '!'],
#  ['congrats', 'on', 'your', 'wonderful', 'ts', '=d', '.'],
#  ['congrats',
#   '!',
#   'its',
#   'a',
#   'lovely',
#   'set..check',
#   'out',
#   'my',
#   'sets',
#   '!'],
#  ['shoes', 'focused', '.'],
#  ['congrast', 'on', 'your', 'top', 'set', '.'],
#  ['congratulations', 'on', 'your', 'ts', '.'],
#  ['congrats', 'on', 'this', 'wonderful', 'top', 'set', '~', '.'],
#  ['terrific', '!', 'ts', 'congrats', '!'],
#  ['congratulations', 'on', 'ts', 'dear', '.'],
#  ['congratulations',
#   'on',
#   'your',
#   'well',
#   'deserved',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['outstanding', 'set', '.'],
#  ['fresh',
#   'and',
#   'chic',
#   '!',
#   'congratulations',
#   'on',
#   'top',
#   'sets',
#   'darling',
#   '.'],
#  ['congrats', 'on', 'top', 'fashion', 'set', '.'],
#  ['yay',
#   '!',
#   'beautiful',
#   'set',
#   '(',
#   'as',
#   'you',
#   'always',
#   'do',
#   ')',
#   '...',
#   'congratulations',
#   'on',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['congrats', 'ts', '!', 'fab', '!'],
#  ['terrific', '!', 'ts', 'congrats', '!'],
#  ['congratulations', 'darling', '!'],
#  ['perfect', 'set', '!', 'congrats', 'well', 'deserved', '.'],
#  ['congrats', 'on', 'ts', '!', '<', '3', '<', '3', '.'],
#  ['congratulations', 'on', 'ts', '!'],
#  ['congrats', 'on', 'ts', 'dear', '!'],
#  ['yay', '!', '...', 'schools', '...', '.'],
#  ['what', 'a', 'great', 'set', ',', 'congrats', 'on', 'tfs', '!'],
#  ['woww', 'sweetie', ',', 'congrats', '.'],
#  ['outstanding', 'set', '!', 'congratulations', '.'],
#  ['well', 'organised', '!', 'looks', 'cute', '.'],
#  ['sooo', 'pretty', '!'],
#  ['молодежно', 'и', 'стильно', '.'],
#  ['great', 'school', 'outfit', '.'],
#  ['great', 'look', 'great', 'set', 'n', "'", 'nice', 'bag', '.'],
#  ['already', '!', 'gorgeous', 'set', ',', '.'],
#  ['простой',
#   ',',
#   'комфортный',
#   'и',
#   'стильный',
#   'casual',
#   'look',
#   ',',
#   'в',
#   'котором',
#   'можно',
#   'ходить',
#   'целый',
#   'день',
#   'где',
#   'угодно',
#   '!'],
#  ['это',
#   'просто',
#   'невероятно',
#   'мило',
#   'и',
#   'кавайно',
#   '!',
#   'очень',
#   'нравится',
#   '.'],
#  ['marvelous', 'set', 'and', 'look', '.'],
#  ['marvellous', 'x', '.'],
#  ['congrats', 'on', 'great', 'tfs', '.'],
#  ['congratulation', 'dear', '.'],
#  ['flipping', 'fantastic', '!'],
#  ['congratulations', '!', 'wonderful', 'set', 'hun', 'xx', '.'],
#  ['congrats', 'on', 'your', 'gorgeous', 'ts', 'dear', '!'],
#  ['wow', '!', 'congrats', 'on', 'ts', '!'],
#  ['awesome', '!', 'congratulations', 'dear', 'on', 'ts', '!'],
#  ['congrats', 'on', 'top', 'set', '!', 'so', 'fun', '!'],
#  ['perfection', ',', 'loveeeeee', 'it', '!'],
#  ['great',
#   'look',
#   'great',
#   'set',
#   'great',
#   'mixing',
#   'w/',
#   'denim',
#   'n',
#   "'",
#   'nice',
#   't-shirt',
#   '.'],
#  ['congrats', 'on', 'the', 'amazing', 'set', 'beautifully', 'designed', '.'],
#  ['looks', 'so', 'lovely', 'and', 'cool', '!'],
#  ['congratulations', 'on', 'ts', '!'],
#  ['perfect', '!', 'congrats', '=d', '.'],
#  ['would', 'totally', 'wear', 'this', '!', 'congrats', '!'],
#  ['congrats', ',', 'sweetye', '.'],
#  ['ts', 'congrats', '!'],
#  ['congrats', 'on', 'ts', '.'],
#  ['nice', 'shoes', '!', 'congrats', '!'],
#  ['follow', 'me', '.'],
#  ['congrats', 'on', 'amazing', 'ts', 'dear', '!'],
#  ['add', 'me', '.'],
#  ['wow', 'absolutely', 'amazing', 'congrats', 'on', 'tfs', '.'],
#  ['yay', 'congrats', 'dear', '!'],
#  ['congrats', 'on', 'your', 'fantastic', 'ts', 'sweetie', '!'],
#  ['congrats',
#   '!',
#   'super',
#   'fab',
#   'set',
#   '!',
#   'i',
#   'will',
#   'follow',
#   'back',
#   '.',
#   ':',
#   ')',
#   '.'],
#  ['congrats', 'on', 'top', 'fashion', 'set', 'and', 'the', 'top', 'slot', '!'],
#  ['thanks',
#   'so',
#   'much',
#   'polyvore',
#   'made',
#   'my',
#   'day',
#   'congrats',
#   'to',
#   'everyone',
#   'else',
#   '.'],
#  ['congratulations',
#   'on',
#   'your',
#   'well',
#   'deserved',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['congratulations', '☆☆☆☆☆', '.'],
#  ['congrats', 'on', 'ts', '!'],
#  ['wow', '!', 'amazing', 'set', 'dear', '!', 'big', 'congrats', '!'],
#  ['another', 'cool', 'combo', '!'],
#  ['so', 'cool', 'and', 'creative', '.'],
#  ['lovely', 'fashion', 'and', 'nice', 'style', 'here', '~', '.'],
#  ['on', 'point', '!', 'perfect', 'outfit', 'and', 'layout', '!'],
#  ['pure', 'awesomeness', 'and', 'gorgeousness', '!'],
#  ['love', 'how', 'its', 'simple', 'but', 'really', 'cute', '.'],
#  ['this', 'is', 'great', '!', 'keep', 'on', 'making', 'sets', '.'],
#  ['lovely',
#   'set',
#   '!',
#   'fantastic',
#   'job',
#   'on',
#   'the',
#   'layout',
#   '.',
#   'love',
#   'it',
#   '!'],
#  ['love', 'it', ':', "'", ')', '.'],
#  ['nice', '!', 'thanks', 'for', 'joining', 'my', 'group', '!'],
#  ['great', 'work', '.'],
#  ['congrats', 'on', 'ts', '!'],
#  ['really', 'cute', ',', 'congrats', 'on', 'tfs', '!'],
#  ['congrats', 'on', 'your', 'ts', '!'],
#  ['nice', '!', 'ts', 'congrats', '!'],
#  ['congratulations',
#   'on',
#   'your',
#   'well',
#   'deserved',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['cute', '!', 'congrats', 'on', 'top', 'fashion', 'set', '!'],
#  ['congrats', 'on', 'ts', 'dear', '!'],
#  ['extra', 'set', '!', 'sve', 'cestitke', '!'],
#  ['congrats', 'on', 'your', 'gorgeous', 'ts', 'dear', 'xx', '.'],
#  ['amazing', 'creation', '.'],
#  ['love', 'these', 'pants', '.'],
#  ['love',
#   'this',
#   '...',
#   'and',
#   'congratulations',
#   'on',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['ahhh', 'love', 'this', '!', '#', '1', '.'],
#  ['great', 'layout', '.'],
#  ['lovely', '!', 'ts', 'congrats', '!'],
#  ['how',
#   'do',
#   'people',
#   'with',
#   'only',
#   'like',
#   '2',
#   'luke',
#   "'s",
#   'win',
#   'the',
#   'contests',
#   'and',
#   'how',
#   'do',
#   'we',
#   'know',
#   'which',
#   'people',
#   'out',
#   'of',
#   'an',
#   'endless',
#   'list',
#   'of',
#   'outfits',
#   'who',
#   'are',
#   'the',
#   'winners',
#   '.'],
#  ['congrats', '!', 'great', 'work', '!'],
#  ['amazing', '!', 'i', 'will', 'follow', 'back', ':', ')', '.'],
#  ['cool', '!', '☆', '.'],
#  ['lovely', 'set', '!', 'nice', 'tee', '.'],
#  ['that', "'s", 'put', '.'],
#  ['congratulations',
#   'on',
#   'your',
#   'well',
#   'deserved',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['follow', 'me', 'and', 'i', 'follow', 'you', 'too', '!'],
#  ['outstanding', 'casual', 'chic', 'look', '.'],
#  ['creative',
#   'and',
#   'looks',
#   'very',
#   'cute',
#   '!',
#   ':',
#   ')',
#   'congratulations',
#   'to',
#   'you',
#   'dear',
#   ':',
#   ')',
#   '.'],
#  ['congrats..so', 'cool', '!'],
#  ['congrats',
#   '!',
#   'that',
#   "'s",
#   'my',
#   'skirt',
#   '!',
#   'so',
#   'funny',
#   ')',
#   ')',
#   '.'],
#  ['how', 'fabulous', 'sweetie', '!', 'congratulations', 'to', 'you', '.'],
#  ['congrats', 'ts', '!', 'cool', '!'],
#  ['perfection', 'congrats', '.'],
#  ['cool', '!', 'ts', 'congrats', '!'],
#  ['congrats', 'on', 'top', 'sets', 'today', '~', '.'],
#  ['congratulations', 'on', 'ts', '!'],
#  ['congratulations',
#   'on',
#   'your',
#   'very',
#   'charming',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['congratulations', 'dear', 'on', 'ts', '!'],
#  ['congrats', 'on', 'wonderful', 'ts', '.'],
#  ['congratulations',
#   'on',
#   'your',
#   'tfs',
#   'my',
#   'dear',
#   'friend',
#   'cheers',
#   'and',
#   'hugs',
#   'xxxxxxxxx',
#   'xx',
#   '.'],
#  ['perfection', 'sweetie', '.'],
#  ['marvelous', 'set', '!', 'great', 'style', 'dear', '!'],
#  ['love',
#   'this',
#   'whole',
#   'look',
#   '!',
#   'fantastic',
#   'skirt',
#   ',',
#   'gorgeous',
#   'shoes',
#   '!'],
#  ['fun', 'and', 'fab', 'xx', '.'],
#  ['great', 'set', 'hun', 'xx', '.'],
#  ['great',
#   'look',
#   'great',
#   'set',
#   'great',
#   'mixing',
#   'w/',
#   't-shirt',
#   'n',
#   "'",
#   'nice',
#   'pleated',
#   '.'],
#  ['pretty',
#   'and',
#   'fab',
#   'outfit',
#   'items',
#   'here',
#   'such',
#   'a',
#   'nice',
#   'style',
#   'for',
#   'summer',
#   '!'],
#  ['thank',
#   'you',
#   'so',
#   'much',
#   'everyone',
#   '!',
#   'i',
#   'really',
#   'appreciate',
#   'your',
#   'kind',
#   'words',
#   'and',
#   'wishes',
#   '!',
#   'love',
#   'ya',
#   'all',
#   '!'],
#  ['congrats', 'on', 'your', 'wonderful', 'ts', '=d', '.'],
#  ['love', 'everything', 'about', 'this', '.', 'great', 'job', ',', '!'],
#  ['i', 'love', 'that', 'jeans', '.'],
#  ['congrats', 'on', 'ts', '!'],
#  ['um', 'so', 'u', 'the', 'devil', '.'],
#  ['ts', 'congrats', '!'],
#  ['congrats',
#   'dear',
#   'on',
#   'this',
#   'superb',
#   'jeans',
#   'set..great',
#   'pieces',
#   '!'],
#  ['congratulations', 'on', 'your', 'pretty', 'top', 'fashion', 'set', '.'],
#  ['ok',
#   'how',
#   'do',
#   'i',
#   'get',
#   'views',
#   'or',
#   'likes',
#   'via',
#   'i',
#   'feel',
#   'that',
#   'i',
#   'have',
#   'great',
#   'outfits',
#   'but',
#   '...',
#   '...'],
#  ['thank', 'you', 'dear', 'friends', '!', '^^', '.'],
#  ['congrats', 'on', 'your', 'gorgeous', 'ts', 'dear', '!'],
#  ['thank', 'you', 'lovely', 'people', '!'],
#  ['congratulations', 'on', 'your', 'tfs', 'x', '.'],
#  ['congratulations', 'on', 'ts', '!'],
#  ['great',
#   'look',
#   'great',
#   'set',
#   'great',
#   'mixing',
#   'w/',
#   'jeans',
#   'n',
#   "'",
#   'nice',
#   'gucci',
#   '.'],
#  ['wow',
#   'every',
#   'detail',
#   'in',
#   'this',
#   'set',
#   'is',
#   'just',
#   'perfect',
#   '!',
#   'love',
#   'it',
#   '.'],
#  ['fun', 'outfit', '!'],
#  ['it', "'s", 'a', 'wonderful', 'combination', '!'],
#  ['thank', 'you', 'al', 'so', 'much', '!'],
#  ['fabuloso',
#   'yexy',
#   '!',
#   'felicitaciones',
#   '!',
#   '<',
#   '3',
#   '<',
#   '3',
#   '<',
#   '3',
#   '.'],
#  ['yay', ',', 'congrats', '!'],
#  ['congarts',
#   '!',
#   'beautiful',
#   'set',
#   'but',
#   'it',
#   'would',
#   'look',
#   'better',
#   'with',
#   'a',
#   'skinny',
#   'jean',
#   '.'],
#  ['congrats', 'ts', '!', 'beautiful', '!'],
#  ['congrats', 'on', 'ts', '!', 'yay', '!'],
#  ['outstanding', 'set', '!', 'congratulations', '☆☆☆☆☆', '.'],
#  ['yayyy', ',', 'comgratssss', '.'],
#  ['ts', 'congrats', '!'],
#  ['fabuloso', '.', 'enhorabuena', '!'],
#  ['congrats', 'on', 'ts', '!'],
#  ['omgosh',
#   '!',
#   'love',
#   'this',
#   'fashion',
#   'set',
#   '!',
#   'congrats',
#   'on',
#   'tfs',
#   '!'],
#  ['my', 'favorite', 'outfit', 'with', 'this', 'top', '!', '<', '3', '.'],
#  ['congrats', 'to', 'you', ',', 'darling', '.'],
#  ['yay', ',', 'fab', 'top', 'set', '!', 'congrats', '!'],
#  ['fantastic', '!', 'congrats', 'on', 'ts', 'honey', '.'],
#  ['congrats', 'on', 'ts', 'dear', '!'],
#  ['gorgeous',
#   'set',
#   '!',
#   'congrats',
#   'dear',
#   '!',
#   'you',
#   'deserve',
#   'it',
#   '!'],
#  ['what', 'an', 'amazing', 'outfit', '.'],
#  ['congratulations',
#   'on',
#   'your',
#   'well',
#   'deserved',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['yeayyyy', 'congratss', '.'],
#  ['congrats', 'on', 'your', 'amazing', 'ts', 'dear', 'xx', '.'],
#  ['fantastic', '!', 'congratulations', 'on', 'ts', '.'],
#  ['beautiful', '...', '.congrats', '.'],
#  ['excellent', 'dear', ',', 'congrats', '!'],
#  ['congratulations', 'on', 'your', 'tfs', '.'],
#  ['congratulations', 'on', 'your', 'tfs', 'x', '.'],
#  ['such', 'an', 'awesome', 'combo', '!', 'extraordinary', 'top', '.'],
#  ['stunning', 'summer', 'set', '!'],
#  ['love', 'this', 'entire', 'set', '!', 'fantastic', '!'],
#  ['great',
#   'look',
#   'great',
#   'set',
#   'great',
#   'mixing',
#   'outfits',
#   'n',
#   "'",
#   'nice',
#   '3d',
#   'shoulder',
#   '.'],
#  ['incredible', 'styling', '!'],
#  ['definitely', 'pretty', 'dear', '!'],
#  ['flawless', 'dear', '!'],
#  ['so', 'fabulously', 'pretty', 'dear', '!'],
#  ['chic', 'look', "'", "''", "'", "''", "'", "''", "'", "''", '.'],
#  ['pretty', 'set', ',', 'pretty', 'outfits', 'here', '.'],
#  ['big', 'love', '.'],
#  ['so', 'very', 'beauitful', ',', 'great', 'pumps', '.'],
#  ['stylish', 'for', 'summer', 'and', 'fab', 'outfit', 'here', '.'],
#  ['thank', 'you', 'both', 'very', 'much', '!'],
#  ['thanks',
#   'for',
#   'the',
#   'lovely',
#   'comments',
#   'and',
#   'congratulations',
#   'everyone',
#   '!'],
#  ['congrats', 'on', 'ts', '!'],
#  ['very', 'chic', 'congrats', 'on', 'tfs', '.'],
#  ['congrats', 'ts', '!', 'wonderful', '!'],
#  ['omg',
#   '!',
#   'i',
#   'love',
#   'it',
#   '!',
#   'the',
#   'set',
#   'is',
#   'absolutely',
#   'gorgeous',
#   '!',
#   ':',
#   ')',
#   '.'],
#  ['congrats', 'on', 'ts', '!'],
#  ['wow', 'i', 'get', '4-9', 'votes', '.', 'congratulations', '!'],
#  ['thanks', 'very', 'much', 'everyone', '!', '<', '3', '.'],
#  ['outstanding',
#   'set',
#   '!',
#   'beautiful',
#   'ensemble',
#   'and',
#   'perfect',
#   'layout',
#   '!',
#   'congratulations',
#   '☆☆☆☆☆',
#   '.'],
#  ['beautiful', '.', 'i', 'love', 'the', 'skirt', '!'],
#  ['congrats', '!', 'this', 'is', 'an', 'amazing', 'set', '.'],
#  ['wow', '!', 'so', 'many', 'likes', 'congrats', '.'],
#  ['love', 'the', 'color', 'scheme', '!'],
#  ['terrific', '!', 'ts', 'congrats', '!'],
#  ['i', 'appreciate', 'it', ',', 'thank', 'you', '!', ':', ')', '.'],
#  ['fantastic', ',', 'so', 'happy', 'for', 'you', '!', 'congratulations', '!'],
#  ['thanks',
#   'for',
#   'the',
#   'congratulations',
#   'and',
#   'nice',
#   'comments',
#   'everyone',
#   ',',
#   'i',
#   'appreciate',
#   'it',
#   '!',
#   '<',
#   '3',
#   '.'],
#  ['so', 'pretty', '!', 'this', 'set', 'inspired', 'me', '.'],
#  ['i', 'love', 'this', 'one', '.'],
#  ['congratulations', 'dear', 'on', 'ts', '!'],
#  ['congratulations',
#   'on',
#   'your',
#   'very',
#   'pretty',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['congrats', 'on', 'wonderful', 'ts', 'dear', 'xx', '.'],
#  ['wonderful', '...', 'congrats', 'on', 'ts', '.'],
#  ['congrats', 'on', 'your', 'amazing', 'ts', 'dear', '!'],
#  ['congratulations', 'on', 'your', 'tas', 'x', '.'],
#  ['lovely', 'top', 'fashion', 'set', '!', 'congrats', '!'],
#  ['thanks', ',', 'it', "'s", 'nice', 'to', 'hear', '!'],
#  ['gorgeously', 'styled', 'look', '.'],
#  ['pretty', 'skirt', ',', 'very', 'lovely', 'look', '!'],
#  ['wow',
#   ',',
#   'thank',
#   'you',
#   '!',
#   'that',
#   "'s",
#   'a',
#   'nice',
#   'compliment',
#   '<',
#   '3',
#   '.'],
#  ['absolutely',
#   'gorgeous',
#   ',',
#   'looks',
#   'like',
#   'another',
#   '#',
#   'topset',
#   'to',
#   'me',
#   '!'],
#  ['thanks', 'very', 'much', 'everyone', '!', '<', '3', '.'],
#  ['great',
#   'look',
#   'great',
#   'set',
#   'great',
#   'mixing',
#   'w/',
#   'cardigan',
#   'n',
#   "'",
#   'nice',
#   'embroidered',
#   '.'],
#  ['fresh', 'look', ',', 'great', 'styling', '!'],
#  ['outstanding', 'set', 'beautifully', 'designed', '.'],
#  ['absolutely', 'darling', 'outfit', '.', '<', '3', '.'],
#  ['adorable',
#   'outfit',
#   'fab',
#   'this',
#   'style',
#   'and',
#   'outfit',
#   'too',
#   'mix',
#   '&',
#   'match',
#   'as',
#   'well',
#   'for',
#   'this',
#   'season',
#   '!'],
#  ['great', 'look', 'great', 'set', 'n', "'", 'nice', 'pleated', '.'],
#  ['perfection', '!', 'congrats', '.'],
#  ['giveaway', 'on', 'my', 'channel', '.'],
#  ['lovely..', 'congrats', '!'],
#  ['classy',
#   '!',
#   'congrats',
#   'dear',
#   '.',
#   'i',
#   'love',
#   'this',
#   ':',
#   ')',
#   ')',
#   '.'],
#  ['follow', 'meee', '!'],
#  ['gorgeous',
#   '...',
#   'and',
#   'congratulations',
#   'on',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['gorgeous', ',', 'congrats', 'on', 'tfs', '!'],
#  ['beautiful',
#   'outfit',
#   '!',
#   'congrats',
#   'on',
#   'your',
#   'top',
#   'fashion',
#   'set',
#   '!'],
#  ['yay', '!', 'congrats', 'dear', '!'],
#  ['terrific', '!', 'ts', 'congrats', '!'],
#  ['i', 'knew', 'this', 'was', 'a', 'winner', '!', 'congratulations', '.'],
#  ['congratulations',
#   'on',
#   'your',
#   'well',
#   'deserved',
#   'top',
#   'fashion',
#   'set',
#   '.'],
#  ['congrsts', 'dear', '.'],
#  ['congratulations', 'on', 'top', 'sets', 'darling', '.'],
#  ['gorgeousness', ',', 'congrats', '!'],
#  ['gorgeous', 'top', 'fashion', 'set', '!', 'congrats', '!'],
#  ['so', 'much', 'everyone', '!', 'have', 'a', 'lovely', 'day', '!'],
#  ['congratulations', 'on', 'your', 'tfs', 'x', '.'],
#  ['thanks',
#   'so',
#   'much',
#   'sweet',
#   'friends',
#   '!',
#   'have',
#   'a',
#   'great',
#   'day',
#   '!'],
#  ['so', 'much', 'for', 'the', 'lovely', 'comments', '!'],
#  ['thanks',
#   'a',
#   'bunch',
#   'sweet',
#   'friends',
#   'and',
#   'a',
#   'happy',
#   'weekend',
#   'to',
#   'you',
#   '!'],
#  ['thanks', 'so', 'much', 'sweet', 'friends', '!'],
#  ['thanks',
#   'so',
#   'much',
#   'sweet',
#   'friends',
#   'and',
#   'have',
#   'a',
#   'lovely',
#   'day',
#   '!'],
#  ['beautiful', 'ensemble', 'and', 'perfect', 'layout', '.'],
#  ...]

# %%
word_to_int,int_to_word = build_vocab(vocab_path,min_num)
vocab_size = len(word_to_int)
print(vocab_size)
# Out:
# 16519

# %%
comments = convert_comments(comments,word_to_int,int_to_word)
comments
# Out:
# [[16517, 20, 24, 27, 73, 1, 16518],
#  [16517, 23, 12, 1, 32, 120, 2, 16518],
#  [16517, 23, 12, 1, 120, 2, 16518],
#  [16517, 20, 24, 73, 1, 27, 56, 57, 25, 1, 16518],
#  [16517, 121, 54, 20, 24, 377, 2, 16518],
#  [16517, 20, 24, 8, 25, 59, 6, 147, 2, 16518],
#  [16517, 50, 1, 73, 20, 1, 16518],
#  [16517, 132, 100, 35, 3, 77, 547, 20, 24, 33, 59, 6, 2, 16518],
#  [16517, 62, 24, 27, 37, 52, 59, 84, 6, 2, 16518],
#  [16517, 170, 76, 33, 1, 34, 288, 2, 16518],
#  [16517, 197, 1, 62, 1, 16518],
#  [16517, 7, 44, 311, 7, 16516, 2, 16518],
#  [16517, 55, 1797, 29, 64, 1, 16518],
#  [16517, 103, 27, 138, 4, 23, 12, 1, 120, 2, 16518],
#  [16517,
#   23,
#   12,
#   7,
#   36,
#   28,
#   295,
#   1,
#   9,
#   225,
#   301,
#   216,
#   3,
#   26,
#   216,
#   120,
#   13,
#   2,
#   16518],
#  [16517, 25, 1, 20, 274, 1, 9, 234, 139, 178, 2, 13, 11, 2, 16518],
#  [16517, 53, 1, 62, 16, 24, 73, 1, 16518],
#  [16517, 835, 4, 2672, 2, 16518],
#  [16517,
#   62,
#   24,
#   481,
#   97,
#   462,
#   59,
#   6,
#   431,
#   4,
#   7,
#   85,
#   29,
#   12,
#   2,
#   162,
#   12,
#   260,
#   1439,
#   42,
#   349,
#   76,
#   4696,
#   2,
#   16518],
#  [16517, 3117, 1174, 1778, 1053, 377, 654, 1230, 16516, 1, 16518],
#  [16517, 20, 24, 481, 97, 40, 51, 10, 2780, 51, 10, 2239, 56, 507, 2, 16518],
#  [16517, 82, 457, 1027, 1, 5, 15, 2, 16518],
#  [16517, 25, 3932, 2, 16518],
#  [16517, 20, 24, 377, 2, 25, 2, 16518],
#  [16517, 174, 1, 16516, 4, 4120, 4, 487, 16516, 16516, 1, 16518],
#  [16517, 30, 1, 73, 20, 1, 16518],
#  [16517,
518],
#  [16517, 50, 1, 73, 20, 1, 16518],
#  [16517, 25, 6, 16, 1, 62, 1, 12, 511, 15, 1, 13, 11, 2, 16518],
#  [16517, 64, 55, 1390, 10, 10594, 16516, 2, 16518],
#  [16517, 39, 14, 5743, 16516, 1, 34, 240, 2, 16518],
#  [16517, 20, 24, 59, 6, 1, 12, 511, 15, 1, 34, 40, 2, 16518],
#  [16517, 60, 18, 1, 20, 24, 73, 16, 1, 16518],
#  [16517, 128, 128, 23, 12, 63, 7, 36, 1, 34, 240, 2, 16518],
#  [16517, 4344, 1, 12, 511, 15, 1, 16518],
#  [16517, 585, 8, 17, 34, 40, 2, 16518],
#  [16517, 680, 64, 101, 116, 12, 260, 2596, 328, 6410, 27, 483, 2, 16518],
#  [16517, 20, 1, 12, 99, 511, 15, 1, 16518],
#  [16517, 1766, 4, 8, 6, 17, 24, 1240, 1, 156, 20, 13, 11, 2, 16518],
#  [16517, 20, 1171, 12, 66, 511, 15, 1, 34, 40, 2, 16518],
#  [16517, 128, 1171, 20, 1, 34, 240, 2, 16518],
#  [16517, 39, 14, 1339, 569, 34, 40, 3, 1722, 1, 16518],
#  [16517, 211, 205, 515, 360, 1, 39, 7, 36, 3, 879, 7, 36, 34, 240, 2, 16518],
#  [16517,
#   128,
#   274,
#   9,
#   118,
#   5,
#   28,
#   214,
#   47,
#   1,
#   3,
#   107,
#   228,
#   173,
#   727,
#   412,
#   4,
#   879,
#   14,
#   148,
#   2,
#   16518],
#  [16517,
#   277,
#   39,
#   7,
#   36,
#   2763,
#   1,
#   3,
#   42,
#   541,
#   4,
#   389,
#   10,
#   224,
#   29,
#   12,
#   156,
#   13,
#   167,
#   11,
#   128,
#   12,
#   136,
#   55,
#   90,
#   4,
#   2319,
#   272,
#   34,
#   288,
#   2,
#   16518],
#  [16517,
#   174,
#   4,
#   195,
#   28,
#   760,
#   15,
#   1,
#   39,
#   7,
#   36,
#   1863,
#   4,
#   3,
#   205,
#   515,
#   34,
#   40,
#   2,
#   16518],
#  [16517, 95, 926, 1, 156, 4, 39, 13, 81, 11, 2, 16518],
#  [16517, 128, 9, 5, 8, 6, 1, 10, 79, 57, 31, 1, 16518],
#  [16517, 7, 52, 360, 1, 16518],
#  [16517,
#   9,
#   116,
#   119,
#   242,
#   178,
#   29,
#   342,
#   1379,
#   2,
#   9,
#   118,
#   66,
#   373,
#   12,
#   12927,
#   27,
#   105,
#   2,
#   16518],
#  [16517, 39, 5066, 1, 70, 2, 16518],
#  [16517, 15, 490, 526, 156, 1, 39, 7, 36, 2440, 1, 70, 2, 16518],
#  [16517,
#   39,
#   10694,
#   1,
#   597,
#   47,
#   65,
#   14,
#   107,
#   479,
#   4,
#   9,
#   526,
#   78,
#   1685,
#   130,
#   27,
#   2313,
#   29,
#   47,
#   3,
#   27,
#   175,
#   57,
#   7,
#   45,
#   1,
#   34,
#   40,
#   2,
#   16518],
#  [16517,
#   109,
#   3778,
#   3130,
#   3,
#   1194,
#   2444,
#   383,
#   29,
#   14,
#   588,
#   152,
#   1,
#   156,
#   2,
#   8,
#   6,
#   17,
#   66,
#   50,
#   34,
#   40,
#   5,
#   10,
#   248,
#   2,
#   107,
#   228,
#   61,
#   412,
#   3,
#   564,
#   51,
#   27,
#   440,
#   13,
#   11,
#   2,
#   16518],
#  [16517, 174, 9, 93, 195, 12, 136, 1700, 1, 3, 39, 75, 81, 11, 2, 16518],
#  [16517,
#   10,
#   175,
#   42,
#   10,
#   308,
#   118,
#   526,
#   129,
#   14,
#   66,
#   38,
#   479,
#   1,
#   1594,
#   5,
#   28,
#   214,
#   15,
#   1,
#   212,
#   107,
#   228,
#   396,
#   178,
#   28,
#   412,
#   2,
#   16518],
#  [16517,
#   39,
#   7,
#   36,
#   1,
#   174,
#   4,
#   9,
#   93,
#   195,
#   12,
#   263,
#   49,
#   28,
#   214,
#   47,
#   75,
#   81,
#   11,
#   2,
#   16518],
#  [16517,
#   8,
#   17,
#   7,
#   31,
#   1,
#   3,
#   211,
#   10,
#   412,
#   512,
#   801,
#   1486,
#   109,
#   9,
#   334,
#   12,
#   107,
#   228,
#   2,
#   3,
#   9,
#   118,
#   5,
#   28,
#   214,
#   123,
#   175,
#   42,
#   10,
#   308,
#   1,
#   97,
#   9807,
#   2,
#   16518],
#  [16517, 205, 515, 1, 70, 2, 16518],
#  [16517, 39, 29, 496, 64, 10, 6967, 34, 40, 2, 16518],
#  [16517, 20, 24, 73, 1, 16518],
#  [16517, 26, 139, 64, 74, 2, 16518],
#  [16517,
#   25,
#   6,
#   1,
#   20,
#   24,
#   73,
#   1,
#   34,
#   40,
#   164,
#   12,
#   324,
#   255,
#   786,
#   64,
#   260,
#   28,
#   5396,
#   746,
#   4,
#   9,
#   263,
#   129,
#   37,
#   1319,
#   1,
#   13,
#   11,
#   14436,
#   947,
#   2,
#   16518],
#  [16517, 38, 1, 73, 20, 1, 16518],
#  [16517,
#   125,
#   124,
#   1,
#   66,
#   49,
#   10,
#   370,
#   837,
#   61,
#   10,
#   259,
#   2,
#   1787,
#   14,
#   125,
#   2285,
#   2,
#   16518],
#  [16517, 586, 1131, 2, 16518],
#  [16517, 9, 276, 8, 7, 36, 2, 16518],
#  [16517, 26, 32, 20, 3, 477, 236, 10, 53, 154, 1, 16518],
#  [16517, 220, 1, 20, 2, 16518],
#  [16517, 8, 6, 17, 526, 117, 1, 15, 65, 7, 131, 3, 6284, 94, 2, 16518],
#  [16517,
#   15,
#   17,
#   7,
#   52,
#   1,
#   9,
#   5,
#   101,
#   15,
#   379,
#   14,
#   37,
#   339,
#   310,
#   28,
#   15,
#   1,
#   16518],
#  [16517, 278, 66, 25, 2, 16518],
#  [16517, 5, 15, 1, 20, 111, 2, 16518],
#  [16517, 8, 17, 10, 461, 31, 108, 407, 1, 41, 1, 16518],
#  [16517, 8, 17, 7, 26, 1, 121, 489, 1, 16518],
#  [16517, 30, 202, 2, 16518],
#  [16517, 46, 4, 89, 123, 456, 26, 6, 1, 16518],
#  [16517, 339, 3, 489, 20, 2, 16518],
#  [16517, 12, 9922, 10, 570, 957, 15, 65, 16516, 7717, 2, 16518],
#  [16517, 7, 31, 1, 1558, 16516, 4, 20, 24, 377, 3, 27, 92, 1, 16518],
#  [16517, 20, 24, 73, 16, 1, 16518],
#  [16517, 8, 17, 305, 1076, 1, 16518],
#  [16517, 30, 1, 73, 20, 1, 16518],
#  [16517, 95, 550, 47, 65, 7, 52, 1, 16518],
#  [16517, 62, 26, 16516, 2, 282, 2, 16518],
#  [16517, 831, 1, 20, 2, 16518],
#  [16517, 101, 52, 2, 16518],
#  [16517, 1010, 4, 7, 77, 4, 2191, 105, 49, 14, 5048, 62, 2, 16518],
#  [16517, 14, 2172, 1, 179, 858, 28, 426, 172, 20, 13, 11, 2, 16518],
#  [16517, 46, 1, 62, 24, 8, 1521, 18, 2, 16518],
#  [16517, 484, 33, 1, 16518],
#  [16517, 20, 24, 377, 2, 16518],
#  [16517, 77, 1, 78, 5, 15, 1, 20, 1, 7, 80, 262, 1, 16518],
#  [16517, 20, 24, 27, 26, 377, 1, 16518],
#  [16517,
#   46,
#   9,
#   93,
#   51,
#   5,
#   61,
#   8,
#   6,
#   7,
#   346,
#   3,
#   26,
#   62,
#   24,
#   73,
#   12,
#   121,
#   511,
#   15,
#   2,
#   16518],
#  [16517, 62, 24, 390, 219, 4, 26, 6, 2, 16518],
#  [16517, 46, 4, 46, 4, 46, 10, 114, 1, 16518],
#  [16517, 139, 64, 3, 9, 234, 139, 12, 55, 1, 16518],
#  [16517, 74, 71, 22, 297, 13, 2, 16518],
#  [16517, 31, 20, 24, 10, 25, 6, 275, 437, 2, 16518],
#  [16517, 30, 457, 75, 11, 16516, 2, 16518],
#  [16517, 54, 1, 20, 1, 9, 234, 139, 178, 13, 11, 2, 16518],
#  [16517, 322, 1, 73, 20, 1, 16518],
#  [16517, 20, 16, 278, 7, 26, 2, 16518],
#  [16517, 447, 17, 15, 2911, 2, 16518],
#  [16517, 50, 124, 2, 16518],
#  [16517, 3005, 16516, 1305, 2, 16518],
#  [16517, 62, 24, 27, 80, 262, 59, 84, 6, 2, 16518],
#  [16517, 20, 16, 24, 8, 80, 262, 59, 6, 1, 16518],
#  [16517, 62, 24, 377, 1, 16518],
#  [16517, 62, 24, 73, 1, 16518],
#  [16517, 25, 1, 9, 234, 139, 178, 13, 11, 20, 1, 16518],
#  [16517, 30, 3, 68, 26, 18, 147, 2, 16518],
#  [16517, 7, 191, 2, 16518],
#  [16517, 426, 64, 2, 16518],
#  [16517, 381, 137, 12, 159, 22, 1006, 2, 16518],
#  [16517, 71, 22, 297, 4, 3859, 2, 16518],
#  [16517, 15, 65, 86, 703, 1247, 1, 340, 15, 1, 16518],
#  [16517, 426, 64, 2, 16518],
#  [16517, 16516, 1, 139, 64, 1, 16518],
#  [16517, 128, 9, 207, 51, 5, 61, 8, 6, 34, 16516, 2, 16518],
#  [16517, 54, 32, 20, 24, 27, 92, 2, 16518],
#  [16517, 20, 1, 9, 334, 22, 56, 255, 129, 49, 4748, 1, 16518],
#  [16517,
#   62,
#   24,
#   97,
#   462,
#   59,
#   6,
#   4,
#   162,
#   12,
#   260,
#   1439,
#   42,
#   4696,
#   76,
#   349,
#   431,
#   2,
#   16518],
#  [16517, 62, 24, 59, 84, 6, 1, 16518],
#  [16517, 9, 5, 8, 270, 11, 2, 16518],
#  [16517,
#   20,
#   24,
#   73,
#   1,
#   54,
#   6,
#   2,
#   13,
#   11,
#   9,
#   234,
#   139,
#   16516,
#   34,
#   40,
#   2,
#   16518],
#  [16517,
#   46,
#   4,
#   8,
#   6,
#   17,
#   7,
#   19,
#   1,
#   9,
#   5,
#   551,
#   79,
#   3,
#   10,
#   213,
#   15,
#   1462,
#   251,
#   876,
#   10,
#   352,
#   283,
#   57,
#   10,
#   1791,
#   2,
#   80,
#   146,
#   1,
#   16518],
#  [16517, 132, 6, 2, 16518],
#  [16517,
#   37,
#   26,
#   91,
#   2,
#   9,
#   49,
#   15,
#   14,
#   148,
#   2,
#   62,
#   28,
#   12,
#   16,
#   13,
#   11,
#   2,
#   16518],
#  [16517, 20, 24, 73, 1, 16518],
#  [16517,
 1, 16518],
#  [16517, 20, 24, 73, 1, 16518],
#  [16517, 20, 24, 27, 377, 16, 1, 16518],
#  [16517, 26, 73, 20, 2, 16518],
#  [16517, 20, 24, 27, 25, 73, 1, 16518],
#  [16517, 80, 146, 1, 16518],
#  [16517, 20, 24, 8, 25, 59, 6, 147, 2, 16518],
#  [16517,
#   20,
#   24,
#   59,
#   6,
#   2,
#   48,
#   14,
#   31,
#   35,
#   12,
#   327,
#   198,
#   76,
#   37,
#   80,
#   262,
#   1,
#   16518],
#  [16517, 20, 111, 2, 16518],
#  [16517, 275, 182, 1, 62, 1, 16518],
#  [16517, 20, 24, 73, 1, 16518],
#  [16517, 20, 24, 73, 1, 16518],
#  [16517, 38, 32, 20, 22, 16, 106, 2, 16518],
#  [16517, 174, 1, 20, 2, 16518],
#  [16517, 381, 20, 24, 59, 56, 2, 16518],
#  [16517, 20, 24, 73, 1, 33, 1, 16518],
#  [16517, 60, 59, 3134, 3, 59, 84, 6, 1, 20, 43, 1, 16518],
#  [16517, 62, 16, 24, 73, 1, 16518],
#  [16517, 20, 1, 59, 1129, 1, 16518],
#  [16517, 3022, 1, 20, 2, 16518],
#  [16517, 20, 16, 33, 73, 2, 16518],
#  [16517, 19, 73, 20, 16, 94, 2, 16518],
#  [16517,
#   62,
#   24,
#   481,
#   97,
#   462,
#   59,
#   6,
#   431,
#   4,
#   213,
#   28,
#   242,
#   1,
#   7,
#   85,
#   29,
#   12,
#   2,
#   16518],
#  [16517, 1217, 4, 24, 59, 2, 16518],
#  [16517, 20, 24, 73, 16, 1, 16518],
#  [16517, 62, 24, 27, 80, 262, 59, 84, 6, 2, 16518],
#  [16517, 20, 24, 25, 2194, 73, 16, 70, 5, 2, 16518],
#  [16517, 53, 1514, 3, 19, 35, 70, 2, 16518],
#  [16517, 103, 8, 170, 44, 1, 16518],
#  [16517, 2763, 89, 14, 26, 6, 1, 16516, 2, 16518],
#  [16517, 5, 364, 1533, 119, 156, 19, 126, 42, 79, 1, 20, 2, 16518],
#  [16517, 5, 8, 4, 20, 4, 192, 1, 16518],
#  [16517, 137, 12, 139, 64, 74, 74, 2, 16518],
#  [16517, 60, 223, 13, 2, 16518],
#  [16517, 20, 11575, 1, 12, 511, 15, 1, 34, 288, 2, 16518],
#  [16517,
#   62,
#   2763,
#   24,
#   59,
#   6,
#   2,
#   162,
#   27,
#   649,
#   14,
#   107,
#   226,
#   51,
#   1099,
#   70,
#   2,
#   16518],
#  [16517, 30, 1, 159, 130, 22, 56, 2, 16518],
#  [16517, 5145, 1, 5, 8, 1, 16518],
#  [16517, 62, 24, 73, 1, 16518],
#  [16517, 9, 5, 396, 412, 1189, 158, 2, 16518],
#  [16517, 20, 24, 10, 31, 59, 6, 135, 1, 16518],
#  [16517,
#   490,
#   3817,
#   412,
#   11707,
#   2466,
#   9,
#   69,
#   119,
#   544,
#   10,
#   583,
#   138,
#   311,
#   7,
#   9,
#   4612,
#   89,
#   208,
#   398,
#   4,
#   109,
#   9,
#   49,
#   47,
#   224,
#   4,
#   156,
#   13,
#   167,
#   11,
#   5,
#   8,
#   6,
#   1,
#   16518],
#  [16517,
#   8,
#   17,
#   48,
#   14,
#   45,
#   6,
#   1,
#   22,
#   332,
#   512,
#   222,
#   412,
#   17,
#   788,
#   28,
#   214,
#   22,
#   269,
#   1,
#   16518],
#  [16517,
#   969,
#   1,
#   12,
#   136,
#   37,
#   209,
#   55,
#   4,
#   22,
#   332,
#   186,
#   222,
#   412,
#   118,
#   69,
#   28,
#   129,
#   22,
#   269,
#   102,
#   80,
#   97,
#   16516,
#   2,
#   16518],
#  [16517,
#   5,
#   8,
#   7,
#   36,
#   1,
#   25,
#   1,
#   22,
#   693,
#   186,
#   42,
#   412,
#   17,
#   63,
#   22,
#   269,
#   87,
#   13,
#   2,
#   16518],
#  [16517,
#   743,
#   7,
#   52,
#   2763,
#   1,
#   22,
#   332,
#   186,
#   42,
#   412,
#   17,
#   176,
#   396,
#   28,
#   15,
#   491,
#   2,
#   16518],
#  [16517,
#   22,
#   710,
#   512,
#   173,
#   412,
#   17,
#   269,
#   3,
#   1811,
#   3,
#   10015,
#   9,
#   5,
#   8,
#   6859,
#   34,
#   695,
#   2,
#   16518],
#  [16517, 26, 388, 42, 1480, 258, 1, 19, 178, 28, 412, 18, 1, 16518],
#  [16517, 58, 6, 1, 22, 710, 512, 222, 412, 17, 788, 11707, 13, 87, 2, 16518],
#  [16517,
#   12,
#   136,
#   86,
#   209,
#   55,
#   1,
#   22,
#   332,
#   512,
#   51,
#   412,
#   17,
#   2494,
#   87,
#   9,
#   93,
#   14,
#   5663,
#   13,
#   439,
#   11,
#   2,
#   16518],
#  [16517, 77, 3, 2247, 102, 112, 2, 16518],
#  [16517, 9, 49, 788, 10, 16516, 11707, 4, 3, 212, 22, 269, 2, 16518],
#  [16517, 8, 17, 7, 52, 1, 22, 332, 512, 222, 412, 17, 412, 1189, 1, 16518],
#  [16517, 22, 332, 186, 42, 412, 17, 178, 28, 412, 1189, 2, 16518],
#  [16517,
#   8,
#   17,
#   7,
#   52,
#   1,
#   109,
#   896,
#   22,
#   332,
#   186,
#   42,
#   412,
#   17,
#   396,
#   847,
#   173,
#   10,
#   992,
#   42,
#   10,
#   152,
#   2,
#   16518],
#  [16517,
#   8,
#   17,
#   140,
#   52,
#   2763,
#   1,
#   9,
#   526,
#   5,
#   180,
#   222,
#   412,
#   4,
#   1764,
#   29,
#   10,
#   1544,
#   1638,
#   42,
#   7633,
#   156,
#   2,
#   109,
#   722,
#   3363,
#   61,
#   22,
#   269,
#   328,
#   529,
#   297,
#   15703,
#   1,
#   16518],
#  [16517, 3580, 75, 11, 8, 17, 66, 45, 1, 16518],
#  [16517, 264, 6015, 2, 16518],
#  [16517, 264, 3657, 2, 16518],
#  [16517, 264, 2422, 2, 16518],
#  [16517, 264, 1860, 2, 97, 3829, 2, 16518],
#  [16517, 264, 1770, 2, 16518],
#  [16517, 264, 1637, 2, 16518],
#  [16517, 264, 1522, 2, 16518],
#  [16517, 264, 1517, 2, 97, 7099, 2, 16518],
#  [16517, 264, 1571, 2, 16518],
#  [16517, 7, 170, 311, 77, 2, 16518],
#  [16517, 9, 336, 119, 392, 374, 63, 42, 12, 136, 26, 175, 2, 16518],
#  [16517, 20, 16, 1, 97, 4145, 2, 16518],
#  [16517, 808, 1, 67, 17, 14, 1507, 635, 4261, 1, 16518],
#  [16517, 20, 24, 73, 1, 16518],
#  [16517, 137, 12, 139, 64, 74, 2, 16518],
#  [16517, 12, 252, 358, 1433, 13, 2, 16518],
#  [16517, 133, 1980, 1, 2, 20, 360, 2, 16518],
#  [16517, 73, 20, 1, 16518],
#  [16517,
#  [16517, 26, 442, 2, 62, 28, 12, 2, 16518],
#  [16517, 245, 124, 1, 37, 68, 1, 80, 146, 13, 11, 70, 2, 16518],
#  [16517,
#   101,
#   405,
#   1,
#   161,
#   851,
#   4016,
#   626,
#   3,
#   44,
#   345,
#   57,
#   993,
#   198,
#   2,
#   268,
#   62,
#   28,
#   12,
#   70,
#   2,
#   16518],
#  [16517,
#   37,
#   68,
#   4,
#   19,
#   124,
#   42,
#   10,
#   35,
#   61,
#   428,
#   76,
#   568,
#   13,
#   11,
#   11,
#   2,
#   16518],
#  [16517, 89, 123, 25, 21, 1, 31, 79, 3, 345, 1, 715, 20, 1, 16518],
#  [16517, 369, 151, 1, 16518],
#  [16517, 333, 1, 62, 24, 73, 16, 1, 16518],
#  [16517, 62, 1, 245, 6, 1, 16518],
#  [16517, 220, 1, 20, 24, 27, 80, 262, 73, 2, 16518],
#  [16517, 58, 1, 20, 24, 27, 73, 1, 16518],
#  [16517, 46, 121, 31, 20, 24, 377, 2, 16518],
#  [16517, 20, 24, 73, 1, 16518],
#  [16517, 30, 1, 20, 24, 27, 73, 2, 16518],
#  [16517, 346, 2, 20, 1, 16518],
#  [16517, 139, 64, 3, 9, 139, 12, 55, 1, 16518],
#  [16517, 26, 1, 20, 24, 73, 1, 16518],
#  [16517, 101, 31, 1, 592, 15, 22, 106, 1, 20, 1, 16518],
#  [16517,
#   715,
#   62,
#   22,
#   921,
#   5044,
#   24,
#   27,
#   461,
#   1076,
#   76,
#   193,
#   59,
#   6,
#   1,
#   12,
#   511,
#   15,
#   1,
#   514,
#   1,
#   16518],
#  [16517, 9, 350, 272, 352, 51, 22, 440, 2, 12, 252, 586, 64, 2, 16518],
#  [16517, 20, 1, 80, 262, 2, 16518],
#  [16517, 73, 20, 1, 16518],
#  [16517, 104, 62, 2, 16518],
#  [16517, 62, 24, 73, 2, 37, 52, 2, 16518],
#  [16517, 26, 6, 135, 70, 2, 16518],
#  [16517, 20, 24, 73, 1, 50, 160, 1, 16518],
#  [16517, 159, 355, 1, 16518],
#  [16517, 25, 154, 2, 16518],
#  [16517, 20, 24, 73, 1, 16518],
#  [16517, 20, 24, 27, 25, 73, 16, 70, 2, 16518],
#  [16517, 48, 14, 26, 18, 4, 20, 24, 73, 1, 16518],
#  [16517, 20, 24, 73, 16, 2, 16518],
#  [16517, 10, 368, 17, 7, 26, 3, 104, 4, 20, 1, 16518],
#  [16517, 26, 1, 132, 18, 1, 20, 1, 16518],
#  [16517, 62, 24, 27, 80, 262, 59, 84, 6, 2, 16518],
#  [16517, 20, 24, 27, 31, 73, 16, 1, 16518],
#  [16517, 20, 24, 377, 2, 80, 146, 16, 2, 16518],
#  [16517, 62, 16, 24, 377, 1, 16518],
#  [16517, 220, 3, 104, 21, 1, 5, 15, 1, 897, 87, 11, 400, 2, 16518],
#  [16517, 78, 245, 1, 16518],
#  [16517, 25, 18, 1, 282, 2, 16518],
#  [16517, 16516, 91, 16516, 149, 17, 405, 1, 16518],
#  [16517, 117, 385, 18, 16, 1, 34, 40, 2, 16518],
#  [16517,
#   121,
#   50,
#   213,
#   55,
#   31,
#   3,
#   33,
#   8,
#   21,
#   55,
#   19,
#   6,
#   16,
#   12,
#   249,
#   664,
#   16516,
#   55,
#   50,
#   1,
#   16518],
#  [16517, 1582, 130, 31, 2, 16518],
#  [16517, 19, 18, 19, 6, 19, 285, 420, 1615, 232, 167, 50, 1021, 122, 2, 16518],
#  [16517, 41, 35, 4, 5, 10, 59, 167, 13, 11, 2, 16518],
#  [16517, 19, 6, 4, 47, 368, 17, 33, 1, 16518],
#  [16517, 7, 30, 296, 2, 16518],
#  [16517, 31, 202, 3, 35, 1, 16518],
#  [16517, 200, 18, 111, 1, 5, 10, 82, 3, 929, 1, 346, 1, 16518],
#  [16517, 48, 14, 31, 714, 6, 2, 16518],
#  [16517,
#   16516,
#   4,
#   5,
#   10,
#   72,
#   3,
#   10,
#   1795,
#   7065,
#   568,
#   304,
#   3282,
#   3,
#   6167,
#   1,
#   16518],
#  [16517, 54, 43, 1, 319, 2, 16518],
#  [16517, 128, 1, 5, 8, 35, 2238, 2, 16518],
#  [16517, 19, 126, 1, 5, 10, 79, 3, 91, 2, 16518],
#  [16517, 30, 82, 1642, 2, 16518],
#  [16517, 121, 588, 1, 16518],
#  [16517, 46, 1, 33, 248, 3, 352, 21, 2, 5, 15, 1, 16518],
#  [16517, 37, 104, 3, 1817, 1, 16518],
#  [16517, 20, 24, 73, 1, 26, 1, 16518],
#  [16517, 131, 1384, 2, 16518],
#  [16517, 19, 1, 62, 24, 73, 2, 16518],
#  [16517, 20, 24, 8, 33, 59, 6, 147, 2, 16518],
#  [16517, 50, 1, 73, 20, 1, 16518],
#  [16517, 62, 24, 73, 1, 16518],
#  [16517, 62, 24, 27, 37, 52, 59, 84, 6, 2, 16518],
#  [16517, 25, 1, 20, 24, 73, 13, 11, 2, 16518],
#  [16517, 128, 1, 7, 107, 2, 16518],
#  [16517,
#   8,
#   17,
#   22,
#   607,
#   59,
#   6,
#   431,
#   4,
#   62,
#   4,
#   48,
#   14,
#   38,
#   6,
#   76,
#   908,
#   202,
#   2,
#   16518],
#  [16517, 20, 24, 27, 132, 73, 22, 16, 70, 5, 2, 16518],
#  [16517, 20, 24, 73, 2, 16518],
#  [16517, 51, 5, 61, 10, 122, 1, 16518],
#  [16517, 20, 1, 151, 2, 16518],
#  [16517, 69, 14, 18, 173, 16516, 2, 16518],
#  [16517, 5, 15, 274, 2, 16518],
#  [16517, 4012, 205, 16516, 14, 16516, 16516, 13256, 11674, 495, 1, 16518],
#  [16517, 20, 24, 60, 73, 1, 16518],
#  [16517, 322, 1, 73, 20, 1, 16518],
#  [16517, 62, 24, 73, 1, 16518],
#  [16517, 20, 2, 278, 190, 2, 16518],
#  [16517, 62, 24, 59, 56, 111, 2, 16518],
#  [16517, 46, 121, 25, 4, 80, 262, 20, 24, 377, 2, 16518],
#  [16517, 62, 24, 73, 1, 16518],
#  [16517, 10, 2769, 3597, 719, 2, 535, 16516, 2, 16518],
#  [16517, 132, 1, 20, 24, 73, 2, 9, 234, 139, 178, 1, 13, 11, 2, 16518],
#  [16517, 45, 6, 4, 20, 24, 377, 1, 16518],
#  [16517, 20, 24, 73, 16, 1, 16518],
#  [16517, 251, 25, 20, 2, 16518],
#  [16517, 62, 927, 2, 16518],
#  [16517, 19, 18, 19, 6, 19, 285, 420, 568, 232, 167, 50, 1400, 2, 16518],
#  [16517, 68, 3, 38, 110, 84, 33, 8, 21, 1, 16518],
#  [16517, 132, 6, 1, 41, 35, 3, 83, 2, 16518],
#  [16517, 48, 14, 125, 789, 2, 16518],
#  [16517,
#   179,
#   32,
#   9,
#   3960,
#   15,
#   65,
#   834,
#   6598,
#   109,
#   10,
#   2081,
#   725,
#   24,
#   733,
#   733,
#   13853,
#   733,
#   13853,
#   13853,
#   172,
#   87,
#   61,
#   399,
#   11,
#   2,
#   16518],
#  [16517,
#   102,
#   42,
#   287,
#   247,
#   22,
#   710,
#   284,
#   17,
#   3229,
#   304,
#   381,
#   4773,
#   4,
#   109,
#   47,
#   65,
#   16062,
#   28,
#   985,
#   51,
#   14,
#   308,
#   2,
#   16518],
#  [16517, 50, 1, 73, 20, 1, 16518],
#  [16517,
#   20,
#   1442,
#   12,
#   511,
#   8,
#   102,
#   14,
#   59,
#   6,
#   454,
#   967,
#   15,
#   65,
#   78,
#   25,
#   1,
#   13,
#   88,
#   2,
#   16518],
#  [16517, 294, 1, 5, 1, 16518],
#  [16517, 16516, 304, 16516, 13, 11, 2, 16518],
#  [16517,
#   257,
#   57,
#   37,
#   688,
#   109,
#   722,
#   7083,
#   3,
#   108,
#   459,
#   387,
#   13,
#   11,
#   9,
#   66,
#   5,
#   3273,
#   108,
#   3535,
#   719,
#   392,
#   719,
#   9,
#   69,
#   119,
#   2219,
#   28,
#   180,
#   2,
#   8,
#   17,
#   31,
#   427,
#   1,
#   16518],
#  [16517,
#   9,
#   69,
#   14,
#   1092,
#   42,
#   332,
#   3267,
#   109,
#   9,
#   2713,
#   1183,
#   28,
#   6043,
#   8680,
#   3,
#   436,
#   2,
#   9,
#   207,
#   7,
#   195,
#   9,
#   116,
#   119,
#   69,
#   28,
#   242,
#   28,
#   412,
#   1360,
#   2,
#   16518],
#  [16517,
#   156,
#   10,
#   178,
#   28,
#   412,
#   512,
#   65,
#   7,
#   465,
#   1,
#   22,
#   710,
#   1295,
#   17,
#   12699,
#   3898,
#   28,
#   6046,
#   13,
#   11,
#   2,
#   16518],
#  [16517, 9, 453, 1206, 1820, 1, 243, 65, 22, 63, 226, 607, 996, 2, 16518],
#  [16517,
#   22,
#   332,
#   7133,
#   17,
#   5338,
#   11663,
#   3,
#   22,
#   332,
#   2174,
#   17,
#   1109,
#   1206,
#   1820,
#   328,
#   16516,
#   1915,
#   2,
#   16518],
#  [16517, 30, 1, 73, 20, 1, 16518],
#  [16517, 20, 24, 14, 59, 6, 1, 197, 21, 3, 6616, 126, 42, 79, 2, 16518],
#  [16517, 64, 689, 1, 16518],
#  [16517, 20, 24, 377, 2, 16518],
#  [16517, 9, 249, 2, 16518],
#  [16517, 62, 135, 2, 16518],
#  [16517, 38, 1, 73, 20, 1, 16518],
#  [16517, 5, 10, 646, 1, 16518],
#  [16517, 20, 24, 73, 2, 16518],
#  [16517,
#   62,
#   24,
#   73,
#   1,
#   8,
#   6,
#   1790,
#   15,
#   1,
#   19,
#   646,
#   454,
#   9,
#   154,
#   51,
#   15,
#   3,
#   16516,
#   17,
#   7,
#   1775,
#   29,
#   47,
#   4282,
#   1,
#   16518],
#  [16517, 188, 29, 63, 564, 16516, 1, 16518],
#  [16517, 19, 21, 16, 1, 20, 24, 73, 1, 16518],
#  [16517, 62, 24, 27, 37, 52, 59, 84, 6, 2, 16518],
#  [16517, 45, 59, 84, 6, 1, 20, 1, 16518],
#  [16517, 870, 16, 2, 16518],
#  [16517,
#   62,
#   24,
#   27,
#   377,
#   22,
#   16,
#   106,
#   1317,
#   582,
#   644,
#   3,
#   194,
#   3,
#   8832,
#   3970,
#   2,
#   16518],
#  [16517, 20, 24, 27, 377, 1, 16518],
#  [16517, 62, 24, 73, 1, 16518],
#  [16517,
#   46,
#   1,
#   8,
#   108,
#   17,
#   7,
#   77,
#   1,
#   5,
#   8,
#   169,
#   4,
#   248,
#   3,
#   258,
#   18,
#   1,
#   132,
#   124,
#   1,
#   16518],
#  [16517, 19, 18, 19, 6, 19, 285, 420,
 16518],
#  [16517, 62, 24, 27, 377, 94, 2, 16518],
#  [16517, 20, 24, 27, 31, 73, 2, 16518],
#  [16517, 174, 4, 20, 1, 16518],
#  [16517, 4335, 3771, 1, 1063, 16516, 4632, 1, 16518],
#  [16517, 8, 17, 10, 1424, 6, 54, 21, 2, 16518],
#  [16517, 105, 50, 1, 70, 2, 16518],
#  [16517, 46, 1, 8, 17, 140, 41, 29, 110, 13, 11, 11, 11, 2, 16518],
#  [16517, 37, 26, 29, 110, 4, 62, 28, 12, 16, 13, 11, 2, 16518],
#  [16517, 117, 1, 514, 1, 16518],
#  [16517, 275, 182, 1, 20, 4, 2, 16518],
#  [16517, 20, 265, 2, 16518],
#  [16517, 20, 135, 1, 120, 2, 16518],
#  [16517, 20, 4, 4558, 2, 16518],
#  [16517, 62, 24, 27, 377, 94, 2, 16518],
#  [16517, 1040, 18, 1, 16518],
#  [16517, 73, 20, 1, 16518],
#  [16517, 62, 24, 27, 37, 30, 59, 84, 6, 2, 16518],
#  [16517, 62, 24, 73, 1, 16518],
#  [16517, 174, 4, 20, 2477, 1, 16518],
#  [16517, 19, 18, 19, 6, 19, 175, 232, 167, 50, 425, 1847, 2, 16518],
#  [16517, 8, 17, 58, 1, 19, 388, 4, 18, 3, 6, 1, 16518],
#  [16517, 5, 180, 222, 8, 6, 2, 16518],
#  [16517, 588, 16, 2, 16518],
#  [16517, 7, 30, 84, 3, 33, 35, 67, 19, 6, 1, 16518],
#  [16517, 58, 22, 16, 106, 94, 2, 16518],
#  [16517, 30, 1, 73, 20, 1, 16518],
#  [16517, 62, 24, 27, 37, 52, 59, 84, 6, 2, 16518],
#  [16517, 5, 10, 345, 51, 8, 6, 1, 16518],
#  [16517, 62, 24, 59, 56, 111, 2, 16518],
#  [16517, 20, 24, 73, 16, 2, 16518],
#  [16517, 62, 24, 73, 1, 16518],
#  [16517, 45, 1, 20, 24, 377, 1, 16518],
#  [16517, 20, 24, 73, 16, 1, 16518],
#  [16517, 20, 24, 27, 25, 73, 70, 2, 16518],
#  [16517, 132, 6, 1, 41, 35, 3, 83, 1, 62, 927, 2, 16518],
#  [16517, 174, 1, 20, 2, 16518],
#  [16517, 62, 24, 27, 377, 22, 16, 106, 1317, 582, 644, 3, 194, 2342, 2, 16518],
#  [16517, 19, 18, 19, 6, 19, 16516, 3849, 50, 581, 2, 16518],
#  [16517, 140, 45, 1, 13, 11, 2, 16518],
#  [16517, 8, 17, 22, 332, 21, 2, 16518],
#  [16517, 144, 3088, 96, 92, 1150, 415, 2, 16518],
#  [16517, 7, 68, 3, 77, 62, 24, 73, 2, 16518],
#  [16517, 426, 64, 2, 16518],
#  [16517, 20, 1, 32, 2103, 5, 15, 2, 16518],
#  [16517,
#   381,
#   324,
#   242,
#   3056,
#   22,
#   483,
#   3,
#   1636,
#   14,
#   49,
#   3,
#   14,
#   139,
#   677,
#   2,
#   16518],
#  [16517, 30, 1, 73, 20, 1, 16518],
#  [16517, 62, 24, 73, 1, 16518],
#  [16517, 48, 14, 38, 201, 21, 2, 16518],
#  [16517, 23, 12, 133, 36, 326, 34, 40, 2, 16518],
#  [16517, 220, 6, 1, 3815, 2, 16518],
#  [16517, 68, 3, 38, 84, 33, 35, 3, 8, 21, 55, 19, 6, 16, 147, 2, 16518],
#  [16517, 19, 18, 19, 6, 19, 285, 420, 581, 232, 167, 50, 122, 2, 16518],
#  [16517,
#   268,
#   62,
#   24,
#   27,
#   7,
#   90,
#   4,
#   403,
#   4,
#   191,
#   3,
#   37,
#   80,
#   262,
#   59,
#   6,
#   1,
#   16518],
#  [16517,
#   25,
#   4,
#   137,
#   113,
#   145,
#   159,
#   22,
#   523,
#   16516,
#   47,
#   451,
#   14,
#   148,
#   2,
#   16518],
#  [16517,
#   7,
#   52,
#   2,
#   5,
#   10,
#   82,
#   457,
#   3,
#   63,
#   10,
#   370,
#   307,
#   4,
#   682,
#   66,
#   1914,
#   8,
#   6,
#   198,
#   3,
#   237,
#   15,
#   7,
#   37,
#   54,
#   2,
#   16518],
#  [16517, 20, 24, 73, 1, 974, 26, 1, 16518],
#  [16517,
#   39,
#   37,
#   36,
#   29,
#   63,
#   10,
#   30,
#   138,
#   9,
#   225,
#   15,
#   37,
#   36,
#   29,
#   63,
#   27,
#   661,
#   268,
#   1784,
#   29,
#   12,
#   579,
#   108,
#   9,
#   833,
#   69,
#   6227,
#   2,
#   16518],
#  [16517, 20, 2, 107, 160, 102, 667, 2, 12, 57, 7, 107, 51, 8, 1718, 2, 16518],
#  [16517, 30, 1, 73, 20, 1, 16518],
#  [16517, 20, 24, 73, 16, 1, 16518],
#  [16517,
 24, 73, 1, 16518],
#  [16517, 62, 24, 27, 37, 52, 59, 84, 6, 2, 16518],
#  [16517, 20, 24, 53, 73, 16, 70, 2, 16518],
#  [16517, 53, 32, 20, 24, 73, 2, 16518],
#  [16517, 20, 24, 27, 25, 73, 16, 1, 16518],
#  [16517, 62, 24, 27, 2760, 94, 2, 16518],
#  [16517, 30, 59, 84, 6, 1, 20, 1, 16518],
#  [16517, 39, 4, 15, 65, 50, 28, 760, 1, 16518],
#  [16517, 1015, 182, 18, 2, 16518],
#  [16517, 52, 98, 4, 37, 30, 18, 1, 16518],
#  [16517, 46, 4, 23, 12, 1, 47, 65, 14, 50, 877, 34, 40, 2, 16518],
#  [16517, 121, 31, 4, 105, 49, 342, 97, 433, 28, 64, 1, 16518],
#  [16517, 39, 37, 36, 295, 1, 34, 40, 2, 16518],
#  [16517, 19, 18, 19, 6, 19, 285, 420, 699, 232, 167, 50, 2202, 2, 16518],
#  [16517, 153, 18, 4, 19, 91, 1, 16518],
#  [16517, 132, 6, 275, 437, 2, 16518],
#  [16517, 121, 111, 35, 2, 34, 40, 2, 16518],
#  [16517,
#   117,
#   35,
#   33,
#   8,
#   21,
#   3,
#   35,
#   55,
#   126,
#   76,
#   244,
#   102,
#   80,
#   29,
#   8,
#   474,
#   1,
#   16518],
#  [16517, 19, 18, 19, 6, 232, 167, 50, 1400, 2, 16518],
#  [16517, 151, 1, 20, 2, 16518],
#  [16517, 3303, 24, 22, 2936, 2, 16518],
#  [16517, 2737, 20, 1, 16518],
#  [16517, 131, 1, 20, 16, 2, 9, 5, 8, 13, 11, 11, 2, 16518],
#  [16517, 139, 4638, 1, 16518],
#  [16517, 31, 32, 3, 62, 24, 59, 84, 6, 2, 16518],
#  [16517, 31, 4, 20, 24, 377, 1, 16518],
#  [16517, 26, 35, 1, 20, 24, 27, 59, 84, 6, 1, 16518],
#  [16517, 174, 1, 20, 16, 1, 16518],
#  [16517, 322, 1, 73, 20, 1, 16518],
#  [16517, 9, 1121, 8, 155, 14, 987, 1, 62, 2, 16518],
#  [16517, 62, 24, 27, 80, 262, 59, 84, 6, 2, 16518],
#  [16517, 6833, 16, 2, 16518],
#  [16517, 62, 24, 59, 56, 111, 2, 16518],
#  [16517, 574, 4, 20, 1, 16518],
#  [16517, 31, 59, 84, 6, 1, 20, 1, 16518],
#  [16517, 7, 36, 295, 1, 69, 14, 30, 152, 1, 16518],
#  [16517, 62, 24, 27, 377, 94, 2, 16518],
#  [16517, 39, 7, 36, 90, 269, 1, 69, 14, 19, 152, 1, 16518],
#  [16517, 7, 36, 29, 10, 30, 138, 1, 16518],
#  [16517, 39, 14, 1092, 90, 269, 3, 14, 85, 163, 28, 12, 1, 16518],
#  [16517, 39, 7, 36, 90, 269, 1, 16518],
#  [16517, 39, 7, 36, 90, 269, 3, 69, 14, 30, 152, 1, 16518],
#  [16517, 26, 183, 3, 41, 83, 2, 16518],
#  ...]

# %%
toplist = []
topidlist = {}
with open('dataset/toplist.dat','r') as f:#in toplist, the first col is img_name of top, the second col is comments_index
    content = f.readlines()
for line in content:
    line = line.split('\t')
    toplist.append(line[0])
    topidlist[line[0]] = len(topidlist)
toplist

# %%
topidlist
# Out:
# {'100007206': 0,
#  '100015289': 1,
#  '100018253': 2,
#  '100018720': 3,
#  '100027085': 4,
#  '100049216': 5,
#  '100051783': 6,
#  '100058266': 7,
#  '100058372': 8,
#  '100060461': 9,
#  '100060516': 10,
#  '100060655': 11,
#  '100061551': 12,
#  '100061862': 13,
#  '146566930117015027',
#  '157406123154440331',
#  '777392127520952',
#  '144300247172074437',
#  '5586419866375286',
#  '158101518162214666',
#  '128565581122592460',
#  '17813702249487127',
#  '137695364146826834',
#  '14746654623411964',
#  '7043476112422701',
#  '130297773138892921',
#  '209269768202157748',
#  '99607808110213798',
#  '193650155195401702',
#  '201392995165814781',
#  '126112311120648842',
#  '119476753147900594',
#  '123848940101050256',
#  '191550720184009379',
#  '193496035192404903',
#  '10943006883296549',
#  '95107114129865157',
#  '103332146129066022',
#  '150798281150239696',
#  '170358115204173059',
#  '173134487171820080',
#  '178156627180867557',
#  '132749177129657405',
#  '101119106105750265',
#  '9000384278954926',
#  '207428920204071710',
#  '101989877101835255',
#  '202045324179660718',
#  '10119510197705851',
#  '4333108370370928',
#  '127600353133718651',
#  '111899774152297464',
#  '100064184103466962',
#  '194104332194157707',
#  '213242016212488110',
#  '7461264818118626',
#  '6418296765899999',
#  '9164336588404780',
#  '119871964112128725',
#  '70518591102413755',
#  '6825390666298607',
#  '181321081193955197',
#  '207309850209856035',
#  '106633590140250403',
#  '136476423138010973',
#  '127293248121759438',
#  '14309088467650975',
#  '123851728125917356',
#  '162097071164679282',
#  '156528707151372091',
#  '129273240130803540',
#  '183924431168530709',
#  '189705720202996982',
#  '191593377102406891',
#  '152954968131121686',
#  '143527142149680523',
#  '117460972147151663',
#  '17685308676661481',
#  '143711606140742447',
#  '184295682191903896',
#  '196179955191901209',
#  '126511477146311588',
#  '170119415134293639',
#  '4235720146315274',
#  '71419511191903896',
#  '11838654159627865',
#  '136739834136305410',
#  '23637228139078985',
#  '116347728115094854',
#  '3933787142530221',
#  '144977007117654150',
#  '202289259192401231',
#  '183648968188219068',
#  '6631269565084242',
#  '108580813110958683',
#  '134033408144855367',
#  '4079718372782988',
#  '167009055135695313',
#  '191512017193475672',
#  '216640294213153643',
#  '135534617169964732',
#  '136117450128869353',
#  '185993125157884396',
#  '162200763160809288',
#  '116643583112685144',
#  '161136317121856672',
#  '191849996193237098',
#  '177016716169594848',
#  '213279340213003632',
#  '17526128884705482',
#  '134759451137612004',
#  '138018302134988268',
#  '4399307796954859',
#  '177859243167148162',
#  '7062346280245518',
#  '147663289146800193',
#  '79388054106921979',
#  '187974429183797260',
#  '168448626172480759',
#  '202272526199696764',
#  '666192412156405',
#  '15187527089819283',
#  '3631418525536409',
#  '9662027998052872',
#  '107343661131112707',
#  '127222107138054789',
#  '193506756194798977',
#  ...}

# %%
# imglist = {}
# with open('dataset/datafull.dat','w') as f:
#   for img_idx in toplist:
#       img = Image.open('img/'+img_idx+'.jpg')
#       img = np.array(img)
#       img = img/255.0
#       imglist[img_idx] = img
#   for img_idx in downlist:
#       img = Image.open('img/'+img_idx+'.jpg')
#       img = np.array(img)
#       img = img/255.0
#       imglist[img_idx] = img
# imglist

# %% [markdown]
# # Build Model

# %%
def get_input():
    img1 = tf.placeholder(tf.float32,[None,224,224,3],'img1')
    img2 = tf.placeholder(tf.float32,[None,224,224,3],'img2')
    img1id = tf.placeholder(tf.int32,[None,],'img1id')
    img2id = tf.placeholder(tf.int32,[None,],'img2id')
    label = tf.placeholder(tf.float32,[None,2],'label')
    sequence_input = tf.placeholder(tf.int32,[None,None],name='sequence_input')
    sequence_output = tf.placeholder(tf.int32,[None,None],name='sequence_output')
    sequence_length = tf.placeholder(tf.int32,[None,],name='sequence_length')
    max_sequence_length = tf.placeholder(tf.int32,[],name='max_sequence_length')
    batch_size = tf.placeholder(tf.int32,[],name='batch_size')
    learning_rate = tf.placeholder(tf.float32,[],name='learning_rate')
    keep_prob = tf.placeholder(tf.float32,[],name='keep_prob')
    ratio_c = tf.placeholder(tf.float32,[],name='ratio_c')
    ratio_g = tf.placeholder(tf.float32,[],name='ratio_g')
    weight = tf.placeholder(tf.float32,[None,],name='weight')
    flag = tf.placeholder(tf.bool,name='flag')
    return img1,img2,img1id,img2id,label,sequence_input,sequence_output,sequence_length,max_sequence_length,batch_size,learning_rate,keep_prob,ratio_c,ratio_g,weight,flag

# %%
def extractor(img):
    conv1 = keras.layers.Conv2D(filters=32,kernel_size=(3,3),strides=(1,1),padding='same',activation='relu',data_format='channels_last',kernel_initializer='glorot_normal')(img)
    conv2 = keras.layers.Conv2D(filters=32,kernel_size=(3,3),strides=(1,1),padding='same',activation='relu',data_format='channels_last',kernel_initializer='glorot_normal')(conv1)
    pool1 = keras.layers.MaxPool2D(pool_size=(16,16),padding='same')(conv1)
    #print(pool1)
    pool2 = keras.layers.MaxPool2D(pool_size=(16,16),padding='same')(conv2)
    #print(pool2)
    concat = keras.layers.Concatenate(axis=-1)([pool1,pool2])
    #print(concat)
    globalpool = keras.layers.GlobalAveragePooling2D()(concat)
    #print(globalpool)
    return concat,globalpool

# %%
def image_to_image_attention(conv,globalpool):#conv=[batch_size,14,14,64]，globalpool=[batch_size,64]  
    weights1 = tf.get_variable('weights1',shape=[64,64],initializer=tf.contrib.layers.xavier_initializer(uniform=False))
    weights2 = tf.get_variable('weights2',shape=[64,64],initializer=tf.contrib.layers.xavier_initializer(uniform=False))
    weights3 = tf.get_variable('weights3',shape=[64,1],initializer=tf.contrib.layers.xavier_initializer(uniform=False))
    attn_from = tf.matmul(globalpool,weights1)#attn_form=[batch_size,64]
    features = keras.layers.Reshape([-1,64])(conv)#features=[batch_size,196,64] 
    attn_to = tf.matmul(tf.reshape(features,[-1,64]),weights2)#tf.reshape(features,[-1,64])=[batch_size*196,64]，attn_to=[batch_size*196,64]
    attn_from  = tf.expand_dims(attn_from,1)#attn_from=[batch_size,1,64]
    attn_to = tf.reshape(attn_to,tf.shape(features))#attn_to=[batch_size,196,64] 
    attn_logit = tf.add(attn_from,attn_to)#attn_logit=[batch_size,196,64]
    attn_logit = tf.reshape(attn_logit,[-1,64])#attn_logit=[batch_size*196,64]
    attn_logit = tf.tanh(attn_logit)
    attn_weight = tf.matmul(attn_logit,weights3)#attn_weight=[batch_size*196,1]
    attn_weight = tf.reshape(attn_weight,shape=[tf.shape(conv)[0],tf.shape(conv)[1]*tf.shape(conv)[2]])#attn_weight=[batch_size,196]
    attn_weight = tf.nn.softmax(attn_weight,name='attention_img2img')   
    attn_weight = tf.expand_dims(attn_weight,-1)#attn_weight=[batch_size,196,1]
    attn_conv = tf.multiply(features,attn_weight)#attn_conv=[batch_size,196,64]
    attn_conv = tf.reduce_sum(attn_conv,axis=1)#attn_conv=[batch_size,64]
    return features,attn_conv#e=v^Ttanh(W1s+W2h)，a=softmax(e)

# %%
def img2vec(conv):
    extractor_output = keras.layers.Dense(300,activation='relu',kernel_initializer='glorot_normal')(conv)
    return extractor_output

# %%
def img_embedding(img1id,img2id):
    top_embedding_matrix = tf.get_variable('top_embedding_matrix',shape=[len(toplist),embedding_size],initializer=tf.contrib.layers.xavier_initializer(uniform=False))
    down_embedding_matrix = tf.get_variable('down_embedding_matrix',shape=[len(downlist),embedding_size],initializer=tf.contrib.layers.xavier_initializer(uniform=False))
    img1_embedding = tf.nn.embedding_lookup(top_embedding_matrix,img1id)
    img2_embedding = tf.nn.embedding_lookup(down_embedding_matrix,img2id)
    return img1_embedding,img2_embedding

# %%
def classifier(extractor_output,keep_prob):
    dense = keras.layers.Dense(256,activation='relu',kernel_initializer='glorot_normal')(extractor_output)
    dropout = tf.nn.dropout(dense,keep_prob)
    classifier_output = keras.layers.Dense(2,activation='softmax',kernel_initializer='glorot_normal')(dropout) 
    return classifier_output

# %%
def get_gru_cell(keep_prob):
    gru_cell = tf.contrib.rnn.GRUCell(512,kernel_initializer=tf.contrib.layers.xavier_initializer(uniform=False))
    dropout_gru_cell = tf.contrib.rnn.DropoutWrapper(gru_cell,input_keep_prob=keep_prob,output_keep_prob=keep_prob,state_keep_prob=keep_prob)
    return dropout_gru_cell

# %%
def generator(sequence_input,initial_state,encoder_output,batch_size,sequence_length,max_sequence_length,vocab_size,embedding_size,keep_prob):
    embedding_matrix = tf.get_variable('embedding_matrix',shape=[vocab_size,embedding_size],initializer=tf.contrib.layers.xavier_initializer(uniform=False))
    generator_embed_sequence = tf.nn.embedding_lookup(embedding_matrix,sequence_input)
    generator_cell = tf.contrib.rnn.MultiRNNCell([get_gru_cell(keep_prob) for _ in range(1)])
    output_layer = Dense(vocab_size,kernel_initializer=tf.contrib.layers.xavier_initializer(uniform=False))
    with tf.variable_scope('generator'):
        training_helper = tf.contrib.seq2seq.TrainingHelper(generator_embed_sequence,sequence_length=sequence_length,time_major=False)
        #attention
        training_LuongAttention = tf.contrib.seq2seq.LuongAttention(num_units=512,memory=encoder_output,memory_sequence_length=None)   
        training_attn_cell = tf.contrib.seq2seq.AttentionWrapper(cell=generator_cell,attention_mechanism=training_LuongAttention,
                                                                 attention_layer_size=512,alignment_history=False,output_attention=True)    
        training_attn_state = training_attn_cell.zero_state(batch_size,tf.float32).clone(cell_state=initial_state) 
        #attention
        training_decoder = tf.contrib.seq2seq.BasicDecoder(training_attn_cell,helper=training_helper,initial_state=training_attn_state,output_layer=output_layer)
        training_generator_output,training_generator_state,_ = tf.contrib.seq2seq.dynamic_decode(training_decoder,output_time_major=False,
                                                                                                 impute_finished=True,maximum_iterations=max_sequence_length)
    with tf.variable_scope('generator',reuse=True):
        start_tokens = tf.tile(tf.constant([word_to_int['<GO>']],dtype=tf.int32),[batch_size])
        #attention
        predicting_LuongAttention = tf.contrib.seq2seq.LuongAttention(num_units=512,memory=encoder_output,memory_sequence_length=None)
        predicting_attn_cell = tf.contrib.seq2seq.AttentionWrapper(cell=generator_cell,attention_mechanism=predicting_LuongAttention,
                                                                   attention_layer_size=512,alignment_history=True,output_attention=True) 
        predicting_attn_state = predicting_attn_cell.zero_state(batch_size,tf.float32).clone(cell_state=initial_state) 
        #attention
        predicting_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(embedding_matrix,start_tokens,word_to_int['<EOS>'])
        predicting_decoder = tf.cotf.contrib.seq2seq.dynamic_decodentrib.seq2seq.BasicDecoder(predicting_attn_cell,predicting_helper,predicting_attn_state,output_layer)
        predicting_generator_output,predicting_generator_state,_ = tf.contrib.seq2seq.dynamic_decode(predicting_decoder,output_time_major=False,
                                                                                                     impute_finished=True,maximum_iterations=max_sequence_length)
        attention_matrix = tf.identity(predicting_generator_state.alignment_history.stack(),name='attention_matrix')
        #print(attention_matrix)
    with tf.variable_scope('generator',reuse=True):
        start_tokens = tf.tile(tf.constant([word_to_int['<GO>']],dtype=tf.int32),[batch_size])
        beamsearch_initial_state = tf.contrib.seq2seq.tile_batch(initial_state,multiplier=3)
        #attention
        beamsearch_encoder_output = tf.contrib.seq2seq.tile_batch(encoder_output,multiplier=3)
        beamsearch_LuongAttention = tf.contrib.seq2seq.LuongAttention(num_units=512,memory=beamsearch_encoder_output,memory_sequence_length=None)
        beamsearch_attn_cell = tf.contrib.seq2seq.AttentionWrapper(cell=generator_cell ,attention_mechanism=beamsearch_LuongAttention,
                                                                   attention_layer_size=512,alignment_history=False,output_attention=True) 
        beamsearch_attn_state = beamsearch_attn_cell.zero_state(batch_size*3,tf.float32).clone(cell_state=beamsearch_initial_state)
        #attention
        beamsearch_predicting_decoder = tf.contrib.seq2seq.BeamSearchDecoder(beamsearch_attn_cell,embedding=embedding_matrix,start_tokens=start_tokens,
                                                                             end_token=word_to_int['<EOS>'],
                                                                             initial_state=beamsearch_attn_state,beam_width=3,
                                                                             output_layer=output_layer,length_penalty_weight=0.6)
        beamsearch_generator_output,beamsearch_generator_state,_ = tf.contrib.seq2seq.dynamic_decode(beamsearch_predicting_decoder,output_time_major=False,
                                                                                                     impute_finished=False,maximum_iterations=max_sequence_length)
    return training_generator_output,predicting_generator_output,beamsearch_generator_output

# %%
def loss(classifier_output,label,training_generator_output,sequence_output,sequence_length,max_sequence_length,ratio_c,ratio_g,weight,flag):
    classifier_loss = tf.reduce_mean(tf.contrib.keras.losses.categorical_crossentropy(label,classifier_output),name='classifier_loss')
    classifier_loss_freeze = tf.stop_gradient(classifier_loss)
    classifier_loss = tf.where(flag,classifier_loss,classifier_loss_freeze)
    training_logits = tf.identity(training_generator_output.rnn_output,name='training_logits')
    masks = tf.sequence_mask(sequence_length,max_sequence_length,dtype=tf.float32,name='mask')  
    generator_loss = tf.contrib.seq2seq.sequence_loss(training_logits,sequence_output,masks,average_across_timesteps=False,average_across_batch=False)  
    generator_loss = tf.reduce_sum(generator_loss,axis=1)
    generator_loss = tf.multiply(weight,generator_loss)
    generator_loss = tf.reduce_mean(generator_loss,name='generator_loss')
    classifier_loss = tf.multiply(ratio_c,classifier_loss)
    generator_loss = tf.multiply(ratio_g,generator_loss)
    tv = tf.trainable_variables()
    reg_loss = tf.reduce_sum([tf.nn.l2_loss(v) for v in tv])
    reg_loss_gen = tf.reduce_sum([tf.nn.l2_loss(v) for v in tv if ('generator' in v.name)])
    reg_loss = tf.where(flag,reg_loss,reg_loss_gen)
    loss = tf.add_n([classifier_loss,generator_loss,0.0001*reg_loss],name='loss')      
    return loss

# %%
# def loss(label,training_generator_output,sequence_output,sequence_length,max_sequence_length,ratio_g,weight,flag):
# #     classifier_loss = tf.reduce_mean(tf.contrib.keras.losses.categorical_crossentropy(label,classifier_output),name='classifier_loss')
# #     classifier_loss_freeze = tf.stop_gradient(classifier_loss)
# #     classifier_loss = tf.where(flag,classifier_loss,classifier_loss_freeze)
#     training_logits = tf.identity(training_generator_output.rnn_output,name='training_logits')
#     masks = tf.sequence_mask(sequence_length,max_sequence_length,dtype=tf.float32,name='mask')  
#     generator_loss = tf.contrib.seq2seq.sequence_loss(training_logits,sequence_output,masks,average_across_timesteps=False,average_across_batch=False)  
#     generator_loss = tf.reduce_sum(generator_loss,axis=1)
#     generator_loss = tf.multiply(weight,generator_loss)
#     generator_loss = tf.reduce_mean(generator_loss,name='generator_loss')
# #     classifier_loss = tf.multiply(ratio_c,classifier_loss)
#     generator_loss = tf.multiply(ratio_g,generator_loss)
#     tv = tf.trainable_variables()
#     reg_loss = tf.reduce_sum([tf.nn.l2_loss(v) for v in tv])
#     reg_loss_gen = tf.reduce_sum([tf.nn.l2_loss(v) for v in tv if ('generator' in v.name)])
#     reg_loss = tf.where(flag,reg_loss,reg_loss_gen)
#     loss = tf.add_n([generator_loss,0.0001*reg_loss],name='loss')      
#     return loss

# %%
def optimizer(loss,learning_rate):
    optimizer = tf.train.AdamOptimizer(learning_rate)
    gradients = optimizer.compute_gradients(loss)
    capped_gradients = [(tf.clip_by_value(grad,-5.,5.),var) for grad,var in gradients if grad is not None]
    train_op = optimizer.apply_gradients(capped_gradients)
    return train_op

# %%
def prediction(classifier_output):
    prediction = tf.identity(classifier_output,name='prediction')
    return prediction

# %%
def generation(predicting_generator_output,beamsearch_generator_output):
    greedysearch_sequence = tf.identity(predicting_generator_output.sample_id,name='greedysearch_sequence')
    beamsearch_sequence = tf.identity(beamsearch_generator_output.predicted_ids,name='beamsearch_sequence')
    return greedysearch_sequence,beamsearch_sequence

# %%
embedding_size = 300
train_graph = tf.Graph()
with train_graph.as_default():
    tf.set_random_seed(1)
    with tf.name_scope('inputs'):
        img1,img2,img1id,img2id,label,sequence_input,sequence_output,sequence_length,
        max_sequence_length,batch_size,learning_rate,keep_prob,ratio_c,ratio_g,weight,flag = get_input()
    with tf.name_scope('extractor'):
        with tf.variable_scope('extractor'):
            conv_img1,globalpool_img1 = extractor(img1)
        with tf.variable_scope('extractor',reuse=True):
            conv_img2,globalpool_img2 = extractor(img2)
        with tf.variable_scope('image_to_image_attention'):
            features_img1,attn_conv_img1 = image_to_image_attention(conv_img1,globalpool_img2)
        with tf.variable_scope('image_to_image_attention',reuse=True):
            features_img2,attn_conv_img2 = image_to_image_attention(conv_img2,globalpool_img1)
        with tf.variable_scope('img2vec'):
            extractor_output_img1 = img2vec(attn_conv_img1)
        with tf.variable_scope('img2vec',reuse=True):
            extractor_output_img2 = img2vec(attn_conv_img2)
        with tf.variable_scope('img_embedding'):
            img1_embedding,img2_embedding = img_embedding(img1id,img2id)
        extractor_output = tf.concat([extractor_output_img1,extractor_output_img2,img1_embedding,img2_embedding],axis=1)
        encoder_output = tf.concat([features_img1,features_img2],axis=1)
        encoder_output_freeze = tf.stop_gradient(encoder_output)
        extractor_output_freeze = tf.stop_gradient(extractor_output)
        encoder_output = tf.where(flag,encoder_output,encoder_output_freeze)
        extractor_output = tf.where(flag,extractor_output,extractor_output_freeze)
    with tf.name_scope('classifier'):
        classifier_output = classifier(extractor_output,keep_prob)
    with tf.name_scope('prediction'):
        prediction = prediction(classifier_output)  
    with tf.name_scope('generator'):
        dense_output = keras.layers.Dense(512,activation='tanh',kernel_initializer='glorot_normal')(extractor_output)
        initial_state = (dense_output,)    
        training_generator_output,predicting_generator_output,beamsearch_generator_output = generator(sequence_input,initial_state,
                                                                                                      encoder_output,batch_size,sequence_length,
                                                                                                      max_sequence_length,vocab_size,embedding_size,keep_prob)  
    with tf.name_scope('generation'):
        greedysearch_sequence,beamsearch_sequence = generation(predicting_generator_output,beamsearch_generator_output) 
    with tf.name_scope('loss'):
        loss = loss(classifier_output,label,training_generator_output,sequence_output,sequence_length,
                    max_sequence_length,ratio_c,ratio_g,weight,flag)
    with tf.name_scope('optimizer'): 
        train_op = optimizer(loss,learning_rate)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From <ipython-input-36-7088461ce172>:3: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From <ipython-input-37-c40bf8baad24>:2: GRUCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.GRUCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-38-b0c1df2a2f41>:4: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/seq2seq/python/ops/beam_search_decoder.py:733: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/seq2seq/python/ops/beam_search_decoder.py:1005: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/seq2seq/python/ops/beam_search_decoder.py:1006: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/seq2seq/python/ops/beam_search_decoder.py:784: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
# embedding_size = 300
# train_graph = tf.Graph()
# with train_graph.as_default():
#     tf.set_random_seed(1)
#     with tf.name_scope('inputs'):
#         img1,img2,img1id,img2id,label,sequence_input,sequence_output,sequence_length,max_sequence_length,batch_size,learning_rate,keep_prob,ratio_g,weight,flag = get_input()
#     with tf.name_scope('extractor'):
#         with tf.variable_scope('extractor'):
#             conv_img1,globalpool_img1 = extractor(img1)
#         with tf.variable_scope('extractor',reuse=True):
#             conv_img2,globalpool_img2 = extractor(img2)
#         with tf.variable_scope('image_to_image_attention'):
#             features_img1,attn_conv_img1 = image_to_image_attention(conv_img1,globalpool_img2)
#         with tf.variable_scope('image_to_image_attention',reuse=True):
#             features_img2,attn_conv_img2 = image_to_image_attention(conv_img2,globalpool_img1)
#         with tf.variable_scope('img2vec'):
#             extractor_output_img1 = img2vec(attn_conv_img1)
#         with tf.variable_scope('img2vec',reuse=True):
#             extractor_output_img2 = img2vec(attn_conv_img2)
#         with tf.variable_scope('img_embedding'):
#             img1_embedding,img2_embedding = img_embedding(img1id,img2id)
            
#         extractor_output = tf.concat([extractor_output_img1,extractor_output_img2,img1_embedding,img2_embedding],axis=1)
#         encoder_output = tf.concat([features_img1,features_img2],axis=1)
#         encoder_output_freeze = tf.stop_gradient(encoder_output)
#         extractor_output_freeze = tf.stop_gradient(extractor_output)
#         encoder_output = tf.where(flag,encoder_output,encoder_output_freeze)
#         extractor_output = tf.where(flag,extractor_output,extractor_output_freeze)
#     with tf.name_scope('classifier'):
#         classifier_output = classifier(extractor_output,keep_prob)
#     with tf.name_scope('prediction'):
#         prediction = prediction(classifier_output)  
#     with tf.name_scope('generator'):
#         dense_output = keras.layers.Dense(512,activation='tanh',kernel_initializer='glorot_normal')(extractor_output)
#         initial_state = (dense_output,)    
#         training_generator_output,predicting_generator_output,beamsearch_generator_output = generator(sequence_input,initial_state,encoder_output,batch_size,sequence_length,max_sequence_length,vocab_size,embedding_size,keep_prob)  
#     with tf.name_scope('generation'):
#         greedysearch_sequence,beamsearch_sequence = generation(predicting_generator_output,beamsearch_generator_output) 
#     with tf.name_scope('loss'):
#         loss = loss(label,training_generator_output,sequence_output,sequence_length,max_sequence_length,ratio_g,weight,flag)
#     with tf.name_scope('optimizer'): 
#         train_op = optimizer(loss,learning_rate)

# %% [markdown]
# # Train Model

# %%
with open('dataset/traindata.dat','r') as f:#in traindata, the first col is img_name of top, the second col is img_name of down(i.e. bottom), the third col is comment_index  
    content = f.readlines()
traindata = []
for line in content:
    line = line[:-1].split('\t')
    traindata.append((line[0],line[1],int(line[2])))
traindata
# Out:
# [('210837856', '212370292', 147906),
#  ('210837856', '212370292', 147907),
#  ('210837856', '212370292', 147908),
#  ('217373397', '212370292', 147906),
#  ('217373397', '212370292', 147907),
#  ('217373397', '212370292', 147908),
#  ('210837856', '209881254', 199566),
#  ('206022153', '209881254', 199566),
#  ('210837856', '214725146', 199567),
#  ('90436531', '214725146', 199567),
#  ('217373397', '207520081', 256556),
#  ('217373397', '207520081', 256557),
#  ('217373397', '207520081', 256558),
#  ('217373397', '207520081', 256559),
#  ('217373397', '206282094', 1124),
#  ('217373397', '206282094', 1125),
#  ('217373397', '206282094', 1126),
#  ('217373397', '206282094', 1127),
#  ('217373397', '206282094', 1128),
#  ('217373397', '206282094', 1129),
#  ('217373397', '206282094', 1130),
#  ('217373397', '206282094', 1131),
#  ('217373397', '206282094', 1132),
#  ('217373397', '206282094', 1133),
#  ('217373397', '214358193', 8780),
#  ('217373397', '214606215', 285012),
#  ('217373397', '214606215', 285013),
#  ('217373397', '214606215', 285014),
#  ('217373397', '214606215', 285015),
#  ('219311790', '214606215', 285012),
#  ('219311790', '214606215', 285013),
#  ('219311790', '214606215', 285014),
#  ('219311790', '214606215', 285015),
#  ('219265057', '214606215', 285012),
#  ('219265057', '214606215', 285013),
#  ('219265057', '214606215', 285014),
#  ('219265057', '214606215', 285015),
#  ('217373397', '213039115', 333159),
#  ('165180251', '213039115', 333159),
#  ('217373397', '215999658', 335547),
#  ('217373397', '215999658', 335548),
#  ('217373397', '215999658', 335549),
#  ('217373397', '215999658', 335550),
#  ('217373397', '215999658', 335551),
#  ('217373397', '210543659', 346253),
#  ('217373397', '219353185', 382086),
#  ('217373397', '219353185', 382087),
#  ('217373397', '219353185', 382088),
#  ('217373397', '219046454', 382089),
#  ('217373397', '219046454', 382090),
#  ('217373397', '219046454', 382091),
#  ('217373397', '219046454', 382092),
#  ('217373397', '219046454', 382093),
#  ('219311790', '219046454', 382089),
#  ('219311790', '219046454', 382090),
#  ('219311790', '219046454', 382091),
#  ('219311790', '219046454', 382092),
#  ('219311790', '219046454', 382093),
#  ('210579556', '219046454', 382089),
#  ('210579556', '219046454', 382090),
#  ('210579556', '219046454', 382091),
#  ('210579556', '219046454', 382092),
#  ('210579556', '219046454', 382093),
#  ('217373397', '190753511', 382094),
#  ('217373397', '190753511', 382095),
#  ('217373397', '216851490', 382096),
#  ('211985499', '216851490', 382096),
#  ('217373397', '178141183', 382097),
#  ('217373397', '178141183', 382098),
#  ('217373397', '214046531', 382099),
#  ('217373397', '213153643', 382100),
#  ('217373397', '213153643', 382101),
#  ('217373397', '213153643', 382102),
#  ('211014140', '213153643', 382100),
#  ('211014140', '213153643', 382101),
#  ('211014140', '213153643', 382102),
#  ('217373397', '217989710', 382103),
#  ('217373397', '192893198', 384038),
#  ('217373397', '218188945', 384056),
#  ('217373397', '214340598', 388192),
#  ('217373397', '214340598', 388193),
#  ('217373397', '214340598', 388194),
#  ('217373397', '214340598', 388195),
#  ('217373397', '214340598', 388196),
#  ('217373397', '195372276', 539534),
#  ('217373397', '195372276', 539535),
#  ('217373397', '217419429', 436765),
#  ('217373397', '217419429', 436766),
#  ('217373397', '217419429', 436767),
#  ('217373397', '213815417', 540071),
#  ('217373397', '213815417', 540072),
#  ('217373397', '213815417', 540073),
#  ('217373397', '213815417', 540074),
#  ('217373397', '213815417', 540075),
#  ('217373397', '213815417', 540076),
#  ('217373397', '213815417', 540077),
#  ('217373397', '213815417', 540078),
#  ('217373397', '213016860', 569733),
#  ('219311791', '213016860', 569733),
#  ('219400766', '213016860', 569733),
#  ('217373397', '205301307', 583280),
#  ('217373397', '138010528', 575212),
#  ('217373397', '138010528', 575213),
#  ('217373397', '138010528', 575214),
#  ('210933151', '212370292', 369836),
#  ('91229859', '212370292', 369836),
#  ('214603189', '212370292', 220629),
#  ('202363444', '212370292', 1892),
#  ('202363444', '212370292', 1893),
#  ('202363444', '212370292', 1894),
#  ('202363444', '212370292', 1895),
#  ('214212022', '212370292', 24115),
#  ('214212022', '212370292', 24116),
#  ('214212022', '212370292', 24117),
#  ('214212022', '212370292', 24118),
#  ('212020495', '212370292', 110907),
#  ('212020495', '212370292', 110908),
#  ('108275055', '212370292', 113729),
#  ('108275055', '212370292', 113730),
#  ('108275055', '212370292', 113731),
#  ('108275055', '212370292', 113732),
#  ('108275055', '212370292', 113733),
#  ('108275055', '212370292', 113734),
#  ('108275055', '212370292', 113735),
#  ('108275055', '212370292', 113736),
#  ('215513834', '212370292', 113737),
#  ('215513834', '212370292', 113738),
#  ('215513834', '212370292', 113739),
#  ('206045924', '212370292', 113740),
#  ('206045924', '212370292', 113741),
#  ('215216252', '212370292', 169468),
#  ('207781378', '212370292', 220607),
#  ('188111432', '212370292', 220607),
#  ('211838097', '212370292', 220608),
#  ('211838097', '212370292', 220609),
#  ('211838097', '212370292', 220610),
#  ('211838097', '212370292', 220611),
#  ('90672038', '68523285', 478637),
#  ('90672038', '68523285', 478638),
#  ('90672038', '68523285', 478639),
#  ('90672038', '68523285', 478640),
#  ('90672038', '68523285', 478641),
#  ('90672038', '68523285', 478642),
#  ('90672038', '68523285', 478643),
#  ('90436531', '85856597', 478646),
#  ('90436531', '85856597', 478647),
#  ('90436531', '85856597', 478648),
#  ('90436531', '85856597', 478649),
#  ...]

# %%
tops_qrel_file_path = 'evaluation/devdata_tops_qrel.dat'
tops_trec_file_path = 'evaluation/devdata_tops_trec.dat'
# #downs_qrel_file_path = 'evaluation/devdata_downs_qrel.dat'
# #downs_trec_file_path = 'evaluation/devdata_downs_trec.dat'

# %%
data_path = 'dataset/devdata_tops.dat'
dev_tops_data,tops_orderlist,model_tops_comments,tops_labellist = prepare_evaluation(data_path,comments,int_to_word,word_to_int)

# %%
model_tops_comments
# Out:
# {('108709333',
#   '103003853'): [['hahaha',
#    '<UNK>',
#    '<UNK>',
#    'pear',
#    '<UNK>',
#    '<UNK>',
#    'workout',
#    '<UNK>',
#    '!'], ['<UNK>', '<UNK>', 'pear', 'haha', '.'], ['thanks',
#    ':',
#    ')',
#    'and',
#    'no',
#    'prob',
#    'x',
#    '.'], ['love',
#    'this',
#    'set',
#    '!',
#    'thanks',
#    'for',
#    'the',
#    'tag',
#    'x',
#    '#',
#    'mihstydothis',
#    '.'], ['<UNK>',
#    'tag',
#    'hahaha',
#    '<UNK>',
#    '<UNK>',
#    '<UNK>',
#    'tag',
#    '<UNK>',
#    'kali',
#    '.'], ['love',
#    'so',
#    'much',
#    'this',
#    'style',
#    ',',
#    'so',
#    'classic',
#    'that',
#    'cant',
#    'image',
#    '.']],
#  ('108709333', '116332528'): [['aww', 'thanks', ':', ')', '.'],
#   ['your',
#    'set',
#    'is',
#    'truly',
#    'amazing',
#    ',',
#    '<UNK>',
#    '.',
#    'i',
#    'have',
#    'one',
#    ',',
#    'too',
#    ':',
#    'pls',
#    ',',
#    'have',
#    'a',
#    'look',
#    '.',
#    'xoxo',
#    '.']],
#  ('191278703',
#   '188568826'): [['nice', 'sets', '!', 'join', 'my', 'group', '!']],
#  ('191278703',
#   '193161790'): [['but',
#    'i',
#    'believe',
#    'you',
#    '<UNK>',
#    'must',
#    'write',
#    'iti',
#    'believe',
#    'in',
#    '<UNK>',
#    'anything',
#    '.'], ['<UNK>',
#    '<UNK>',
#    'no',
#    'more',
#    'xd',
#    'i',
#    'have',
#    'no',
#    '<UNK>',
#    'me',
#    'i',
#    'say',
#    '.'], ['<UNK>',
#    'potter',
#    '<UNK>',
#    'are',
#    'my',
#    '<UNK>',
#    "'s",
#    'so',
#    'few',
#    'i',
#    'may',
#    'just',
#    'write',
#    '<UNK>',
#    'mean',
#    'she',
#    'might',
#    "'ve",
#    'planned',
#    'some',
#    'but',
#    'not',
#    'all',
#    '.'], ['i',
#    'just',
#    'heard',
#    'about',
#    'that',
#    'musical',
#    'yesterday',
#    '!',
#    'i',
#    'have',
#    "n't",
#    'listened',
#    'to',
#    'it',
#    'yet',
#    '.'], ['i',
#    "'ve",
#    'discovered',
#    'heathers',
#    'the',
#    'musical',
#    'which',
#    'is',
#    'quite',
#    'amazing',
#    'if',
#    'i',
#    'do',
#    'say',
#    'so',
#    'myself',
#    '.']],
#  ('109212080',
#   '107232732'): [['i',
#    'love',
#    'this',
#    'man',
#    '!',
#    '.amazing',
#    'creation',
#    '!',
#    '*-*',
#    '.'], ['the', 'best', 'actor', 'ever', '!']],
#  ('98197033',
#   '100888847'): [['fabulous',
#    'style',
#    '!',
#    'love',
#    'polka',
#    'dots',
#    '!'], ['totally', 'fab', 'set', 'and', 'style', '!'], ['love',
#    'those',
#    'shoes',
#    '!',
#    'great',
#    'pick',
#    '.'], ['adorable',
#    'set',
#    'dear',
#    'this',
#    'is',
#    'so',
#    'cool',
#    'casual',
#    'to',
#    'wear',
#    'i',
#    'fab',
#    'those',
#    'heels',
#    'and',
#    'shirt',
#    'so',
#    'much',
#    ',',
#    'picked',
#    'up',
#    'cool',
#    'item',
#    'and',
#    'i',
#    'like',
#    'this',
#    'style',
#    'so',
#    'much',
#    '!'], ['simple', '&', 'gorgeous', '.'], ['this',
#    'is',
#    'so',
#    'classy',
#    'chic',
#    'and',
#    'beautiful',
#    '!']],
#  ('98197033',
#   '99596777'): [['at',
#    'first',
#    'i',
#    'believed',
#    'it',
#    'was',
#    'nina',
#    'dobrev',
#    'x',
#    ')',
#    'great',
#    'job',
#    '!',
#    'xoxo',
#    '.']],
#  ('184194929',
#   '186746453'): [['warm', 'and', 'cozy', '!', 'well', 'combined', '!'], ['so',
#    'chic',
#    'combo',
#    'and',
#    'fab',
#    'this',
#    'style',
#    'for',
#    'fall',
#    'mix',
#    '&',
#    'match',
#    'so',
#    'nice',
#    'i',
#    'like',
#    'it',
#    'so',
#    'much',
#    '<',
#    '33',
#    '.'], ['predivno', 'draga', '¤', '.'], ['fabulous',
#    'look',
#    'for',
#    'fall',
#    '!',
#    '¤¤',
#    '.']],
#  ('184194929', '188782811'): [['can', 'you', 'follow', 'me', 'please', '.']],
#  ('171663984',
#   '161815135'): [['awesome',
#    '!',
#    'i',
#    'need',
#    'those',
#    'boots',
#    'today',
#    '!'], ['what',
#    'a',
#    'wonderful',
#    'look',
#    'for',
#    'rainy',
#    'days',
#    '!'], ['cute', 'rainy', 'day', 'style', '!'], ['indeed',
#    'cute',
#    'look',
#    'for',
#    'these',
#    'rainy',
#    'european',
#    'summer',
#    'days',
#    '2016',
#    '.'], ['really',
#    'cute',
#    '...',
#    'love',
#    'the',
#    'stripes',
#    'together',
#    '!'], ['incredibly',
#    'cute',
#    'and',
#    'stylish',
#    '!',
#    ':',
#    'dddd',
#    '.'], ['stylish', 'fashion', 'fab', 'this', 'combo', 'and', 'nice', 'style', '.']],
#  ('171663984', '170484760'): [['cute', 'set', '!', 'enter', '.'],
#   ['какой', 'интересный', 'образ', '!', 'супер', '!'],
#   ['pretty', '!', 'enter', ':', '.']],
#  ('133877855', '140397290'): [['wonderful', 'vibrant', 'color', 'set', '.']],
#  ('206557910',
#   '208300745'): [['great',
#    'set',
#    'great',
#    'mixing',
#    'color',
#    'n',
#    "'",
#    'outfits',
#    '.'], ['love',
#    'it',
#    '.',
#    'thx',
#    'for',
#    'using',
#    'our',
#    'items',
#    '.'], ['ahhh', 'this', 'is', 'so', 'great', '!', 'i', 'just', 'love', 'your', 'layout', 'and', 'all', 'the', 'pieces', 'you', 'chose', '.']],
#  ('206557910', '210519453'): [['perfect', ',', 'so', 'elegant', '!'],
#   ['wow', 'real', 'elegance', '<', '3', '<', '3', '<', '3', '.'],
#   ['woow', 'amazing', '!'],
#   ['outstanding',
#    '!',
#    'love',
#    'the',
#    '<UNK>',
#    'and',
#    'the',
#    'entire',
#    'set',
#    'darling',
#    '!'],
#   ['very',
#    'beautiful',
#    ',',
#    'is',
#    'so',
#    'chic',
#    'set',
#    '!',
#    '\\',
#    '(',
#    ')',
#    '/',
#    '.'],
#   ['so', 'classy', '!'],
#   ['elegant', 'and', 'impressive', '.']],
#  ('206557910',
#   '213910952'): [['np',
#    ',',
#    'i',
#    'look',
#    'forward',
#    'to',
#    'seeing',
#    'more',
#    'of',
#    'your',
#    'work',
#    '.']],
#  ('206557910',
#   '214347454'): [['great',
#    'look',
#    'great',
#    'set',
#    'great',
#    'mixing',
#    'color',
#    'n',
#    "'",
#    'nice',
#    'bow',
#    'shirt',
#    '.'], ['beautiful', 'look', '&', 'color', 'scheme', '!'], ['very',
#    'pretty',
#    'mix',
#    '!'], ['enchanting', 'set', '.'], ['so',
#    'cute',
#    'and',
#    'colorful',
#    '.'], ['lollipop', 'colours', '...', '<UNK>', 'outfit', '.']],
#  ('206557910', '218987301'): [['thank', 'u', '!']],
#  ('208673636', '202998003'): [['yes', 'it', 'is', '.']],
#  ('208673636',
#   '204121420'): [['gorgeous',
#    'looks',
#    'ideas',
#    '!',
#    'love',
#    'the',
#    'red',
#    'color',
#    '!']],
#  ('120653979',
#   '120663731'): [['divine',
#    'work',
#    '!',
#    'love',
#    'this',
#    'colors',
#    '!',
#    'so',
#    'gorgeous',
#    '!'], ['awesome', 'style', 'for', 'fall', '!'], ['fab',
#    'set',
#    '!',
#    'love',
#    'the',
#    'colours',
#    '.'], ['love',
#    'the',
#    'color',
#    'combination',
#    '!',
#    'i',
#    'love',
#    'this',
#    'set',
#    '.'], ['you', 'find', 'the', 'best', 'fashions', '!'], ['soo',
#    'gorgeous',
#    'dear',
#    ':',
#    ')',
#    ')',
#    ')',
#    ')',
#    '.']],
#  ('120653979', '141980519'): [['beautiful', 'mix', '.']],
#  ('83359798',
#   '157699432'): [['cool', 'and', 'fab', 'beautiful', 'look~', '.']],
#  ('83359798', '78795452'): [['amaizng', 'set', '.'],
#   ['this', 'is', 'so', 'original', '!', 'i', 'love', 'it', '.']],
#  ('106318203',
#   '105346606'): [['congrats',
#    'on',
#    'your',
#    '8th',
#    'place',
#    'win',
#    '!',
#    'awesome',
#    'set',
#    '!'], ['so', 'good', '!'], ['oh', 'i', 'love', 'this', '!']],
#  ('106318203', '108105831'): [['soo', 'fab', '!'],
#   ['so', 'pretty', '!', 'love', 'those', 'shoes', '.'],
#   ['this', 'is', 'soo', 'pretty', '!', 'congrats', '!'],
#   ['lovely', 'set', '[', '=', '.'],
#   ['thank',
#    'you',
#    '!',
#    'i',
#    'can',
#    'say',
#    'same',
#    'about',
#    'you',
#    '!',
#    ':',
#    '}',
#    '.'],
#   ['looove', 'this', 'look', 'so', 'much', '!'],
#   ['always',
#    'love',
#    'knowing',
#    'more',
#    'about',
#    'poly',
#    'friends',
#    ':',
#    ')',
#    '.',
#    'great',
#    'look',
#    '!'],
#   ['adorable', 'and', 'lovely', 'cute', 'casual', 'look', '~', '.'],
#   ['congrats', '!', 'você', '<UNK>', ',', 'lindo', 'set', ':', ')', ')', '.'],
#   ['i', 'love', 'this', '!', 'thanks', 'for', 'the', 'tag', ':', ')', '.'],
#   ['so',
#    'many',
#    'sets',
#    'featuring',
#    'jamie',
#    '<UNK>',
#    'haha',
#    'great',
#    'outfit',
#    'of',
#    'course',
#    '.'],
#   ['congrats',
#    'dear',
#    '!',
#    'i',
#    'will',
#    'answer',
#    'these',
#    'questions',
#    'as',
#    'soon',
#    'as',
#    'i',
#    'can',
#    '.'],
#   ['it',
#    "'s",
#    'not',
#    'hard',
#    'to',
#    'know',
#    'with',
#    '<UNK>',
#    'i',
#    "'m",
#    'obsessed',
#    ':',
#    '}',
#    '.'],
#   ['fantastic', 'street', 'style', '!'],
#   ['oh', ',', 'this', 'looks', 'so', 'fantastic', '!'],
#   ['excellent', 'combo', '.'],
#   ['this',
#    'is',
#    'so',
#    'chic',
#    '!',
#    'lovely',
#    'combo',
#    ',',
#    'fantastic',
#    'outfit',
#    '!',
#    'amazing',
#    'work',
#    '!'],
#   ['yay', 'congrats', '!'],
#   ['first',
#    'of',
#    'all',
#    'gorgeous',
#    'outfit',
#    '!',
#    'and',
#    'second',
#    'that',
#    'was',
#    'really',
#    'nice',
#    'to',
#    'read',
#    'and',
#    'learn',
#    'more',
#    'about',
#    'you',
#    '!',
#    ':',
#    'd',
#    '.'],
#   ['i',
#    'loved',
#    'the',
#    'idea',
#    'of',
#    'putting',
#    'two',
#    'white',
#    'pieces',
#    '(',
#    'and',
#    'working',
#    'so',
#    'beautiful',
#    ')',
#    'together',
#    ',',
#    'amazing',
#    '<',
#    '3',
#    '.'],
#   ['love', '<UNK>', 'days', 'of', 'summer', '!'],
#   ['thanks',
#    ',',
#    'well',
#    'i',
#    'hope',
#    'you',
#    'will',
#    'do',
#    'it',
#    'as',
#    'well',
#    ':',
#    '}',
#    '.'],
#   ['how', 'gorgeous', ':', ')', ')', ')', ')', '.'],
#   ['so', 'fresh', 'and', 'pretty', 'styling', 'dear', '!'],
#   ['simple', 'but', 'beautiful', 'and', 'stylish', '!']],
#  ('106318203', '109984766'): [['i', 'followed', ':', ')', '.']],
#  ('37496887',
#   '106881439'): [['you',
#    'say',
#    'that',
#    'you',
#    "'re",
#    'no',
#    'good',
#    'for',
#    'me',
#    '(',
#    '1',
#    ')',
#    'hey',
#    'i',
#    'really',
#    'do',
#    "n't",
#    'know',
#    'you',
#    ',',
#    'but',
#    'i',
#    'love',
#    'your',
#    'sets',
#    'and',
#    'you',
#    "'re",
#    'such',
#    'an',
#    'inspiration',
#    'to',
#    'me',
#    '.'], ['called',
#    'you',
#    'at',
#    'midnight',
#    ',',
#    'not',
#    'in',
#    'my',
#    'right',
#    'mind',
#    '(',
#    '3',
#    ')',
#    'you',
#    'guys',
#    'are',
#    'amazing',
#    'and',
#    'i',
#    'love',
#    'your',
#    'icons',
#    '.']],
#  ('138235913',
#   '138325202'): [['beautiful',
#    'earthy',
#    'tones',
#    '&',
#    'look',
#    '!',
#    'this',
#    'is',
#    'so',
#    'amazing',
#    '!',
#    'xx',
#    '.'], ['fabulous',
#    'sets',
#    ',',
#    'as',
#    'always',
#    '!',
#    'sorry',
#    'that',
#    'i',
#    "'ve",
#    'lost',
#    'your',
#    'last',
#    'creations',
#    ',',
#    'but',
#    'lately',
#    'i',
#    "'m",
#    'a',
#    'little',
#    'absent',
#    'from',
#    'polyvore',
#    '!'], ['gorgeous', 'chic', 'style', ',', 'amazing', 'layout', '!'], ['soo',
#    'pretty',
#    '.'], ['i',
#    'like',
#    'the',
#    'modern',
#    'feel',
#    'in',
#    'the',
#    'layout',
#    'and',
#    'how',
#    'classy',
#    'is',
#    'the',
#    'outfit',
#    '<',
#    '3have',
#    'fun',
#    'at',
#    'the',
#    'concert',
#    ':',
#    ')',
#    '.'], ['slick', ',', 'sleek', 'n', 'chic', ':', ')', ')', '.'], ['perfect',
#    'styling',
#    'and',
#    'amazing',
#    'lay-out',
#    '.'], ['excellent',
#    '!',
#    'love',
#    'the',
#    'color',
#    'palette',
#    '!'], ['elegant', 'and', 'chic', 'outfit', ',', 'dear', '!'], ['wonderful',
#    'style',
#    '!',
#    'so',
#    'feminine',
#    'and',
#    'elegant',
#    '.'], ['magnifique', '!', '*`', '<UNK>', 'set', '!'], ['so',
#    'pretty',
#    'and',
#    'such',
#    'a',
#    'great',
#    'style',
#    'too',
#    'sweetie',
#    'i',
#    'totally',
#    'like',
#    'it',
#    'esp',
#    'heels',
#    '!'], ['fabulously', 'unique', 'and', 'chic', 'styling', '!'], ['gorgeous',
#    'and',
#    'amazing',
#    'chic',
#    'style~',
#    '.'], ['you',
#    'do',
#    "n't",
#    'have',
#    'to',
#    'apologize',
#    'we',
#    'all',
#    'have',
#    'busy',
#    'times',
#    'very',
#    'beautiful',
#    'set',
#    ',',
#    'anyway',
#    '!'], ['classy', 'elegant', 'an', 'lovely..'], ['modern',
#    'elegance',
#    '!'], ['beautiful', 'combo', 'dear', ':', ')', 'lovee', '.'], ['have',
#    'a',
#    'fab',
#    'weekend',
#    '-',
#    'lovely',
#    'look',
#    '!'], ['gorgeous',
#    'look',
#    'dear',
#    'and',
#    'chic',
#    'styling',
#    '!',
#    'enjoy',
#    'your',
#    'concert',
#    'and',
#    'see',
#    'you',
#    '<UNK>',
#    '.'], ['love',
#    'this',
#    'beautiful',
#    ',',
#    'classy',
#    'look',
#    '!',
#    'fabulous',
#    'items',
#    '!'], ['great', 'enjoy', '!'], ['aww',
#    'i',
#    'will',
#    'miss',
#    'you',
#    'dear~',
#    'amazing',
#    'set',
#    '!'], ['no',
#    'apologies',
#    'necessary',
#    ',',
#    'i',
#    'have',
#    'difficulty',
#    'keeping',
#    'up',
#    'as',
#    'well',
#    '!'], ['no', 'apologies', 'needed', '!', 'enjoy', '!'], ['amazing',
#    'set',
#    '!',
#    'hope',
#    'you',
#    'had',
#    'a',
#    'great',
#    'time',
#    '!'], ['wonderful',
#    'outfit',
#    '.',
#    'very',
#    'feminine',
#    'set',
#    '.',
#    'love',
#    'the',
#    'colors',
#    '!'], ['gorgeous', '!', 'enjoy', 'yourself', '!']],
#  ('138235913', '144425509'): [['i', 'know', 'right', '!']],
#  ('186040283', '179745267'): [['so', 'beautiful', '!', '=', ')', '.']],
#  ('186040283',
#   '190879308'): [['congratulations',
#    '.',
#    'brilliant',
#    'set',
#    '.'], ['gorgeous', 'my', 'dear', 'friend', 'congrats', 'to', 'you', 'my', 'friend', '.'], ['dazzled',
#    'by',
#    'this',
#    '.'], ['woohoo',
#    '!',
#    'congratulations',
#    'on',
#    'ts',
#    ',',
#    'my',
#    'friend',
#    '!'], ['congrats', '!', 'xo', '.'], ['congrats', 'on', 'ts', '!'], ['so',
#    'gorgeous',
#    'and',
#    'fab',
#    'this',
#    'creation',
#    'too',
#    'great',
#    'set',
#    '!'], ['love',
#    'the',
#    'sequins',
#    '!',
#    'nice',
#    'set',
#    '&',
#    'congratulations',
#    '!',
#    ':',
#    ')',
#    '.'], ['beautiful', 'ensemble', '!', 'congratulations', '.'], ['cool',
#    '!',
#    'ts',
#    'congrats',
#    '!'], ['congratulations',
#    'on',
#    'your',
#    'beautiful',
#    'top',
#    'fashion',
#    'set',
#    '.']],
#  ('186040283', '197041634'): [['aso', 'amazing', '!'],
#   ['i', 'just', 'lov', 'this', '.', 'my', 'mins', '.'],
#   ['aww', 'thanks', '.']],
#  ('186040283',
#   '207722756'): [['great',
#    'look',
#    'great',
#    'set',
#    'great',
#    'outfits',
#    'n',
#    "'",
#    'nice',
#    'tshirt',
#    '.'], ['outstanding', 'set', '.']],
#  ('112229540', '106117054'): [['ahaha', 'thankyou', 'dear', ':', ')', '.'],
#   ['congrats', 'on', 'your', 'win', '!'],
#   ['wow',
#    '!',
#    'looks',
#    'like',
#    'a',
#    'top',
#    'set',
#    'candidate',
#    '#',
#    'amazing',
#    '.'],
#   ['congrats',
#    'on',
#    'the',
#    'best',
#    'sets',
#    'of',
#    'august',
#    'contest',
#    'dear',
#    ',',
#    'such',
#    'a',
#    'sweet',
#    'romantic',
#    'look',
#    ';',
#    'd',
#    '.'],
#   ['thank', 'you', 'so', 'much', 'guys', '!', ':', ')', '.'],
#   ['gorgeous', 'design', '!', 'congrats', '!', ':', ')', '.']],
#  ('112229540',
#   '112229531'): [['never',
#    'can',
#    'go',
#    'wrong',
#    'with',
#    '#',
#    'chanel',
#    'in',
#    'general',
#    '.'], ['wow', 'again', '!', 'this', 'is', 'beautiful', '!'], ['classy',
#    'and',
#    'fabulous',
#    '!'], ['very', 'beautiful', 'vintage', '.'], ['absolutely',
#    'lovely',
#    '!',
#    'i',
#    'wanted',
#    'to',
#    'thank',
#    'you',
#    ',',
#    'you',
#    '<UNK>',
#    'my',
#    'love',
#    'of',
#    'vintage',
#    'fashion',
#    '!'], ['fantastic', '!', 'so', 'very', 'sophisticated', '!'], ['a',
#    'classic',
#    'never',
#    'goes',
#    'out',
#    'of',
#    'style',
#    '!',
#    'excellent',
#    'work',
#    'so',
#    'classy',
#    ',',
#    'so',
#    'elegant',
#    'p',
#    '!']],
#  ('47533511',
#   '40675598'): [['used',
#    'to',
#    'be',
#    'one',
#    'of',
#    'my',
#    'favorite',
#    'series',
#    ':',
#    ')',
#    ')',
#    '.'], ['totally',
#    'agree',
#    'with',
#    'you',
#    '!',
#    '<UNK>',
#    'is',
#    'the',
#    'shit',
#    ',',
#    'love',
#    'it',
#    '!',
#    'and',
#    'your',
#    'set',
#    'is',
#    'beautiful',
#    ',',
#    'as',
#    'usual',
#    '!',
#    ':',
#    ')',
#    '.'], ['wow',
#    'gorgeous',
#    'set',
#    'sweetie',
#    '!',
#    'i',
#    'adore',
#    'everything',
#    'of',
#    'it',
#    '!',
#    '*-*',
#    'and',
#    'congrats',
#    'on',
#    'top',
#    'sets',
#    '!',
#    '^-^',
#    '.'], ['amazing',
#    '!',
#    'so',
#    'chic',
#    'and',
#    'cool',
#    '!',
#    'love',
#    'the',
#    'look',
#    ',',
#    'all',
#    'those',
#    'different',
#    'colours',
#    'and',
#    'textures',
#    'mix',
#    'so',
#    'well',
#    '!']],
#  ('121608640',
#   '111944922'): [['i',
#    'do',
#    "n't",
#    'mind',
#    'as',
#    'long',
#    'as',
#    'you',
#    'give',
#    'credit',
#    'and',
#    'it',
#    'is',
#    "n't",
#    'identical',
#    'and',
#    'thank',
#    'you',
#    '.'], ['i',
#    'love',
#    'this',
#    'set',
#    '!',
#    'is',
#    'it',
#    'ok',
#    'if',
#    'i',
#    'do',
#    'something',
#    'like',
#    'this',
#    '.'], ['super',
#    'cute',
#    '!',
#    'congrats',
#    '.',
#    '<UNK>',
#    'my',
#    '-',
#    '>',
#    'xoxo',
#    '.']],
#  ('121608640',
#   '121851612'): [['you',
#    'should',
#    'entire',
#    'this',
#    'set',
#    'in',
#    '#',
#    '<UNK>',
#    '.'], ['lovely',
#    'pink',
#    '<UNK>',
#    'sweater',
#    'with',
#    'white',
#    '!',
#    'so',
#    'pretty',
#    'and',
#    'feminine',
#    'and',
#    'the',
#    'floral',
#    'sneakers',
#    'are',
#    'very',
#    'cute',
#    'with',
#    'this',
#    'lovely',
#    'feminine',
#    'outfit',
#    '!']],
#  ('90774632', '89622870'): [['fab', 'autumn', 'set', '!'],
#   ['brilliant', 'style', 'x', '.'],
#   ['gorgeous', 'outfit', '!', 'xo', '.'],
#   ['congrats', 'on', 'top', 'sets', 'sweetie', '!', 'xxo', '.'],
#   ['fantastic', 'fall', 'look', '!', 'congrats', ':', ')', '.'],
#   ['love',
#    'the',
#    'skirt',
#    ',',
#    'love',
#    'the',
#    'bag',
#    ',',
#    'love',
#    'it',
#    'all',
#    '!',
#    'fab',
#    'job',
#    '!'],
#   ['such', 'a', 'stunning', 'look', '!', 'congratualtions', '!'],
#   ['congrats', 'on', 'a', 'stylish', 'top', 'set', 'darling', '!'],
#   ['fab', 'set', '!', 'congrats', '!', '#', 'topset', ':', ')', ')', '.'],
#   ['so',
#    'stylish',
#    '!',
#    'love',
#    'the',
#    'look',
#    'and',
#    'that',
#    'skirt',
#    'is',
#    'just',
#    'divine',
#    '!'],
#   ['so',
#    'beautiful',
#    '!',
#    'i',
#    'love',
#    'the',
#    'skirt',
#    'and',
#    'the',
#    'bag',
#    '!'],
#   ['beautiful', 'fall', 'outfit', 'and', 'amazing', 'background', '!'],
#   ['just', 'beautiful', 'autumn', 'outfit', '!', ';', ')', '.'],
#   ['awesome', 'tops', '!'],
#   ['congrats', '~', 'gorgeous', '!'],
#   ['amazing',
#    'set',
#    'and',
#    'styling',
#    'sweetie',
#    '!',
#    'congrats',
#    'on',
#    'a',
#    'well',
#    'deserved',
#    'top',
#    'sets',
#    ':',
#    ')',
#    ')',
#    ')',
#    ')',
#    ')',
#    '.']],
#  ('7573897',
#   '22686504'): [['love',
#    'it',
#    '!',
#    'do',
#    'you',
#    'like',
#    'my',
#    'sets',
#    '.'], ['if', 'that', 'is', 'fake', 'fur', 'coat', ',', 'i', 'love', 'it', '!', 'but', 'if', 'animal', 'skin', 'or', 'do', 'not', 'want', 'it', 'free', '!'], ['hey',
#    'my',
#    'dear',
#    'this',
#    'outfit',
#    'is',
#    'fantastic',
#    '...',
#    'wish',
#    'you',
#    'all',
#    'the',
#    'best',
#    'in',
#    'new',
#    '<UNK>',
#    'ya',
#    '!'], ['so',
#    'so',
#    'cute',
#    ',',
#    'and',
#    'individual',
#    'with',
#    'the',
#    'fur',
#    'addition',
#    ':',
#    'd',
#    'xx',
#    '.'], ['happy',
#    'holidays',
#    'my',
#    'dear',
#    '!',
#    'so',
#    'wonderful',
#    'to',
#    'see',
#    'your',
#    'gorgeous',
#    'sets',
#    'again',
#    '!'], ['happy',
#    'new',
#    'year',
#    'darling',
#    '!',
#    'i',
#    'wish',
#    'you',
#    'all',
#    'the',
#    'best',
#    '!',
#    'great',
#    'set',
#    '!'], ['this', 'is', 'one', 'superb', 'set', '!'], ['so',
#    'cuuute',
#    '!'], ['love', 'all', 'the', 'grey', 'with', 'the', 'fur', '!']],
#  ('70591939', '70590584'): [['thank', 'you', 'girls', '!']],
#  ('70591939', '71972310'): [['this', 'is', 'gorggg', '.'],
#   ['amazing', 'job', '!', 'love', 'this', 'song', '.'],
#   ['sjajan',
#    'set',
#    ',',
#    '<UNK>',
#    'kombinacija',
#    'je',
#    'uvek',
#    'tako',
#    'dobra',
#    '...'],
#   ['stunning', ',', 'love', 'the', 'heels', '!'],
#   ['wow',
#    ',',
#    'kakav',
#    'set',
#    '!',
#    'jako',
#    'lijepa',
#    'i',
#    'elegantna',
#    'crno',
#    'bijela',
#    'kombinacija',
#    '!',
#    'slike',
#    'i',
#    'detalji',
#    'su',
#    '<UNK>',
#    ',',
#    'draga',
#    '.'],
#   ['estitke',
#    'na',
#    'jo',
#    'jednom',
#    'setu',
#    'danas',
#    '!',
#    'fantastine',
#    'fotke',
#    'i',
#    'divan',
#    'styling',
#    '!',
#    'haljina',
#    'je',
#    'divna',
#    '!'],
#   ['yes', ',', 'congrats', ':', ')', ')', 'xx', '.'],
#   ['alluring', 'and', 'lovely', '!'],
#   ['congrats', 'again', 'dear', '!'],
#   ['top', 'set', 'dearest', '!', 'congratulations', '!'],
#   ['congrats', 'dear~', '.'],
#   ['wooow', 'sweety', '<UNK>', 'lov', 'this', '..', 'kisses', '.'],
#   ['cestitam', 'draga', '!'],
#   ['2', 'sets', 'of', 'top', 'sets', '!', 'congrats', '!'],
#   ['wow', '.', 'so', 'good', '.'],
#   ['wooooow',
#    'draga',
#    'ovo',
#    'je',
#    'zaista',
#    'fenomenalno',
#    '!',
#    'obozavam',
#    'svaki',
#    '<UNK>',
#    'tu',
#    'sve',
#    'je',
#    '<UNK>',
#    '!',
#    'kombinacija',
#    'je',
#    'predivna',
#    'obozavam',
#    'je',
#    '!',
#    '<',
#    '3',
#    '<',
#    '3',
#    '<',
#    '3',
#    '.'],
#   ['totally', 'stunning', '!'],
#   ['wow', ',', 'congrats', 'again', ',', 'gorgeous', '!'],
#   ['amazing', 'black', 'and', 'white', 'set', ':', ')', ')', ')', '.'],
#   ['second',
#    'top',
#    'set',
#    'for',
#    'today',
#    '!',
#    'congratulations',
#    'again',
#    '!',
#    'you',
#    'totally',
#    'deserved',
#    'it',
#    '!',
#    'xx',
#    '.'],
#   ['congrats',
#    'to',
#    'you',
#    'again',
#    '(',
#    '2nd',
#    ')',
#    'on',
#    'top',
#    'sets',
#    '!'],
#   ['divan', 'set', ',', 'style', 'je', 'super', '!'],
#   ['amazing',
#    'set',
#    '!',
#    'you',
#    'deserve',
#    'the',
#    'top',
#    'set',
#    'darling',
#    '!'],
#   ['wow', '!', 'breathtakingly', 'gorgeous', '!'],
#   ['congrats', 'on', 'top', 'sets', 'sweetie', '!', 'xxo', '.']],
#  ('20772422',
#   '126052274'): [['sheinside',
#    'contest',
#    '!',
#    'it',
#    ',',
#    'please',
#    'join',
#    'dear',
#    '!']],
#  ('118531931',
#   '114704389'): [['hi', 'thanks', 'for', 'liking', 'my', 'set', '.']],
#  ('118531931',
#   '117725919'): [['really',
#    'nice',
#    'color',
#    'scheme',
#    'you',
#    'used',
#    'in',
#    'this',
#    'set',
#    '<',
#    '3',
#    '.'],
#   ['love', 'her', 'lorde', 'pretty', 'set', '.']],
#  ('165266604', '166291099'): [['thank', 'you', 'fr', '.'],
#   ['me', 'too', '.', 'so', 'fly', '.'],
#   ['loving', 'this', 'look', '!'],
#   ['thank', 'you', 'sis', '.'],
#   ['thank', 'you', 'fr', '.', 'i', 'love', 'it', 'too', '.']],
#  ('61132151',
#   '55020284'): [['athanks',
#    ',',
#    ',',
#    'i',
#    "'ll",
#    'defiantly',
#    'do',
#    'more',
#    '<',
#    '<UNK>',
#    '.'], ['this',
#    'looks',
#    'great',
#    'can',
#    'you',
#    'do',
#    'more',
#    'outfits',
#    'i',
#    'love',
#    'them',
#    '.']],
#  ('61132151',
#   '57116775'): [['athanks',
#    ',',
#    ',',
#    'i',
#    "'ll",
#    'defiantly',
#    'do',
#    'more',
#    '<',
#    '<UNK>',
#    '.'], ['this',
#    'looks',
#    'great',
#    'can',
#    'you',
#    'do',
#    'more',
#    'outfits',
#    'i',
#    'love',
#    'them',
#    '.']],
#  ('61132151',
#   '65198854'): [['athanks',
#    ',',
#    ',',
#    'i',
#    "'ll",
#    'defiantly',
#    'do',
#    'more',
#    '<',
#    '<UNK>',
#    '.'], ['this',
#    'looks',
#    'great',
#    'can',
#    'you',
#    'do',
#    'more',
#    'outfits',
#    'i',
#    'love',
#    'them',
#    '.']],
#  ('61132151',
#   '67006693'): [['athanks',
#    ',',
#    ',',
#    'i',
#    "'ll",
#    'defiantly',
#    'do',
#    'more',
#    '<',
#    '<UNK>',
#    '.'], ['this',
#    'looks',
#    'great',
#    'can',
#    'you',
#    'do',
#    'more',
#    'outfits',
#    'i',
#    'love',
#    'them',
#    '.']],
#  ('61132151',
#   '821709'): [['amazing',
#    'outfit',
#    '!',
#    'i',
#    'love',
#    'every',
#    'single',
#    'item',
#    '...',
#    '.',
#    'love',
#    'itttt',
#    '!',
#    'and',
#    'the',
#    'layout',
#    'is',
#    'perfect',
#    'as',
#    'always',
#    '!'], ['gorgeous',
#    ',',
#    'incredible',
#    'skirt',
#    'omg',
#    ':',
#    ')',
#    '.'], ['amazing', '!', 'so', 'so', 'hübsch', '!', 'wooooow', '.'], ['again',
#    '...',
#    'love',
#    'the',
#    'outfit',
#    '.'], ['ooooh',
#    '!',
#    ':',
#    '**',
#    'you',
#    'are',
#    'to',
#    'cute',
#    'honey',
#    ':',
#    'd',
#    'thank',
#    'you',
#    '<',
#    '33thank',
#    'you',
#    'soo',
#    'much',
#    'lovely',
#    '(',
#    ':',
#    '.']],
#  ('37810557', '36793807'): [['sehr', 'hübsch', '.']],
#  ('37810557', '44479205'): [['meraviglioso', 'lavoro', '!'],
#   ['lovely',
#    'set',
#    ',',
#    'dear',
#    '!',
#    'i',
#    'hope',
#    'you',
#    "'re",
#    'having',
#    'a',
#    'great',
#    'week',
#    '!'],
#   ['awesome',
#    'rebel',
#    'style',
#    ',',
#    'dearest',
#    '...',
#    'impeccable',
#    '...',
#    'superb',
#    'design',
#    'and',
#    'style',
#    '!'],
#   ['what', 'a', 'lovely', 'outfit', 'sweetie', '=', ')', ')', '.'],
#   ['fantastic', ',', 'dress', 'is', 'so', 'adorable', '!'],
#   ['fab', 'dear', '!', 'the', 'jacket', 'is', 'to', 'die', 'for', '!'],
#   ['gorgeous',
#    ':',
#    ')',
#    'love',
#    'the',
#    'dress',
#    'and',
#    'the',
#    'prada',
#    'shoes',
#    ':',
#    ')',
#    '.'],
#   ['inspired', 'fashion', '!'],
#   ['extremely', 'chic', '!', 'love', 'it', '.'],
#   ['all',
#    'these',
#    'looks',
#    'are',
#    'so',
#    'cool',
#    '--',
#    'military',
#    'chic',
#    'meets',
#    'the',
#    'schoolgirl',
#    'look',
#    '!'],
#   ['gorgeous', '!', 'love', 'the', 'jacket', '!'],
#   ['love', 'this', 'one', '.'],
#   ['oh',
#    'i',
#    'love',
#    'school',
#    'look',
#    'chic',
#    '.',
#    'love',
#    'the',
#    'pictures',
#    'and',
#    'the',
#    'outfits',
#    'you',
#    'put',
#    'together',
#    'are',
#    'also',
#    'amazing',
#    '!',
#    'totally',
#    'cool',
#    '!',
#    'love',
#    'this',
#    'set',
#    'so',
#    'sooo',
#    'much',
#    '!',
#    '<',
#    '3',
#    '<',
#    '3',
#    '.'],
#   ['a',
#    'great',
#    'selection',
#    'of',
#    'fabulous',
#    'outfit',
#    '!',
#    'love',
#    'the',
#    'white',
#    'dress',
#    '!'],
#   ['love', 'this', 'dress', '!', 'girly', 'fun', '!']],
#  ('212368716',
#   '142157394'): [['stylish',
#    'and',
#    'fab',
#    'outfit',
#    'items',
#    'here',
#    'great',
#    'set',
#    '~',
#    '.']],
#  ('173528500',
#   '173329297'): [['love',
#    'the',
#    'neutral',
#    'palette',
#    '!',
#    'wonderful',
#    'casual',
#    'style',
#    'xx',
#    '.'], ['sensational', 'look', '.'], ['love', 'the', 'colours', '!'], ['pls',
#    'join',
#    '.'], ['beautifully', 'styled', '!'], ['amazing',
#    'nude',
#    'colors',
#    'here',
#    '!',
#    'love',
#    '!']],
#  ('173528500',
#   '176722474'): [['congratulations', 'on', 'your', 'set', 'win', '.']],
#  ('89453554', '82188396'): [['this', 'looks', 'fantastic', '!'],
#   ['super', 'hyper', 'mega', 'fabulous', ',', 'dear', '!'],
#   ['exquisite', 'creation', '.'],
#   ['stunning', 'set', ',', 'sweetie', '!', 'perfectly', 'styled', 'look', '!'],
#   ['this',
#    'is',
#    'so',
#    'cute',
#    'angel',
#    '!',
#    'happy',
#    'weekend',
#    'to',
#    'you',
#    'sweetheart',
#    '!']],
#  ('161184715', '156854457'): [['gorg', 'pastel', '!']],
#  ('161184715',
#   '175024300'): [['congratulations',
#    '!',
#    'very',
#    'deserving',
#    '!'], ['splendid', '!', 'ts', 'congrats', '!'], ['so',
#    'lovely',
#    'and',
#    'elegant',
#    '!'], ['insanely', 'fabulous', '.'], ['congratulations',
#    '☆☆☆☆☆',
#    '.'], ['so',
#    'lovely',
#    '!',
#    'love',
#    'the',
#    'color',
#    'combination',
#    '!'], ['totally', 'chic', '!'], ['on',
#    'point',
#    '!',
#    'perfect',
#    'outfit',
#    '.'], ['awesome', '!', 'love', 'the', 'colours', '!'], ['congratulations',
#    'on',
#    'ts',
#    '!'], ['superb', 'classy', 'look', '!'], ['simply',
#    'beautiful',
#    '!',
#    ')',
#    '.']],
#  ('203251654', '199937584'): [['sassy', 'cute', '.']],
#  ('218065303',
#   '219428095'): [['thanks',
#    'my',
#    'wonderful',
#    'friend',
#    ':',
#    ')',
#    '.'], ['awe', 'thank', 'you', 'lysm', '.'], ['not',
#    'as',
#    'cute',
#    'as',
#    'youuuuuuuuuu',
#    '<',
#    '3',
#    '.'], ['miss', 'you', 'so', 'much', '.'], ['splendid',
#    ';',
#    'love',
#    'the',
#    'backpack',
#    '!'], ['i',
#    "'m",
#    'glad',
#    'you',
#    "'re",
#    'back',
#    'my',
#    'pretty',
#    'little',
#    'stylist',
#    '<',
#    '3',
#    'what',
#    'a',
#    'lovely',
#    'set',
#    '.'], ['perfect', 'look', 'for', 'fall', '!'], ['miss',
#    'youuuuuuuuuu',
#    '<',
#    '3',
#    '.']],
#  ('24042955', '158103282'): [['ah', 'love', 'it', '!'],
#   ['luv', 'it', '!', 'so', 'beautiful', '!'],
#   ['your', 'welcome', ',', 'sweetheart', '!'],
#   [',', 'aw', 'thank', 'you', '!'],
#   ['aw', 'thanks', '!'],
#   ['my',
#    'wonderfully',
#    'weird',
#    'girls',
#    '(',
#    'part',
#    '1',
#    ')',
#    "''",
#    'she',
#    'helps',
#    'me',
#    'put',
#    'the',
#    'we',
#    'in',
#    'weird',
#    "''",
#    'to',
#    'join',
#    'my',
#    'taglist',
#    '!'],
#   ['my',
#    'wonderfully',
#    'weird',
#    'girls',
#    '(',
#    'part',
#    '2',
#    ')',
#    "''",
#    'she',
#    'helps',
#    'me',
#    'put',
#    'the',
#    'we',
#    'in',
#    'weird',
#    "''",
#    'to',
#    'join',
#    'my',
#    'taglist',
#    '!'],
#   [',', 'athanks', 'so', 'much', '!'],
#   [',',
#    'and',
#    ',',
#    'aww',
#    'thank',
#    'you',
#    'so',
#    'much',
#    'guys',
#    '!',
#    'it',
#    'means',
#    'a',
#    'lot',
#    '!']],
#  ('24042955', '95467846'): [['fab', 'edgy', 'girly', 'look', '!']],
#  ('62978184', '46320176'): [['yay', '!', 'congratulations', '!'],
#   ['fabulous', ',', 'wow', 'iove', 'this', '!']],
#  ('62978184',
#   '63821743'): [['sooo',
#    'amaizng',
#    'set',
#    'and',
#    'great',
#    'style',
#    'sweetie',
#    '.'], ['lovely', ',', 'great', 'shirt', '!']],
#  ('176616092', '169826259'): [['so', 'amazing', 'dearest', '.'],
#   ['wow..this',
#    'is',
#    'so',
#    'cute',
#    '<',
#    '3',
#    'love',
#    'this',
#    'look',
#    'daer',
#    '<',
#    '3',
#    'very',
#    'lovely',
#    '.'],
#   ['trendy',
#    'fashion',
#    'and',
#    'such',
#    'a',
#    'nice',
#    'style',
#    'for',
#    'this',
#    'summer',
#    '!']],
#  ('176616092', '178862192'): [['splendid', 'weekend', 'style', '!', 'x', '.'],
#   ['adorable',
#    'for',
#    'casual',
#    'such',
#    'a',
#    'nice',
#    'style',
#    'and',
#    'fab',
#    'for',
#    'all',
#    'details',
#    'here',
#    '~~',
#    '.'],
#   ['hey',
#    'sweetie',
#    ':',
#    ')',
#    'love',
#    'this',
#    'look',
#    'so',
#    'much',
#    'very',
#    'cool',
#    'and',
#    'something',
#    'to',
#    'wear',
#    'everyday',
#    'great',
#    'job',
#    'darling',
#    '.']],
#  ('10355473',
#   '41389835'): [['thank',
#    'you',
#    'friends',
#    'so',
#    'much',
#    'for',
#    'your',
#    'sweet',
#    'comments',
#    '!',
#    'hope',
#    'you',
#    'are',
#    'all',
#    'enjoying',
#    'your',
#    'holiday',
#    '~',
#    'xoxo',
#    '~',
#    '.'], ['nice',
#    'composition',
#    '..good',
#    'model',
#    'choice',
#    'too',
#    'love',
#    'this',
#    '!'], ['sooo',
#    'amaizng',
#    'set',
#    'and',
#    'great',
#    'style',
#    'sweetie',
#    '.'], ['beautiful', 'work', 'dear', '.'], ['sounds',
#    'perfect',
#    ':',
#    ')',
#    'this',
#    'is',
#    'wonderful',
#    '!'], ['lovely',
#    'set',
#    '!',
#    'your',
#    'styling',
#    'is',
#    'perfection',
#    '!'], ['happy', 'holidays', '!', 'best', 'wishes', '!', 'xox', '.'], ['lovely',
#    'set~',
#    '.'], ['this', 'is', 'fabulous', 'my', 'dear', '!', 'xxo', '.'], ['wow',
#    'this',
#    'is',
#    'so',
#    'chic',
#    '!',
#    'love',
#    'the',
#    'booties',
#    'and',
#    'bag',
#    '!',
#    'this',
#    'is',
#    'so',
#    'stylish',
#    '!'], ['beautifully', 'styled', '!'], ['so',
#    'good',
#    'to',
#    'see',
#    'you',
#    'back',
#    '!',
#    'this',
#    'is',
#    'beautiful',
#    '!'], ['wow',
#    '!',
#    'congrats',
#    'on',
#    'your',
#    'first',
#    'place',
#    'win',
#    'my',
#    'friend',
#    '!'], ['amazing',
#    'set',
#    ',',
#    'i',
#    'love',
#    'the',
#    'way',
#    'the',
#    'bag',
#    'ties',
#    'it',
#    'all',
#    'together',
#    ',',
#    'i',
#    'love',
#    'it',
#    '!',
#    'wishing',
#    'you',
#    'a',
#    'wonderful',
#    'new',
#    'year',
#    '!',
#    'xoxo',
#    '.'], ['amazing',
#    'style',
#    '&',
#    'pics',
#    '...',
#    'love',
#    '!',
#    ':',
#    ')',
#    ')',
#    '.'], ['happy', '2013', 'hugs', '.'], ['nice', 'job', '.'], ['wow',
#    'dear',
#    'this',
#    'is',
#    'so',
#    'chic',
#    'adore',
#    'this',
#    'style',
#    'i',
#    'love',
#    'it',
#    'so',
#    'much',
#    'always',
#    'great',
#    'set',
#    'you',
#    "'ve",
#    'best',
#    'style',
#    'too',
#    'sweetie',
#    '<',
#    '333',
#    '.'], ['so',
#    'glad',
#    'you',
#    'are',
#    'home',
#    'safe',
#    'and',
#    '<UNK>',
#    'this',
#    'new',
#    'set',
#    '.'], ['wonderful',
#    'set',
#    'and',
#    'styling',
#    'dear',
#    'friend',
#    ':',
#    ')',
#    ')',
#    ')',
#    '.'], ['i', 'loveee', 'her', 'hair', '!'], ['wow',
#    ',',
#    'fantastic',
#    'style',
#    '!',
#    'love',
#    'the',
#    'bag',
#    '!'], ['wow',
#    ',',
#    'gorgeous',
#    'elegant',
#    'winterlook',
#    ',',
#    'adore',
#    'the',
#    'pretty',
#    'coat',
#    '!'], ['très',
#    'chic',
#    '!',
#    'i',
#    'love',
#    'your',
#    'style',
#    '!',
#    '°',
#    '.'], ['happy', 'holidays', 'to', 'you', '-', 'this', 'is', 'a', 'fabulous', 'set', ',', 'looks', 'so', 'cozy', 'chic', '!', ':', 'd', '.']],
#  ('10355473',
#   '8385604'): [['love', 'the', 'cream', 'with', 'the', 'pink', '!'], ['bel',
#    'vestito',
#    '!',
#    'complimenti',
#    ':',
#    'd',
#    '.'], ['i', 'want', 'that', 'dress', '!'], ['pretty',
#    'set..',
#    ':',
#    'd',
#    '.']],
#  ('65329090', '65974904'): [['такой', 'свежий', 'и', 'элегантный', 'лук', '!'],
#   ['soo',
#    'sweet',
#    'and',
#    'beautiful',
#    'dear',
#    '!',
#    'love',
#    'the',
#    'print',
#    'on',
#    'the',
#    'skirt',
#    '!'],
#   ['fab', 'der', '!'],
#   ['fantastic', 'entry', '!', 'good', 'luck', '!', ':', ')', '.'],
#   ['awww',
#    'sweetie',
#    'this',
#    'is',
#    'so',
#    'cool',
#    'style',
#    'really',
#    'love',
#    'it',
#    'always',
#    'perfect',
#    ':',
#    ')',
#    ')',
#    ')',
#    '.'],
#   ['чудесный', 'сет', '!'],
#   ['потрясающе', '!', 'очень', '<UNK>', 'сочетание', 'цветов', '!'],
#   ['wooow',
#    'sweety',
#    'this',
#    'is',
#    'uber',
#    'cute',
#    'and',
#    'chic..',
#    'i',
#    'would',
#    'wear',
#    'it',
#    'right',
#    'now',
#    '.',
#    ':',
#    ')',
#    ')',
#    ')',
#    '.'],
#   ['woooow', '...', '.so', 'cool', 'darling', '!'],
#   ['lovely', 'set', '!', 'please', ',', 'join', 'my', 'contest', ':', '.'],
#   ['lovely', 'c', ':', '.'],
#   ['вау', '!', 'стильный', 'лук', '!']],
#  ('167153578', '146006471'): [['awesome', '!', 'xxx', '.'],
#   ['great',
#    'look',
#    'goreti',
#    '!',
#    'have',
#    'a',
#    'wonderful',
#    'and',
#    'safe',
#    'weekend',
#    'dear',
#    '!'],
#   ['gorgeous', 'summer', 'set', '!'],
#   ['lovely', 'boho', '.'],
#   ['lovely', 'outdoor', 'style', '.']],
#  ('167153578', '174619956'): [['thanks', 'ladies', '!'],
#   ['such',
#    'a',
#    'nice',
#    'style',
#    'and',
#    'fab',
#    'this',
#    'lovely',
#    'combo',
#    'for',
#    'summer',
#    '!'],
#   ['thank', 'you', 'all', 'for', 'the', 'sweet', 'comments', '!'],
#   ['so', 'pretty', '!', 'happy', 'thursday', 'dear', 'friend', '!'],
#   ['gorgeous', ',', 'such', 'a', 'pretty', 'skirt', '.']],
#  ('106844760', '104657746'): [['loved', 'her', 'in', 'the', 'movie', '!']],
#  ('106844760',
#   '107170140'): [['yep',
#    'dean',
#    'and',
#    'that',
#    'jacket',
#    '!',
#    'and',
#    'his',
#    'car',
#    ':',
#    'p',
#    '.']],
#  ('106844760', '117377888'): [['so', 'chic', 'and', 'fierce', '!'],
#   ['cool', 'style', 'for', 'fall', '!'],
#   ['thank',
#    'you',
#    '!',
#    'my',
#    'button',
#    'is',
#    'still',
#    'not',
#    'allowing',
#    'me',
#    'to',
#    'like',
#    'your',
#    'sets',
#    'but',
#    'they',
#    'are',
#    'amazing',
#    '!',
#    ':',
#    ')',
#    '.'],
#   ['great', 'outfit', 'combo', 'my', 'dear..'],
#   ['perfect', 'calvin', 'look', '!', '#', 'fierce', 'and', 'edgy', '.'],
#   ['gorgeous', 'entry', '!'],
#   ['soo', 'cool', '!'],
#   ['gorgeous',
#    '!',
#    'love',
#    'this',
#    'combo',
#    '!',
#    'so',
#    'cool',
#    ',',
#    'amazing',
#    'job',
#    '!'],
#   ['thank', 'you', 'sweetheart', '!']],
#  ('106844760',
#   '71621119'): [['#',
#    'fiercestyling',
#    '#',
#    'fiercecolorcombo',
#    '#',
#    'homepageworthy',
#    '.'], ['super',
#    'nice',
#    'set',
#    '!',
#    'yellow',
#    'is',
#    "n't",
#    'my',
#    'go',
#    'to',
#    'fashion',
#    'color',
#    'but',
#    'you',
#    'made',
#    'me',
#    'see',
#    'its',
#    'beauty',
#    '!',
#    ':',
#    ')',
#    'love',
#    'your',
#    'set',
#    ':',
#    ')',
#    '.']],
#  ('203435559', '191926026'): [['so', 'pretty', '!', 'pls', 'join', '.']],
#  ('203435559', '197520578'): [['pretty', 'pls', 'join', '.'],
#   ['welcome', 'to', 'join', 'shein', 'navy', 'blouse', '--', '>', '.']],
#  ('177101832', '125091158'): [['yes', ',', 'i', 'love', 'this', '!']],
#  ('177101832', '166962661'): [['merci', 'bcp', '<UNK>', '.'],
#   ['wow', 'c', 'trop', 'beau', '!'],
#   ['merci', 'bcp', '.']],
#  ('177101832', '178612022'): [['pls', 'join', '.']],
#  ('151348079',
#   '62155572'): [['beautiful',
#    'set',
#    ',',
#    'please',
#    'join',
#    'my',
#    'romwe',
#    'contest',
#    '-',
#    '.']],
#  ('94798035',
#   '178376658'): [['i',
#    'could',
#    "n't",
#    'agree',
#    'more',
#    '.',
#    'i',
#    'love',
#    'your',
#    'zoe',
#    'stories',
#    'so',
#    'much',
#    '!',
#    'i',
#    'still',
#    'have',
#    'yet',
#    'to',
#    'read',
#    'the',
#    'one',
#    'you',
#    "'ve",
#    'just',
#    'updated',
#    ':3',
#    '.'], ['literally', 'same', 'question', '.'], ['does',
#    "n't",
#    'matter',
#    ',',
#    'just',
#    'keep',
#    'those',
#    'zoe',
#    'stories',
#    'coming',
#    '!',
#    ':3',
#    '.']],
#  ('94798035',
#   '74518133'): [['that', 'hair', 'is', 'quite', '<UNK>', '0.o', '.']],
#  ('41288503',
#   '140599624'): [['wow',
#    '!',
#    'thats',
#    'crazy',
#    '!',
#    'you',
#    'could',
#    'report',
#    'her',
#    '.'],
#   ['in',
#    'california',
#    'with',
#    'my',
#    'toes',
#    'in',
#    'the',
#    'sand',
#    'you’re',
#    'your',
#    'sets',
#    'are',
#    'legit',
#    'goals',
#    'and',
#    'you’re',
#    'so',
#    'nice',
#    'and',
#    'funny',
#    '.'],
#   ['you',
#    'are',
#    'not',
#    'crazy',
#    ',',
#    'she',
#    'is',
#    'crazy',
#    'for',
#    'doing',
#    'this',
#    'omg',
#    '.'],
#   ['that',
#    'would',
#    'honestly',
#    'really',
#    'get',
#    'me',
#    'so',
#    'pissed',
#    'off',
#    '.',
#    'but',
#    'do',
#    'you',
#    'happen',
#    'to',
#    'know',
#    'this',
#    'person',
#    'in',
#    'real',
#    'life',
#    '.'],
#   ['lol',
#    'what',
#    'who',
#    'does',
#    'this',
#    '.',
#    'like',
#    'are',
#    'u',
#    '3.',
#    'lmao',
#    'rn',
#    '.'],
#   ['i', "'m", 'sorry', 'that', 'sucks', '.'],
#   ['congrats',
#    'on',
#    'top',
#    'set',
#    '!',
#    'i',
#    "'m",
#    'sorry',
#    'about',
#    'the',
#    '<UNK>',
#    '.',
#    'hope',
#    'she',
#    'stops',
#    ',',
#    'it',
#    "'s",
#    'so',
#    'annoying',
#    'when',
#    'people',
#    'raid',
#    '.',
#    'i',
#    'know',
#    'how',
#    'it',
#    'feels',
#    '.'],
#   ['ugh',
#    ',',
#    'that',
#    "'s",
#    'awful',
#    '!',
#    'people',
#    'are',
#    'k',
#    '[',
#    'c',
#    ']',
#    'to',
#    'the',
#    'crazy',
#    '!',
#    'ps',
#    '.',
#    'this',
#    'set',
#    'is',
#    '<UNK>',
#    '.'],
#   ['and',
#    'because',
#    'it',
#    'would',
#    "n't",
#    'let',
#    'me',
#    'tag',
#    'in',
#    'the',
#    'other',
#    'comment',
#    'oops',
#    '.'],
#   ['people',
#    'who',
#    'have',
#    'nuts',
#    'instead',
#    'of',
#    'their',
#    'brain',
#    'in',
#    'their',
#    'head',
#    'tho',
#    ':',
#    '-/',
#    '.'],
#   ['p.s', '.', 'great', 'use', 'of', 'the', 'all', 'caps', '.'],
#   ['awesome',
#    'set',
#    ',',
#    'and',
#    'that',
#    "'s",
#    'happened',
#    'to',
#    'me',
#    ':',
#    'i',
#    'get',
#    'it',
#    '!',
#    'so',
#    'annoying',
#    '!'],
#   ['omg',
#    'wtf',
#    'that',
#    'sucks',
#    '!',
#    '<UNK>',
#    'i',
#    'turned',
#    'off',
#    'those',
#    'notifications',
#    'bcz',
#    'tbh',
#    'idc',
#    'if',
#    'anyone',
#    'likes',
#    'my',
#    'item',
#    'like',
#    'how',
#    'does',
#    'tht',
#    'even',
#    'have',
#    'to',
#    'do',
#    'w',
#    'me',
#    '.'],
#   ['woah',
#    'that',
#    "'s",
#    'really',
#    'stupid',
#    '<UNK>',
#    'h',
#    'tell',
#    'me',
#    'the',
#    'users',
#    '!'],
#   ['i',
#    'hate',
#    'that',
#    '!',
#    'i',
#    'especially',
#    'dislike',
#    'it',
#    'when',
#    'people',
#    'tag',
#    'me',
#    'and',
#    'then',
#    'delete',
#    'the',
#    'comment',
#    '!'],
#   ['love', 'the', 'set', '!', 'wow', 'that', "'s", 'so', 'low', '...'],
#   ['how', 'pretty', '!'],
#   ['so', 'not', 'crazy', '.'],
#   ['and', 'congrats', 'on', 'top', 'set', 'girlie', '!'],
#   ['dripping',
#    'like',
#    'a',
#    'saturated',
#    'sunrise',
#    'omfg',
#    'your',
#    'art',
#    'sets',
#    'are',
#    'the',
#    'bomb.com',
#    'gurl',
#    'your',
#    'magazine',
#    'sets',
#    'are',
#    'so',
#    'pretty',
#    'can',
#    'i',
#    'you’re',
#    'your',
#    'skills',
#    'lol',
#    '.'],
#   ['you',
#    "'re",
#    'def',
#    'not',
#    'the',
#    'crazy',
#    'one',
#    ',',
#    'this',
#    'is',
#    'absolutely',
#    'ridiculous',
#    '!',
#    'people',
#    ',',
#    'ugh',
#    '.',
#    'so',
#    'sorry',
#    ':',
#    '/',
#    '.'],
#   ['cute', 'set', '!', '>', '_', '.'],
#   ['that',
#    "'s",
#    'crazy',
#    '!',
#    'i',
#    'think',
#    'she',
#    'should',
#    'stop',
#    'and',
#    'understand',
#    'what',
#    'she',
#    "'s",
#    'doing',
#    '.',
#    'she',
#    "'s",
#    'crazy',
#    'and',
#    'a',
#    'creepy',
#    'stalker',
#    '!'],
#   ['that', 'soo', 'annoying', '.'],
#   ['you',
#    "'re",
#    'not',
#    '<UNK>',
#    'crazy',
#    '!',
#    'but',
#    'do',
#    "n't",
#    'mind',
#    'with',
#    'this',
#    'kind',
#    ';',
#    ')',
#    'it',
#    "'s",
#    'a',
#    'lovely',
#    'set',
#    'btw',
#    '.'],
#   ['your',
#    'not',
#    'crazy',
#    'but',
#    'they',
#    'are',
#    '!',
#    'hope',
#    'it',
#    'gets',
#    'figured',
#    'out',
#    '(',
#    'although',
#    'i',
#    'did',
#    'that',
#    'once',
#    'lol',
#    'i',
#    "'m",
#    'really',
#    'sorry',
#    ':',
#    '-',
#    '(',
#    ')',
#    'also',
#    'congrats',
#    'on',
#    'this',
#    'ts',
#    '.'],
#   ['ts', 'congrats', '!'],
#   ['congrats',
#    'on',
#    'top',
#    'set',
#    '!',
#    'and',
#    'who',
#    'was',
#    'it',
#    ',',
#    'anyway',
#    '.'],
#   ['what',
#    'the',
#    'hell',
#    'that',
#    "'s",
#    'so',
#    'stupid',
#    '&',
#    '<UNK>',
#    '.',
#    'i',
#    "'m",
#    'laughing',
#    'because',
#    'of',
#    'how',
#    'ridiculous',
#    'that',
#    'is',
#    '!',
#    'i',
#    "'m",
#    'sorry',
#    'this',
#    'is',
#    'happening',
#    'it',
#    'must',
#    'be',
#    'so',
#    '<UNK>',
#    '.'],
#   ['...', 'lol', 'this', 'was', '<UNK>', 'funny', '.'],
#   ['congrats',
#    'on',
#    'the',
#    'top',
#    'set',
#    '!',
#    'seems',
#    'like',
#    'polyvore',
#    'agrees',
#    'with',
#    'you',
#    ',',
#    'haha',
#    ':',
#    ')',
#    '.'],
#   ['if', 'she', 'keeps', 'doing', 'that', ',', 'tell', 'me', 'her', '!'],
#   ['wow',
#    'that',
#    "'s",
#    'annoying',
#    '...',
#    'i',
#    'heard',
#    'you',
#    'can',
#    'block',
#    'people',
#    'so',
#    'they',
#    'ca',
#    "n't",
#    'get',
#    'on',
#    'your',
#    'page',
#    'talk',
#    'to',
#    'i',
#    'think',
#    'she',
#    'knows',
#    'how',
#    'to',
#    '.']],
#  ('41288503',
#   '150912575'): [['totally',
#    'stunning',
#    '!',
#    'especially',
#    'the',
#    'jacket',
#    'and',
#    'the',
#    'skirt',
#    '!'], ['so', 'pretty', 'love', 'it', '~~', '.'], ['adore',
#    'this',
#    'style',
#    'and',
#    'fab',
#    'outfit',
#    'in',
#    'set',
#    'too',
#    'mix',
#    '&',
#    'match',
#    'as',
#    'well..'], ['nice', 'layout', '.']],
#  ('41288503', '81225604'): [['cool', 'mix', '!']],
#  ('214182608',
#   '214758802'): [['hey', 'sis', 'this', 'is', 'my', 'set', 'love', 'it', '.']],
#  ('18187531',
#   '15295573'): [['gorgeous',
#    '!',
#    'i',
#    'love',
#    'that',
#    'blazer',
#    'and',
#    'this',
#    'makes',
#    'me',
#    'crave',
#    'some',
#    'mocha',
#    '!'],
#   ['so', 'elegant', '!'],
#   ['this',
#    'is',
#    'gorgeous',
#    '!',
#    'what',
#    'i',
#    'would',
#    'give',
#    'to',
#    'be',
#    'able',
#    'to',
#    'wear',
#    'that',
#    'outfit',
#    '!',
#    'plus',
#    ',',
#    'the',
#    'background',
#    'you',
#    'used',
#    'is',
#    'stunning',
#    '.',
#    'you',
#    'are',
#    'so',
#    'talented',
#    '!']],
#  ('66157916', '63027379'): [['soo', 'so', 'cool', '!'],
#   ['poly', '<UNK>', '!', '<UNK>', '<UNK>', '!'],
#   ['gorge', 'dear', '!'],
#   ['hello',
#    'my',
#    'dear',
#    '!',
#    'what',
#    'a',
#    'fabulous',
#    'set',
#    '!',
#    'that',
#    'sweater',
#    'is',
#    'so',
#    'pretty',
#    '!',
#    ':',
#    ')',
#    ')',
#    '.'],
#   ['awesome', '~', 'love', 'that', 'sweater', '!'],
#   ['super', 'fab', ',', 'my', 'dear', '...', 'only', 'you', '!'],
#   ['panemorfo',
#    'look',
#    '!',
#    '<UNK>',
#    'ta',
#    'papoutsia',
#    'einai',
#    'uperoxa',
#    '!',
#    '<',
#    '333',
#    '.'],
#   ['very', 'funny', 'and', 'smart', 'set', 'darling', '!'],
#   ['stunning', 'autumn', 'set', '!', 'love', 'these', 'colours', '!'],
#   ['perfect', 'styleee', ':', ')', ')', ')', '.'],
#   ['perfect', 'set', 'and', 'outfit', 'honey', '.'],
#   ['an',
#    'adorable',
#    'style',
#    ',',
#    'very',
#    'nice',
#    'set',
#    'again',
#    ':',
#    ')',
#    '.'],
#   ['so',
#    'cute',
#    'and',
#    'love',
#    'style',
#    'from',
#    'this',
#    'so',
#    'so',
#    'much',
#    'what',
#    'a',
#    'perfect',
#    'set',
#    'well',
#    'done',
#    'here',
#    '!'],
#   ['love',
#    'it',
#    '.love',
#    'it',
#    '!',
#    '<',
#    '3',
#    '<',
#    '3',
#    '<',
#    '3',
#    '<',
#    '3',
#    '.'],
#   ['so', 'amazing', 'outift', '.']],
#  ('66157916',
#   '65514295'): [['fabulous',
#    '-',
#    'love',
#    'the',
#    'black',
#    'kitty',
#    '!'], ['congrats', 'on', 'your', 'win', '!']],
#  ('159932849', '188538097'): [['n', 'love', '.'],
#   ['magnificent',
#    'combination',
#    'absolutely',
#    'gorgeous',
#    'and',
#    'amazing',
#    '.'],
#   ['exceptional',
#    'styling',
#    '!',
#    'love',
#    'this',
#    'fresh',
#    'modern',
#    'look',
#    '.']],
#  ('159932849',
#   '193565445'): [['big',
#    'loooove',
#    '!',
#    'your',
#    'sets',
#    'are',
#    'amazing',
#    '.']],
#  ('159932849',
#   '212155374'): [['i',
#    'love',
#    'all',
#    'your',
#    'sets',
#    '.',
#    'how',
#    'do',
#    'you',
#    'get',
#    'the',
#    'color',
#    'behind',
#    'the',
#    'words',
#    '.']],
#  ('193019394', '183918465'): [['awesome', '=d', '.'],
#   ['so', 'ab', 'fab', '.'],
#   ['so', 'imaginative', '.'],
#   ['wild', 'and', 'edgy', '.', 'love', 'it', '.'],
#   ['beautiful', '.', '.', 'brilliant', '.'],
#   ['incredible', 'look', ',', 'my', 'friend', '!', '<', '3', '.'],
#   ['beautifully', 'styled', '!'],
#   ['amazing', 'and', 'cool', 'fashion', 'such', 'a', 'nice', 'combo', '.'],
#   ['innovative',
#    'style',
#    '!',
#    'the',
#    'earrings',
#    'are',
#    'over',
#    'the',
#    'top',
#    '!',
#    ':',
#    ')',
#    '.'],
#   ['great', 'retro', 'punk', '.']],
#  ('193019394',
#   '195095284'): [['fun',
#    'and',
#    'creative',
#    'day',
#    ',',
#    'love',
#    '.'], ['magnificent', 'combination', '.'], ['so',
#    'edgy',
#    'and',
#    'cool',
#    '.'], ['so', 'incredible', ',', 'my', 'dear', '!', '<', '3', '.'], ['flat',
#    'out',
#    'phenomenal',
#    '!',
#    'love',
#    'it',
#    '!'], ['sorry',
#    'typo',
#    '...',
#    'fun',
#    'and',
#    'edgy',
#    ',',
#    'love',
#    '.'], ['marvelous', 'ensemble', '.'], ['that',
#    "'s",
#    'lovely',
#    'and',
#    'girly',
#    '.'], ['1',
#    'part',
#    'adorable',
#    ',',
#    '1',
#    'part',
#    'edgy',
#    ',',
#    'altogether',
#    'fabulous',
#    '!'], ['trendy', ',', 'cool', 'yet', 'girly', 'xx', '.'], ['fierce',
#    'and',
#    'sassy',
#    'styling',
#    '!'], ['fabulous',
#    '!',
#    'definitely',
#    'a',
#    'statement',
#    'look',
#    '.'], ['you', 'rock', 'girl', '!']],
#  ('193019394',
#   '196737266'): [['very',
#    'edgy',
#    'and',
#    'cool',
#    'and',
#    'the',
#    '<UNK>',
#    'striped',
#    'skirt',
#    'is',
#    'stunning',
#    '.',
#    'not',
#    'to',
#    'mention',
#    'the',
#    'leather',
#    'blouse',
#    '.'], ['wow',
#    '!',
#    'amazing',
#    'style',
#    'love',
#    'the',
#    'boots',
#    'and',
#    'outfit',
#    '.',
#    'great',
#    'job',
#    '!'], ['gorgeous', 'dress', '.', 'beautiful', 'look', '.'], ['remarkable',
#    'styling',
#    'my',
#    'dear',
#    '!'], ['lovely',
#    'bag',
#    '...',
#    'i',
#    'loved',
#    'the',
#    'production',
#    '.'], ['uber', 'modern', 'perfection', 'darling', 'miss', 'o', '!'], ['glorious',
#    'dear',
#    '!']],
#  ('135255392', '108105831'): [['my', 'taglist', '.']],
#  ('135255392',
#   '14429188'): [['congratulations',
#    'you',
#    'are',
#    'now',
#    'under',
#    '<UNK>',
#    'entertainment',
#    '!']],
#  ('141584692', '201273125'): [['gorgeous', 'chic', 'mix', 'dear', '!']],
#  ('160323852', '192893198'): [['edgy', 'cool', '.']],
#  ('160323852',
#   '199614678'): [['great',
#    'look',
#    'great',
#    'set',
#    'great',
#    'mixing',
#    'color',
#    'n',
#    "'",
#    'nice',
#    'stripes',
#    '.'], ['beautiful',
#    '!',
#    'please',
#    'look',
#    'at',
#    'my',
#    'newest',
#    'set',
#    'and',
#    'give',
#    'a',
#    'like',
#    '!'], ['outstanding', 'set', '!', 'congratulations', '.'], ['cool',
#    '!',
#    'ts',
#    'congrats',
#    '!'], ['beautiful', 'mix', '.'], ['congratulations',
#    'on',
#    'your',
#    'well',
#    'deserved',
#    'top',
#    'fashion',
#    'set',
#    '.']],
#  ('163318956', '163804475'): [['oh', 'amazing', 'and', 'stylish', '.'],
# ...
#    'look',
#    '!',
#    'adore',
#    'it',
#    '!'], ['look',
#    'so',
#    'chic',
#    'fab',
#    'this',
#    'style',
#    'and',
#    'outfits',
#    'too',
#    '!']],
#  ('86683190', '89917740'): [['awesome', 'design', 'sweetie', '!'],
#   ['great', 'mix', ',', 'love', 'the', 'plaid', 'and', 'the', 'leopard', '!'],
#   ['great', 'combination', '!', 'perfect', ':', ')', '.'],
#   ['exquisite', '!', 'lovely', 'styling', 'and', 'color', 'combo', '!'],
#   ['&', 'thank', 'you', 'so', 'much', 'ladies', '!', ':', ')', ')', '.'],
#   ['great', 'look', '^_^', '.'],
#   ['&',
#    'i',
#    'appreciate',
#    'your',
#    'comments',
#    'and',
#    'support',
#    '!',
#    'thanks',
#    'so',
#    'much',
#    '!'],
#   ['excellent', 'work', '-', 'beautiful', ',', 'stylish', '!'],
#   ['love', 'this', 'look', '!', 'fab', 'skirt', 'and', 'shoes', '!'],
#   ['love',
#    'the',
#    'tartan',
#    'pencil',
#    'skirt',
#    ',',
#    'gorgeous',
#    'set',
#    'sweetie',
#    '!'],
#   ['love', 'how', 'you', 'styled', 'this', 'so', 'perfectly', '!'],
#   ['this', 'set', 'looks', 'fantastic', '!'],
#   ['congratulation',
#    'on',
#    'your',
#    'talented',
#    'sets',
#    '!',
#    'love',
#    'them',
#    'all',
#    '!',
#    'especially',
#    'the',
#    '<UNK>',
#    "'",
#    'layout',
#    '!'],
#   ['&',
#    'thank',
#    'you',
#    'so',
#    'much',
#    'ladies',
#    'for',
#    'your',
#    'wonderful',
#    'comments',
#    '!',
#    'hope',
#    'you',
#    'have',
#    'a',
#    'great',
#    'saturday',
#    '!'],
#   ['&',
#    'thank',
#    'you',
#    'so',
#    'much',
#    'for',
#    'your',
#    'lovely',
#    'comments',
#    '!',
#    'have',
#    'a',
#    'great',
#    'weekend',
#    '!'],
#   ['woow', ',', 'amazing', '!']],
#  ('86683190',
#   '93955143'): [['asweetie',
#    'this',
#    'is',
#    'so',
#    'cool',
#    'in',
#    'style',
#    'just',
#    'love',
#    'it',
#    'as',
#    'always',
#    'dear',
#    '!'], ['fantatsic', 'set', '!']],
#  ('182260560',
#   '116045218'): [['cool',
#    'styling',
#    'with',
#    'truly',
#    'ugly',
#    'shoes',
#    '!',
#    ':',
#    ')',
#    ')',
#    'x',
#    '.'], ['congratulations', 'on', 'ts', '!'], ['cool',
#    '!',
#    'ts',
#    'congrats',
#    '!'], ['those',
#    'are',
#    'quite',
#    'the',
#    'shoes',
#    '!',
#    'i',
#    'cant',
#    'decide',
#    'if',
#    'i',
#    'like',
#    'them',
#    'or',
#    'not',
#    'lol',
#    '!'], ['check',
#    'my',
#    'polyvore',
#    'and',
#    'like',
#    'thank',
#    'you',
#    '.'], ['well', 'done', '!', 'congrats', '!']],
#  ('182260560',
#   '116845392'): [['such',
#    'a',
#    'perfect',
#    'combo',
#    'for',
#    'this',
#    'season',
#    '.']],
#  ('181595860',
#   '145412983'): [['nice',
#    'fall',
#    'colors',
#    ',',
#    'it',
#    "'s",
#    'a',
#    'great',
#    'outfit',
#    '!'], ['love', 'the', 'color', 'palette', '!']],
#  ('181595860', '169906890'): [['so', 'wow', 'dear~', '.'],
#   ['so',
#    'chic',
#    'casual',
#    'fashion',
#    'such',
#    'a',
#    'nice',
#    'style',
#    'too',
#    '.'],
#   ['so', 'prettyy', '!'],
#   ['on', 'point', '.'],
#   ['great', 'styling', ',', 'clean', 'look', '.']],
#  ('65511308',
#   '54838974'): [['woooow',
#    'super',
#    'great',
#    'stylelove',
#    'it',
#    '.'], ['woamazing', 'outfit', 'honey', '.'], ['<UNK>',
#    '...',
#    'i',
#    'love',
#    'this',
#    'match',
#    '.']],
#  ('65511308', '81147412'): [['i', 'am', 'lovin', 'that', 'shirt', '!'],
#   ['so', 'lovely', 'outfits', 'love', 'it', '!']],
#  ('154132541', '148442679'): [['picture', 'perfect', '.']],
#  ('154132541', '160028089'): [['simply', '<UNK>']],
#  ('154132541', '164563137'): [['gorgeous', '...', 'love', 'it', '¤', '.'],
#   ['pls', 'join', '.'],
#   ['amazing', 'set¤', '.']],
#  ('154132541',
#   '177170635'): [['brilliant', 'set', ',', 'fantastic', 'style', '!'], ['oh',
#    ',',
#    'i',
#    'love',
#    'that',
#    'top',
#    '!',
#    'fab',
#    'set',
#    '!',
#    '<',
#    '3',
#    '.'], ['woow', 'stunning', 'look', '!']],
#  ('154132541',
#   '188039601'): [['extra',
#    '!',
#    'please',
#    ',',
#    'join',
#    'the',
#    'group',
#    'in',
#    'the',
#    'description',
#    'of',
#    'my',
#    'profile',
#    '.']],
#  ('122362051', '119123608'): [['<UNK>', 'shoes', ':', 'p', '.']],
#  ('122362051', '121505742'): [['nice', 'retro', 'pants', '.']],
#  ('158278122', '152594457'): [['beautiful', 'sporty', 'look', '!'],
#   ['wonderful', 'and', 'fun', '.'],
#   ['great', 'sporty', 'look', '!'],
#   ['divine', '!', 'great', 'style', '!', '──σ──', '.'],
#   ['wow', 'that', 'bag', '!'],
#   ['fab', 'fendi', '.']],
#  ('212330768', '205590367'): [['magnificent', 'combination', '.'],
#   ['i',
#    'would',
#    'wear',
#    'this',
#    'set',
#    'any',
#    'day',
#    'of',
#    'the',
#    'week',
#    '.',
#    'just',
#    'fabulous',
#    '!']],
#  ('185356165',
#   '113261996'): [['so',
#    'gorgeous',
#    'combo',
#    'fab',
#    'this',
#    'style',
#    'and',
#    'all',
#    'details',
#    'in',
#    'set',
#    '~',
#    '.'], ['thanks', 'ladies', '!'], ['gorgeous',
#    'color',
#    'combo',
#    '!',
#    ':',
#    ')',
#    '.'], ['wonderful', 'fall', 'set', '!'], ['gorgeous',
#    'fall',
#    'style',
#    'fab',
#    'cloth',
#    'and',
#    'nice',
#    'in',
#    'details',
#    '.'], ['beautiful',
#    'look',
#    'kristen',
#    '!',
#    'have',
#    'a',
#    'great',
#    'weekend',
#    'my',
#    'friend',
#    '!']],
#  ('185356165',
#   '160828804'): [['я',
#    'рада',
#    '<UNK>',
#    '<UNK>',
#    '-',
#    'именно',
#    'это',
#    'для',
#    'меня',
#    '<UNK>',
#    '<UNK>',
#    '<UNK>',
#    '<UNK>',
#    ',',
#    'еще',
#    'и',
#    'стиль',
#    '<UNK>',
#    '!',
#    'спасибо',
#    '!'], ['замечательный', 'сет', '!', 'и', 'удобно', 'и', 'стильно', '!']],
#  ('185356165', '17981295'): [['darling', '!', 'congrats', 'my', 'friend', '!'],
#   ['congrats', 'on', '3rd', 'place', '!'],
#   ['thank', 'you', 'my', 'friend', '.']],
#  ('185356165', '184934174'): [['great', 'autumn', 'style', '!'],
#   ['it', "'s", 'a', 'superb', 'fall', 'outfit', '!'],
#   ['love', 'her', 'my', 'dear', 'friend', 'xxxxxx', '.'],
#   ['lol', '!', 'great', 'title', '!', 'fab', 'set', '!'],
#   ['gorgeous', 'look', '!', '¤', '.'],
#   ['excellent', 'look', '!'],
#   ['on', 'point', '.'],
#   ['so', 'fabulous', '!', '¤', '.'],
#   ['marvellous', 'and', 'chic', 'look', 'dear', '!'],
#   ['great', 'design', 'and', 'outfit', '.'],
#   ['so', 'cool', ',', 'love', 'the', 'title', 'too', '.'],
#   ['chic', 'timeless', 'style', '.'],
#   ['great', 'set', 'for', 'autumn', '.'],
#   ['stylish',
#    'fashion',
#    'and',
#    'fab',
#    'this',
#    'combo',
#    'too',
#    'great',
#    'set',
#    '!'],
#   ['so',
#    'beautiful',
#    'and',
#    'such',
#    'a',
#    'nice',
#    'style',
#    'here',
#    'totally',
#    'fab',
#    'this',
#    'combo',
#    '!'],
#   ['hahahahahahaha', '!', 'fantastic', '!', ':', 'dddd', '.']],
#  ('214322629', '213251364'): [['cute', 'look', 'em', '!'],
#   ['thanks', 'to', 'both', 'of', 'you', '!']],
#  ('214322629',
#   '214321243'): [['i',
#    'love',
#    'this',
#    ',',
#    'everything',
#    'is',
#    'so',
#    '<UNK>',
#    '=',
#    ')',
#    '.'], ['precioso',
#    '...',
#    'muy',
#    'buen',
#    'gusto',
#    'para',
#    'el',
#    '<UNK>',
#    'de',
#    'los',
#    'sets',
#    '.'], ['great', 'look', 'great', 'set', 'great', 'color', '.'], ['love',
#    'this',
#    'summer',
#    'look',
#    '!'], ['adorable', 'summer', 'style', '.'], ['splendid',
#    'dear',
#    '.'], ['lovely',
#    'summer',
#    'fashion',
#    'fab',
#    'outfit',
#    'here',
#    '!'], ['perfect', 'summer', 'chic', '!'], ['how', 'adorable', '!'], ['my',
#    'fave',
#    '!'], ['beautiful', 'summer', 'style', '.']],
#  ('214322629',
#   '214718546'): [['great',
#    'look',
#    'kari',
#    '!',
#    'happy',
#    'weekend',
#    'dear',
#    '!'], ['very', 'creative', '!', 'xx', '.']],
#  ('129457093', '127379958'): [['wooow', 'so', 'fab', '!'],
#   ['my',
#    'uncle',
#    'jack',
#    'got',
#    'an',
#    'awesome',
#    '9',
#    'month',
#    'old',
#    '<UNK>',
#    '<UNK>',
#    'convertible',
#    'by',
#    'work',
#    'part',
#    'time',
#    'using',
#    'a',
#    '<UNK>',
#    '.',
#    'go',
#    'to',
#    'this',
#    'site',
#    '...',
#    '...',
#    '.'],
#   ['adorable', 'outfit', '<', '3', 'love', 'itt', '.']],
#  ('129457093',
#   '128005960'): [['amazing',
#    'set',
#    'dear',
#    '!',
#    'love',
#    'the',
#    'colors',
#    'and',
#    'fab',
#    'styling',
#    '!',
#    'have',
#    'a',
#    'great',
#    'weekend',
#    '!']],
#  ('129457093', '133762984'): [["j'adore", '!', 'super', 'veste', '!'],
#   ["j'adore", "c'est", 'parfait', '<', '3', '.']],
#  ('129457093', '141194273'): [['super', 'fresh', '.']],
#  ('129457093', '84962689'): [['this', 'outfit', 'is', 'everything', '.']],
#  ('154725157', '154725134'): [['so', 'interesting', 'set', '.']],
#  ('154725157', '154725151'): [['cute', 'mix', '.'],
#   ['ts', 'congrats', '!'],
#   ['fantatsic', 'set', 'sweetie', '.'],
#   ['thank', 'u', '.']],
#  ('154725157', '155964266'): [['boho', 'chic', '.'],
#   ['lovely', '!', 'merry', 'christmas', '<UNK>', '.'],
#   ['tysm',
#    ',',
#    'wish',
#    'you',
#    'and',
#    'your',
#    'family',
#    'merry',
#    'christmas',
#    'and',
#    'a',
#    'happy',
#    'new',
#    'year',
#    'dear',
#    ':',
#    ')',
#    '.']],
#  ('183726580', '191575221'): [['thank', 'u', '<', '3', '.']],
#  ('183726580',
#   '196826651'): [['so',
#    'gorgeous',
#    'fashion',
#    'and',
#    'such',
#    'a',
#    'nice',
#    'style',
#    'for',
#    'this',
#    'season',
#    'i',
#    'like',
#    'it',
#    '!']],
#  ('98723495', '99527158'): [['classy', 'and', 'fabulous', '!'],
#   ['gorgeous', 'chic', 'and', 'elegant', '!'],
#   ['gorgeous',
#    'sweetie',
#    '!',
#    'love',
#    'the',
#    'look',
#    'and',
#    'cute',
#    'jacket',
#    '!'],
#   ['podoba', 'mi', 'si', ',', 'dobra', 'robota', '!'],
#   ['the',
#    'burberry',
#    'coat',
#    'and',
#    'bag',
#    'go',
#    'perfectly',
#    'with',
#    'the',
#    'boots',
#    ',',
#    'amazing',
#    'set',
#    ',',
#    'great',
#    'job',
#    '!',
#    'x',
#    '.'],
#   ['wonderful', 'classy', 'style', ':', ')', '.'],
#   ['soo', 'lovely', 'chic', 'look', 'sweetie', '.'],
#   ['bardzo', 'fajny', 'set', '.'],
#   ['wow', '...', 'perfection', '!'],
#   ['so', 'beautiful', ',', 'completely', 'chic', '.'],
#   ['bardzo', '<UNK>', '<UNK>', ':', ')', '<UNK>', 'weekendu', ':', ')', '.'],
#   ['so', 'pretty', 'look', ',', 'i', 'love', 'the', 'layout', 'here', '.'],
#   ['adore', 'this', 'fabulous', 'fashion', '.'],
#   ['tres', 'chic', '!'],
#   ['fabulous', 'elegant', 'set', '!']],
#  ('169601116', '159574047'): [['omg', 'i', "'m", 'in', 'love', '!'],
#   ['outstanding', 'set', '.']],
#  ('169601116',
#   '178913161'): [['wow',
#    '!',
#    'such',
#    'a',
#    'chic',
#    'combo',
#    '!',
#    'that',
#    'skirt',
#    'and',
#    'that',
#    'jacket',
#    'so',
#    'cool',
#    '!'], ['incredible',
#    'jacket',
#    '.',
#    'want',
#    'for',
#    'my',
#    'real',
#    'life',
#    'wardrobe',
#    '.',
#    'well',
#    'done',
#    '.'], ['so',
#    'good',
#    'as',
#    'usual',
#    ':',
#    ')',
#    'love',
#    'how',
#    'you',
#    'always',
#    'find',
#    'the',
#    'most',
#    'unique',
#    'pieces',
#    'and',
#    'how',
#    'u',
#    'put',
#    'them',
#    'together',
#    '!'], ['super', 'cute', '!', 'love', 'the', 'skirt', '!']],
#  ('169601116',
#   '197268845'): [['beautiful',
#    'and',
#    'perfect',
#    '!',
#    'xo',
#    ',',
#    'oft',
#    '.'], ['congratulations', 'on', 'your', 'very', 'pretty', 'top', 'fashion', 'set', '.'], ['congrats',
#    'n',
#    '.'], ['fantastic', '!', 'ts', 'congrats', '!'], ['looks',
#    'so',
#    'pretty',
#    'and',
#    'stylish',
#    '!'], ['congratulations',
#    '!',
#    'fabulous',
#    'set',
#    '!',
#    'perfect',
#    'for',
#    'mexico',
#    'city',
#    '!',
#    'xo',
#    ',',
#    'oft',
#    '.'], ['congratulations', 't', '.'], ['great',
#    'set',
#    'hun',
#    'xx',
#    '.'], ['very', 'sharp', 'set', '...', 'congrats', '!'], ['congratulations',
#    'on',
#    'ts',
#    '!'], ['love', 'it', 'all', '...', '.congrats', '!'], ['outstanding',
#    'set',
#    '!',
#    'congratulations',
#    '.'], ['so', 'spring', '!']],
#  ('169601116', '202006197'): [['love', 'these', 'colors', '!'],
#   ['great', 'set', 'great', 'mixing', 'color', '.']],
#  ('145952400',
#   '144507523'): [['cool', 'and', 'fantastic', 'superb', 'look~', '.']],
#  ('116298881', '112578121'): [['love', 'layout', '!']],
#  ('116298881', '112912595'): [['thank', 'you', 'hon', ':', ')', '.'],
#   ['those', 'shoes', 'are', 'fierce', '!', '!'],
#   ['спасибо', 'дорогая', '.'],
#   ['what',
#    'a',
#    'great',
#    'look',
#    'with',
#    'the',
#    'vest',
#    '!',
#    'so',
#    'chic',
#    '&',
#    'stylish',
#    '!',
#    'loving',
#    'everything',
#    'in',
#    'this',
#    'set',
#    '&',
#    'awesome',
#    'items',
#    'too',
#    '!',
#    'how',
#    'amazing',
#    '.']],
#  ('116298881',
#   '113613417'): [['fabulous',
#    '!',
#    'i',
#    'adore',
#    'layers',
#    'and',
#    'all',
#    'the',
#    'playful',
#    'things',
#    'that',
#    'it',
#    'can',
#    'create',
#    '.']],
#  ('116298881', '115110012'): [['class', 'all', 'the', 'way', '!'],
#   ['thank', 'you', 'so', 'much', 'everyone', '!', ':', 'd', '.'],
#   ['simple', 'beautiful', '.'],
#   ['good', 'job', '!', 'love', 'this', 'pairing', '!'],
#   ['kind',
#    'of',
#    'reminds',
#    'me',
#    'of',
#    'blair',
#    'waldorf',
#    '.',
#    'nice',
#    'job',
#    '!'],
#   ['elegant',
#    ',',
#    'beauty',
#    'ang',
#    'lovely',
#    '.',
#    'amazing',
#    'set',
#    '!',
#    ';',
#    ')',
#    '.'],
#   ['so',
#    'preppy',
#    'outfit',
#    ',',
#    'boots',
#    'just',
#    'make',
#    'this',
#    'set',
#    'a',
#    'little',
#    'bit',
#    'sexy',
#    '.',
#    'very',
#    'cool',
#    'combination',
#    '.'],
#   ['a', 'belated', 'congrats', '!'],
#   ['very', 'cool', '...', '..congrats', '.'],
#   ['great', 'set', '+', 'styling', '!', 'love', 'it', '!'],
#   ['amazing', 'set', '!', 'well', 'done', '!', ':', ')', '.']],
#  ('116298881',
#   '118987591'): [['dark',
#    'and',
#    'mysterious',
#    ',',
#    'fabulous',
#    'work',
#    '!'], ['fresh', ',', 'trendy', 'and', 'modern', '!', 'awesome', 'styling', 'dear', '!'], ['fresh',
#    '&',
#    'beautiful',
#    '!'], ['this', 'is', 'sooooo', 'fabulous', '!'], ['wow',
#    ',',
#    'love',
#    'thie',
#    'one',
#    '.'], ['fantatsic', 'it', 'too', '.'], ['beautiful', 'mix', '!'], ['great',
#    'b',
#    '&',
#    'w',
#    'set',
#    '!'], ['fabulous', '!', 'such', 'a', 'gorgeous', 'dress', '!'], ['love',
#    'it',
#    '!',
#    'really',
#    'stylish',
#    '!',
#    'it',
#    'looks',
#    'really',
#    'amazing',
#    '.'], ['beautiful',
#    '!',
#    'love',
#    'this',
#    'such',
#    'a',
#    'gorgeous',
#    'work',
#    '!'], ['so',
#    'chic',
#    'casual',
#    'wear',
#    'fab',
#    'style',
#    'and',
#    'outfits',
#    'here',
#    'a',
#    'lot',
#    '!']],
#  ('185239903',
#   '183356656'): [['sweet',
#    '!',
#    '¤',
#    'love',
#    'this',
#    'set',
#    '!',
#    '¤',
#    '.'], ['simply', 'gorgeous', '¤', '.']],
#  ('168484817', '146336866'): [['thanks', 'a', 'lot', '.'],
#   ['truly',
#    'amazing',
#    'and',
#    'fantastic',
#    'look',
#    '!',
#    'great',
#    'style',
#    'dear',
#    '!',
#    ':',
#    ')',
#    '.'],
#   ['thanks', 'a', 'lot', ':', ')', '.']],
#  ('114013015',
#   '112603598'): [['gorgeous', '!', '20', 'points', '!', 'c', ':', '.']],
#  ('114013015', '114798467'): [['hell', 'yeah', ':', ')', '.']],
#  ('114013015',
#   '70646813'): [['look', 'so', 'chic', 'fab', 'tyle', 'and', 'jacket', '!'],
#   ['terrific', '!', 'great', 'set', 'xoxo', '.'],
#   ['so',
#    'pretty',
#    '.',
#    'i',
#    "'d",
#    'totally',
#    'wear',
#    'that',
#    'outfit',
#    '<',
#    '3',
#    '.']],
#  ('114013015', '89144664'): [['daisy', ',', 'maybe', '.'],
#   ['aw', 'np', 'glad', 'you', 'like', 'it', ':', ')', '.']],
#  ('134544255',
#   '193707347'): [['perfection',
#    '!',
#    'wow',
#    '!',
#    '*easter',
#    'egg',
#    'from',
#    'the',
#    'totally',
#    'today',
#    'group',
#    '!',
#    '*',
#    '<',
#    '3',
#    '.'], ['so', 'sweet', ',', 'honey', '!', '<', '3', '.'], ['so',
#    'they',
#    'do',
#    '!',
#    'lovely',
#    'set',
#    '!']],
#  ('134544255',
#   '206046047'): [['simply',
#    'adorable',
#    'fashion',
#    'and',
#    'fab',
#    'this',
#    'style',
#    'too',
#    '!'], ['thank', 'you', ',', 'how', 'have', 'you', 'been', 'doing', '.']],
#  ('165667387',
#   '195714159'): [['great',
#    'set',
#    '!',
#    'perfect',
#    'outfit',
#    'and',
#    'layout',
#    '.']],
#  ('213429071', '208039964'): [['love', 'the', 'shorts', '!'],
#   ['lovely', 'the', 'shorts', 'are', 'great', '!']],
#  ('213429071', '211657841'): [['beautiful', 'ensemble', '.']],
#  ('213429071', '213381147'): [['hi', 'enter', 'my', 'group', 'pls', '.']],
#  ('213429071', '213437616'): [['hi', 'enter', 'my', 'group', 'pls', '.']],
#  ...}

# %%
data_path = 'dataset/devdata_downs.dat'
dev_downs_data,downs_orderlist,model_downs_comments,downs_labellist = prepare_evaluation(data_path,comments,int_to_word,word_to_int)

# %%
# model_downs_comments

# %%
lr = 0.001
rat_c = 1.0
rat_g = 1.0
epochs = 5
rate = 1.0

# %%
cla_cost_list = []
gen_cost_list = []

bleus_tops = []
auc_tops = []
trec_evals_tops = []

bleus_downs = []
trec_evals_downs = []
auc_downs = []

# %%
beamsearch = True
checkpoint = 'checkpoint/trained_model.ckpt'
with tf.Session(graph=train_graph,config=config) as sess:
    writer = tf.summary.FileWriter('checkpoint/',sess.graph)
    saver = tf.train.Saver(save_relative_paths=True)
    saver = tf.train.import_meta_graph('checkpoint/trained_model.ckpt-1.meta')
    saver.restore(sess, tf.train.latest_checkpoint('checkpoint/'))
#     sess.run(tf.global_variables_initializer())
    print(time.localtime())
    classifier_loss = train_graph.get_tensor_by_name('loss/classifier_loss:0')
    generator_loss = train_graph.get_tensor_by_name('loss/generator_loss:0')
    for epoch in range(epochs):
        b_s = 64#batch_size
        train_cla_cost = 0
        train_gen_cost = 0
        temp_cla_cost_list = []
        temp_gen_cost_list = []
        step = 0
        for _,(x_i1,x_i2,x_id1,x_id2,y_l,x_s_i,x_s_o,seq_len,max_seq_len,wei) in enumerate(get_batches(traindata,b_s,comments,toplist,downlist,
                                                                                                       combinationlist,topidlist,downidlist,word_to_int['<PAD>'])):
            _,cost1,cost2 = sess.run([train_op,classifier_loss,generator_loss],{img1:get_img(x_i1),img2:get_img(x_i2),img1id:x_id1,img2id:x_id2,label:y_l,sequence_input:x_s_i,sequence_output:x_s_o,sequence_length:seq_len,max_sequence_length:max_seq_len,batch_size:len(x_i1),learning_rate:lr,keep_prob:rate,ratio_c:rat_c,ratio_g:rat_g,weight:wei,flag:True})   
            train_cla_cost += cost1
            train_gen_cost += cost2
            step += 1
            if step%1000 == 0:
                temp_cla_cost_list.append(train_cla_cost/step)
                temp_gen_cost_list.append(train_gen_cost/step)
                print('Matching Loss: '+ str(train_cla_cost/step)+' & Gennerate Loss: '+str(train_gen_cost/step)+' '+'pass!')
        temp_cla_cost_list.append(train_cla_cost/step)
        temp_gen_cost_list.append(train_gen_cost/step)
        cla_cost_list.append(temp_cla_cost_list)
        gen_cost_list.append(temp_gen_cost_list)
        print('Epoch {}/{} - Training Loss: {:.3f} & {:.3f}'.format(epoch+1,epochs,train_cla_cost/step,train_gen_cost/step))
        saver.save(sess,checkpoint,global_step=epoch+1)
        print('Model Trained and Saved')
        print(time.localtime())

# %% [markdown]
# # **Validation - Bleu**

# %%
beamsearch = True
checkpoint = 'checkpoint/trained_model.ckpt'
with tf.Session(graph=train_graph,config=config) as sess:
    writer = tf.summary.FileWriter('checkpoint/',sess.graph)
    saver = tf.train.Saver()
    saver = tf.train.import_meta_graph('checkpoint/trained_model.ckpt-1.meta')
    saver.restore(sess, tf.train.latest_checkpoint('checkpoint/'))
    
    print(time.localtime())
    print('Top-Down:')
    #validation       
    b_s = 64
    max_seq_len = 30
    system_tops_comments = {}
    query_number = 0
    step = 0
    for top in tops_orderlist:
        downsoftop = dev_tops_data[top]
        probabilitylist = {}
        for batch_i in range(len(downsoftop)//b_s+1):
            start_i = batch_i*b_s
            downs = downsoftop[start_i:start_i+b_s]
            x_i1,x_i2,x_id1,x_id2 = build_evaluation_batch(top,downs,0,topidlist,downidlist)
            seq_len = [30]*len(x_i1)
            prob,gred_seq,beam_seq = sess.run([prediction,greedysearch_sequence,beamsearch_sequence],{img1:get_img(x_i1),img2:get_img(x_i2),
                                                                                                      img1id:x_id1,img2id:x_id2,sequence_length:seq_len,
                                                                                                      max_sequence_length:max_seq_len,batch_size:len(x_i1),keep_prob:1.0,flag:True})
            j = 0
            for down in downs:
                probabilitylist[down] = prob[j][1]
                if model_tops_comments.get((top,down)) != None:
                    if beamsearch:
                        system_tops_comments[(top,down)] = [(id_seq_to_word_seq(beam_seq[j][:,index],int_to_word,word_to_int['<EOS>'])).split()[:-1] for index in range(3)]#3 is beam_width
                    else:
                        system_tops_comments[(top,down)] = (id_seq_to_word_seq(gred_seq[j],int_to_word,word_to_int['<EOS>'])).split()[:-1]
                j += 1 
            step += 1
            if step%1000 == 0:
                print('pass!')
        del probabilitylist,downsoftop
    bleu,_ = bleu_evalaution(model_tops_comments,system_tops_comments,beamsearch)
    bleus_tops.append(bleu)
    del system_tops_comments
    #validation        
    print(time.localtime())
    print('Down-Top:')
    system_downs_comments = {}
    downs_trec = {}
    query_number = 0
    step = 0
    for down in downs_orderlist:
        topsofdown = dev_downs_data[down]
        probabilitylist = {}
        for batch_i in range(len(topsofdown)//b_s+1):
            start_i = batch_i*b_s
            tops = topsofdown[start_i:start_i+b_s]
            x_i1,x_i2,x_id1,x_id2 = build_evaluation_batch(down,tops,1,topidlist,downidlist)
            seq_len = [30]*len(x_i1)
            prob,gred_seq,beam_seq = sess.run([prediction,greedysearch_sequence,beamsearch_sequence],{img1:get_img(x_i1),img2:get_img(x_i2),img1id:x_id1,img2id:x_id2,sequence_length:seq_len,max_sequence_length:max_seq_len,batch_size:len(x_i1),keep_prob:1.0,flag:True})
            j = 0
            for top in tops:
                probabilitylist[top] = prob[j][1]
                if model_downs_comments.get((down,top)) != None:
                    if beamsearch:
                        system_downs_comments[(down,top)] = [(id_seq_to_word_seq(beam_seq[j][:,index],int_to_word,word_to_int['<EOS>'])).split()[:-1] for index in range(3)]
                    else:
                        system_downs_comments[(down,top)] = (id_seq_to_word_seq(gred_seq[j],int_to_word,word_to_int['<EOS>'])).split()[:-1]
                j += 1
            step += 1
            if step%1000 == 0:
                print('pass!')
        del probabilitylist,topsofdown
    bleu,_ = bleu_evalaution(model_downs_comments,system_downs_comments,beamsearch)
    bleus_downs.append(bleu)
    del system_downs_comments
    #validation        
    print(time.localtime())
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from checkpoint/trained_model.ckpt-1
# time.struct_time(tm_year=2019, tm_mon=5, tm_mday=25, tm_hour=10, tm_min=26, tm_sec=42, tm_wday=5, tm_yday=145, tm_isdst=0)
# Top-Down:
# pass!
# pass!
# 0.3024702183136237
# time.struct_time(tm_year=2019, tm_mon=5, tm_mday=25, tm_hour=10, tm_min=38, tm_sec=59, tm_wday=5, tm_yday=145, tm_isdst=0)
# Down-Top:
# pass!
# pass!
# 0.3192542251236773
# time.struct_time(tm_year=2019, tm_mon=5, tm_mday=25, tm_hour=10, tm_min=51, tm_sec=1, tm_wday=5, tm_yday=145, tm_isdst=0)

# %% [markdown]
# # Evaluate Model

# %%
# tops_qrel_file_path = 'evaluation/testdata_tops_qrel.dat'
# tops_trec_file_path = 'evaluation/testdata_tops_trec.dat'
# downs_qrel_file_path = 'evaluation/testdata_downs_qrel.dat'
# downs_trec_file_path = 'evaluation/testdata_downs_trec.dat'

# %%
data_path = 'dataset/testdata_tops.dat'#in testdata_tops, the first col is img_name of top, the second col is img_name of down(i.e. bottom), the third col is rel(1 relevant, 0 irrelevant), the fourth col is comments_index(-1 is a special comment_index for irrelevant combination)    
test_tops_data,tops_orderlist,model_tops_comments,tops_labellist = prepare_evaluation(data_path,comments,int_to_word,word_to_int)

# %%
data_path = 'dataset/testdata_downs.dat'#in testdata_downs, the first col is img_name of down(i.e. bottom), the second col is img_name of top, the third col is rel(1 relevant, 0 irrelevant), the fourth col is comments_index(-1 is a special comment_index for irrelevant combination)    
test_downs_data,downs_orderlist,model_downs_comments,downs_labellist = prepare_evaluation(data_path,comments,int_to_word,word_to_int)

# %%
model_tops_comments
# Out:
# {('100335564',
#   '100888640'): [['surely',
#    'you',
#    'do',
#    ',',
#    'and',
#    'this',
#    'is',
#    'sweet',
#    'like',
#    'cake',
#    '!'], ['this', 'is', 'darling', '!', ':', ')', '.']],
#  ('100335564',
#   '107323184'): [['hey', '!', 'thanks', 'for', 'following', 'us', '!']],
#  ('100335564', '77253917'): [['so', 'modern', '&', 'minimalistic', '!']],
#  ('100335564', '87141708'): [['thanks', 'girl', ':', ')', '.']],
#  ('100335564', '98349501'): [['very', 'pretty', 'summer', 'look', '!']],
#  ('71546030',
#   '107171059'): [['this',
#    'is',
#    'an',
#    'amazing',
#    'set',
#    ',',
#    'really',
#    'well',
#    'thought',
#    'out',
#    '.',
#    ':',
#    ')',
#    '.'],
#   ['love',
#    'that',
#    'handbag',
#    '!',
#    'perfect',
#    'with',
#    'the',
#    'gorgeous',
#    'valentino',
#    'shoes',
#    '!']],
#  ('71546030',
#   '69560239'): [['wow',
#    '!',
#    'this',
#    'is',
#    'fabulous',
#    'dear',
#    ',',
#    'love',
#    'it',
#    'all',
#    'very',
#    'much-',
#    'well',
#    'done',
#    ':',
#    ')',
#    ')',
#    '.'], ['splendid', 'look', 'darling', '!'], ['so',
#    'wonderful',
#    'dear',
#    '<',
#    '3',
#    'loveeeeeeeeee',
#    '.']],
#  ('71546030',
#   '76226833'): [['gorgeous',
#    'for',
#    'a',
#    'lovely',
#    'person',
#    '!',
#    'xoxo',
#    '.'], ['sooooooo', 'beautiful', '!', ':', ')', ')', '.'], ['beautiful',
#    'sweetie',
#    '!',
#    'xox',
#    '.'], ['lovely',
#    'darling',
#    ',',
#    'so',
#    '<UNK>',
#    'the',
#    'shorts',
#    '.'], ['waww', 'so', 'romantic', 'and', 'amazing', 'set', 'sweetie', '.'], ['gorgeous',
#    '!',
#    'i',
#    'love',
#    'the',
#    'photo',
#    ',',
#    'too',
#    ':',
#    ')',
#    '.'], ['i', 'love', 'the', 'shorts', ':', ')', '!'], ['wow',
#    ',',
#    'beautiful',
#    'gift',
#    'set',
#    'dear',
#    '!'], ['this',
#    'set',
#    'looks',
#    'absolutely',
#    'perfect',
#    '!',
#    'love',
#    'it',
#    '!'], ['so', 'delicate', 'my', '<UNK>', ')', '.'], ['i',
#    'love',
#    'it',
#    '!',
#    'happy',
#    'birthday',
#    ',',
#    'whoever',
#    'you',
#    'are',
#    '!',
#    'if',
#    'you',
#    'deserve',
#    'a',
#    'set',
#    'after',
#    'you',
#    ',',
#    'you',
#    'are',
#    'definitely',
#    'worth',
#    'following',
#    '!'], ['love',
#    'this',
#    'look',
#    'dear',
#    '!',
#    'so',
#    'cute',
#    'and',
#    'chic',
#    'and',
#    'summery',
#    '!'], ['lovely', 'birthday', 'set', '!'], ['excellent',
#    '!',
#    'xx',
#    '.'], ['gorgeous',
#    'bd',
#    'set',
#    'for',
#    'the',
#    'lovely',
#    '<UNK>',
#    '!',
#    'xo',
#    '.'], ['oh',
#    'what',
#    'a',
#    'sweet',
#    'outfit',
#    '!',
#    'it',
#    "'s",
#    'flawless',
#    ',',
#    'dear',
#    '!'], ['soo',
#    'lovely',
#    'and',
#    'amaizng',
#    'style',
#    'my',
#    'sweetie',
#    ',',
#    'love',
#    'it',
#    'soo',
#    'much',
#    '.'], ['so',
#    'lovely',
#    'set',
#    '!',
#    'and',
#    'happy',
#    'birthday',
#    '.'], ['this', 'looks', 'so', 'lovely', '!'], ['ohhhh',
#    '...',
#    'so',
#    'adorable',
#    'and',
#    'cosy',
#    '!',
#    '<',
#    '3',
#    '.'], ['lovely', 'colors', 'and', 'ensemble', '!'], ['soft',
#    'and',
#    'lovely',
#    'summer',
#    'set',
#    '~',
#    'wonderful',
#    '!'], ['how', 'beautiful', '!'], ['great',
#    '!',
#    'love',
#    'this',
#    'pullover',
#    '!'], ['hmmm',
#    'relaxing',
#    'just',
#    'looking',
#    'at',
#    'this',
#    '!',
#    'gorgeous',
#    'summer',
#    'look',
#    '!'], ['fantastic',
#    'look',
#    ',',
#    'so',
#    'beautiful',
#    '!',
#    '<',
#    '3333',
#    '.'], ['#',
#    '<UNK>',
#    'are',
#    'beautiful',
#    '.',
#    'try',
#    'check',
#    'here',
#    'for',
#    'more',
#    'simple',
#    'but',
#    'elegant',
#    '#',
#    '<UNK>',
#    'set',
#    '.',
#    'cool',
#    'birthday',
#    'sets',
#    '!'], ['love',
#    'it',
#    'honey..',
#    'the',
#    'colours',
#    'are',
#    'amazing',
#    '!'], ['ah', 'so', 'nice', '.'], ['so',
#    'dreamy',
#    'set',
#    'sweetie',
#    '!'], ['sp', 'beautiful', '.'], ['thank',
#    'you',
#    'sweetie',
#    '!',
#    'what',
#    'a',
#    'beautiful',
#    'set',
#    '!',
#    'love',
#    'love',
#    'love',
#    'it',
#    'sweet',
#    'friend',
#    '!',
#    ':',
#    ')',
#    'xoxo',
#    '.'], ['amazing', 'set', 'dear~', '.'], ['so',
#    'lovely',
#    'end',
#    'delicate',
#    ':',
#    ')',
#    ')',
#    ')',
#    ')',
#    ')',
#    '.'], ['fantastic',
#    'summery',
#    'set',
#    ':',
#    ')',
#    ')',
#    ')',
#    'like',
#    'layout',
#    'and',
#    'outfit',
#    '<',
#    '33',
#    '.'], ['magnífico', 'set', '!'], ['bello',
#    'e',
#    'affascinante',
#    'come',
#    'il',
#    'mare',
#    'al',
#    '<UNK>',
#    '!']],
#  ('71546030',
#   '82188396'): [['look', 'so', 'chic', 'for', 'both', 'looks', '!'], ['love',
#    'these',
#    'versatile',
#    'styles',
#    '!'], ['goregous', ',', 'sweetie', '!']],
#  ('148888485', '148808438'): [['beautiful', 'love', 'these', 'boots', '.']],
#  ('148888485', '154709183'): [['love', 'this', 'dramatic', 'look', '.'],
#   ['you', 'did', 'it', '.']],
#  ('148888485',
#   '158923968'): [['thank',
#    'you',
#    ',',
#    'sweet',
#    'friends',
#    '!',
#    ':',
#    ')',
#    '.'], ['excellent', 'set', '.'], ['this',
#    'looks',
#    'so',
#    'balanced',
#    'and',
#    'perfect',
#    '!',
#    'fantastic',
#    'layout',
#    '!',
#    ':',
#    ')',
#    '.']],
#  ('160956866', '162496992'): [['great', 'work', '!'],
#   ['<UNK>', 'ma', 'molto', 'bello', 'questo', 'look', '...', '!'],
#   ['veramente', 'glam', '!']],
#  ('160956866', '163345414'): [['2', 'is', 'my', 'favourite', ':', ')', '.']],
#  ('160956866',
#   '178246699'): [['stylish',
#    'fashion',
#    'such',
#    'a',
#    'nice',
#    'combo',
#    'for',
#    'this',
#    'season',
#    '!']],
#  ('156254549', '152131746'): [['thank', 'you', 'mu', 'dear', '.']],
#  ('156254549', '152829528'): [['amaizng', 'set', 'sweetie', '.'],
#   ['woooooow', 'cats', '<', '3', '.']],
#  ('156254549',
#   '156543338'): [['hi',
#    '!',
#    'could',
#    'you',
#    'please',
#    'like',
#    'this',
#    'set',
#    'thank',
#    'you',
#    'so',
#    'much',
#    'and',
#    'i',
#    'hope',
#    'you',
#    'have',
#    'a',
#    'wonderful',
#    'day',
#    ':',
#    ')',
#    '.'], ['cool', 'and', 'adorable', 'superb', 'casual', 'look~', '.']],
#  ('103099751',
#   '108388854'): [['ooo',
#    'i',
#    'am',
#    'not',
#    'surprised',
#    '!',
#    'congrats',
#    '<',
#    '3',
#    '<',
#    '3',
#    '<',
#    '3',
#    '.'], ['gorgeous', 'skirt', '!', 'stunning', '!'], ['congrats',
#    'to',
#    'you',
#    'on',
#    'such',
#    'a',
#    'chic',
#    'elegant',
#    'design',
#    '!',
#    ':',
#    ')',
#    '.'], ['your', 'welcome', '.', ':', ')', '.'], ['gorgeous',
#    'stylelove',
#    'e',
#    '.'], ['perfection',
#    '!',
#    'i',
#    'love',
#    'every',
#    'item',
#    'of',
#    'this',
#    'set',
#    '!',
#    'the',
#    'pumps',
#    'are',
#    'to',
#    'die',
#    'for',
#    'and',
#    'this',
#    'bag',
#    'is',
#    'one',
#    'of',
#    'my',
#    'favourites',
#    '!'], ['thank',
#    'you',
#    'very',
#    'much',
#    ',',
#    'i',
#    'am',
#    'glad',
#    'you',
#    'like',
#    'it',
#    '!'], ['thank',
#    'you',
#    'very',
#    'much',
#    'for',
#    'your',
#    'lovely',
#    'comment',
#    '!']],
#  ('165310336',
#   '164702284'): [['that', 'jacket', 'is', 'to', 'die', 'for', '!', 'xx', '.']],
#  ('150920232',
#   '138807931'): [['fab',
#    'set..please',
#    'join',
#    'fashion',
#    'club+',
#    '$',
#    '60',
#    'coupon',
#    'good',
#    'luck',
#    '!'],
#   ['enter', 'the', 'contest', '.']],
#  ('163466491', '166103567'): [['looks', 'fabulous', ':', ')', '.']],
#  ('80442405',
#   '94044162'): [['oh',
#    'my',
#    'god',
#    '!',
#    'this',
#    'is',
#    'brilliant',
#    'my',
#    'dear',
#    '!',
#    'modern',
#    'styling',
#    ',',
#    'great',
#    'color',
#    'combo',
#    'and',
#    'this',
#    'skirt',
#    'is',
#    'to',
#    'die',
#    'for',
#    '!',
#    'for',
#    'me',
#    'this',
#    'is',
#    'by',
#    'far',
#    'a',
#    '#',
#    'topset',
#    '.'], ['love',
#    'this',
#    '!',
#    'also',
#    'congrats',
#    'on',
#    'your',
#    'member',
#    'profile',
#    '.',
#    'it',
#    'is',
#    'great',
#    '!'], ['great',
#    '&',
#    'love',
#    'each',
#    'of',
#    'your',
#    'color',
#    'compositions',
#    ':',
#    ')',
#    '.'], ['stunning', '!', 'lover', 'the', 'skirt', 'so', 'much', '!']],
#  ('147318291',
#   '146458342'): [['мне',
#    'без',
#    'хаки',
#    '<UNK>',
#    '!',
#    'просто',
#    '<UNK>',
#    '<UNK>',
#    ',',
#    'если',
#    'хаки',
#    '<UNK>',
#    '...',
#    '.',
#    ':',
#    ')',
#    '.'], ['с', '<UNK>', '<UNK>', 'хаки', '!']],
#  ('320016', '37631537'): [['marvelous', 'dear', '!'],
#   ['hi', 'dear', '!', 'absolutely', 'gorgeous', '!', 'xoxo', '.'],
#   ['wow',
#    '!',
#    'superb',
#    'combination',
#    ',',
#    'love',
#    'the',
#    'coat',
#    ',',
#    'the',
#    'style',
#    'perfect',
#    '!'],
#   ['incredibly', 'great', '>', '.'],
#   ['stunning', 'and', 'extraordinary', '!'],
#   ['colors', 'really', 'pop', ',', 'great', 'job', '.']],
#  ('320016', '43687288'): [['soo', '<UNK>', 'job', '.'],
#   ['beautiful',
#    '!',
#    'love',
#    'this',
#    'set',
#    'dear',
#    '!',
#    'awsome',
#    'outfit',
#    '!'],
#   ['stunning',
#    'mix',
#    ')',
#    'i',
#    'love',
#    'the',
#    'coat',
#    'here',
#    ',',
#    'so',
#    'fashionable',
#    'look',
#    ')',
#    '.'],
#   ['wow', 'super', 'set', 'i', 'love', 'outfits', 'there', 'so', 'much', '!'],
#   ['i', 'love', 'everything', 'in', 'this', 'set', '!'],
#   ['amazing', 'set', ',', 'good', 'job', '!', ':', 'd', '.'],
#   ['omg', ',', 'this', 'is', 'stunning', '!', 'love', 'the', 'colors', '!'],
#   ['i',
#    'did',
#    "n't",
#    'think',
#    'they',
#    'could',
#    'get',
#    'better',
#    'but',
#    'this',
#    'is',
#    'stunning',
#    '!'],
#   ['wodarling..', 'incredibly', 'gorgeous', '...', 'powerful', '!'],
#   ['amazing',
#    'set',
#    '!',
#    'very',
#    'colorful',
#    '.',
#    'love',
#    'the',
#    'skirt',
#    'with',
#    'the',
#    'top',
#    '.'],
#   ['amaaazing', '!', 'i', 'love', 'the', 'color', 'combination', '!'],
#   ['wow',
#    'these',
#    'colours',
#    'are',
#    'so',
#    'gorgeous',
#    'dear',
#    '!',
#    'i',
#    'simply',
#    'adore',
#    'this',
#    'look',
#    '!'],
#   ['well', 'done', '!']],
#  ('320016',
#   '60427679'): [['omg',
#    'i',
#    'luv',
#    '<UNK>',
#    '<UNK>',
#    'nd',
#    'then',
#    'she',
#    'gets',
#    'w',
#    'rob',
#    'nd',
#    'boom',
#    '.',
#    'the',
#    'cutest',
#    'couple',
#    'to',
#    'ever',
#    'grace',
#    'the',
#    'planet',
#    '.'], ['but', 'anyhow', ',', 'me', 'was', 'a', 'word', '.'], ['omg',
#    'i',
#    'love',
#    '<UNK>',
#    'fashion',
#    'fix',
#    'so',
#    'much',
#    'it',
#    'was',
#    'my',
#    'childhood',
#    '!',
#    'i',
#    'was',
#    'like',
#    '8',
#    'when',
#    'that',
#    'was',
#    'on',
#    'telly',
#    'omfg',
#    '.'], ['a', 'word', 'just', 'like', 'now', '.'], ['and',
#    'so',
#    'i',
#    'know',
#    'a',
#    'need',
#    'for',
#    'anyone',
#    '.'], ['so', 'are', 'we', 'erasing', 'ourselves', '.'], ['seeing',
#    'the',
#    '<UNK>',
#    'soon',
#    'sooooo',
#    'excited',
#    '.'], ['i', 'am', 'a', 'return', 'was', 'born', 'unheard', '.'], ['and',
#    'so',
#    'i',
#    'learned',
#    'a',
#    'need',
#    'for',
#    'anyone',
#    '.']],
#  ('88665472', '89303864'): [['is', 'this', 'set', 'for', 'meee', '!']],
#  ('159936822',
#   '158921499'): [['great',
#    'look',
#    '!',
#    'b',
#    '&',
#    'w',
#    'is',
#    'always',
#    'chic',
#    '!'], ['adoro', 'look', 'branco', 'e', 'preto', '.'], ['love',
#    'black',
#    'and',
#    'white',
#    '!',
#    'awesome',
#    'look',
#    '!'], ['stunning',
#    'black',
#    '&',
#    'white',
#    'combo',
#    ',',
#    'fab',
#    'set',
#    'and',
#    'style',
#    '.']],
#  ('159936822',
#   '160560917'): [['outstanding',
#    'set',
#    '!',
#    'perfect',
#    'layout',
#    '.'], ['thank', 'you', 'for', 'your', 'kind', 'words', '!']],
#  ('159936822', '188706188'): [['excellent', 'look', '!'],
#   ['truly', 'amazing', 'and', 'stylish', '!'],
#   ['great', 'look', '!', 'xxx', '.'],
#   ['love', 'it', 'my', 'friend', 'xxx', '.'],
#   ['on', 'point', '!', 'love', 'those', 'boots', '.'],
#   ['classy', 'look', 'and', 'great', 'design', 'layout', '!'],
#   ['fabulous', 'black', 'and', 'white', '<UNK>', '!'],
#   ['cool', 'and', 'sophisticated', '...', 'love', '!']],
#  ('168186859', '157025522'): [['amazing', '<UNK>', 'sexy', '2', '.']],
#  ('168186859', '160145184'): [['so', 'lovely', 'and', 'chic', 'z', '.']],
#  ('168186859', '171491988'): [['congratulations', 'on', '2nd', 'place', '!']],
#  ('71136029', '69978236'): [['i', 'luv', 'your', 'design', 'style', '.'],
#   ['lovin',
#    "'",
#    'the',
#    'outfits',
#    'you',
#    'put',
#    'together',
#    '!',
#    'your',
#    'layouts',
#    'are',
#    'so',
#    'cool',
#    'and',
#    'creative',
#    'as',
#    'well',
#    '!'],
#   ['so', 'so', 'gorg', 'dearr', '.'],
#   ['urban', 'chic', 'street', 'style', '!'],
#   ['very', 'fashion', '.'],
#   ['love',
#    'the',
#    'lay-out',
#    '!',
#    'original',
#    'and',
#    'stylish',
#    ':',
#    ')',
#    '.']],
#  ('202087523',
#   '154221915'): [['outstanding',
#    'set',
#    '!',
#    'perfect',
#    'outfit',
#    'and',
#    'layout',
#    '.'], ['superb', 'set', 'hun', '!'], ['your',
#    'layouts',
#    'are',
#    'fresh',
#    'and',
#    'pretty',
#    '!']],
#  ('202087523', '194871479'): [['beautiful..', 'congratulations', '.'],
#   ['this',
#    'reminds',
#    'me',
#    'of',
#    'the',
#    '<UNK>',
#    'queen',
#    ',',
#    'when',
#    '<UNK>',
#    'goes',
#    'to',
#    'that',
#    'rose',
#    'garden',
#    '^_^',
#    '.'],
#   ['such',
#    'a',
#    'beautiful',
#    'set',
#    '!',
#    'i',
#    "'d",
#    'like',
#    'to',
#    'wear',
#    'this',
#    'look',
#    '!',
#    'congrats',
#    '!'],
#   ['congratulations', 'on', 'ts', '!'],
#   ['congratulations', 'on', 'ts', '!', 'well', 'deserved', '!'],
#   ['outstanding', 'set', '!', 'congratulations', '.'],
#   ['fab', 'set', 'hun', 'xx', '.'],
#   ['lovely', '!', 'ts', 'congrats', '!'],
#   ['thank', 'dear', 'than', '.']],
#  ('202087523',
#   '195973345'): [['i',
#    "'m",
#    'going',
#    'to',
#    'camp',
#    'and',
#    'wo',
#    "n't",
#    'be',
#    'posting',
#    'till',
#    'friday',
#    'love',
#    'all',
#    "y'all",
#    'bye',
#    '.']],
#  ('202087523',
#   '196350061'): [['great',
#    'look',
#    'great',
#    'set',
#    'great',
#    'mixing',
#    'w/',
#    'red',
#    '.'], ['oh',
#    'how',
#    'i',
#    'adore',
#    'rose',
#    'prints',
#    'and',
#    'this',
#    'look',
#    'is',
#    'so',
#    'perfectly',
#    'casual',
#    'chic',
#    '.'], ['cool', 'denim', 'set', ',', 'i', 'love', 'roses', '!'], ['fab',
#    'mix',
#    'so',
#    'well',
#    'done',
#    '.'], ['fantastico',
#    '!',
#    'le',
#    '<UNK>',
#    '<UNK>',
#    '<UNK>',
#    'una',
#    '<UNK>',
#    'in',
#    'più',
#    'a',
#    '<UNK>',
#    'outfit',
#    '!',
#    'poi',
#    'con',
#    'il',
#    'denim',
#    'sono',
#    'perfette',
#    '.'], ['gorgeous',
#    'casual',
#    'look',
#    'sweetie',
#    'love',
#    'the',
#    'denim',
#    'outfit',
#    'and',
#    'how',
#    'you',
#    'stylish',
#    'everything',
#    'it',
#    'is',
#    'just',
#    'perfect',
#    '!'], ['very', 'edgy', 'and', 'awesome', '.'], ['lovely',
#    'denim',
#    'set',
#    '!'], ['gorgeous', '-', 'i', 'love', 'that', 'shirt', '!'], ['excellent',
#    'dear',
#    '.']],
#  ('207953242', '159278229'): [['this', 'is', 'beautiful', '¤', '.'],
#   ['lovely', 'delicate', 'colors', '!']],
#  ('207953242', '207847360'): [['fantastically', 'styled', 'look', '.']],
#  ('104442987', '191530360'): [['congrats', '!', 'xo', '.'],
#   ['thank', 'you', 'everyone', ':', ')', '.'],
#   ['so', 'cute', 'x', 'grunge', 'sets', 'here', 'x', '.'],
#   ['like',
#    'my',
#    'sets',
#    'an',
#    'i',
#    "'ll",
#    'like',
#    'double',
#    'the',
#    'number',
#    'on',
#    'your',
#    'account',
#    '...',
#    'follow',
#    'and',
#    'i',
#    "'ll",
#    'follow',
#    'you',
#    'back',
#    '.'],
#   ['thank', 'u', ':', ')', ')', '.'],
#   ['cute', '!', 'ts', 'congrats', '!'],
#   ['that',
#    'is',
#    'so',
#    'true',
#    '.',
#    'people',
#    'tell',
#    'me',
#    'go',
#    'be',
#    'myself',
#    ',',
#    'tho',
#    'i',
#    'get',
#    '<UNK>',
#    'and',
#    'judged',
#    '.',
#    ':',
#    '(',
#    '.'],
#   ['thank', 'u', ':', ')', '.'],
#   ['omg', ',', 'the', 'best', 'set', 'ever', 'i', "'m", 'in', 'love', '.'],
#   ['awesome', 'style.congrats', 'on', '#', 'topsets', '.'],
#   ['congratulations', 'on', 'ts', '!']],
#  ('194503065', '200781998'): [['thank', 'you', 'my', 'friend', '!'],
#   ['athat',
#    "'s",
#    'okay',
#    ',',
#    'there',
#    'is',
#    'a',
#    'fashion',
#    'style',
#    'for',
#    'everyone',
#    '!',
#    'thank',
#    'you',
#    'my',
#    'friend',
#    '!']],
#  ('126340739', '155688433'): [['please', 'join', 'to', 'my', 'group', '.']],
#  ('187809846',
#   '179655331'): [['such',
#    'a',
#    'cool',
#    'yet',
#    'trendy',
#    'fashion',
#    'and',
#    'i',
#    "'d",
#    'like',
#    'to',
#    'wear',
#    'this',
#    'set',
#    'love',
#    'love',
#    'sweetie~',
#    '.'], ['hello', 'bella', '...', '<UNK>', 'the', 'rain', 'xo', '.']],
#  ('145957142', '140487537'): [['thank', 'u', 'so', 'much', 'ladies', '!'],
#   ['fun', 'set', '!']],
#  ('145957142',
#   '147965344'): [['dear',
#    ',',
#    'join',
#    'this',
#    'contest',
#    'too',
#    'and',
#    'win',
#    'a',
#    'prize',
#    '!']],
#  ('145957142', '151746900'): [['..so', 'incredibly', 'pretty', '.'],
#   ['such', 'a', 'fun', 'look', '!', 'love', '!'],
#   ['loose', 'and', 'fun', '.'],
#   ['splendid', 'dear', '!'],
#   ['so', 'fun', '...', 'great', 'look', '!'],
#   ['love', 'm', '&', 'ms', '!']],
#  ('216464807', '211739499'): [['hi', 'my', 'dear', 'stunning', 'combo', '.'],
#   ['very', 'hip', '!']],
#  ('167677359',
#   '171397204'): [['how',
#    'incredibly',
#    'gorgeous',
#    '&',
#    'fierce',
#    'is',
#    'this',
#    '!',
#    'want',
#    'it',
#    ',',
#    'need',
#    'it',
#    '!',
#    ';',
#    '-',
#    ')',
#    ')',
#    ')',
#    '.'], ['woah',
#    '!',
#    'smokin',
#    'hot',
#    'sweetie',
#    '!',
#    'gorgeous',
#    'combo',
#    '.'], ['fierce', 'set', 'dear', '!'], ['what',
#    'a',
#    'look',
#    '!',
#    'this',
#    'is',
#    'absolutely',
#    'amazing',
#    'dear',
#    'to',
#    ',',
#    'adore',
#    'all',
#    'golden',
#    'accessories',
#    'that',
#    'here',
#    'are',
#    '!'], ['outstanding',
#    'set',
#    '!',
#    'picture',
#    'perfect',
#    '!',
#    'perfect',
#    'outfit',
#    'and',
#    'layout',
#    '!'], ['awesome', 'edginess', '!']],
#  ('167677359', '176892142'): [['thanks', 'dolls', '!'], ['awesome', '¤', '.']],
#  ('194277106', '186591177'): [['really', 'pretty', 'and', 'sharp', 'too', '!'],
#   ['perfect',
#    'look',
#    'and',
#    'set',
#    '!',
#    'lovely',
#    'colors',
#    'and',
#    'combine',
#    '<',
#    '3',
#    '<',
#    '3',
#    '<',
#    '3',
#    '.'],
#   ['outstanding', 'set', '!', 'perfect', 'outfit', 'and', 'layout', '.'],
#   ['awesome', 'styling', '&', 'colours', '!'],
#   ['striking', 'leather', 'black', '&', 'pastel', 'pink', 'combo', '!'],
#   ['lovely', 'casual', 'fashion', 'and', 'fab', 'this', 'style', 'too', '.']],
#  ('194277106', '193667668'): [['now', 'im', 'wanting', '!'],
#   ['ooh', 'la', 'la', '.'],
#   ['love', 'the', 'bling', '!'],
#   ['thank', 'you', 'dear', 'hearts', '.']],
#  ('194277106', '200717966'): [['pretty', 'items', '.']],
#  ('194277106',
#   '201777819'): [['congrats',
#    'on',
#    'your',
#    'win',
#    '!',
#    'so',
#    'pretty',
#    "'",
#    '.'], ['congrats', 'my', 'dear', '!', 'love', 'this', 'jacket', '!']],
#  ('194277106', '209706551'): [['thank', 'you', '.', ':', '*', '.']],
#  ('103275652', '101873579'): [['<UNK>', 'the', 'camo', '!']],
#  ('103275652',
#   '103492950'): [['gorgeous',
#    '!',
#    ':',
#    'dlike',
#    'the',
#    'photos',
#    'you',
#    'have',
#    'chosen',
#    'also',
#    '!'], ['so', 'elegant', 'bit', 'exotic', 'look', '!']],
#  ('98041840',
#   '95322796'): [['thank',
#    'you',
#    'so',
#    'much',
#    'both',
#    'of',
#    'you',
#    '!',
#    'xxxx',
#    '.']],
#  ('60390620',
#   '87003754'): [['i',
#    'love',
#    'that',
#    'song',
#    '!',
#    'fabulous',
#    'set',
#    ',',
#    'love',
#    'the',
#    'pattern',
#    '!'], ['love', 'the', 'bag', '!']],
#  ('196322616',
#   '210658622'): [['great',
#    'look',
#    'great',
#    'set',
#    'great',
#    'mixing',
#    'w/',
#    'shoulder',
#    'n',
#    "'",
#    'nice',
#    'skirt',
#    '.']],
#  ('194104978', '164586423'): [['very', '1st', 'lady', '!']],
#  ('194104978',
#   '170548273'): [['fantastic',
#    ';',
#    'love',
#    'the',
#    'shoes',
#    'with',
#    'the',
#    'dress',
#    '!']],
#  ('194104978',
#   '181670708'): [['it',
#    "'s",
#    'so',
#    'cute',
#    'and',
#    'spring',
#    'time',
#    'true',
#    'inspiration',
#    '!']],
#  ('194104978',
#   '187408602'): [['amazing',
#    'dress',
#    'and',
#    'rhe',
#    'whole',
#    'combo',
#    ';',
#    ')',
#    '.'], ['so', 'elegant', 'and', 'stylish', '!'], ['very',
#    'elegant',
#    '.'], ['splendid', 'creation', 'darling', '.'], ['amazing',
#    '...',
#    'so',
#    'classy',
#    '.'], ['so', 'so', 'spectacular', '.'], ['so',
#    'elegant',
#    '!'], ['exquisitely', 'styled', '!'], ['stunning',
#    'winter',
#    'wedding',
#    'set',
#    '!',
#    'amazing',
#    'colors',
#    '!'], ['gorgeous',
#    'and',
#    'sophisticated',
#    ',',
#    'great',
#    'look',
#    'darling',
#    '.'], ['stunning', 'ensemble', '=d', '.'], ['amazingly',
#    'beautiful',
#    '!'], ['what',
#    'a',
#    'gorgeous',
#    'look',
#    'dear',
#    '!',
#    'xo',
#    '.'], ['elegance',
#    'combo',
#    'and',
#    'such',
#    'a',
#    'nice',
#    'style',
#    'here',
#    '!'], ['simply', 'stunning', '!'], ['absolutely',
#    'adore',
#    'this',
#    'set',
#    'dear',
#    '!',
#    'very',
#    'classy',
#    'and',
#    'sexy',
#    '!',
#    '5/5',
#    '.'], ['stunning',
#    'i',
#    'adore',
#    'this',
#    'beautiful',
#    'combination',
#    '.'], ['so', 'elegant', '!'], ['brilliant', 'set', '!'], ['fab',
#    'set',
#    'hun',
#    '.'], ['perfect', 'for', 'a', 'winter', 'wedding', '!'], ['how',
#    'gorgeous',
#    'and',
#    'very',
#    'elegant',
#    '.'], ['so',
#    'glamorous',
#    'and',
#    'charming',
#    'look',
#    'dear',
#    ',',
#    'as',
#    'always',
#    '!'], ['очень', 'красиво', '.'], ['wow', '...', 'brilliant', '!']],
#  ('194104978',
#   '192580877'): [['thank',
#    'you',
#    'so',
#    'much',
#    '!',
#    'i',
#    'am',
#    'thrilled',
#    '!',
#    '1',
#    'my',
#    'first',
#    'win',
#    '!'], ['thank',
#    'you',
#    'so',
#    'much',
#    '!',
#    'i',
#    'am',
#    'so',
#    'excited',
#    '!',
#    'my',
#    'first',
#    'win',
#    '!'], ['interesting', 'but', 'good', '!', 'congratulations', '.']],
#  ('194104978', '192663284'): [['pls', 'join', '.']],
#  ('194104978',
#   '192968334'): [['congratulations',
#    'on',
#    'your',
#    '4th',
#    'place',
#    'win',
#    'in',
#    'contest',
#    '``',
#    'wear',
#    'it',
#    'in',
#    'a',
#    'lace',
#    'dress',
#    "''",
#    'in',
#    'group',
#    'wear',
#    'it',
#    '(',
#    'outfit',
#    'only',
#    ')',
#    '!'], ['yes',
#    ',',
#    'divine',
#    '!',
#    'i',
#    'love',
#    'your',
#    'styling',
#    '.',
#    'congrats',
#    'on',
#    'your',
#    'win',
#    '!'], ["c'est", 'si', 'joli', '!']],
#  ('194104978',
#   '195833987'): [['styled',
#    'beautifully',
#    '...',
#    '..',
#    'loove',
#    'this',
#    'beautiful',
#    'look',
#    '.'], ['thanks', 'very', 'much', "'", '.'], ['love',
#    'the',
#    'vintage',
#    'feel',
#    '.'], ['awe', ',', 'true', 'romance', '!'], ['stunning',
#    '.',
#    'so',
#    'classy',
#    '.'], ['thanks',
#    'very',
#    'much',
#    'for',
#    'all',
#    'the',
#    'lovely',
#    'comments',
#    '.'], ['outstanding',
#    'set',
#    '!',
#    'beautiful',
#    'ensemble',
#    'and',
#    'perfect',
#    'layout',
#    '!']],
#  ('194104978', '220231656'): [['absolutely', 'darling', '!']],
#  ('170538469',
#   '159947822'): [['on',
#    'point',
#    '!',
#    'perfect',
#    'outfit',
#    'and',
#    'layout',
#    '.']],
#  ('170538469',
#   '166641168'): [['awesome',
#    'quote',
#    '..awesome',
#    'set',
#    'sweetie',
#    '<',
#    '3',
#    '.'], ['such',
#    'a',
#    'cool',
#    'vibe',
#    'here',
#    'sweetie',
#    'with',
#    'the',
#    'awesome',
#    'backdrop',
#    'and',
#    'amazing',
#    'look',
#    'xx',
#    '.'], ['wooow', 'absolutely', 'amazing', 'set', '!'], ['this',
#    'is',
#    'fantastic',
#    '!',
#    'i',
#    'adore',
#    'every',
#    'perfectly',
#    'styled',
#    'piece',
#    'here',
#    ',',
#    'such',
#    'a',
#    'wonderful',
#    'carefree',
#    'summer',
#    'vibe',
#    '.'], ['so', 'lovely', 'and', 'summery', '!'], ['adore',
#    'this',
#    'style',
#    'so',
#    'chic',
#    'casual',
#    'summer',
#    'and',
#    'fab',
#    'for',
#    'all',
#    'details',
#    'here',
#    '!'], ['adore',
#    'this',
#    'cool',
#    'summer',
#    'fashion',
#    'and',
#    'such',
#    'a',
#    'nice',
#    'style',
#    'too',
#    'great',
#    'set',
#    'here',
#    '!'], ['love', 'this', 'summer', 'style', '<', '3', '.'], ['amazing',
#    'outfit',
#    'and',
#    'layout',
#    '!'], ['utterly', 'beautiful', 'dear', '!']],
#  ('171904445',
#   '11834136'): [['congratulations',
#    'on',
#    'your',
#    '11th',
#    'place',
#    'win',
#    'in',
#    'contest',
#    '``',
#    'brown',
#    'challenge',
#    "''",
#    'in',
#    'group',
#    'wear',
#    'it',
#    '(',
#    'outfit',
#    'only',
#    ')',
#    '!'], ['thanks', 'all', '!', 'much', 'appreciated', '!'], ['congratz',
#    'on',
#    'your',
#    'win',
#    'with',
#    'this',
#    'beautiful',
#    'outfit',
#    '!']],
#  ('143936656', '144376459'): [['amazing', 'set', 'honey', '.'],
#   ['bas', 'lepo', '.'],
#   ['trés', 'jolie', '!'],
#   ['very', 'lovely', 'dear', '!', 'happy', 'weekend', '!'],
#   ['maravilhoso', '!', 'amei', 'o', 'set', '.'],
#   ['wow', '!', 'stunning', 'outfit', '!', 'like', 'it', 'a', 'lot', '!'],
#   ['splendid', 'dear', '!', 'so', 'pretty', '.'],
#   ['simply', 'amazing', '!'],
#   ['wow',
#    '!',
#    'wonderful',
#    'set',
#    'dear',
#    '!',
#    'fantastic',
#    'combo',
#    '!',
#    'so',
#    'pretty',
#    'and',
#    'stylish',
#    'outfit',
#    '!',
#    'love',
#    'this',
#    'suede',
#    'skirt',
#    '!',
#    ':',
#    ')',
#    ')',
#    '.'],
#   ['excellent',
#    'style',
#    'lilly',
#    '!',
#    'love',
#    'the',
#    'coat',
#    '!',
#    ':',
#    ')',
#    '.'],
#   ['so',
#    'chic',
#    'and',
#    'nice',
#    'skirt',
#    'such',
#    'a',
#    'great',
#    'set',
#    'too~~',
#    '.'],
#   ['classy', 'style', '.'],
#   ['predivan', 'set', 'i', 'look', '!'],
#   ['divine',
#    '!',
#    'love',
#    'this',
#    'mix',
#    '!',
#    'love',
#    'this',
#    'sweet',
#    'and',
#    'chic',
#    'style',
#    '!',
#    'adorable',
#    'touch',
#    'with',
#    'that',
#    'skirt',
#    '!',
#    'wonderful',
#    '!'],
#   ['preppy', 'sweet', '.'],
#   ['wow',
#    'my',
#    'dera',
#    'pretty',
#    'white',
#    'black',
#    'outfit',
#    'combo',
#    'here',
#    ',',
#    'really',
#    'like',
#    'thi',
#    '<UNK>',
#    'combination',
#    'my',
#    'dera',
#    '.'],
#   ['fabulous', 'nautical', 'inspired', 'outfit', '!'],
#   ['b', '&', 'w', ',', 'love', 'the', 'jacket', '.'],
#   ['gorgoeus', ',', 'love', 'this', 'outfit', 'esp', 'the', 'coat', '!'],
#   ['pretty', 'and', 'cute', 'adorable', 'look~', '.']],
#  ('143936656',
#   '148613002'): [['pretty',
#    ',',
#    'makes',
#    'me',
#    'smile',
#    'too',
#    '!'], ['awesome', '!', 'my', 'favourite', ':', ')', ')', ')', '.']],
#  ('49111066', '41280082'): [['congrats', '!', 'xoox', '.'],
#   ['amazing',
#    '!',
#    'congrats',
#    'on',
#    'top',
#    'sets',
#    ',',
#    'dear',
#    '!',
#    '<',
#    '33333',
#    '.'],
#   ['omg', ',', 'amazing', '!'],
#   ['luv', "'", 'it', '!'],
#   ['jeij', '!', 'congrats', 'on', 'top', 'set', '!', ':', ')', '.'],
#   ['congrats', 'xxxx', '.'],
#   ['wow',
#    ',',
#    'thanks',
#    'to',
#    'everyone',
#    "'s",
#    'amazing',
#    'words',
#    '!',
#    'i',
#    'am',
#    'stunned',
#    ',',
#    'its',
#    'my',
#    'first',
#    'time',
#    'to',
#    'make',
#    'top',
#    'sets',
#    ',',
#    'yay',
#    '!'],
#   ['aww', 'my', '<UNK>', "'s", 'amazing', 'style.i', 'really', 'love', '.'],
#   ['everyone',
#    '!',
#    'thanks',
#    'so',
#    'much',
#    ',',
#    'happy',
#    'to',
#    'hear',
#    'i',
#    "'m",
#    'not',
#    'too',
#    'late',
#    ':',
#    ')',
#    '.'],
#   ['heey',
#    '!',
#    '<UNK>',
#    'set',
#    '!',
#    'and',
#    'not',
#    'a',
#    'day',
#    'too',
#    'late',
#    ':',
#    ')',
#    '.'],
#   ['congrats', 'honey', ',', 'this', 'set', 'is', 'superb', '!']],
#  ('49111066',
#   '47454106'): [['gorgeous',
#    'set',
#    '!',
#    'and',
#    'beautiful',
#    'dress',
#    ',',
#    'love',
#    'it',
#    '!'], ['замечательные',
#    'сеты',
#    '!',
#    'очень',
#    'нравится',
#    'платье',
#    '!',
#    ':',
#    ')',
#    '.'], ['very',
#    'elegant',
#    'and',
#    'chic',
#    'combo',
#    '!',
#    'fab',
#    'set',
#    'dear',
#    '!']],
#  ('87467285', '177536656'): [['love', 'the', 'sea', '<UNK>', '!'],
#   ['yup', ',', 'they', "'re", 'pretty', '!']],
#  ('87467285',
#   '59308546'): [['i',
#    'have',
#    'never',
#    'been',
#    'on',
#    'a',
#    'tag',
#    'list',
#    'before',
#    ',',
#    'i',
#    'think',
#    'it',
#    "'d",
#    'be',
#    'really',
#    'cool',
#    'to',
#    'be',
#    'on',
#    'one',
#    '.',
#    'i',
#    "'d",
#    'love',
#    'to',
#    'be',
#    'on',
#    'it',
#    ':3',
#    '.'], ['rock', 'n', "'", 'rollers', 'part', 'three', ':', '.'], ['welcome',
#    'to',
#    'the',
#    'tag-list',
#    ';',
#    ')',
#    '.'], ['rock', 'n', "'", 'rollers', 'part', 'two', ':', '.'], ['no',
#    'problemo',
#    ':3',
#    '.']],
#  ('87467285',
#   '84702398'): [['cute',
#    'set',
#    '!',
#    'happy',
#    'almost',
#    'birthday',
#    '!',
#    '^^',
#    '.'], ['hot', 'girl', 'in', 'the', 'bikini', 'thee', '.'], ['super',
#    'cute',
#    '!',
#    'i',
#    'think',
#    'you',
#    'captured',
#    'a',
#    'day',
#    'at',
#    'the',
#    'beach',
#    'quite',
#    'well',
#    '!'], ['thank', 'you', '!', '^.^', '.'], ['great',
#    '!',
#    'i',
#    'have',
#    'a',
#    'set',
#    'with',
#    'the',
#    'same',
#    'shorts',
#    '!',
#    ':',
#    ')',
#    '.'], ['love',
#    'this',
#    '<',
#    '3',
#    'come',
#    'check',
#    'out',
#    'mine',
#    '<',
#    '3',
#    '.'], ['happy', 'early', 'birthday', '!'], ['congrats',
#    'on',
#    'your',
#    'top',
#    'set',
#    ',',
#    'wonderful',
#    'creation',
#    '!'], ['reminds', 'me', 'of', 'the', 'beach', ':', ')', '.'], ['love',
#    'this',
#    '<',
#    '3',
#    'love',
#    'the',
#    'beachy',
#    'vibe',
#    '!',
#    'congrats',
#    'dear',
#    ':',
#    ')',
#    '.'], ['i',
#    "'m",
#    'wishing',
#    'u',
#    'a',
#    'happy',
#    'birthday',
#    'now',
#    ',',
#    'cuz',
#    'i',
#    'wo',
#    "n't",
#    'be',
#    'able',
#    'to',
#    'get',
#    'on',
#    'in',
#    '5',
#    'days',
#    '...',
#    '.so',
#    'happy',
#    'birthday',
#    '!'], ['sweet', 'set', '!', 'thanks', 'for', 'tag', '!']],
#  ('87467285', '89752314'): [['love', 'the', 'sea', '<UNK>', '!'],
#   ['yup', ',', 'they', "'re", 'pretty', '!']],
#  ('171151857',
#   '161072000'): [['fantastic', 'set', '...', 'enter', 'here', ':', '.']],
#  ('171151857', '172312601'): [['dear', 'enter', 'pls', ':', '.']],
#  ('120038329',
#   '143704729'): [['wonderful', 'sweater', 'and', 'great', 'look', '.']],
#  ('152166922', '135924392'): [['thank', 'youu', '.']],
#  ('152166922',
#   '150414635'): [['very',
#    'stylish',
#    'set',
#    '!',
#    'i',
#    'love',
#    'this',
#    'skirt',
#    '.']],
#  ('152166922',
#   '155465418'): [['it',
#    "'s",
#    'so',
#    'cool',
#    'how',
#    'you',
#    'make',
#    'your',
#    'outfits',
#    'look',
#    'like',
#    'it',
#    "'s",
#    'in',
#    'a',
#    'magazine',
#    '!',
#    'is',
#    'it',
#    'something',
#    'everyone',
#    'does',
#    '.']],
#  ('134043683',
#   '140231702'): [['so',
#    'stunning',
#    ',',
#    'join',
#    'my',
#    'stylemoi',
#    'contest',
#    'to',
#    'win',
#    '$',
#    '60',
#    '+',
#    'free',
#    'tattoo',
#    ':',
#    '(',
#    'っ〃ω〃c',
#    ')',
#    '.'], ['great', 'style', ',', 'pls', '<UNK>'], ['you',
#    'can',
#    'win',
#    'all',
#    'the',
#    'items',
#    'from',
#    'this',
#    'set',
#    ',',
#    'join',
#    '.']],
#  ('51288125',
#   '51600263'): [['superb',
#    ',',
#    'dear..',
#    'so',
#    'awesome',
#    'and',
#    'chicness',
#    '!'], ['amazing',
#    'look',
#    '!',
#    'this',
#    'bag',
#    'is',
#    'divine',
#    '!'], ['gorgeous', 'set', 'sweetie..'], ['fab',
#    ',',
#    'love',
#    'the',
#    'leopard',
#    'print',
#    'shirt',
#    '!',
#    'great',
#    'bag',
#    'too',
#    ':',
#    ')',
#    '.'], ['casual',
#    'yet',
#    'totally',
#    'chic',
#    '!',
#    'stunning',
#    ',',
#    'love',
#    'the',
#    'bag',
#    ',',
#    'the',
#    'ab',
#    'fab',
#    'heels',
#    'and',
#    'the',
#    'blazer',
#    '!',
#    'kisses',
#    '!',
#    '<',
#    '3',
#    '.']],
#  ('192722996', '185115070'): [['beautiful', 'dress', 'xx', '.'],
#   ['thank', 'you', 'so', 'much', ',', 'ladies', '!'],
#   ['stunning', 'fierce', '.'],
#   ['grand', 'lk', '.'],
#   ['thank', 'you', 'so', 'much', ',', 'ladies', '!']],
#  ('211214820',
#   '202373524'): [['your',
#    'style',
#    'of',
#    'creating',
#    'sets',
#    'is',
#    'amazing',
#    '!',
#    'love',
#    'your',
#    'account',
#    '!'], ['congrats', 'ts', '!', 'beautiful', '!'], ['magnific',
#    ',',
#    'congrats',
#    '!',
#    '☆',
#    '.'], ['ts', 'congrats', '!'], ['excelente',
#    '.',
#    'enhorabuena',
#    '!'], ['outstanding', 'set', '!', 'congratulations', '.'], ['stylish',
#    'and',
#    'so',
#    'elegance',
#    'casual',
#    'summer',
#    'fab',
#    'outfit',
#    'and',
#    'this',
#    'style',
#    'too',
#    '!']],
#  ('179668740',
#   '206372245'): [['great', 'look', 'great', 'mixing', '<UNK>', '.'], ['bravo',
#    'to',
#    'you',
#    '!'], ['super', 'bright', 'and', 'fab', '.'], ['congrats',
#    'on',
#    'your',
#    'win',
#    ';',
#    ')',
#    '.'], ['congratulations', '!', 'fun', 'set', '.'], ['bright',
#    '&',
#    'colorful',
#    'summer',
#    'fashion',
#    '.'], ['sunny', 'and', 'fresh', 'look', '.'], ['very',
#    'cool',
#    'and',
#    'trendy',
#    '!',
#    'congrats',
#    '!']],
#  ('34625531',
#   '131006260'): [['so', 'pretty', 'and', 'sophisticated', '!', ':', ')', '.']],
#  ('34625531', '131562511'): [['soo', 'lovely', '!'],
#   ['would', 'wear', 'this', ':', ')', '.']],
#  ('192500655',
#   '185115070'): [['congratulations',
#    'on',
#    'your',
#    '1st',
#    'place',
#    'win',
#    '!'], ['lovely', 'set', '.', 'congrats', 'on', 'your', 'win', '.']],
#  ('192500655', '189053329'): [['wow', '!', 'flawless', '!'],
#   ['stylish',
#    'and',
#    'fab',
#    'outfit',
#    'here',
#    'totally',
#    'nice',
#    'combo',
#    'fab',
#    'set',
#    '~',
#    '.']],
#  ('192500655', '189310646'): [['stylish', 'look', '¤', '.']],
#  ('192500655', '192220577'): [['quirky', 'and', 'chic', '!']],
#  ('192500655', '200243377'): [['most', 'exquisite', '!', '<', '3', '.'],
#   ['please', 'join', 'shein', 'contest', ':', '.'],
#   ['great', 'look', 'great', 'set', 'nice', 'color', '.'],
#   ['feminine',
#    'casual',
#    'for',
#    'this',
#    'season',
#    'fab',
#    'outfit',
#    'and',
#    'this',
#    'style',
#    '!'],
#   ['ultra', 'classy', '!'],
#   ['fabulous', 'style', ',', 'love', 'the', 'coat', 'color', '.'],
#   ['stunning', 'set', 'perfectly', 'designed', '.']],
#  ('146832680', '148597162'): [['great', 'set', '!', 'enter', ':', '.'],
#   ['so', 'cool', 'set', '...', 'enter', ':', '.']],
#  ('55322257', '53863269'): [['phenomenal', '<UNK>', '.'],
#   ['oooo', 'you', 'made', 'an', 'amazing', 'set', '!', 'perfect', '.'],
#   ['wow',
#    'sweetie',
#    'this',
#    'is',
#    'so',
#    'lovely',
#    'yet',
#    'cool',
#    'style',
#    '!'],
#   ['dear',
#    ',',
#    'i',
#    'am',
#    'obsessed',
#    'with',
#    'your',
#    'sets',
#    '!',
#    'they',
#    'are',
#    'gorgeous',
#    '!',
#    'sincerely',
#    ',',
#    '<UNK>',
#    '.'],
#   ['dear',
#    'this',
#    'is',
#    'perfect',
#    '!',
#    ':',
#    'd',
#    'love',
#    'the',
#    'dress',
#    '.']],
#  ('55322257', '54449077'): [['sooo', 'cute', '!']],
#  ('55322257',
#   '55826765'): [['this',
#    'set',
#    'is',
#    'something',
#    'perfect',
#    ',',
#    'love',
#    'everything',
#    'about',
#    'it',
#    '<',
#    '3333333',
#    '.'], ['great',
#    'great',
#    'styling',
#    ',',
#    'love',
#    'the',
#    'details',
#    'and',
#    'all',
#    ':',
#    ')',
#    '.'], ['full', 'of', 'style', 'and', 'energy', '!'], ['wow',
#    '!',
#    'gorgeous',
#    'hun',
#    '!',
#    'looove',
#    'it',
#    '!'], ['brilliant',
#    'styling',
#    ',',
#    'love',
#    'the',
#    'whole',
#    'outfit',
#    '!'], ['so',
#    'amazing',
#    'set',
#    '!',
#    'i',
#    'love',
#    'all',
#    'these',
#    'colors',
#    '!'], ['soooo',
#    '<UNK>',
#    '<UNK>',
#    'it',
#    '!',
#    'the',
#    'colors',
#    'look',
#    'great',
#    'together',
#    '!'], ['oh',
#    ',',
#    'what',
#    'a',
#    'fun',
#    '&',
#    'perfect',
#    'gift',
#    'for',
#    '!',
#    ':',
#    ')',
#    ')',
#    ')',
#    '.'], ['amazing',
#    '...',
#    'such',
#    'a',
#    'cool',
#    'set',
#    'and',
#    'outfit',
#    '...',
#    'stylish',
#    'and',
#    'fun',
#    '...',
#    'looove',
#    'it',
#    '.'], ['i',
#    'used',
#    'to',
#    'have',
#    'those',
#    'all',
#    'stars',
#    '!',
#    'this',
#    'exact',
#    'pair',
#    'and',
#    'color',
#    '!',
#    ':',
#    'p',
#    '.'], ['so',
#    'fun',
#    'and',
#    'stylish',
#    '!',
#    'great',
#    'mix',
#    'of',
#    'items',
#    '!'], ['such',
#    'a',
#    'pretty',
#    'set',
#    '<',
#    '33',
#    'really',
#    'chic',
#    '(',
#    ':',
#    '.'], ['so',
#    'cute',
#    ',',
#    'fun',
#    'and',
#    'quirky',
#    '!',
#    'in',
#    'love',
#    'with',
#    'this',
#    'darling',
#    '.'], ['your', 'taste', 'in', 'fashion', 'amazes', 'me', '!'], ['beautiful',
#    'colors',
#    'and',
#    'prints',
#    '!'], ['so',
#    'adorable',
#    '!',
#    'amazing',
#    'top',
#    'and',
#    'skirt',
#    '!',
#    'lovely',
#    'bag',
#    '!',
#    'adore',
#    '!'], ['such', 'a', 'fun', 'set', '!'], ['this',
#    'is',
#    'gorgeous',
#    ',',
#    'dear',
#    '!',
#    'i',
#    'love',
#    'you',
#    'used',
#    'red',
#    'too',
#    'lately..',
#    '<UNK>',
#    'love',
#    'this',
#    'combo',
#    '!',
#    'fab..',
#    ':',
#    ')',
#    '.'], ['thank',
#    'you',
#    'again',
#    ',',
#    'dear',
#    ',',
#    'i',
#    'love',
#    'this',
#    'so',
#    'much',
#    '!'], ['amazing', 'sweetie', '!', 'xoxo', '.'], ['you',
#    'are',
#    'so',
#    'wonderfully',
#    'combines',
#    '<UNK>',
#    '<UNK>',
#    'things',
#    '!',
#    'get',
#    'out',
#    'tremendous',
#    'outfit',
#    '!'], ['cute',
#    ',',
#    'she',
#    'is',
#    'right',
#    ',',
#    'below',
#    ',',
#    'full',
#    'of',
#    'energy',
#    ':',
#    ')',
#    '.'], ['coool', 'set', '!'], ['this',
#    'is',
#    'such',
#    'a',
#    'fun',
#    'set',
#    '!',
#    'i',
#    'love',
#    'it',
#    '!'], ['wooow', ',', 'sooooooo', 'looovely', '!'], ['so',
#    '<UNK>',
#    'girly',
#    'lovely',
#    'set',
#    'dear',
#    '.',
#    'those',
#    'colors',
#    'and',
#    'animal',
#    'prints',
#    'combo',
#    'is',
#    'cool',
#    '!',
#    'love',
#    'everything',
#    'in',
#    'this',
#    'set',
#    '!',
#    'great',
#    'job',
#    'as',
#    'always',
#    '!',
#    '<',
#    '3',
#    '.'], ['wonderful', ',', 'just', 'amazing', 'skirt', '.', '!'], ['funky',
#    ',',
#    'fun',
#    '&',
#    'unique',
#    '!',
#    'we',
#    'need',
#    'more',
#    'outfits',
#    'like',
#    'this',
#    '!',
#    'genius',
#    '!'], ['hmm',
#    ',',
#    'i',
#    'need',
#    'to',
#    'use',
#    'that',
#    'skirt',
#    ',',
#    'it',
#    "'s",
#    'gorgeous',
#    ':',
#    ')',
#    ')',
#    'this',
#    'set',
#    'is',
#    'so',
#    'fun',
#    'and',
#    'beautiful',
#    '!'], ['wooow', 'fantastic', '!'], ['awesome',
#    'set..hugs',
#    'oxox',
#    '.'], ['awww', 'soo', 'cute..'], ['wow',
#    '!',
#    'such',
#    'a',
#    'unique',
#    'retro',
#    'style',
#    ',',
#    'love',
#    'it',
#    'so',
#    'much',
#    'honey',
#    '.'], ['adorable',
#    'outfit',
#    '!',
#    'the',
#    'whole',
#    'set',
#    'is',
#    'very',
#    'cute',
#    'and',
#    'funny',
#    '!',
#    'love',
#    'that',
#    'bag',
#    '!',
#    'love',
#    'also',
#    'the',
#    'top',
#    '!',
#    'xxx',
#    '.'], ['wow', 'i', 'adore', 'this', 'honey', 'xoxo', '.'], ['love',
#    'this',
#    'style..',
#    'great',
#    'look',
#    '.'], ['really',
#    'sweet',
#    'color',
#    'mix',
#    'dear',
#    '<',
#    '3',
#    'love',
#    'it',
#    '!'], ['love',
#    'the',
#    'side',
#    'happy',
#    'of',
#    'this',
#    'set',
#    '!'], ['playful', 'and', 'happy', '!', 'great', 'styles', 'and', 'colours', '!', 'awesome', 'set', '.', 'love', 'this.x', '.'], ['wow',
#    'darling',
#    '!',
#    'this',
#    'set',
#    'is',
#    'amazing',
#    'for',
#    'summer',
#    'time',
#    '!',
#    'so',
#    'chic',
#    'and',
#    'feminine',
#    ':',
#    ')',
#    ')',
#    '.'], ['beyond', 'perfection', 'sweetheart', '!'], ['wodear',
#    '...',
#    '..',
#    'totally',
#    'awesome..',
#    'fantastic',
#    'set',
#    '!'], ['gorgeous',
#    'darling',
#    ',',
#    'awesome',
#    'pictures',
#    'and',
#    'very',
#    'cool',
#    'outfit',
#    '!'], ['fabulous', 'darlin', "'", '!'], ['this',
#    'is',
#    'so',
#    'gorgeous',
#    'and',
#    'adorable',
#    ',',
#    'sweetie',
#    '!',
#    'a',
#    'wonderful',
#    'gift',
#    'xoxoxo',
#    '.'], ['chic',
#    ',',
#    'colorful',
#    ',',
#    'simply',
#    'a',
#    'lovely',
#    'set',
#    '!'], ['fresh', 'and', 'perfectly', 'beautiful', 'for', 'an', 'a', 'm', 'a', 'z', 'i', 'n', 'g', 'friend', '!'], ['amazing',
#    '!',
#    'love',
#    'all',
#    'item',
#    'you',
#    'used',
#    '!'], ['gorgeous', 'sweetie', '<', '33', ':', 'd', '.'], ['so',
#    'fun',
#    'and',
#    'tropical',
#    '!',
#    'great',
#    'colors',
#    '!'], ['oh',
#    'so',
#    'cute',
#    '.',
#    'love',
#    'how',
#    'this',
#    'set',
#    'is',
#    'just',
#    'popping',
#    '.'], ['wonderful',
#    'set',
#    'sweetie',
#    '=',
#    ')',
#    ')',
#    'and',
#    'so',
#    'cute',
#    'pictures',
#    '.'], ['wooooo', 'so', 'sweet', '!', 'love', 'it', ':', ')', '.'], ['love',
#    'your',
#    'set',
#    'especially',
#    'the',
#    'handbag',
#    ',',
#    'my',
#    'dear',
#    '!'], ['so', 'much', 'fun', '!', '<', '33', '.'], ['woaw',
#    'amazing',
#    'my',
#    'dear',
#    '!',
#    'love',
#    'this',
#    '<UNK>',
#    '.'], ['what',
#    'an',
#    'amazng',
#    'set',
#    '!',
#    'i',
#    'really',
#    'love',
#    'this',
#    '!',
#    'great',
#    'styles',
#    '.']],
#  ('202340999',
#   '172375933'): [['really',
#    'fab',
#    '!',
#    'love',
#    'that',
#    'combo',
#    '!',
#    'xoxo',
#    '.']],
#  ('202340999', '195479135'): [['just', 'darling', '.']],
#  ('202340999', '206294739'): [['izuzetno', 'lijepo', '!']],
#  ('192412208',
#   '178853156'): [['great', ',', 'i', 'would', 'like', 'wear', 'it', '.']],
#  ('215459914', '215458931'): [['simply', 'lovely', '!'],
#   ['incredible', 'set', '.'],
#   ['great', 'combination', '.'],
#   ['splendid', 'look', '.'],
#   ['great',
#    'look',
#    'great',
#    'set',
#    'great',
#    'mixing',
#    'w/',
#    'stripes',
#    'n',
#    "'",
#    'nice',
#    '<UNK>',
#    '.'],
#   ['love', 'the', 'earrings', 'and', 'the', 'shirt', '.']],
#  ('156849784', '132985025'): [['amazing', 'style', 'and', 'color', '!'],
#   ['cute', 'skirt', '!'],
#   ['impeccable', 'style', 'and', 'design', '!'],
#   ['gorgeous', 'mint', '!', 'so', 'pretty', 'laura', '!'],
#   ['wonderful',
#    'set',
#    'and',
#    'ice',
#    'skating',
#    'style',
#    ',',
#    'with',
#    'the',
#    'perfect',
#    'colours',
#    '!',
#    'happy',
#    'new',
#    'year',
#    'my',
#    'dear',
#    'friend',
#    '!',
#    'best',
#    'wishes',
#    '!',
#    'xxx',
#    '.'],
#   ['cute',
#    'n',
#    'cosy',
#    '!',
#    'love',
#    'the',
#    'mint',
#    'green',
#    'bag',
#    ':',
#    ')',
#    ')',
#    '.'],
#   ['love', 'it', ',', 'great', 'colour', 'combo', '!'],
#   ['ooooooh', 'am', 'loving', 'your', 'green', 'sets', '!'],
#   ['mint', 'love', '.'],
#   ['divine', '!', 'love', 'this', 'mint', 'ice', 'blue', '!']],
#  ('156849784',
#   '187722279'): [['this',
#    'is',
#    'so',
#    'cute',
#    '!',
#    'i',
#    "'d",
#    'wear',
#    'that',
#    'dress',
#    '200',
#    '%',
#    '.'], ['thank',
#    'you',
#    'sweetie',
#    '!',
#    'yes',
#    'it',
#    "'s",
#    'so',
#    'lovely',
#    'and',
#    'cute',
#    'dress',
#    '.']],
#  ('97757053', '94185594'): [['sooo', 'amazing', 'look', 'sweetie', '.']],
#  ('97757053',
#   '97634316'): [['gorgeous',
#    'sweetie',
#    'you',
#    'can',
#    'tell',
#    'you',
#    'put',
#    'in',
#    'a',
#    'lot',
#    'of',
#    'effort',
#    'into',
#    'your',
#    'sets',
#    '!',
#    ':',
#    ')',
#    '.'], ['sweetie',
#    'this',
#    'is',
#    'so',
#    'pretty',
#    'fab',
#    'so',
#    'much',
#    'this',
#    'style',
#    'and',
#    'all',
#    'detail',
#    'too',
#    '!']],
#  ('117712136',
#   '116246993'): [['beautiful',
#    '!',
#    'i',
#    'love',
#    'this',
#    'set',
#    'dear',
#    '!',
#    'the',
#    'style',
#    'is',
#    'perfect',
#    '&',
#    'so',
#    'glamorous',
#    'looking',
#    '!'], ['stunning', 'darling', ';', 'd', '.']],
#  ('117712136',
#   '130173400'): [['<UNK>',
#    'follow',
#    'my',
#    'account',
#    'polyvore',
#    '.'], ['wowww', 'love', 'the', 'look', 'so', 'much', '.']],
#  ('61545707', '119198144'): [['thank', 'youu', '.']],
#  ('209144606',
#   '204071710'): [['gorgeous',
#    'look',
#    'join',
#    'also',
#    'here',
#    'win',
#    'shein',
#    '$',
#    '35',
#    'coupon',
#    '--',
#    '>',
#    '.']],
#  ('201790879', '194409308'): [['hope', 'you', 'guys', 'like', 'it', '!']],
#  ('201790879',
#   '195531790'): [['stylish',
#    'spring',
#    'fashion',
#    'and',
#    'fab',
#    'this',
#    'combo',
#    'too',
#    '.']],
#  ('201790879',
#   '203167841'): [['i',
#    'love',
#    'how',
#    'harmonious',
#    ',',
#    'yet',
#    'eclectic',
#    'this',
#    'set',
#    'was',
#    'executed',
#    '.',
#    'well',
#    'done',
#    '.']],
#  ('143269897', '142013601'): [['just', 'magnificent', '.']],
#  ('143269897', '150726380'): [['omg', '!', 'perfect', 'combination', '!']],
#  ('143269897', '160461274'): [['thank', 'u', '.']],
#  ('127296564', '112733613'): [['fantastically', 'cool', '!'],
#   ['thank',
#    'you',
#    'so',
#    'much',
#    'have',
#    'a',
#    'wonderful',
#    'weekend',
#    '!',
#    ':',
#    '-',
#    ')',
#    '.'],
#   ['woow', 'great', 'look', '!'],
#   ['fabulous',
#    'dear',
#    '!',
#    'amazing',
#    'weekend',
#    'set',
#    '!',
#    'a',
#    'top',
#    'set',
#    'for',
#    'sure',
#    '!'],
#   ['gorgeous', 'set', '!', 'xo', ',', 'lvr', '.'],
#   ['thank',
#    'you',
#    'so',
#    'much',
#    'for',
#    'all',
#    'your',
#    'support',
#    '!',
#    ':',
#    '-',
#    ')',
#    ')',
#    '.'],
#   ['thank',
#    'you',
#    'so',
#    'much',
#    'and',
#    '!',
#    ':',
#    '-',
#    ')',
#    'have',
#    'a',
#    'wonderful',
#    'weekend',
#    '!'],
#   ['great', 'styling', 'sweetie', '!', 'have', 'a', 'happy', 'weekend', '!'],
#   ['#', 'awesomestyling', '#', 'great', 'weekend', 'look', '!'],
#   ['so', 'niceeee', '.'],
#   ['thank',
#    'you',
#    'so',
#    'much',
#    'and',
#    ':',
#    '-',
#    ')',
#    'have',
#    'a',
#    'nice',
#    'weekend',
#    '!'],
#   ['<UNK>',
#    ',',
#    'this',
#    'is',
#    'cute',
#    '.',
#    'check',
#    'out',
#    'my',
#    'selection',
#    '--',
#    '>',
#    ';',
#    '-',
#    ')',
#    'xoxo',
#    '.'],
#   ['cool', 'weekend', 'style', '!']],
#  ('64634438',
#   '65365329'): [['i',
#    'love',
#    'the',
#    'combination',
#    'of',
#    'green',
#    'and',
#    'brown',
#    'colors',
#    ',',
#    'i',
#    'think',
#    'this',
#    'is',
#    'great',
#    'combo',
#    '.',
#    'i',
#    'adore',
#    'the',
#    'sunglasses',
#    '.']],
#  ('211028890',
#   '171177845'): [['great',
#    'and',
#    'so',
#    'cool',
#    'set',
#    '!',
#    '╰',
#    '(',
#    ')',
#    '.'], ['``',
#    'caught',
#    'in',
#    'a',
#    'lie',
#    "''",
#    '(',
#    'tag',
#    'list',
#    '1',
#    ')',
#    '-',
#    '.'], ['thanks', 'you', '^^', '.']],
#  ('211028890',
#   '202957146'): [['this', 'is', 'so', 'lovely', 'my', 'friend', '.'], ['so',
#    'comfy',
#    'and',
#    'stylish',
#    '!'], ['i', 'love', 'these', '.'], ['omg',
#    'yess',
#    '!',
#    'i',
#    'just',
#    'luv',
#    'that',
#    'hoodie',
#    'the',
#    'one',
#    'that',
#    'says',
#    '<UNK>',
#    '.']],
#  ('211028890', '204072072'): [['i', 'loove', '<UNK>', '.'],
#   ['np', '<UNK>', 'it', 'is', 'everything', '.'],
#   ['ilysm', 'too', '!', '¤¤', '.'],
#   ['adidas',
#    'are',
#    'my',
#    'life',
#    '!',
#    'i',
#    'literally',
#    'have',
#    'so',
#    'many',
#    'lol',
#    '.'],
#   ['tysm', 'bestie', '!', '¤', '.'],
#   ['thank', 'you', 'so', 'much', 'love', '...', 'amazing', 'set¤', '.'],
#   ['tysm', 'bestie', '!', 'love', 'it', ',', 'babe', '!'],
#   ['adidas', 'is', 'everything', 'love', 'it', '.']],
#  ('211028890', '214718546'): [['rita', '--', '--', '--', '<UNK>', '.']],
#  ('156895610',
#   '122991752'): [['fabulous',
#    'set',
#    'love',
#    'the',
#    'color',
#    'combination',
#    '.']],
#  ('156895610',
#   '145016479'): [['cute', 'little', 'trouble', ':', ')', 'great', 'set', '!']],
#  ('128179194',
#   '113435729'): [['thank',
#    'you',
#    '!',
#    'that',
#    "'s",
#    'what',
#    'i',
#    'was',
#    'going',
#    'for',
#    '!'],
#   ['love',
#    'you',
#    'chose',
#    'the',
#    'neutral',
#    'accessories',
#    'with',
#    'this',
#    'cool',
#    'edgy',
#    'look',
#    '!',
#    'really',
#    'changes',
#    'it',
#    'up',
#    '!',
#    'amazing',
#    'look',
#    '!',
#    'enjoy',
#    'the',
#    'rest',
#    'of',
#    'your',
#    'weekend',
#    'dear',
#    '!']],
#  ('14182889',
#   '100019428'): [['thanks',
#    'for',
#    'your',
#    'set',
#    'giving',
#    'me',
#    'feels',
#    '.'], ['i', "'m", 'sorry', '!'], ['it',
#    "'s",
#    'alright',
#    ',',
#    'it',
#    "'s",
#    'a',
#    '<UNK>',
#    'cool',
#    'outfit',
#    '.']],
#  ('14182889',
#   '59008524'): [['pretty',
#    'set',
#    '!',
#    'kaya',
#    '<UNK>',
#    'is',
#    'gorgeous',
#    'c',
#    ':',
#    '.']],
#  ('14182889',
#   '9583190'): [['this',
#    'layout',
#    'is',
#    'amazing',
#    ',',
#    'love',
#    'it',
#    ':',
#    'd',
#    '.']],
#  ('109429974', '108732816'): [['gorgeous', '!', 'xo', ',', 'lvr', '.']],
#  ('109429974', '118450188'): [['great', 'layout', '.'],
#   ['simple', 'and', 'pretty', '!']],
#  ('209337390', '195733653'): [['well', 'done', '.']],
#  ('209337390',
#   '209437425'): [['great',
#    'look',
#    'great',
#    'set',
#    'great',
#    'mixing',
#    'patterns',
# ...
#    'styling',
#    '!'],
#   ['great',
#    '!',
#    'love',
#    'the',
#    'dress',
#    'and',
#    'the',
#    'bag',
#    ':',
#    ')',
#    'xx',
#    '.'],
#   ['brilliant',
#    'set',
#    '!',
#    'wonderful',
#    'pictures',
#    'and',
#    'great',
#    'look',
#    '!'],
#   ['fabulous', '!', 'colors', 'are', 'so', 'vibrant', 'and', 'bold', '!'],
#   ['wow',
#    '!',
#    'stunning',
#    'does',
#    "n't",
#    'begin',
#    'to',
#    'describe',
#    'this',
#    '.',
#    'this',
#    'is',
#    'just',
#    'brilliant',
#    ',',
#    'so',
#    'very',
#    'fantastic',
#    '.'],
#   ['breathtaking', 'dear', '!'],
#   ['she', "'s", 'so', 'divine', '!', 'splendid', 'creation', '.'],
#   ['wow', '...', '..wow', '...', '..wow', '!', '☆☆☆', '.'],
#   ['i', 'love', 'that', 'dress', '!'],
#   ['ohhhh', 'darling', 'this', 'is', 'gorgeous', '!'],
#   ['stunning', 'dress', '!'],
#   ['this', 'dress', 'is', 'gorgeous', '!'],
#   ['super',
#    'lovely',
#    '!',
#    'dolce',
#    '&',
#    'gabbana',
#    'tapestry',
#    'dress',
#    '!',
#    '<',
#    '3',
#    '<',
#    '3',
#    '.'],
#   ['amazing', 'set', 'dear', ',', 'beautiful', 'dress', '.'],
#   ['beautiful', ',', 'she', 'is', 'awesome', '!', 'stunning', 'dress', '!'],
#   ['asuch', 'beautiful', 'patterns', 'and', 'prints', '!', '<UNK>', '!'],
#   ['oh', ',', 'so', 'amazing', ',', 'dear', '!'],
#   ['<UNK>',
#    "''",
#    'superb',
#    'dress',
#    '.',
#    'love',
#    'the',
#    'pics',
#    ':',
#    ')',
#    '.'],
#   ['fantastic', 'darling', '!'],
#   ['oh', ',', 'sooo', 'lovely', '!', '<', '3', '.'],
#   ['perfection',
#    '<',
#    '3',
#    'awesome',
#    'set',
#    '-',
#    'great',
#    'work',
#    'sweetie',
#    ':',
#    ')',
#    ')',
#    '.'],
#   ['love',
#    'this',
#    'set',
#    ',',
#    'it',
#    'just',
#    'looks',
#    'so',
#    'beautiful',
#    ':',
#    ')',
#    ')',
#    ')',
#    'the',
#    'colours',
#    'are',
#    'so',
#    'pretty',
#    ';',
#    '3',
#    '.'],
#   ['gorge', '!', 'well', 'done', '!'],
#   ['wow', '!', 'oh', 'gosh', 'so', 'beautiful', 'so', 'beautiful', '!'],
#   ['fabulous', '!', 'love', 'the', 'jacket', '!'],
#   ['wonderful',
#    'set',
#    'dear',
#    '!',
#    'love',
#    'this',
#    'dress',
#    'and',
#    'this',
#    'cute',
#    'bag',
#    '!'],
#   ['adore',
#    'this',
#    'dolce',
#    '&',
#    'gabbana',
#    'renaissance',
#    'dress',
#    '!',
#    'amazing',
#    'set',
#    '!'],
#   ['gorgeous', 'dress', 'and', 'set', '!'],
#   ['omg', '!', 'fantastic', 'set', 'and', 'styling', ':', ')', ')', ')', '.'],
#   ['magnificent', 'sweetie', '!'],
#   ['pure', 'perfection', 'dear', '!'],
#   ['breathtaking',
#    'colors',
#    ':',
#    ')',
#    'you',
#    'know',
#    ',',
#    'every',
#    'set',
#    'of',
#    'your',
#    "'s",
#    'remind',
#    'me',
#    'of',
#    'the',
#    'sunset',
#    'because',
#    'that',
#    "'s",
#    'how',
#    'breathtaking',
#    'it',
#    'is',
#    '!',
#    ':',
#    'd',
#    '.'],
#   ['how', 'gorgeous', 'my', 'dear', '!'],
#   ['wowww', 'truly', 'stunning', '.'],
#   ['beautiful',
#    '...',
#    '.love',
#    'the',
#    'dress',
#    'and',
#    'coat',
#    '...',
#    '.totally',
#    'love',
#    'the',
#    'clutch',
#    '!'],
#   ['this', 'set', 'is', 'incredible', '!'],
#   ['woooow', '...', '<UNK>', 'beautiful', 'my', 'darling', '.'],
#   ['woow', ',', 'love', 'it', '.'],
#   ['sooooooo', 'pretty', '.'],
#   ['wooow', ',', 'so', 'stunning', 'and', 'really', 'fantastic', 'dear', '!'],
#   ['very', 'stunning', 'and', 'so', 'striking', '!'],
#   ['wow', 'this', 'is', 'so', 'pretty', 'o', 'high', 'fashion', 'here', '!'],
#   ['adore',
#    'this',
#    'beautiful',
#    'set',
#    '-',
#    'so',
#    'glam',
#    ',',
#    'love',
#    'it',
#    '!'],
#   ['this', 'is', 'omg', 'stunning', '!'],
#   ['haha',
#    ',',
#    'that',
#    'dress',
#    'is',
#    'on',
#    'sale',
#    '...',
#    '<UNK>',
#    'affordable',
#    ';',
#    ')',
#    '!',
#    'love',
#    'your',
#    'combo',
#    '!',
#    'stunning',
#    'look',
#    '!'],
#   ['fantastic', 'set', 'dear', ',', 'love', 'everything', '!', '=', ')', '.'],
#   ['breathtakingly', 'gorgeous', '!'],
#   ['fabulous', 'set', 'hun', '!'],
#   ['this',
#    'looks',
#    'amazing',
#    '!',
#    'i',
#    'love',
#    'the',
#    'deep',
#    'blue',
#    'shade',
#    'the',
#    'coat',
#    'has',
#    '!'],
#   ['amazing', 'darling', '!'],
#   ['wow', 'sooo', 'brilliant', 'set', '!', 'amazing', '.'],
#   ['wow',
#    '...',
#    'love',
#    'the',
#    'clutch',
#    'and',
#    'the',
#    'set',
#    'is',
#    'amazing',
#    '!'],
#   ['this',
#    'is',
#    'so',
#    'gorgeous',
#    '!',
#    'the',
#    'vibrant',
#    'colours',
#    'are',
#    'flying',
#    'right',
#    'off',
#    'the',
#    'page',
#    '...',
#    'outstanding',
#    'sweetie',
#    '!',
#    'xo',
#    '.'],
#   ['please',
#    'follow',
#    'us',
#    'by',
#    'clicking',
#    'our',
#    'polyvore',
#    'page',
#    ':',
#    '.'],
#   ['love', 'this', 'vintage', 'look', '.'],
#   ['love',
#    'this',
#    'style',
#    ',',
#    'such',
#    'gorgeous',
#    'colours',
#    'and',
#    'elegant',
#    'outfit',
#    '!'],
#   ['gorgeous', 'set', '...', 'perfectly', 'styled', '!', ':', ')', ')', '.'],
#   ['beautiful', 'look', 'honey', ',', 'love', 'the', 'dress', '!'],
#   ['wow',
#    ',',
#    'amazingly',
#    'beautiful',
#    '.',
#    'great',
#    'work',
#    'my',
#    'dear',
#    ':',
#    ')',
#    '.'],
#   ['absolutely', 'phenomenal', '!'],
#   ['looks', 'so', 'gorgeous', '!', 'love', 'the', 'colors', '!'],
#   ['my',
#    'mouth',
#    'just',
#    'dropped',
#    'open',
#    '...',
#    '<UNK>',
#    '...',
#    'this',
#    'is',
#    'one',
#    'of',
#    'my',
#    'favorites',
#    'you',
#    "'ve",
#    'ever',
#    'done',
#    '!',
#    'wow..',
#    'the',
#    'colours',
#    'are',
#    'superb',
#    '!'],
#   ['so', 'incredible', '!'],
#   ['perfectly',
#    'capturing',
#    'the',
#    'atmosphere',
#    'in',
#    'the',
#    'form',
#    'of',
#    'clothing',
#    '!',
#    'awesome',
#    '!'],
#   ['gosh', ',', 'gorgeous', '!'],
#   ['incredible', '!', 'amazing', '!'],
#   ['superb', 'set..love', 'it', '!'],
#   ['that',
#    'dress',
#    'is',
#    'beautiful',
#    ',',
#    'fab',
#    'set',
#    'styling',
#    '(',
#    'as',
#    'always',
#    ')',
#    '.'],
#   ['fantastic', ',', 'love', 'how', 'bold', 'this', 'is', '!'],
#   ['spectacular', ',', 'dear', '...', 'gorgeousness', '!']],
#  ('78102684',
#   '31449889'): [['a',
#    'cool',
#    'relaxed',
#    'vibe',
#    'anyone',
#    'can',
#    'bring',
#    'to',
#    'the',
#    'city',
#    '!'], ['thank', "'s", 'sweety', '.'], ['<UNK>',
#    '<UNK>',
#    ',',
#    'ευχαριστ',
#    '.']],
#  ('74771760', '73470859'): [['fab', 'set', 'swetie', '.']],
#  ('105144923',
#   '87781217'): [['i',
#    "'d",
#    'hold',
#    'closer',
#    'than',
#    'i',
#    'ever',
#    'did',
#    'before',
#    '.'], ['you',
#    'can',
#    'be',
#    'beautiful',
#    ',',
#    'wonderful',
#    ',',
#    'anything',
#    'you',
#    'want',
#    'to',
#    'be',
#    '.'], ['omg',
#    '*-*',
#    'you',
#    "'re",
#    'my',
#    '300th',
#    'like',
#    '!',
#    'i',
#    'love',
#    'you',
#    '*-*',
#    '<',
#    '3',
#    '.'], ['you', 'got', 'a', 'bae', ',', 'or', 'nah', '<UNK>', '.']],
#  ('96641744',
#   '96457838'): [['hi', 'dear', ',', 'join', 'my', 'contest', ':', ')', '.']],
#  ('64162599',
#   '38634303'): [['great',
#    'casual',
#    'style',
#    '!',
#    'love',
#    'the',
#    'owl',
#    'top',
#    '!'],
#   ['awesomeness', '!', 'looove', 'this', '!', 'xoxoxo', '.'],
#   ['wonderful', 'for', 'fall', ',', 'looks', 'cosy', 'and', 'comfty', '!'],
#   ['very', 'special', 'set', '!'],
#   ['love',
#    'it',
#    'so',
#    'much',
#    '...',
#    'you',
#    'are',
#    'fantastic',
#    'cute',
#    'my',
#    'friend',
#    ':',
#    ')',
#    'xx',
#    '.'],
#   ['another', 'fantastic', 'outfit', '!', 'very', 'inspiring', '!'],
#   ['fab', '!', 'love', 'the', 'jumper', '!'],
#   ['wow',
#    'dear',
#    'this',
#    'is',
#    'so',
#    'chic',
#    ',',
#    'cool',
#    'yet',
#    'in',
#    'style',
#    'just',
#    'love',
#    'it',
#    'so',
#    'much',
#    'great',
#    'set',
#    '<',
#    '333',
#    '.'],
#   ['special', 'as', 'your', 'all', 'sets', '!', 'fantastic', '!'],
#   ['so', 'young', '!', 'fab', '.'],
#   ['hello',
#    ',',
#    'sweet',
#    'friend',
#    '...',
#    '.love',
#    'this',
#    '...',
#    'the',
#    'outfit',
#    'is',
#    'so',
#    'cute',
#    'and',
#    'totally',
#    'love',
#    'the',
#    'guitar',
#    'in',
#    'the',
#    'background',
#    '!'],
#   ['gorgeous', 'honey', '!', 'so', 'cool', 'and', 'comfort', '.'],
#   ['wow',
#    ',',
#    'this',
#    'set',
#    'is',
#    'awesome',
#    '.',
#    'i',
#    'would',
#    'so',
#    'wear',
#    'this',
#    'super',
#    'comfy',
#    'and',
#    'oh',
#    'so',
#    'chic',
#    'outfit',
#    '.',
#    'love',
#    'the',
#    'owl',
#    'sweater',
#    '.',
#    'perfect',
#    'for',
#    'fall',
#    '.',
#    'love',
#    'this',
#    'so',
#    'much',
#    '.',
#    'xoxoxo',
#    '.'],
#   ['adorable-',
#    'the',
#    'red',
#    'jumper',
#    'and',
#    'the',
#    'blue',
#    'bag',
#    'with',
#    'neutral',
#    'shoes-',
#    'genius',
#    '!'],
#   ['so', 'charming', '!'],
#   ['beautiful', 'set', 'my', 'friend', '!', ':', ')', ')', 'xo', '.']],
#  ('64162599',
#   '67603536'): [['this',
#    'is',
#    'so',
#    'amazing',
#    ',',
#    'i',
#    'love',
#    'the',
#    'owl',
#    'sweater',
#    '!'], ['this',
#    'is',
#    'great',
#    'outfit',
#    ',',
#    'i',
#    'adore',
#    'that',
#    'owl',
#    'sweater',
#    ',',
#    'amazing',
#    'color',
#    'combo',
#    '!'], ['xoxoxo', 'thank', 'you', 'xoxox', '.'], ['superb',
#    ',',
#    'my',
#    'dear',
#    '...',
#    'so',
#    'gorgeous',
#    'and',
#    'chicness',
#    '!'], ['fantastic..hugs', 'xoxo', '.'], ['this',
#    'is',
#    'fantastic',
#    '!',
#    'love',
#    'all',
#    'your',
#    'layouts',
#    '!']],
#  ('149115577',
#   '174650022'): [['demure☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '.'], ['you',
#    'think',
#    'it',
#    'resembles',
#    'me',
#    'really',
#    'thanks',
#    'that',
#    "'s",
#    'so',
#    'nice',
#    ':',
#    ')',
#    '.'], ['ohh',
#    'reading',
#    'your',
#    'answers',
#    'was',
#    'fun',
#    '!',
#    '<',
#    '3',
#    'thanks',
#    'for',
#    'doing',
#    'it',
#    'haha',
#    'i',
#    "'m",
#    'on',
#    'love',
#    'with',
#    'this',
#    'set',
#    'btw',
#    'xx',
#    '.'], ['benevolence☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '.'], ['aquiver☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '.'], ['bombinate☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '.'], ['#', 'pepdothistag', 'hard', 'core', ':', 'p', '.'], ['mellifluous☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '.'], ['this',
#    'is',
#    'such',
#    'a',
#    'beautiful',
#    'set',
#    '!',
#    '(',
#    ':',
#    'cool',
#    'tag',
#    ',',
#    'too',
#    '(',
#    ':',
#    '.'], ['this', 'set', 'is', 'stunninggg', '.'], ['perpetuity☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '☆',
#    '.']],
#  ('168253031', '128151294'): [['soo', 'very', 'lovely', 'and', 'cute', '!'],
#   ['perfect', 'summer', '!'],
#   ['nicely', 'put', 'together', '!']],
#  ('168253031', '136713600'): [['appreciate', 'u', '.']],
#  ('168253031', '142441747'): [['<UNK>', ',', 'moje', 'boje', '!'],
#   ['fantastic', '!', 'graceful', 'look', '.'],
#   ['adore',
#    'this',
#    'combo',
#    'and',
#    'such',
#    'a',
#    'nice',
#    'style',
#    'here',
#    'i',
#    'really',
#    'like',
#    'it',
#    '~~',
#    '.'],
#   ['wonderful', ',', 'sore', 'the', 'colours', '.']],
#  ('168253031',
#   '170232954'): [['great',
#    'outfit',
#    '!',
#    'i',
#    'especially',
#    'love',
#    'those',
#    'shorts',
#    '!']],
#  ('168253031', '177158665'): [['loooove', 'this', 'short', '.'],
#   ['yeah', ',', 'me', 'too', '!']],
#  ('204740705', '201151761'): [['great', 'set', 'great', 'outfits', '.'],
#   ['magnificent', 'combination', '.']],
#  ('204740705', '206301985'): [['beautiful', 'set', 'and', 'style', '¤', '.']],
#  ('126481518',
#   '131561421'): [['thank',
#    'you',
#    'my',
#    'dear',
#    'for',
#    'participation',
#    'in',
#    'nyfw',
#    'contest',
#    ',',
#    'kiss',
#    '!'], ['congrats', 'on', 'your', 'set', 'win', '.'], ['very',
#    'nice',
#    '.',
#    'really',
#    'digging',
#    'the',
#    'simple',
#    'sports',
#    'luxe',
#    'look',
#    '!'], ['unique', 'as', 'usual', '.']],
#  ('126481518',
#   '201480472'): [['gorgeous',
#    ',',
#    'lovely',
#    ',',
#    'and',
#    'cute',
#    'in',
#    'the',
#    'same',
#    'time',
#    '.']],
#  ('191248317', '178931680'): [['looks', 'warm', 'and', 'pretty', '.']],
#  ('58126557',
#   '57922428'): [['thanks',
#    'so',
#    'much',
#    ';',
#    'glad',
#    'you',
#    'like',
#    'it',
#    '.']],
#  ('207095493', '176985956'): [['loving', 'it', '.']],
#  ('207095493',
#   '206233572'): [['love',
#    'the',
#    'pop',
#    'of',
#    'color',
#    '!',
#    'xx',
#    'hugs',
#    '.']],
#  ('207095493',
#   '206981877'): [['lovely',
#    'ruffled',
#    'fashion',
#    'and',
#    'nice',
#    'style',
#    'for',
#    'spring',
#    '!'], ['absolutely', 'exquisite', 'look', 'love', 'it', '.'], ['gorgeous',
#    'my',
#    'dear',
#    'friend',
#    'x',
#    '.']],
#  ('207095493',
#   '207293631'): [['great', 'look', 'great', 'set', 'nice', 'ruffles', '.']],
#  ('207095493', '210456455'): [['fab', 'color', '!'],
#   ['great', 'look', '!', 'loving', 'the', 'skirt', '.']],
#  ('91402708', '116845392'): [['woow', 'so', 'fab', '!'],
#   ['marvelous', 'set', 'dear', '!', 'love', 'these', 'pieces', '!'],
#   ['gorgeous', 'creation', '!'],
#   ['beautiful',
#    'and',
#    'fun',
#    'look',
#    'as',
#    'always',
#    ',',
#    'perfect',
#    '<UNK>',
#    'set~',
#    '<',
#    '3',
#    '.'],
#   ['goddess', '!', 'love', 'every', 'piece', 'to', 'bits', '!'],
#   ['oh', 'this', 'is', 'so', 'lush', 'and', 'green', '!']],
#  ('91402708',
#   '71673920'): [['thank', 'you', 'all', 'soo', 'soo', 'much', '!']],
#  ('91402708', '82794537'): [['fantatic', 'style', 'sweetie', '.'],
#   ['perfect', 'set', 'dear', '!', 'love', 'the', 'shoes', 'so', 'much', '!']],
#  ('101779395',
#   '118508663'): [['i',
#    'really',
#    'mean',
#    'it',
#    ':',
#    ')',
#    'i',
#    'love',
#    'your',
#    'sets',
#    '!'], ['love',
#    'the',
#    'color',
#    'combo',
#    '!',
#    'check',
#    'put',
#    'my',
#    'profile',
#    ':',
#    ')',
#    'outfits',
#    'for',
#    'every',
#    'occasion',
#    '.'], ['thanks',
#    'again',
#    ':',
#    ')',
#    'you',
#    'made',
#    'me',
#    'happy',
#    '.'], ['thank', 'you', 'for', 'all', 'comments', ':', ')', '.']],
#  ('101779395', '120534100'): [['thank', 'you', '!', '~', 'annabeth', '.']],
#  ('101779395', '163605837'): [['stunning', 'look', 'my', 'friend', 'x', '.']],
#  ('165535543',
#   '187597408'): [['stylish',
#    'fashion',
#    'fab',
#    'outfit',
#    'in',
#    'set',
#    '~~',
#    '.']],
#  ('153471199', '80031111'): [['odlican', 'set', '.'],
#   ['stunning',
#    'stylish',
#    '&',
#    'casual',
#    'combo',
#    ',',
#    'love',
#    'a',
#    'poncho',
#    'and',
#    'fab',
#    'set',
#    'here',
#    ':',
#    ')',
#    '.']],
#  ('156380108',
#   '128172178'): [['классный',
#    'и',
#    'супер',
#    'стильный',
#    'образ',
#    '!',
#    'свитерок',
#    'действительно',
#    'миленький',
#    ':',
#    ')',
#    ')',
#    'очень',
#    'нравятся',
#    '<UNK>',
#    'и',
#    'то',
#    ',',
#    'что',
#    'они',
#    'на',
#    '<UNK>',
#    '<UNK>',
#    '.',
#    '<UNK>',
#    ')',
#    ')',
#    '.'], ['oh',
#    'my',
#    '<UNK>',
#    'this',
#    'is',
#    'sooo',
#    'adorable',
#    'love',
#    '!'], ['oh',
#    ',',
#    'such',
#    'a',
#    'great',
#    'idea',
#    'to',
#    'put',
#    'a',
#    'festive',
#    'sweater',
#    'in',
#    'the',
#    'set',
#    '!',
#    'love',
#    'it',
#    'so',
#    'much',
#    '!'], ['neat',
#    'festive',
#    'set',
#    ',',
#    'like',
#    'vet',
#    'the',
#    'hat',
#    '.',
#    'gorgeous',
#    'bag',
#    '.'], ['super', 'super', 'cute', 'xxx', '.'], ['so',
#    'lovely',
#    'and',
#    'cool',
#    'mix',
#    '!']],
#  ('156380108', '157711198'): [['beautiful', 'creation', '!']],
#  ...}

# %%
model_downs_comments
# Out:
# {('177509842',
#   '177295763'): [['very',
#    'casual',
#    'but',
#    'wonderful',
#    'design',
#    '!'], ['great', 'set', '!', 'perfect', 'outfit', 'and', 'layout', '.'], ['so',
#    'awesome',
#    'summer',
#    'look',
#    ',',
#    'so',
#    'pretty',
#    'and',
#    'fresh',
#    'combo',
#    '!'], ['so', 'fresh', '.'], ['perfect',
#    'getaway',
#    'look',
#    ',',
#    'have',
#    'a',
#    'lovely',
#    'sunday',
#    'sweetie',
#    '!',
#    '!',
#    '!'], ['love', 'the', 'cool', 'blues', 'of', 'this', 'set', '!'], ['sweet',
#    'and',
#    'lovely',
#    'holiday',
#    'look',
#    '!'], ['makes', 'me', 'want', 'to', 'go', 'on', 'a', 'holiday', '!']],
#  ('177509842',
#   '177308163'): [['so',
#    'fab',
#    'that',
#    'knit',
#    'sweater',
#    'and',
#    'such',
#    'a',
#    'nice',
#    'style',
#    'cool',
#    'pairing',
#    'with',
#    'flat',
#    'sandals',
#    '!'], ['outstanding',
#    'and',
#    'stunning',
#    'look',
#    'sweetie',
#    '!',
#    'i',
#    "'m",
#    'totally',
#    'amazed',
#    '!'], ['adorable', 'sweetie', '...', 'love', 'it', '¤', '.'], ['today',
#    'is',
#    'wonderful',
#    'and',
#    'so',
#    'are',
#    'you',
#    '.'], ['soo', 'beautiful', 'sweetie..'], ['you',
#    'undoubtedly',
#    'deserve',
#    'the',
#    'best',
#    '.'], ['you',
#    'are',
#    'the',
#    'dancing',
#    'queen',
#    ',',
#    'blood-curdling',
#    'scream',
#    ',',
#    '47',
#    'bees',
#    '.'], ['a', 'great', 'layout', 'and', 'look', '.'], ['such',
#    'a',
#    'cute',
#    'and',
#    'lovely',
#    'pastel',
#    'look',
#    '!'], ['love',
#    'this',
#    'set',
#    'so',
#    'much',
#    'dear',
#    ',',
#    'lovely',
#    'colors',
#    'and',
#    'style',
#    ',',
#    'also',
#    'great',
#    'title',
#    '!'], ['sweet',
#    'winter',
#    'style',
#    '!',
#    'wonderful',
#    'set',
#    'darling',
#    'xoxo',
#    '.'], ['you’re',
#    'bright',
#    'and',
#    'i’m',
#    'so',
#    'proud',
#    'of',
#    'you',
#    '.'], ['a', 'grace', '!'], ['congrats',
#    'on',
#    'your',
#    'win',
#    '!'], ['gorgeous',
#    'sweater',
#    ',',
#    'lovely',
#    'set',
#    'my',
#    'dear',
#    ':',
#    ')',
#    '.'], ['do', 'something', 'you', 'love', 'today', '.']],
#  ('177509842',
#   '180707667'): [['today',
#    'is',
#    'wonderful',
#    'and',
#    'so',
#    'are',
#    'you',
#    '.'], ['clean',
#    ',',
#    'organised',
#    'and',
#    'perfect',
#    '!',
#    'happy',
#    '<UNK>',
#    'darling',
#    '!',
#    'xx',
#    '.'], ['adorable',
#    'creation',
#    'and',
#    'fab',
#    'outfit',
#    'here',
#    'such',
#    'a',
#    'nice',
#    'style',
#    'way',
#    'too',
#    'cute',
#    'for',
#    'casual~',
#    '.'], ['you',
#    'are',
#    'the',
#    'dancing',
#    'queen',
#    ',',
#    'blood-curdling',
#    'scream',
#    ',',
#    '47',
#    'bees',
#    '.'], ['you', 'undoubtedly', 'deserve', 'the', 'best', '.'], ['lovely',
#    'set',
#    'as',
#    'always',
#    'sweetie',
#    '...',
#    'and',
#    'i',
#    'agree',
#    'with',
#    ';',
#    'tomorrow',
#    'is',
#    'a',
#    'new',
#    'day',
#    ';',
#    ')',
#    '.'], ['this', 'is', 'very', 'enchanting', 'my', 'dear', '!'], ['you’re',
#    'bright',
#    'and',
#    'i’m',
#    'so',
#    'proud',
#    'of',
#    'you',
#    '.'], ['everyone',
#    'has',
#    'those',
#    'days',
#    '.',
#    'the',
#    'best',
#    'thing',
#    'you',
#    'can',
#    'while',
#    'going',
#    'through',
#    'one',
#    'is',
#    'reminding',
#    'yourself',
#    'that',
#    'tomorrow',
#    'is',
#    'a',
#    'new',
#    '<UNK>',
#    'look',
#    ',',
#    'love',
#    '.'], ['do', 'something', 'you', 'love', 'today', '.'], ['it',
#    "'ll",
#    'all',
#    'fall',
#    'into',
#    'place',
#    ',',
#    'just',
#    'do',
#    "n't",
#    'give',
#    'up',
#    '!',
#    'wonderful',
#    'choices',
#    'on',
#    'this',
#    'set',
#    ',',
#    'dear',
#    '!',
#    '<',
#    '3',
#    'xoxoxo',
#    '.'], ['flawless', 'and', 'fabulous', 'set', '.'], ['those',
#    'are',
#    'the',
#    'days',
#    'that',
#    'make',
#    'you',
#    'appreciate',
#    'when',
#    'good',
#    'days',
#    'are',
#    'a',
#    'blessing',
#    '.',
#    'good',
#    'energy',
#    ',',
#    'good',
#    'energy',
#    '...',
#    'cute',
#    'denim',
#    'style',
#    'sweetie',
#    '.'], ['cute', 'styling', '.', 'tomorrow', "'s", 'a', 'new', 'day', '.']],
#  ('177509842',
#   '196161005'): [['so',
#    'cute',
#    'for',
#    'summer',
#    'day',
#    'out',
#    'such',
#    'a',
#    'nice',
#    'style',
#    'love',
#    'it',
#    '!']],
#  ('177509842',
#   '201893923'): [['so',
#    'cute',
#    'for',
#    'summer',
#    'day',
#    'out',
#    'such',
#    'a',
#    'nice',
#    'style',
#    'love',
#    'it',
#    '!']],
#  ('24125032', '25465693'): [['it', 'looks', 'very', 'nice', '.'],
#   ['i', 'love', 'these', 'shoes', '!'],
#   ['super', 'gift', 'for', 'such', 'talented', 'and', 'lovely', 'girls', '!'],
#   ['so',
#    'amazing',
#    ',',
#    'i',
#    'love',
#    'those',
#    'heels',
#    'and',
#    'that',
#    'velvet',
#    'bag',
#    'is',
#    'so',
#    'gorg',
#    '!',
#    ':',
#    'd',
#    '.'],
#   ['wow',
#    '!',
#    'so',
#    'lovely',
#    '&',
#    'got',
#    'style',
#    'dear',
#    'love',
#    'this',
#    'set',
#    'so',
#    'much',
#    'this',
#    'is',
#    'perfect',
#    'dear',
#    ':',
#    ')',
#    ')',
#    ')',
#    '.'],
#   ['jac',
#    'looks',
#    'amazing',
#    'here',
#    '.',
#    'and',
#    'this',
#    'is',
#    'a',
#    'very',
#    'chic',
#    'set',
#    '!'],
#   ['thank',
#    'you',
#    'soooo',
#    'much',
#    ',',
#    'hun',
#    '!',
#    '<UNK>',
#    'beautiful',
#    'set',
#    '...',
#    '.',
#    'very',
#    'cool',
#    'outfit',
#    '!']],
#  ('24125032', '71322017'): [['fantastic', 'winter', 'set', '!']],
#  ('24125032', '72761319'): [['fantastic', 'winter', 'set', '!']],
#  ('174087169',
#   '114548173'): [['fab',
#    'this',
#    'chic',
#    'stylish',
#    'and',
#    'simple',
#    'look',
#    '.'], ['fabulous', 'items', '.'], ['really',
#    'amazing',
#    'style',
#    ',',
#    'wish',
#    'to',
#    'wear',
#    'it',
#    ',',
#    'wow',
#    ',',
#    'dear',
#    '!',
#    ';',
#    ')',
#    '.'], ['love', 'the', 'coat', '!'], ['so',
#    'simple',
#    'and',
#    'perfect',
#    '!'], ['for', 'you.xoxomarty', '.'], ['fantastic',
#    '!',
#    'love',
#    'this',
#    'look',
#    '!',
#    'so',
#    'gorgeous',
#    'and',
#    'chic',
#    '!',
#    'divine',
#    '!'], ['love', 'the', 'way', 'you', 'styled', 'this', '!'], ['great',
#    'casual',
#    'styling',
#    '!',
#    'i',
#    'love',
#    'this',
#    'heather',
#    'colored',
#    'top',
#    'coat',
#    'with',
#    'these',
#    'simple',
#    'pieces',
#    '!'], ['this',
#    'is',
#    'beyond',
#    'chic',
#    'and',
#    'amazing',
#    '!',
#    'wonderful',
#    'look',
#    'as',
#    'always',
#    '!'], ['happy',
#    'new',
#    'year',
#    'el',
#    "'s",
#    '!',
#    'sending',
#    'you',
#    'hugs',
#    'xxx',
#    '!'], ['lovely', 'choice', ':', ')', '.'], ['great',
#    'style',
#    ',',
#    'love',
#    'this',
#    'simple',
#    'minimal',
#    'laid',
#    'back',
#    'look',
#    '!'], ['fantastic',
#    'winter',
#    '<UNK>',
#    '!',
#    'this',
#    'is',
#    'amazing',
#    'as',
#    'always',
#    '.'], ['very', 'chic', 'street', 'style', '!'], ['such',
#    'a',
#    'wonderful',
#    'set',
#    'my',
#    'dear',
#    ',',
#    'so',
#    'elegant',
#    'and',
#    'stylish',
#    '!'], ['love',
#    'this',
#    'set',
#    'dear',
#    '*-*',
#    'the',
#    'colors',
#    'are',
#    'so',
#    'pretty',
#    '.']],
#  ('174087169', '138386406'): [['nice', '!', 'congrats', 'on', 'tops', '.'],
#   ['congrats', 'on', 'top', 'sets', 'today~', '.']],
#  ('174087169', '140735506'): [['nice', '!', 'congrats', 'on', 'tops', '.'],
#   ['congrats', 'on', 'top', 'sets', 'today~', '.']],
#  ('174087169', '175502336'): [['best', 'meg', 'set', '.']],
#  ('38813616', '47224516'): [['fabbbb', '!', 'happy', 'new', 'year', '!'],
#   ['happy', 'new', 'year', 'to', 'you', 'also', '!'],
#   ['your', 'sets', 'are', 'sooo', 'wonderful', 'and', 'lovely', '!'],
#   ['happy', 'new', 'year', '!', 'so', 'lovely', '!'],
#   ['have',
#    'a',
#    'great',
#    '2012',
#    '!',
#    'happy',
#    'new',
#    'year',
#    '!',
#    'fabulous',
#    'look',
#    ';',
#    ')',
#    '.'],
#   ['so', 'dazzling', ':', 'congrats', 'on', 'top', 'sets', '!'],
#   ['gorgeous', '!', 'happy', 'new', 'year', '!'],
#   ['superb', ',', 'dear', '...', 'happy', 'new', 'year', '!'],
#   ['loooove', 'thisss', '.'],
#   ['love', 'this', 'colorful', 'set', '!', ':', ')', ')', '.'],
#   ['this', 'looks', 'so', 'gorgeous', '!'],
#   ['happy', 'new', 'year', '!', 'it', "'s", 'an', 'amazing', 'set', '!'],
#   ['sooo', 'fab', 'dear', '!', 'happy', 'new', 'year', '.'],
#   ['so', 'elegant', 'outfit', '!', 'amazing', 'dear', '!', ':', ')', '.'],
#   ['happy', 'new', 'year', '!', ':', 'd', '.'],
#   ['amazing', ',', 'happy', 'new', 'year', 'dear', '.'],
#   ['thank', 'youu', '!'],
#   ['gorgeous', '!', 'happy', 'new', 'year', '!', '1', '.'],
#   ['happy',
#    'new',
#    'year',
#    'dear',
#    '!',
#    'congrats',
#    'on',
#    'top',
#    'sets',
#    'dear',
#    '!']],
#  ('38813616', '47581307'): [['so', 'romantic', ':', ')', '.'],
#   ['σ', "'", '<UNK>', '!', ':', 'd', '.'],
#   ['πολ', 'μορφο', '!']],
#  ('100459830', '82879583'): [['life', '<UNK>', 'gah', 'hes', 'perf', '.'],
#   ['luke', 'hemmings', 'is', 'a', 'bish', '.'],
#   ['`four`',
#    'oh',
#    ',',
#    'it’s',
#    'what',
#    'you',
#    'do',
#    'to',
#    'me',
#    'is',
#    'rad',
#    'as',
#    'is',
#    'really',
#    'sweet',
#    'ash',
#    'is',
#    'an',
#    'amazing',
#    'setmaker',
#    'and',
#    'writer',
#    '.'],
#   ['luke',
#    'hemmings',
#    'is',
#    'definitely',
#    '<UNK>',
#    'is',
#    'ashton',
#    '<UNK>',
#    '<UNK>',
#    'also',
#    'love',
#    'this',
#    'set',
#    'jemma',
#    '^.^',
#    '.'],
#   ['aha',
#    'yeahhh',
#    'and',
#    'yeah',
#    'and',
#    'yeah',
#    '.',
#    '<UNK>',
#    'tho',
#    '.',
#    'and',
#    '<UNK>',
#    'he',
#    'got',
#    'it',
#    'a',
#    'while',
#    'back',
#    ',',
#    'i',
#    '<UNK>',
#    'farrah',
#    ',',
#    'only',
#    'you',
#    '.'],
#   ['`three`',
#    'listen',
#    'to',
#    'my',
#    'voice',
#    'it’s',
#    'my',
#    'disguise',
#    'has',
#    'cute',
#    'sets',
#    'makes',
#    'perfect',
#    'sets',
#    'is',
#    'fab',
#    'is',
#    'perf',
#    'is',
#    'lovely',
#    '#',
#    'marinaluvsu',
#    '.'],
#   ['be',
#    'my',
#    'valentine',
#    'jem',
#    'did',
#    'you',
#    'see',
#    'my',
#    'valentine',
#    "'s",
#    'day',
#    'card',
#    'for',
#    'you',
#    '.'],
#   ['this',
#    'outfit',
#    'is',
#    'super',
#    'cute',
#    '<UNK>',
#    'i',
#    'saw',
#    'a',
#    'video',
#    'on',
#    'the',
#    '5sos',
#    'instagram',
#    'account',
#    'and',
#    'luke',
#    'has',
#    'a',
#    'lip',
#    'ring',
#    'eek',
#    'is',
#    'that',
#    'new',
#    '!',
#    'it',
#    "'s",
#    'hot',
#    '.']],
#  ('210336059', '209784122'): [['excellent', 'set', '!'],
#   ['great', 'look', 'great', 'outfits', 'n', "'", 'nice', 'denim', '.'],
#   ['amen', ',', 'sista', '!'],
#   ['how', 'pretty', '.'],
#   ['so', 'cool', '!', 'yeah', 'feminist', '.']],
#  ('106229316', '102269368'): [['awe', 'thanks', '!']],
#  ('106229316', '105468756'): [['awe', 'thanks', '!']],
#  ('106229316', '116740056'): [['that', 'hair', 'though', 'x', '.']],
#  ('124461011', '110256346'): [['thank', 'u', 'ladies', ':', '*', '&', '.'],
#   ['omggg', 'i', 'just', 'love', 'it', '.']],
#  ('124461011',
#   '121606000'): [['i',
#    'think',
#    'a',
#    'splash',
#    'of',
#    'green',
#    '(',
#    'maybe',
#    'a',
#    'plaid',
#    'shirt',
#    ')',
#    'or',
#    'something',
#    'with',
#    'a',
#    'bit',
#    'of',
#    'color',
#    'would',
#    'have',
#    'ben',
#    'useful',
#    '...'], ['very', 'classic', 'winter', 'outfit', '!']],
#  ('124461011', '129850571'): [['thank', 'u', 'ladies', ':', '*', '&', '.'],
#   ['omggg', 'i', 'just', 'love', 'it', '.']],
#  ('124461011',
#   '136448733'): [['sorry',
#    'about',
#    'the',
#    'spelling',
#    'i',
#    'ment',
#    'to',
#    'say',
#    'wear',
#    '!']],
#  ('124461011',
#   '145417179'): [['so', 'cute', 'those', 'boots', 'are', 'amazing', '!']],
#  ('168533965', '136884668'): [['join', 'new', 'yoins', '.']],
#  ('197520600', '185518291'): [['lol', '!', 'thanks', '!'],
#   ['<UNK>', '!', 'as', 'joey', '<UNK>', 'would', 'say', '!']],
#  ('197520600', '188381045'): [['congratulations', 'on', 'ts', '!'],
#   ['congratulations', 'on', 'top', 'sets', 'darling', '.'],
#   ['yay', '!', 'congratulations', '.'],
#   ['congrats', 'on', 'ts', '!', '<', '3', 'nice', 'set', ':', ')', '.'],
#   ['congrats', 'outstanding', '.'],
#   ['love', 'this', 'set', '!', 'congrats', 'on', 'ts', '!'],
#   ['lovely', 'ts', 'dear', ',', 'congrats', '.'],
#   ['cool', '!', 'ts', 'congrats', '!'],
#   ['perfect', 'nyfw', 'look', '-', 'such', 'amazing', 'choices', '!'],
#   ['ah', '!', 'love', 'this', '!', 'xo', ',', 'oft', '.'],
#   ['superb', 'bravo', '!'],
#   ['congratulations', 'on', 'ts', 'dear', '.'],
#   ['fantastic', 'outfit', 'here', '!', 'ts', 'congratulations', '.'],
#   ['congratulations',
#    'on',
#    'your',
#    'well',
#    'deserved',
#    'top',
#    'fashion',
#    'set',
#    '.'],
#   ['congratulation', 'dear', '.'],
#   ['perfect', 'eccentric', 'look', '.'],
#   ['outstanding', 'set', '!', 'congratulations', '.'],
#   ['very', 'cute', 'nyfw', '.'],
#   ['congratulations', 'on', 'tfs', '.'],
#   ['totally', 'fab', '!']],
#  ('197520600', '192283348'): [['pretty', '¤', '.']],
#  ('197520600',
#   '193049413'): [['oooo',
#    'yay',
#    'ty',
#    'it',
#    'will',
#    'be',
#    'right',
#    'up',
#    '.'], ['glad', 'u', 'like', 'it', ':', ')', '.']],
#  ('197520600', '200311540'): [['same', 'here', '!']],
#  ('197520600', '215672801'): [['omg', 'your', 'sets', '.'],
#   ['super', '!', 'krásné', '<UNK>', 'copy', ':', '-', ')', '.']],
#  ('116341090',
#   '121703669'): [['so',
#    'cool',
#    'and',
#    'fab',
#    'style',
#    'dear',
#    'i',
#    'def',
#    '.',
#    'love',
#    'it',
#    '!']],
#  ('116341090', '77452771'): [['love', 'this', '!', 'pretty', 'indeed', '.'],
#   ['stunning', 'and', 'fab', 'stylish', 'look~', '.'],
#   ['fab',
#    'this',
#    'look',
#    'style',
#    'and',
#    'outfits',
#    'such',
#    'a',
#    'great',
#    'set',
#    'too',
#    '!'],
#   ['divine',
#    '!',
#    'love',
#    'this',
#    'combo',
#    '!',
#    'so',
#    'chic',
#    'and',
#    'cool',
#    '!',
#    'amazing',
#    'color',
#    'touch',
#    'and',
#    'perfect',
#    'match',
#    'with',
#    'those',
#    'sneakers',
#    '!'],
#   ['wan', 'na', 'wear', 'this', 'right', 'now', '!', ';', ')', '.']],
#  ('113847386', '113103148'): [['<UNK>', 'same', '.']],
#  ('113847386', '128079994'): [['thank', 'you', '^^', '.']],
#  ('113847386', '131482030'): [['thank', 'you', '^^', '.']],
#  ('113847386',
#   '207962748'): [['when',
#    'are',
#    'you',
#    'going',
#    'portugal',
#    'i',
#    "'m",
#    'from',
#    'there',
#    'let',
#    'me',
#    'know',
#    'if',
#    'you',
#    'want',
#    'tips',
#    '.']],
#  ('60008389',
#   '60825375'): [['thank',
#    'you',
#    'for',
#    'your',
#    'lovely',
#    'comment',
#    'and',
#    'for',
#    'choosing',
#    'my',
#    'set',
#    'among',
#    'many',
#    'other',
#    'beautiful',
#    'sets',
#    '!'], ['congrats', 'on', 'your', 'second', 'place', 'win', '.'], ['you',
#    "'re",
#    'welcome',
#    '!'], ['tr¨s', 'jolie', '!', ':', ')', 'congrats', '!'], ['goegeous',
#    'set',
#    ',',
#    'as',
#    'always',
#    '!',
#    'congrats',
#    'on',
#    'your',
#    'win',
#    '!'], ['congrats',
#    '!',
#    'you',
#    'placed',
#    'in',
#    'the',
#    'contest',
#    '``',
#    'casadei',
#    "''",
#    'in',
#    'my',
#    'group',
#    'glam',
#    'fresh',
#    '!',
#    'beautiful',
#    '!',
#    'i',
#    'love',
#    'the',
#    'color',
#    'palette',
#    '.',
#    'this',
#    'is',
#    'such',
#    'a',
#    'beautiful',
#    'sophisticated',
#    'summer',
#    'look',
#    '.',
#    'amazing',
#    'job',
#    '!']],
#  ('60008389',
#   '82357938'): [['thank',
#    'you',
#    'for',
#    'your',
#    'lovely',
#    'comment',
#    'and',
#    'for',
#    'choosing',
#    'my',
#    'set',
#    'among',
#    'many',
#    'other',
#    'beautiful',
#    'sets',
#    '!'], ['congrats', 'on', 'your', 'second', 'place', 'win', '.'], ['you',
#    "'re",
#    'welcome',
#    '!'], ['tr¨s', 'jolie', '!', ':', ')', 'congrats', '!'], ['goegeous',
#    'set',
#    ',',
#    'as',
#    'always',
#    '!',
#    'congrats',
#    'on',
#    'your',
#    'win',
#    '!'], ['congrats',
#    '!',
#    'you',
#    'placed',
#    'in',
#    'the',
#    'contest',
#    '``',
#    'casadei',
#    "''",
#    'in',
#    'my',
#    'group',
#    'glam',
#    'fresh',
#    '!',
#    'beautiful',
#    '!',
#    'i',
#    'love',
#    'the',
#    'color',
#    'palette',
#    '.',
#    'this',
#    'is',
#    'such',
#    'a',
#    'beautiful',
#    'sophisticated',
#    'summer',
#    'look',
#    '.',
#    'amazing',
#    'job',
#    '!']],
#  ('156507219', '146616487'): [['excellent', 'set', '.']],
#  ('156507219',
#   '160124831'): [['such',
#    'a',
#    'lovely',
#    'outfit',
#    '!',
#    'shoes',
#    'are',
#    'fantastic',
#    '!',
#    'thank',
#    'you',
#    'for',
#    'this',
#    'entry',
#    '!',
#    'cheers',
#    '.'], ['thanks', 'a', 'lot', ',', 'dear', '!']],
#  ('51106564',
#   '47385493'): [['-',
#    'thank',
#    'you',
#    '.',
#    'i',
#    "'d",
#    'love',
#    'to',
#    'wear',
#    'this',
#    'too',
#    '!'], ['i', 'want', 'all', 'of', 'this', 'set', '!'], ['me', 'gusta', '!']],
#  ('51106564', '49154990'): [['thank', 'youu', '.'],
#   ['it',
#    'would',
#    'actually',
#    ';',
#    'i',
#    'would',
#    '<UNK>',
#    'the',
#    'legs',
#    'really',
#    ';',
#    'so',
#    'i',
#    'guess',
#    'we',
#    'could',
#    'get',
#    'away',
#    'with',
#    'it',
#    ':',
#    'p',
#    'x',
#    '.'],
#   ['yeah',
#    'i',
#    'got',
#    'ur',
#    'point',
#    '!',
#    'although',
#    'i',
#    'totally',
#    'love',
#    'petite',
#    'ladies',
#    'whatever',
#    'they',
#    'choose',
#    'to',
#    'wear',
#    '...',
#    'i',
#    'think',
#    'that',
#    'if',
#    'u',
#    'know',
#    'how',
#    't',
#    'wear',
#    'something',
#    'it',
#    'will',
#    'be',
#    'perfect',
#    '.'],
#   ['(',
#    ':',
#    'maybe',
#    ',',
#    'they',
#    "'d",
#    'be',
#    'lucky',
#    'to',
#    'get',
#    'away',
#    'with',
#    'it',
#    ';',
#    'i',
#    'do',
#    "n't",
#    'like',
#    'petite',
#    'ladies',
#    'could',
#    'wear',
#    'this',
#    'at',
#    'all',
#    '(',
#    ':',
#    '.'],
#   ['im',
#    'petite',
#    'too',
#    '...',
#    '.',
#    'ive',
#    'never',
#    'tried',
#    'a',
#    '<UNK>',
#    'cause',
#    'im',
#    'not',
#    'a',
#    'fan',
#    '...',
#    'but',
#    'i',
#    'think',
#    'a',
#    'high',
#    'waisted',
#    '<UNK>',
#    'would',
#    'be',
#    'beautiful',
#    '.'],
#   ['λατρεω',
#    'το',
#    '<UNK>',
#    'και',
#    'τα',
#    '<UNK>',
#    '.',
#    '<UNK>',
#    'να',
#    '<UNK>',
#    '<UNK>',
#    'τλεια',
#    'με',
#    'λα',
#    '.'],
#   ['yeah',
#    'i',
#    'agree',
#    '...',
#    '.',
#    'but',
#    'i',
#    'think',
#    'someone',
#    'that',
#    'is',
#    'not',
#    'that',
#    '<UNK>',
#    'can',
#    'wear',
#    'this',
#    'outfit',
#    '...'],
#   ['<UNK>',
#    'does',
#    "n't",
#    'work',
#    'for',
#    'everyone',
#    ';',
#    'but',
#    'this',
#    'outfit',
#    'would',
#    'look',
#    'super',
#    'nice',
#    'on',
#    'a',
#    'tall',
#    'person',
#    '(',
#    ':',
#    '.'],
#   ['nai',
#    't',
#    '<UNK>',
#    '<UNK>',
#    'm',
#    '<UNK>',
#    'styl',
#    'k',
#    '<UNK>',
#    'n',
#    'eisai',
#    'teleia',
#    '.'],
#   ['love',
#    'the',
#    'green',
#    'blazer',
#    'and',
#    '<UNK>',
#    'jeans',
#    'with',
#    'chanel',
#    'bag',
#    '!'],
#   ['fab', 'outfit', '!', 'love', 'the', 'shoes', '!', ':', ')', ')', '.']],
#  ('51106564',
#   '67410391'): [['hello',
#    'sweetie',
#    '!',
#    'this',
#    'is',
#    'such',
#    'classic',
#    'style',
#    '&',
#    'beauty',
#    '!',
#    'hope',
#    'you',
#    'are',
#    'doing',
#    'great',
#    'my',
#    'friend',
#    '.',
#    'enjoy',
#    'your',
#    'easter',
#    '!',
#    ':',
#    ')',
#    'xo',
#    '.']],
#  ('188040867',
#   '191447590'): [['thank',
#    'you',
#    'all',
#    'so',
#    'much',
#    'my',
#    'friends',
#    'and',
#    'have',
#    'a',
#    'wonderful',
#    'day',
#    '<',
#    '3xx',
#    '.'], ['congratulations', 'on', 'ts', '!'], ['congratulations',
#    'on',
#    'your',
#    'very',
#    'pretty',
#    'top',
#    'fashion',
#    'set',
#    '.'], ['terrific', '!', 'ts', 'congrats', '!'], ['outstanding',
#    'set',
#    '!',
#    'congratulations',
#    '.'], ['fab', 'hun', '.']],
#  ('188040867',
#   '195137972'): [['congratulations',
#    'on',
#    'your',
#    'tfs',
#    'my',
#    'dear',
#    'friend',
#    'xxxxx',
#    '.'], ['congratulations',
#    'on',
#    'your',
#    'well',
#    'deserved',
#    'top',
#    'fashion',
#    'set',
#    '.'], ['nice', '!', 'ts', 'congrats', '!'], ['on',
#    'point',
#    '!',
#    'perfect',
#    'outfit',
#    'and',
#    'layout',
#    '!',
#    'congratulations',
#    '.'], ['congrats', '=d', '.'], ['yay',
#    'congrats',
#    'sweetie',
#    '.',
#    'fab',
#    'styling',
#    'as',
#    'always',
#    '.']],
#  ('188040867', '202246089'): [['cool', 'street', 'style', 'sweetie', '.'],
#   ['excellent', '!', 'congratulations', 'on', 'ts', '!'],
#   ['terrific', '!', 'ts', 'congrats', '!'],
#   ['awesome', 'street', 'style', ',', 'dear', '.'],
#   ['fabulous', '!', 'and', 'yay', ',', '<UNK>', 'pilots', '!'],
#   ['congratulations',
#    '!',
#    'i',
#    'love',
#    'that',
#    '<UNK>',
#    'pilots',
#    'and',
#    'that',
#    'song',
#    '...'],
#   ['congrats', 'on', 'top', 'fashion', 'set', '!'],
#   ['congratulations', 'on', 'your', 'great', 'top', 'fashion', 'set', '.'],
#   ['congratulations', '☆☆☆☆☆', '.'],
#   ['congratulations',
#    'sweetheart',
#    'on',
#    'your',
#    'top',
#    'set',
#    '!',
#    'xx',
#    '.'],
#   ['yay', '!', 'congratulations', '.'],
#   ['love', 'this', 'set', 'and', 'the', 'song', '!'],
#   ['yay', '!', 'congrats', '!', '<', '3', '.'],
#   ['outstanding', 'set', '!', 'perfect', 'outfit', 'and', 'layout', '.'],
#   ['perfect', 'street', 'style', ',', 'love', 'this', 'look', 'dear', '!'],
#   ['congrats', 'dear', '!', '#', 'awesomestyling', '.'],
#   ['absolutely',
#    'cool',
#    'and',
#    'such',
#    'a',
#    'nice',
#    'style',
#    'here',
#    'totally',
#    'fab',
#    'outfit',
#    'here',
#    'for',
#    'my',
#    'casual',
#    'day',
#    'out',
#    '!'],
#   ['i',
#    'agree',
#    'with',
#    '-',
#    'very',
#    'well',
#    'said',
#    'dear',
#    '!',
#    'i',
#    'will',
#    'add',
#    'that',
#    'i',
#    'adore',
#    'too',
#    '!',
#    'hope',
#    'you',
#    'both',
#    'have',
#    'a',
#    'fabulous',
#    'weekend',
#    '!',
#    'hugs',
#    'xx',
#    '.'],
#   ['gratulere', 'top', 'set', '.'],
#   ['fabulous',
#    'set',
#    'beautifully',
#    'designed',
#    'and',
#    'creative',
#    'combination',
#    '.']],
#  ('188040867',
#   '205408943'): [['love',
#    'this',
#    'color',
#    'combo',
#    'and',
#    'perfect',
#    'heels',
#    '.'], ['stylish',
#    'casual',
#    'fashion',
#    'for',
#    'this',
#    'season',
#    'fab',
#    'denim',
#    'style',
#    '!'], ['great',
#    'look',
#    'great',
#    'set',
#    'great',
#    'mixing',
#    'color',
#    'n',
#    "'",
#    'nice',
#    'heels',
#    '.'], ['womy', 'dear', '!', 'xx', 'hugs', '.']],
#  ('188040867',
#   '206382226'): [['love',
#    'this',
#    'color',
#    'combo',
#    'and',
#    'perfect',
#    'heels',
#    '.'], ['stylish',
#    'casual',
#    'fashion',
#    'for',
#    'this',
#    'season',
#    'fab',
#    'denim',
#    'style',
#    '!'], ['great',
#    'look',
#    'great',
#    'set',
#    'great',
#    'mixing',
#    'color',
#    'n',
#    "'",
#    'nice',
#    'heels',
#    '.'], ['womy', 'dear', '!', 'xx', 'hugs', '.']],
#  ('50638580',
#   '124953030'): [['such',
#    'a',
#    'great',
#    'style',
#    'and',
#    'so',
#    'fab',
#    'for',
#    'all',
#    'details',
#    'here',
#    '!'], ['fabulous',
#    '!',
#    'such',
#    'great',
#    'styling',
#    '!',
#    'trendy',
#    'and',
#    'perfectly',
#    'coordinated',
#    'look',
#    '!'], ['i', 'adore', 'this', 'skirt', '.']],
#  ('50638580', '51426513'): [['woow', ',', 'really', 'impressive', '!'],
#   ['amazing',
#    '!',
#    'love',
#    'how',
#    'you',
#    'mix',
#    'floral',
#    'and',
#    'leather',
#    'to',
#    'give',
#    'a',
#    'girly',
#    'yet',
#    '<UNK>',
#    'look',
#    ',',
#    'this',
#    'outfit',
#    'is',
#    'amazing',
#    '!']],
#  ('50638580',
#   '84302511'): [['absolutely',
#    'fabulous',
#    '!',
#    'love',
#    'the',
#    'metallic',
#    'skirt',
#    '!'], ['oh',
#    'my',
#    '!',
#    'you',
#    'out',
#    'did',
#    'yourself',
#    'with',
#    'this',
#    'one',
#    '!',
#    'love',
#    'it',
#    '!'], ['very',
#    'cool',
#    'and',
#    'unique',
#    '!',
#    'love',
#    'your',
#    'style',
#    '!'], ['wonderfully', 'done', '!'], ['wow',
#    'dear',
#    'this',
#    'is',
#    'so',
#    'pretty',
#    'and',
#    'such',
#    'a',
#    'great',
#    'skirt',
#    'fab',
#    'dear',
#    'perfect',
#    'combo~~',
#    '.']],
#  ('68155239', '150427412'): [['tis', 'is', 'really', 'cute', '!'],
#   ['amazing', 'look', '!', 'such', 'an', 'amazing', 'sweater', '.'],
#   ['i', 'love', 'it', 'plus', 'taehyung', '<UNK>', '.'],
#   ['oh', 'such', 'a', 'fabulously', 'designed', 'look', '!'],
#   ['indeed',
#    '...',
#    '...',
#    '..this',
#    'is',
#    'a',
#    'sensational',
#    'place',
#    ':',
#    ')',
#    'very',
#    'beautifully',
#    'created',
#    'this',
#    'design',
#    '!',
#    'xo',
#    '.'],
#   ['green',
#    'is',
#    'indeed',
#    'fresh',
#    '-',
#    'love',
#    'this',
#    'one',
#    '!',
#    'xxxx',
#    '.'],
#   ['on', 'point', '...', '.', 'the', 'layout', 'is', 'great', '.'],
#   ['adorable',
#    'combo',
#    '!',
#    'love',
#    'this',
#    'so',
#    'chic',
#    'and',
#    'sweet',
#    '!',
#    'love',
#    'the',
#    'touch',
#    'with',
#    'those',
#    'boots',
#    '!'],
#   ['oh',
#    'i',
#    'love',
#    'these',
#    'green',
#    'details',
#    '!',
#    'they',
#    'are',
#    'indeed',
#    ',',
#    'fresh',
#    '!',
#    'great',
#    'set',
#    'darling',
#    '!'],
#   ['amazing', 'green', 'set', '.'],
#   ['oh', 'i', 'love', 'love', 'this', 'sweetheart', '!'],
#   ['absolutely', 'lovely', 'from', 'colors', 'and', 'sweater', '!']],
#  ('68155239', '68675476'): [['oh', 'i', 'adore', 'it', 'my', 'dear', '!'],
#   ['this', 'looks', 'totally', 'wonderful', '!'],
#   ['stunning', 'dearest', ',', 'such', 'a', 'beautiful', 'set', '.'],
#   ['woow', ',', 'this', 'is', 'so', 'awesome', 'dear', '!'],
#   ['wow',
#    'dear',
#    'this',
#    'is',
#    'so',
#    'cool',
#    'in',
#    'style',
#    'i',
#    'really',
#    'love',
#    'it',
#    'always',
#    'impress',
#    'me',
#    'great',
#    'set',
#    'here',
#    '!'],
#   ['so', 'so', 'so', 'fabulous', 'and', 'magical', '!', 'great', 'look', '!'],
#   ['wonderful',
#    'dear',
#    ',',
#    'you',
#    'are',
#    'a',
#    'such',
#    'a',
#    'sweet',
#    'polyfriend',
#    ',',
#    'love',
#    'your',
#    'amazing',
#    'sets',
#    '!'],
#   ['so', 'very', 'beautiful', '!', 'xxx', '.'],
#   ['wow', '!', 'gorgeous', 'and', 'full', 'of', 'style', '.'],
#   ['what',
#    'a',
#    'pretty',
#    ',',
#    'winter',
#    'set',
#    '!',
#    'such',
#    'a',
#    'lovely',
#    'message',
#    '!'],
#   ['athis',
#    'set',
#    '<UNK>',
#    'like',
#    'christmas',
#    '!',
#    'amazing',
#    'outfit',
#    ',',
#    'hon',
#    ',',
#    'sooo',
#    'great',
#    ':',
#    ')',
#    '.'],
#   ['so', 'gorgeous', 'darling', '.'],
#   ['amazing',
#    'and',
#    'stylish',
#    '!',
#    'love',
#    'the',
#    'scarf',
#    ':',
#    ')',
#    'elizabeth',
#    'is',
#    'really',
#    'pretty',
#    'and',
#    'thanks',
#    'for',
#    'being',
#    'a',
#    'friend',
#    'here',
#    'too',
#    ':',
#    ')',
#    '.'],
#   ['so', 'comfy', 'chic', '-', 'luv', 'this', 'one', '!', ':', 'd', '.'],
#   ['so', 'cuteeeee', '!', 'like', 'from', 'fairytale', '!'],
#   ['beautiful', 'wintry', 'set', '!']],
#  ('68155239',
#   '73614515'): [['great',
#    'job',
#    '!',
#    'i',
#    'really',
#    'think',
#    'that',
#    'it',
#    "'s",
#    'an',
#    'gorgeous',
#    'set',
#    ':',
#    'x',
#    '.'], ['love',
#    'the',
#    'coat',
#    'and',
#    'the',
#    'sweater',
#    '!',
#    'love',
#    'the',
#    'kitty',
#    'sweater',
#    '!'], ['wow',
#    ',',
#    'this',
#    'looks',
#    'so',
#    'cool',
#    ',',
#    'sweetie',
#    '.'], ['awesome', 'set', '!', 'i', 'love', 'the', 'photos', 'you', 'used', 'and', 'aw', 'that', 'sweater', 'is', 'adorable', '!'], ['cute',
#    'and',
#    'cool',
#    ':3',
#    '.'], ['amazing',
#    'set',
#    'dear',
#    'love',
#    'this',
#    'look',
#    'style',
#    'and',
#    'all',
#    'detail',
#    'from',
#    'this',
#    'so',
#    'so',
#    'much',
#    'always',
#    'perfect',
#    'cool',
#    'jackets',
#    'fab',
#    'that',
#    'item',
#    '<',
#    '33',
#    '.'], ['g',
#    'o',
#    'r',
#    'g',
#    'e',
#    'o',
#    'u',
#    's',
#    ',',
#    'edgy',
#    'glam',
#    '!'], ['one', 'hell', 'of', 'a', 'sweater', ':', ')', 'kitty', 'cat', '!', 'so', 'cute', ':', ')', 'beautiful', 'set', '.'], ['yeah',
#    ',',
#    'i',
#    'love',
#    'this',
#    'sweater',
#    '!',
#    ':',
#    ')',
#    '.'], ['i', 'love', '<', '3.', '<', '3', '.'], ['so', 'trendy', '.']],
#  ('212887160',
#   '194599167'): [['outstanding',
#    'set',
#    '!',
#    'beautiful',
#    'ensemble',
#    'and',
#    'perfect',
#    'layout',
#    '.'], ['lovely', 'skirt', 'xx', '.']],
#  ('212887160', '215650463'): [['a', 'real', 'beauty', '.'],
#   ['fantastic',
#    '!',
#    'love',
#    'the',
#    'soft',
#    'colors',
#    'in',
#    'here',
#    '!',
#    'perfect',
#    'combination',
#    '!']],
#  ('51654462',
#   '64264341'): [['such',
#    'a',
#    'beautiful',
#    'sweater',
#    '!',
#    'great',
#    'look',
#    '!'], ['thank',
#    'you',
#    'dear',
#    ':',
#    ')',
#    'thanks',
#    'a',
#    'lot',
#    ':',
#    ')',
#    'nai',
#    'i',
#    '<UNK>',
#    'einai',
#    'ola',
#    'ta',
#    '<UNK>',
#    '!',
#    ':',
#    ')',
#    '.'], ['thank', 'you', 'so', 'much', ':', ')', 'xoxo', '.'], ['fab',
#    '...',
#    'love',
#    'the',
#    'neon',
#    'pink..',
#    ':',
#    ')',
#    ')',
#    '.'], ['you',
#    "'re",
#    'very',
#    'welcome',
#    ',',
#    'dear',
#    '!',
#    ':',
#    ')',
#    '<',
#    '3',
#    '.'], ['this', 'looks', 'so', 'fab', '!'], ['thank',
#    'you',
#    'so',
#    'so',
#    'much',
#    '!',
#    ':',
#    ')',
#    'xoxo',
#    '.'], ['ti', 'teleia', '<UNK>', '!']],
#  ('51654462',
#   '79159030'): [['this',
#    'is',
#    'so',
#    'great',
#    '!',
#    'totally',
#    'gon',
#    'na',
#    'wear',
#    'this',
#    '<',
#    '3',
#    '.'], ['amazing',
#    '!',
#    'love',
#    'your',
#    'style',
#    '...',
#    'great',
#    'job',
#    '.'], ['fabbb',
#    'superb',
#    'stylish',
#    'look',
#    'honey',
#    '!',
#    'love',
#    'it',
#    '.']],
#  ('119025626',
#   '116884393'): [['look',
#    'adorable',
#    'with',
#    'feminine',
#    'style',
#    '!'], ['wooow', 'so', 'amazing', 'dear', '!']],
#  ('119025626',
#   '118531935'): [['look',
#    'adorable',
#    'with',
#    'feminine',
#    'style',
#    '!'], ['wooow', 'so', 'amazing', 'dear', '!']],
#  ('107745440', '160729660'): [['luv', '-', 'sooo', 'cute', '!', ':', ')', '.'],
#   ['such', 'an', 'adorable', 'set', '!', 'love', 'it', '!'],
#   ['as', 'cute', 'as', 'can', 'be', '!', 'congrats', 'on', '2nd', '.']],
#  ('161614314',
#   '114778743'): [['living',
#    'for',
#    'how',
#    'adorable',
#    'this',
#    'set',
#    'is',
#    'xx',
#    '.'], ['ya', 'definitely', '.'], ['<UNK>',
#    'was',
#    'not',
#    'her',
#    '<UNK>',
#    'album',
#    'tbh',
#    'in',
#    'terms',
#    'of',
#    'both',
#    '<UNK>',
#    'and',
#    'music',
#    '.',
#    'i',
#    'felt',
#    'like',
#    'she',
#    'gave',
#    'up',
#    'on',
#    'songs',
#    'like',
#    '24',
#    'and',
#    'the',
#    '<UNK>',
#    'day',
#    '.'], ['lolita', 'is', 'lit', '.'], ['bby', '!', 'x', '.'], ['and',
#    'this',
#    'is',
#    'so',
#    'cute',
#    'i',
#    'love',
#    'the',
#    'song',
#    'lolita',
#    'too',
#    '.']],
#  ('161614314',
#   '133367876'): [['heheh', 'so', 'simple', 'and', 'essential', '!'], ['yes',
#    ',',
#    'your',
#    'list',
#    'has',
#    'very',
#    'good',
#    'essentials',
#    '.',
#    'cute',
#    'travel',
#    'outfit',
#    'too',
#    '!',
#    '^',
#    '^',
#    '.'], ['this',
#    'is',
#    'more',
#    'cool',
#    '!',
#    ':',
#    'd',
#    'hahah',
#    'how',
#    'say',
#    '<UNK>',
#    ',',
#    'you',
#    'do',
#    "n't",
#    'need',
#    'worry',
#    'about',
#    'the',
#    'snack',
#    '...',
#    'we',
#    'full',
#    'our',
#    'bag',
#    'of',
#    'it',
#    '!',
#    ':',
#    'd',
#    '.'], ['nice',
#    '!',
#    'good',
#    'choices',
#    'on',
#    'what',
#    'to',
#    'bring',
#    'on',
#    'your',
#    'trip',
#    '!',
#    'your',
#    'outfit',
#    'is',
#    'also',
#    'too',
#    'cute',
#    '!'], ['lovely',
#    'outfit',
#    '!',
#    'with',
#    'me',
#    'and',
#    '<UNK>',
#    'full',
#    'of',
#    'snacks',
#    'there',
#    "'s",
#    'no',
#    'need',
#    'to',
#    'worry',
#    'about',
#    'it',
#    'lol',
#    '.',
#    'hand',
#    '<UNK>',
#    'will',
#    'be',
#    'good',
#    'then',
#    'lol',
#    '.']],
#  ('161614314',
#   '135766093'): [['thank',
#    'you',
#    'so',
#    'much',
#    '!',
#    '<',
#    '3',
#    'i',
#    'really',
#    'appreciate',
#    'it',
#    ':',
#    ')',
#    '.']],
#  ('161614314', '193452620'): [['cute', 'and', 'comfy', '.'],
#   ['thank', 'you', 'for', 'the', 'mention', '.'],
#   ['thanks', 'for', 'second', 'place', '!'],
#   ['thank',
#    'you',
#    '!',
#    'i',
#    'thought',
#    'i',
#    'might',
#    'be',
#    'too',
#    'late',
#    'with',
#    'my',
#    'entries',
#    'but',
#    'i',
#    "'m",
#    'glad',
#    'you',
#    'liked',
#    'my',
#    'set',
#    '!',
#    'congrats',
#    'to',
#    'the',
#    'winners',
#    '.']],
#  ('65900002', '63954529'): [['thank', 'you', '^^', '.']],
#  ('65900002',
#   '65272617'): [['cool',
#    'layout',
#    '!',
#    'love',
#    'this',
#    ':',
#    ')',
#    '.'], ['amazing', '!', 'love', 'the', 'sweater', '!', 'and', 'if', 'you', 'dont', 'mind', 'please', 'help', 'me', 'out', 'and', 'like', 'all', 'the', 'sets', 'in', 'this', 'collection', 'thanks', 'so', 'much', '!', '=', ')', '.']],
#  ('65900002',
#   '66346213'): [['cool',
#    'layout',
#    '!',
#    'love',
#    'this',
#    ':',
#    ')',
#    '.'], ['amazing', '!', 'love', 'the', 'sweater', '!', 'and', 'if', 'you', 'dont', 'mind', 'please', 'help', 'me', 'out', 'and', 'like', 'all', 'the', 'sets', 'in', 'this', 'collection', 'thanks', 'so', 'much', '!', '=', ')', '.']],
#  ('65900002', '67092560'): [['thank', 'you', '^^', '.']],
#  ('196708315', '195692211'): [['great', 'look', 'great', 'combine', '.']],
#  ('196708315',
#   '205426405'): [['w',
#    'o',
#    'w.',
#    '!',
#    'this',
#    'is',
#    'just',
#    'beautiful',
#    '.'], ['thank', 'you', 'for', 'your', 'kind', 'comments', '.'], ['many',
#    'thanks',
#    '.'], ['thanks', 'so', 'much', 'ladies', '.'], ['thanks',
#    'bunches',
#    '.'], ['many', 'thanks', '.'], ['wow',
#    ',',
#    'i',
#    'just',
#    'love',
#    'this',
#    'look',
#    '--',
#    'the',
#    'dress',
#    ',',
#    'boots',
#    ',',
#    'coat',
#    '!']],
#  ('196708315',
#   '206550826'): [['outstanding',
#    'set',
#    '!',
#    'picture',
#    'perfect',
#    '!',
#    'perfect',
#    'outfit',
#    'and',
#    'layout',
#    '!']],
#  ('66092472',
#   '56263779'): [['gorgeous',
#    'look',
#    '!',
#    'love',
#    'the',
#    'pictures',
#    '<',
#    '3',
#    '.'], ['thanx', 'darling', '!', 'have', 'a', 'great', 'day', '!'], ['wow',
#    'like',
#    'this',
#    'casual',
#    'style',
#    'great',
#    'set',
#    'too',
#    'always',
#    'impress',
#    'me',
#    '.'], ['soo', 'amaizng', 'and', 'chic', 'look', '.']],
#  ('66092472',
#   '61877997'): [['gorgeous',
#    'look',
#    '!',
#    'love',
#    'the',
#    'pictures',
#    '<',
#    '3',
#    '.'], ['thanx', 'darling', '!', 'have', 'a', 'great', 'day', '!'], ['wow',
#    'like',
#    'this',
#    'casual',
#    'style',
#    'great',
#    'set',
#    'too',
#    'always',
#    'impress',
#    'me',
#    '.'], ['soo', 'amaizng', 'and', 'chic', 'look', '.']],
#  ('66092472', '68700804'): [['wow', '!', 'den', 'yparxei', '!', 'agap', '.'],
#   ['congrats', 'honey', ':', ')', 'fabulous', 'look', '.'],
#   ['feeling', 'the', 'holidays', '!'],
#   ['this', 'is', 'really', 'amazing', 'look', 'honey', '!', 'love', 'it', '!'],
#   ['amazing',
#    '!',
#    'love',
#    'the',
#    'color',
#    'combo',
#    'and',
#    'especially',
#    'the',
#    'loafers',
#    '!',
#    ':',
#    ')',
#    ')',
#    'xoxo',
#    '.'],
#   ['really', 'fabulous', 'collection', 'my', 'dear', '!', 'xo', '.'],
#   ['omg',
#    'darling',
#    'you',
#    "'re",
#    'soo',
#    'stylish',
#    ',',
#    'it',
#    "'s",
#    '<UNK>',
#    'look',
#    '!'],
#   ['awsome', 'set', '!'],
#   ['love', 'the', 'color', 'combinations', '!'],
#   ['love',
#    'those',
#    'colors',
#    '.',
#    'the',
#    'pic',
#    'is',
#    'amazing',
#    '.',
#    'thanks',
#    'for',
#    'that',
#    '.']],
#  ('66092472',
#   '73213656'): [['oh',
#    'my',
#    'dearest',
#    'this',
#    'is',
#    'very',
#    'very',
#    'cool',
#    'set',
#    'and',
#    'style',
#    'i',
#    'love',
#    'it',
#    'so',
#    'so',
#    'much',
#    'this',
#    'just',
#    'so',
#    'perfect',
#    'all',
#    'the',
#    'ways',
#    'i',
#    'love',
#    'it',
#    '!'], ['i',
#    'love',
#    'this',
#    'look',
#    '!',
#    'fantastic',
#    '!',
#    'xoxo',
#    '.'], ['awesome', 'set', '!', 'i', 'am', 'in', 'love', 'with', 'that', 'bag', '!'], ['fantastic',
#    'set',
#    '!',
#    'please',
#    'enter',
#    'my',
#    'contest-',
#    'gorgeous',
#    'set',
#    '!',
#    'please',
#    'enter',
#    'my',
#    'contest-',
#    '.'], ['beautiful', 'design', 'and', 'fab', 'outfit', '!'], ['wow',
#    'it',
#    'rocks',
#    '!',
#    'xx',
#    '.'], ['stunning', 'set', '<UNK>', 'christmas', '.']],
#  ('147934245',
#   '119144984'): [['<UNK>',
#    ',',
#    'чудесный',
#    'комплект',
#    '!',
#    'удачи',
#    'в',
#    'конкурсе',
#    '!',
#    ':',
#    ')',
#    '.'], ['wow',
#    'sorry',
#    'i',
#    'missed',
#    'so',
#    'many',
#    'of',
#    'your',
#    'fab',
#    'sets',
#    '!']],
#  ('147934245', '84649357'): [['adorable', 'floral', 'pastels', '.']],
#  ('90987375',
#   '115113715'): [['thank',
#    'you',
#    'for',
#    'your',
#    'kind',
#    'words',
#    'ladies',
#    '!']],
#  ('90987375', '117505978'): [['thank', 'you', 'very', 'much', '!', '¤', '.']],
#  ('90987375',
#   '63364501'): [['aww',
#    'i',
#    'totally',
#    'i',
#    "'m",
#    'love',
#    'with',
#    'this',
#    'outfit',
#    '!',
#    ':',
#    ')',
#    '.'], ['thanks', 'so', 'much', 'luv', '!'], ['amazing',
#    'set',
#    '!',
#    'it',
#    'looks',
#    'great',
#    ':',
#    ')',
#    '.'], ['marvelous',
#    'set',
#    'deary',
#    '!',
#    ';',
#    ')',
#    ')',
#    ')',
#    '.'], ['fabulous', 'outfit', '!', 'it', "'s", 'really', 'beautiful..', ':', ')', '.'], ['marvelous',
#    'atmosphere',
#    '!',
#    'love',
#    'it',
#    '!',
#    ':',
#    ')',
#    '.'], ['hi',
#    'my',
#    'sweet',
#    'friend',
#    '!',
#    'spectacular',
#    ',',
#    'dear',
#    '...',
#    'so',
#    'gorgeous',
#    'and',
#    'chicness',
#    '!',
#    'kisses',
#    '!',
#    '¤',
#    '.'], ['thanks',
#    'so',
#    'much',
#    'luv',
#    ',',
#    'it',
#    'did',
#    "n't",
#    'edit',
#    'well',
#    'but',
#    'i',
#    "'m",
#    'fine',
#    'with',
#    'it',
#    '.'], ['marvelous', 'est', 'deary', '!'], ['absolutely',
#    'fantastic',
#    'xxx',
#    '.'], ['this',
#    'is',
#    'so',
#    'beautiful',
#    'sweetie',
#    '!',
#    'xxo',
#    '.'], ['woamazing', ',', 'woww', 'this', 'is', 'perfect', 'set', 'my', 'sweetie', ',', 'love', 'it', 'soo', ',', 'soo', 'much', '.'], ['fierce',
#    'and',
#    'chic',
#    ':',
#    ')',
#    '.'], ['fabulous', '!', 'xoxo', '.'], ['woa',
#    'masterpiece',
#    'darling',
#    ':',
#    ')',
#    '.'], ['this',
#    'is',
#    'incredible',
#    '...',
#    'you',
#    'are',
#    'much',
#    'talented',
#    'in',
#    'this',
#    '!',
#    'wish',
#    'you',
#    'grest',
#    'weekend',
#    '!',
#    'hugs',
#    'xxx',
#    '.']],
#  ('90987375', '79321553'): [['thank', 'you', ',', 'girl', '<', '33', '.'],
#   ['this',
#    'is',
#    'so',
#    'pretty',
#    ',',
#    'katie',
#    '!',
#    'love',
#    'these',
#    'colors',
#    '.'],
#   ['thank', 'you', 'so', 'much', 'you', 'are', 'so', 'sweet', '<', '33', '.'],
#   ['so', 'pretty', ':', ')', 'ca', "n't", 'go', 'wrong', 'with', 'pink', '!'],
#   ['thank',
#    'you',
#    'ladies',
#    'so',
#    'much',
#    ',',
#    'i',
#    'hope',
#    'you',
#    'are',
#    'all',
#    'having',
#    'a',
#    'great',
#    'week',
#    '<',
#    '33',
#    '.'],
#   ['this',
#    'is',
#    'so',
#    'pretty',
#    '!',
#    'love',
#    'the',
#    'way',
#    'the',
#    'top',
#    'picks',
#    'up',
#    'the',
#    'green',
#    'in',
#    'that',
#    'fab',
#    '<UNK>',
#    '!'],
#   ['thank',
#    'you',
#    '<',
#    '3thanks',
#    'a',
#    'lot',
#    ':',
#    ')',
#    'thank',
#    'you',
#    'so',
#    'much',
#    '<',
#    '3',
#    '.'],
#   ['very', 'pretty', 'indeedy', 'xxx', '.'],
#   ['so', 'lovely', 'and', 'tender', ':', ')', '.'],
#   ['oh', 'my', 'so', 'soft', 'and', 'pretty', '!'],
#   ['so', 'gorgeous', 'katie', '!', ':', ')', '.'],
#   ['so', 'pretty', ',', 'love', 'this', 'pink', 'feminine', 'outfit', '!']],
#  ('90987375', '97139803'): [['thank', 'you', ',', 'girl', '<', '33', '.'],
#   ['this',
#    'is',
#    'so',
#    'pretty',
#    ',',
#    'katie',
#    '!',
#    'love',
#    'these',
#    'colors',
#    '.'],
#   ['thank', 'you', 'so', 'much', 'you', 'are', 'so', 'sweet', '<', '33', '.'],
#   ['so', 'pretty', ':', ')', 'ca', "n't", 'go', 'wrong', 'with', 'pink', '!'],
#   ['thank',
#    'you',
#    'ladies',
#    'so',
#    'much',
#    ',',
#    'i',
#    'hope',
#    'you',
#    'are',
#    'all',
#    'having',
#    'a',
#    'great',
#    'week',
#    '<',
#    '33',
#    '.'],
#   ['this',
#    'is',
#    'so',
#    'pretty',
#    '!',
#    'love',
#    'the',
#    'way',
#    'the',
#    'top',
#    'picks',
#    'up',
#    'the',
#    'green',
#    'in',
#    'that',
#    'fab',
#    '<UNK>',
#    '!'],
#   ['thank',
#    'you',
#    '<',
#    '3thanks',
#    'a',
#    'lot',
#    ':',
#    ')',
#    'thank',
#    'you',
#    'so',
#    'much',
#    '<',
#    '3',
#    '.'],
#   ['very', 'pretty', 'indeedy', 'xxx', '.'],
#   ['so', 'lovely', 'and', 'tender', ':', ')', '.'],
#   ['oh', 'my', 'so', 'soft', 'and', 'pretty', '!'],
#   ['so', 'gorgeous', 'katie', '!', ':', ')', '.'],
#   ['so', 'pretty', ',', 'love', 'this', 'pink', 'feminine', 'outfit', '!']],
#  ('73473085',
#   '71805951'): [['great',
#    'outfitt',
#    'for',
#    'fall',
#    ':',
#    ')',
#    ')',
#    ')',
#    '.'], ['me', 'encanta', '.', 'muy', 'elegante', '.'], ['soo',
#    'amazing',
#    'set',
#    'sweetie',
#    '.'], ['awesome',
#    'set',
#    'love',
#    '!',
#    'this',
#    'is',
#    'fantastic',
#    '!',
#    ':',
#    ')',
#    'xlbx',
#    '.'], ['woww',
#    'dear',
#    ',',
#    'fabulous',
#    'look',
#    ',',
#    'i',
#    'love',
#    'it',
#    '.']],
#  ('73473085',
#   '91408573'): [['great',
#    'outfitt',
#    'for',
#    'fall',
#    ':',
#    ')',
#    ')',
#    ')',
#    '.'], ['me', 'encanta', '.', 'muy', 'elegante', '.'], ['soo',
#    'amazing',
#    'set',
#    'sweetie',
#    '.'], ['awesome',
#    'set',
#    'love',
#    '!',
#    'this',
#    'is',
#    'fantastic',
#    '!',
#    ':',
#    ')',
#    'xlbx',
#    '.'], ['woww',
#    'dear',
#    ',',
#    'fabulous',
#    'look',
#    ',',
#    'i',
#    'love',
#    'it',
#    '.']],
#  ('133971980', '102684794'): [['beautiful', 'xoxo', '.'],
#   ['gorgeous', 'summer', 'look', '!'],
#   ['cute', 'set', '(', '=', '.']],
#  ('133971980',
#   '138750505'): [['stunning',
#    '!',
#    'thanks',
#    'for',
#    'tagging',
#    'me',
#    '!',
#    ':',
#    ')',
#    '.']],
#  ('160223278',
#   '186895252'): [['fabulous',
#    '!',
#    'you',
#    'make',
#    'amazing',
#    'sets',
#    'sweetie',
#    'xx',
#    '.'], ['so', 'good', '!'], ['on', 'point', '.'], ['perfect',
#    '=d',
#    '.'], ['casual', 'and', 'comfy', '.'], ['very',
#    'cozy',
#    'chic',
#    '!'], ['nice', 'sweater', '.'], ['splendidly', 'done', '!']],
#  ('87655208', '87444412'): [['awe', 'thank', 'you', 'xoxox', '.'],
#   ['fun', 'and', 'fabulous', 'combination', '!']],
#  ('82196643', '14353243'): [['great', 'quote', '!', 'fabulous', 'look', '!'],
#   ['<UNK>',
#    'ti',
#    'na',
#    'pw',
#    '<UNK>',
#    '...',
#    'pio',
#    'teleio',
#    'den',
#    '<UNK>',
#    '!'],
#   ['wow',
#    '!',
#    'love',
#    'this',
#    'set',
#    '!',
#    'the',
#    'pictures',
#    'are',
#    'stunning',
#    '!',
#    'amazing',
#    'outfit',
#    'and',
#    'great',
#    'styling',
#    '!',
#    'i',
#    "'d",
#    'totally',
#    'wear',
#    'it',
#    '!',
#    '<',
#    '3',
#    '.'],
#   ['very', 'lovely', 'outfit', 'and', 'set', '!', 'cool', 'quote', 'too', '!'],
#   ['a', 'true', 'masterpiece', '!'],
#   ['stunning', '!', 'perfect', 'layout', 'and', 'outfit', '<', '3', '.'],
#   ['such',
#    'a',
#    'fabulous',
#    'look',
#    ',',
#    'love',
#    'that',
#    'you',
#    'added',
#    'those',
#    'cavalli',
#    'shorts',
#    ',',
#    'they',
#    'sure',
#    'added',
#    'glam',
#    'to',
#    'the',
#    'whole',
#    'look',
#    '!'],
#   ['charming',
#    'set',
#    'dear',
#    '!',
#    'lovely',
#    'fringe',
#    'vest',
#    'with',
#    'the',
#    'white',
#    'chanel',
#    'bag',
#    '!'],
#   ['wonderful', 'look', ',', 'i', 'like', 'the', 'skirt', 'x', '.'],
#   ['ti',
#    'allo',
#    '<UNK>',
#    'na',
#    'pw',
#    'gia',
#    'ta',
#    'set',
#    'sou',
#    '...',
#    'pragmatika',
#    '<UNK>',
#    '...',
#    'katapliktiko',
#    'sunolo',
#    ',',
#    'teleio',
#    'styling',
#    ',',
#    'agapw',
#    'o',
#    ',',
#    'ti',
#    'exeis',
#    '<UNK>',
#    'gia',
#    'to',
#    'set',
#    '!'],
#   ['i',
#    'could',
#    'just',
#    'sit',
#    'here',
#    'and',
#    'like',
#    'all',
#    'your',
#    'sets',
#    '!'],
#   ['amazing', 'set', '!', '**', '.'],
#   ['thank',
#    'you',
#    'so',
#    'much',
#    'for',
#    'your',
#    'words',
#    '!',
#    ':',
#    'dd',
#    'makes',
#    'me',
#    'happy',
#    'that',
#    'you',
#    'liked',
#    'it',
#    '!',
#    'xxx',
#    '.'],
#   ['amazing', ',', 'stunning', 'design', 'and', 'superb', 'styling', '.'],
#   ['so', 'pretty', ',', 'love', 'the', 'outfit', 'and', 'the', 'quote', '!'],
#   ['amazing',
#    'style',
#    '!',
#    'do',
#    "n't",
#    'know',
#    'that',
#    'the',
#    'outfits',
#    'would',
#    'look',
#    'that',
#    'great',
#    'beside',
#    'the',
#    'sneaker',
#    '!'],
#   ['super', 'hip', '!'],
#   ['this', 'is', 'incredible', '!'],
#   ['perfect',
#    'stylish',
#    'look',
#    'sweetie',
#    '!',
#    'love',
#    'the',
#    'shoes',
#    ',',
#    'great',
#    'styling',
#    'too',
#    '!',
#    'beautiful',
#    '.'],
#   ['hello',
#    'dear',
#    'this',
#    'such',
#    'a',
#    'pretty',
#    'what',
#    'a',
#    'perfect',
#    'set',
#    'here',
#    'love',
#    'it',
#    'like',
#    'always',
#    'dear',
#    'great',
#    'set',
#    'too',
#    ',',
#    'always',
#    'impress',
#    'me',
#    ':',
#    ')',
#    ')',
#    '.'],
#   ['wonderful',
#    'look',
#    'dear',
#    '...',
#    '<UNK>',
#    'quote',
#    '...',
#    'but',
#    'mostly',
#    'true',
#    '.'],
#   ['very',
#    'stylish',
#    'set',
#    ',',
#    'as',
#    'always',
#    '!',
#    'love',
#    'the',
#    'bag',
#    '!',
#    '<',
#    '3',
#    '.'],
#   ['this', 'is', 'wonderful', '!', 'love', 'the', 'vest', '!']],
#  ('82196643',
#   '55720602'): [['amaizng',
#    'and',
#    'lovely',
#    'style',
#    'sweetie',
#    '.'], ['exquisite', '!', 'love', 'all', 'these', 'items', '!'], ['super',
#    'cute',
#    '!',
#    'you',
#    'should',
#    'come',
#    'check',
#    'out',
#    'my',
#    'sets',
#    '!']],
#  ('82196643', '81807308'): [['great', 'quote', '!', 'fabulous', 'look', '!'],
#   ['<UNK>',
#    'ti',
#    'na',
#    'pw',
#    '<UNK>',
#    '...',
#    'pio',
#    'teleio',
#    'den',
#    '<UNK>',
#    '!'],
#   ['wow',
#    '!',
#    'love',
#    'this',
#    'set',
#    '!',
#    'the',
#    'pictures',
#    'are',
#    'stunning',
#    '!',
#    'amazing',
#    'outfit',
#    'and',
#    'great',
#    'styling',
#    '!',
#    'i',
#    "'d",
#    'totally',
#    'wear',
#    'it',
#    '!',
#    '<',
#    '3',
#    '.'],
#   ['very', 'lovely', 'outfit', 'and', 'set', '!', 'cool', 'quote', 'too', '!'],
#   ['a', 'true', 'masterpiece', '!'],
#   ['stunning', '!', 'perfect', 'layout', 'and', 'outfit', '<', '3', '.'],
#   ['such',
#    'a',
#    'fabulous',
#    'look',
#    ',',
#    'love',
#    'that',
#    'you',
#    'added',
#    'those',
#    'cavalli',
#    'shorts',
#    ',',
#    'they',
#    'sure',
#    'added',
#    'glam',
#    'to',
#    'the',
#    'whole',
#    'look',
#    '!'],
#   ['charming',
#    'set',
#    'dear',
#    '!',
#    'lovely',
#    'fringe',
#    'vest',
#    'with',
#    'the',
#    'white',
#    'chanel',
#    'bag',
#    '!'],
#   ['wonderful', 'look', ',', 'i', 'like', 'the', 'skirt', 'x', '.'],
#   ['ti',
#    'allo',
#    '<UNK>',
#    'na',
#    'pw',
#    'gia',
#    'ta',
#    'set',
#    'sou',
#    '...',
#    'pragmatika',
#    '<UNK>',
#    '...',
#    'katapliktiko',
#    'sunolo',
#    ',',
#    'teleio',
#    'styling',
#    ',',
#    'agapw',
#    'o',
#    ',',
#    'ti',
#    'exeis',
#    '<UNK>',
#    'gia',
#    'to',
#    'set',
#    '!'],
#   ['i',
#    'could',
#    'just',
#    'sit',
#    'here',
#    'and',
#    'like',
#    'all',
#    'your',
#    'sets',
#    '!'],
#   ['amazing', 'set', '!', '**', '.'],
#   ['thank',
#    'you',
#    'so',
#    'much',
#    'for',
#    'your',
#    'words',
#    '!',
#    ':',
#    'dd',
#    'makes',
#    'me',
#    'happy',
#    'that',
#    'you',
#    'liked',
#    'it',
#    '!',
#    'xxx',
#    '.'],
#   ['amazing', ',', 'stunning', 'design', 'and', 'superb', 'styling', '.'],
#   ['so', 'pretty', ',', 'love', 'the', 'outfit', 'and', 'the', 'quote', '!'],
#   ['amazing',
#    'style',
#    '!',
#    'do',
#    "n't",
#    'know',
#    'that',
#    'the',
#    'outfits',
#    'would',
#    'look',
#    'that',
#    'great',
#    'beside',
#    'the',
#    'sneaker',
#    '!'],
#   ['super', 'hip', '!'],
#   ['this', 'is', 'incredible', '!'],
#   ['perfect',
#    'stylish',
#    'look',
#    'sweetie',
#    '!',
#    'love',
#    'the',
#    'shoes',
#    ',',
#    'great',
#    'styling',
#    'too',
#    '!',
#    'beautiful',
#    '.'],
#   ['hello',
#    'dear',
#    'this',
#    'such',
#    'a',
#    'pretty',
#    'what',
#    'a',
#    'perfect',
#    'set',
#    'here',
#    'love',
#    'it',
#    'like',
#    'always',
#    'dear',
#    'great',
#    'set',
#    'too',
#    ',',
#    'always',
#    'impress',
#    'me',
#    ':',
#    ')',
#    ')',
#    '.'],
#   ['wonderful',
#    'look',
#    'dear',
#    '...',
#    '<UNK>',
#    'quote',
#    '...',
#    'but',
#    'mostly',
#    'true',
#    '.'],
#   ['very',
#    'stylish',
#    'set',
#    ',',
#    'as',
#    'always',
#    '!',
#    'love',
#    'the',
#    'bag',
#    '!',
#    '<',
#    '3',
#    '.'],
#   ['this', 'is', 'wonderful', '!', 'love', 'the', 'vest', '!']],
#  ('94689751', '92267427'): [['amaizing', 'set', ',', 'dear', '!'],
#   ['such', 'a', 'cool', 'casual', 'fashion', 'dear', 'love', 'it', '!'],
# ...
#  ('194378125', '163290710'): [['long', 'live', 'love', '.'],
#   ['oops', '!', 'love', '!']],
#  ('194378125', '181262121'): [['all', 'good', 'stuffs', '.']],
#  ('204264501',
#   '204843177'): [['you',
#    'are',
#    'and',
#    'always',
#    'will',
#    'be',
#    'enough',
#    '.'], ['yeah', ',', 'you’re', 'good', 'enough', '.'], ['take',
#    'your',
#    'time',
#    ',',
#    'it’s',
#    'ok',
#    '.'], ['i', 'like', 'your', 'presence', '.'], ['adorable',
#    'fashion',
#    'and',
#    'fab',
#    'this',
#    'combo',
#    'too',
#    '!'], ['i’ll', 'cheer', 'you', 'on', 'even', 'if', 'others', 'don’t', '.']],
#  ('204264501',
#   '207794477'): [['cute',
#    'all',
#    'the',
#    'way',
#    'such',
#    'a',
#    'nice',
#    'style',
#    'for',
#    'summer',
#    '!'], ['nice', '!', 'pls', 'join', 'here', 'too', ';', '.'], ['*heart',
#    'eyes*',
#    '.'], ['me', 'toooo', 'i', 'love', 'them', '!'], ['pretty',
#    'summer',
#    'fashion',
#    'absolutely',
#    'nice',
#    'fab',
#    'this',
#    'style',
#    '!'], ['thank',
#    'you',
#    '&',
#    'yes',
#    'the',
#    'smiths',
#    'are',
#    'the',
#    'best',
#    '<',
#    '3',
#    '.'], ['omg',
#    'yes',
#    '<UNK>',
#    'my',
#    'wife',
#    '!',
#    'i',
#    "'m",
#    'legit',
#    'so',
#    'in',
#    'love',
#    'with',
#    'all',
#    'the',
#    'girls',
#    'it',
#    'hurts',
#    'x',
#    '}',
#    '<',
#    '3',
#    '.'], ['ahh',
#    'i',
#    'love',
#    'the',
#    'smiths',
#    ':',
#    ')',
#    ')',
#    'this',
#    'clean',
#    'outfit',
#    'set',
#    'is',
#    'so',
#    'nice~~',
#    '.']],
#  ('116679211', '105055884'): [['thanks', 'hun', '.'],
#   ['thank', 'u', '<', '3', '.'],
#   ['i', 'love', 'that', 'skirt', '!', '<', '3', '.'],
#   ['thank', 'you', '!', ':3', '.'],
#   ['so', 'elegant', 'and', 'chic', '!']],
#  ('116679211', '112049247'): [['thanks', 'hun', '.'],
#   ['thank', 'u', '<', '3', '.'],
#   ['i', 'love', 'that', 'skirt', '!', '<', '3', '.'],
#   ['thank', 'you', '!', ':3', '.'],
#   ['so', 'elegant', 'and', 'chic', '!']],
#  ('116679211', '54712482'): [['awesome', 'set', 'my', 'friend', '!']],
#  ('116679211',
#   '99338416'): [['fabulous',
#    '!',
#    'both',
#    'looks',
#    'are',
#    'simply',
#    'stunning',
#    '!']],
#  ('178495687',
#   '150521584'): [['gorgeous', ',', 'amazing', 'top', '!', "'", '.']],
#  ('178495687',
#   '152741585'): [['velvet', '2', 'set/', '3', 'days/', '6', 'winners', '.'],
#   ['amazing',
#    'set',
#    'dear',
#    ',',
#    'please',
#    'join',
#    'my',
#    'summer',
#    'outfit',
#    'contest',
#    '.'],
#   ['could',
#    'you',
#    'look',
#    'at',
#    'my',
#    'sets',
#    'please',
#    'thanks',
#    ':',
#    ')',
#    '.']],
#  ('178495687',
#   '166284246'): [['i',
#    'really',
#    'love',
#    'this',
#    '.',
#    'i',
#    'would',
#    'so',
#    'wear',
#    'this',
#    '!'], ['love', 'those', 'colours', '.'], ['very',
#    'elegant',
#    '!'], ['elegant', 'and', 'beautiful', '!'], ['elegant', 'set', '.']],
#  ('178495687',
#   '170748014'): [['new',
#    'shein',
#    'contest',
#    '.remember',
#    'to',
#    'add',
#    'this',
#    'link',
#    'in',
#    'the',
#    'description',
#    'each',
#    'sets',
#    ':',
#    '.']],
#  ('178495687', '177063419'): [['gorgeous', 'jacket', 'and', 'set', '!']],
#  ('178495687', '178712342'): [['très', 'jolie', 'set', '.']],
#  ('102552085',
#   '107270471'): [['thank',
#    'you',
#    'so',
#    'much',
#    'for',
#    'all',
#    'your',
#    'kind',
#    'comments',
#    'and',
#    '!',
#    ':',
#    '-',
#    ')',
#    ')',
#    '.'], ['thank',
#    'you',
#    'so',
#    'much',
#    'dear',
#    'polyvore',
#    'friend',
#    'for',
#    'your',
#    'support',
#    '!',
#    '!',
#    '<',
#    '3',
#    '.'], ['thank',
#    'you',
#    'so',
#    'much',
#    'dear',
#    'for',
#    'all',
#    'your',
#    'support',
#    '!',
#    ':',
#    '-',
#    ')',
#    '.'], ['so', 'creative', '!', 'love', 'this', 'chair', '!'], ['awesome',
#    'denim',
#    'style',
#    '!'], ['really', 'awesome', 'stying', '.'], ['thank',
#    'you',
#    'so',
#    'much',
#    'for',
#    'all',
#    'your',
#    'kind',
#    'comments',
#    'and',
#    '!',
#    'this',
#    'chair',
#    'ir',
#    'really',
#    'fabulous',
#    '!',
#    'and',
#    ':',
#    '-',
#    ')',
#    ')',
#    '.'], ['thank',
#    'you',
#    'so',
#    'much',
#    'and',
#    'for',
#    'your',
#    'feedback',
#    'and',
#    'support',
#    '!',
#    'i',
#    'really',
#    'appreciate',
#    '!',
#    '<',
#    '3',
#    '.'], ['very',
#    'cool',
#    'and',
#    'trendy',
#    '!',
#    'check',
#    'out',
#    'this',
#    'awesome',
#    '<UNK>',
#    'chair',
#    '!',
#    'amazing',
#    'set',
#    '!'], ['wonderful',
#    '!',
#    'i',
#    "'m",
#    'freaking',
#    'out',
#    'about',
#    'this',
#    'chair',
#    'too',
#    '!'], ['this',
#    'is',
#    'such',
#    'a',
#    'fabulous',
#    'design',
#    'dear',
#    '!'], ['great', 'design', 'dear', '.'], ['woow',
#    'gorgeous',
#    'set',
#    '!'], ['wow', ',', 'this', 'looks', 'so', 'fab', '!'], ['this',
#    'chair',
#    'is',
#    'so',
#    'great',
#    'and',
#    'we',
#    'can',
#    'make',
#    'at',
#    'home',
#    ':',
#    '-',
#    ')',
#    '.'], ['nice', 'work', '!'], ['adoro',
#    'este',
#    'conjunto',
#    'casual',
#    '!',
#    'x',
#    '.'], ['love',
#    'this',
#    '!',
#    'that',
#    'chair',
#    'is',
#    'amazing',
#    '!'], ['thank', 'you', 'so', 'much', 'for', 'all', 'your', 'sweet', 'comments', 'and', 'support', 'dear', '!', ':', '-', ')', ')', '.']],
#  ('102552085',
#   '113502941'): [['this',
#    'set',
#    'is',
#    'soo',
#    'very',
#    'purely',
#    'my',
#    'style',
#    '.',
#    'great',
#    'job',
#    '.'], ['chic', 'an', 'fantastic.~~', '.'], ['love',
#    'the',
#    'print',
#    '!',
#    'fantastic',
#    'set',
#    ',',
#    'love',
#    '!',
#    ':',
#    ')',
#    'xlbx',
#    '.'], ['u', 'go', 'girl', '!', '<UNK>', ')', '.'], ['great',
#    'city',
#    'chic',
#    'look',
#    '!']],
#  ('102552085', '97763344'): [['sweeeet', ',', 'congrats', '.'],
#   ['congrats',
#    ':',
#    ')',
#    'please',
#    'join',
#    'my',
#    'group',
#    'contest',
#    'outfit',
#    'with',
#    'denim',
#    ',',
#    'with',
#    'this',
#    'lovely',
#    'set',
#    '.'],
#   ['cool', 'set..congrats', 'on', 'top', 'sets', '!']],
#  ('77227017',
#   '55109341'): [['absolutely',
#    'lovely',
#    'look',
#    'and',
#    'set',
#    '!',
#    'i',
#    'adore',
#    'the',
#    'whole',
#    'outfit',
#    ':',
#    'd',
#    '.'], ['gorgeous',
#    'look',
#    'sweetie',
#    '.',
#    'another',
#    'amazing',
#    'set',
#    ',',
#    'love',
#    'it',
#    'x',
#    '.'], ['очень', 'красиво', '!'], ['романтично',
#    'и',
#    'нежно',
#    '!'], ['fabulous',
#    'set',
#    'honey',
#    '.',
#    'love',
#    'the',
#    'style',
#    '.'], ['fantastic', ',', 'lov', 'e', 'it', '!'], ['wow',
#    'color',
#    'brilliance',
#    '.',
#    'amazing',
#    'detailing',
#    'and',
#    'superb',
#    'styling',
#    '.',
#    'love',
#    'it',
#    'sweetie',
#    '.'], ['great',
#    'style',
#    ',',
#    'sooo',
#    'amazing',
#    'and',
#    'chic',
#    'swetie',
#    '.'], ['absolutely',
#    'like',
#    'this',
#    'style',
#    'sweetie',
#    'such',
#    'a',
#    'great',
#    'set',
#    'too',
#    'love',
#    'all',
#    'detail',
#    'here',
#    'too',
#    'great',
#    'set',
#    'dear~~',
#    '.'], ['so', 'elegant', 'and', 'stylish', '!'], ['fabulous',
#    'set',
#    '...',
#    'look',
#    'at',
#    'those',
#    'awesome',
#    'shoes',
#    '!'], ['wow',
#    'fabulous',
#    'set',
#    '!',
#    'really',
#    'gorgeous',
#    'outfit',
#    'and',
#    'pics',
#    'too',
#    '!'], ['thank',
#    'you',
#    'all',
#    'for',
#    'commenting',
#    '!',
#    'i',
#    'appreciate',
#    'that',
#    '!'], ['gorgeous',
#    '...',
#    '...',
#    '.love',
#    'this',
#    'shoes',
#    '!'], ['outstanding', 'dear', '!'], ['love',
#    'the',
#    'mix',
#    'of',
#    'textures',
#    '...',
#    ':',
#    ')',
#    '.'], ['i',
#    'am',
#    'speechless',
#    '.',
#    'it',
#    "'s",
#    'so..',
#    'perfect',
#    '!',
#    'great',
#    'job',
#    'as',
#    'always',
#    '.']],
#  ('77227017', '77214488'): [['pure', 'beauty', '.'],
#   ['really',
#    'love',
#    'this',
#    'look',
#    '!',
#    'would',
#    'love',
#    'to',
#    'wear',
#    '!',
#    'good',
#    'luck',
#    'in',
#    'the',
#    'contest',
#    '!'],
#   ['so', 'bright', '!', 'love', 'it', '!'],
#   ['perfection', '~', 'this', 'is', 'so', 'fabulous', 'sweetie', '!'],
#   ['woww', 'dear', ',', 'fantastic', 'set', '!'],
#   ['amazing', '!', 'good', 'luck', ':', ')', '.'],
#   ['thank', 'you', 'sweetie', '!', 'xoxoxoxo', '.'],
#   ['definitely', 'happy', '!', 'love', 'it', '!'],
#   ['amazing',
#    'layout',
#    'and',
#    'a',
#    'wonderful',
#    'white',
#    'on',
#    'white',
#    'outfit',
#    '.'],
#   ['wonderful',
#    'set',
#    'honey',
#    '.',
#    'love',
#    'how',
#    'sunny',
#    'it',
#    'is',
#    '.',
#    '<',
#    '3',
#    '.'],
#   ['splendid', 'sweetheart', '!'],
#   ['very', 'pretty', ',', 'great', 'lace', 'outfit', '.'],
#   ['wow', '!', 'amazing', 'set', 'and', 'look', '!', '<', '333', '.'],
#   ['thank',
#    'you',
#    'everyone',
#    'for',
#    'your',
#    'great',
#    'comments',
#    '!',
#    'hope',
#    'you',
#    'have',
#    'a',
#    'fabulous',
#    'week',
#    '!'],
#   ['this', 'looks', 'amazing', '!'],
#   ['wow', ',', 'again', 'breathtaking', 'set', 'sweetie', '.'],
#   ['wow',
#    'my',
#    'dear',
#    'friend',
#    ',',
#    'this',
#    'is',
#    'gorgeous',
#    '!',
#    'enjoy',
#    'your',
#    'weekend',
#    '.'],
#   ['its',
#    'by',
#    'the',
#    'way',
#    ',',
#    'only',
#    'changed',
#    'my',
#    'username',
#    ':',
#    ')',
#    '.'],
#   ['soo', 'lovely', '.'],
#   ['so', 'wonderful', 'white', 'set', 'dear', 'love', 'it', '!'],
#   ['wow', 'this', 'is', 'awesome', '!', 'enjoy', 'your', 'weekend', '.'],
#   ['fabulous',
#    'look',
#    '!',
#    'good',
#    'luck',
#    '!',
#    'have',
#    'a',
#    'nice',
#    'weekend',
#    'too',
#    '!'],
#   ['oh',
#    'sweetie-',
#    'this',
#    'is',
#    'just',
#    'so',
#    'outstanding',
#    '!',
#    'wow',
#    '!'],
#   ['ta',
#    '<UNK>',
#    'ta',
#    '<UNK>',
#    '...',
#    '...',
#    '...',
#    '...',
#    '...',
#    '<UNK>',
#    '!'],
#   [',',
#    ',',
#    ',',
#    ',',
#    ',',
#    ',',
#    ',',
#    'thank',
#    'you',
#    'so',
#    'much',
#    'for',
#    'your',
#    'support',
#    'and',
#    'lovely',
#    'comments',
#    '!'],
#   ['so',
#    'lovely',
#    'style',
#    'sweetie',
#    'i',
#    'like',
#    'those',
#    'yellow',
#    ':',
#    ')',
#    ')',
#    '.'],
#   ['dont', 'know', 'how', 'i', 'missed', 'this', 'one', ',', 'wow', '!'],
#   ['stunning', 'white', ',', 'hope', 'you', 'win', '!'],
#   ['so',
#    'pretty',
#    'so',
#    'lovely',
#    'white',
#    'set',
#    'just',
#    'love',
#    'it',
#    ':',
#    ')',
#    ')',
#    '.'],
#   ['thank', 'you', 'thank', 'you', ':', 'd', 'xoxo', '.'],
#   ['you',
#    "'re",
#    'welcome',
#    'dear',
#    ',',
#    'thank',
#    'you',
#    'too',
#    'for',
#    'your',
#    'great',
#    'support',
#    '<',
#    '3',
#    '.'],
#   ['<UNK>',
#    'looks',
#    'soo',
#    'fabolous',
#    'and',
#    'awesome',
#    'sweetheart',
#    '!',
#    'love',
#    'the',
#    'loook',
#    '!',
#    'the',
#    'bag',
#    'soo',
#    'stylish',
#    'and',
#    'everything',
#    'is',
#    'soo',
#    'perfect',
#    '!'],
#   ['so',
#    'beautiful',
#    'sweetie',
#    '!',
#    'very',
#    '<UNK>',
#    'a',
#    'dream',
#    '!',
#    ':',
#    ')',
#    ')',
#    '.']],
#  ('77227017',
#   '77225511'): [['fantastic',
#    '!',
#    'i',
#    'can',
#    'see',
#    'you',
#    'racing',
#    'down',
#    'the',
#    'catwalk',
#    'in',
#    'this',
#    'one',
#    '.',
#    'so',
#    'creative',
#    'and',
#    'unique',
#    'as',
#    'all',
#    'your',
#    'sets',
#    'are',
#    '.'], ['and',
#    'i',
#    'can',
#    'make',
#    'little',
#    '``',
#    '<UNK>',
#    '<UNK>',
#    "''",
#    '<UNK>',
#    ',',
#    'too',
#    '!',
#    'lol',
#    '...',
#    'hugs',
#    '!'], ['thank',
#    'you',
#    '...',
#    'i',
#    'just',
#    'thought',
#    'to',
#    'myself',
#    '...',
#    'well',
#    ',',
#    'this',
#    'one',
#    "'s",
#    'pretty',
#    'weird',
#    'but',
#    'what',
#    'the',
#    'heck',
#    ',',
#    'i',
#    "'ll",
#    'publish',
#    'it',
#    'anyway',
#    '!',
#    'lol',
#    '...',
#    ';',
#    'd',
#    'hugs',
#    'and',
#    's',
#    'to',
#    'you',
#    ',',
#    'dear',
#    '!'], ['lmao',
#    '<UNK>',
#    "'s",
#    '``',
#    'racing',
#    "''",
#    'comment',
#    'is',
#    'certainly',
#    '<UNK>',
#    '.',
#    'what',
#    'a',
#    'totally',
#    'wild',
#    'set',
#    '!'], ['thank', 'you', ',', 'dear', '!', 'hugs', '!'], ['that',
#    "'s",
#    'one',
#    'scary',
#    '<UNK>',
#    '!',
#    'and',
#    'then',
#    'the',
#    'handbag',
#    'lol',
#    '!']],
#  ('77227017', '79572936'): [['so', 'classy', '!'],
#   ['so',
#    'stunning',
#    'lace',
#    'set',
#    'and',
#    'perfectly',
#    'chosen',
#    'accessories',
#    ',',
#    'sweetie',
#    '!'],
#   ['cool', 'sophistication', '!', 'lovely', '!'],
#   ['great', 'new', 'layout', '!']],
#  ('77227017',
#   '79629049'): [['fantatsic', 'style', 'and', 'outfit', 'sweetie', '.']],
#  ('77227017', '87832289'): [['love', 'the', 'color', '!']],
#  ('77227017',
#   '90130839'): [['yes', 'yes', 'yes', '.', 'love', 'this', 'outfit', '.'],
#   ['excellent',
#    'unique',
#    'ensemble',
#    'honey',
#    '!',
#    'the',
#    'tee',
#    'rocks',
#    '!',
#    'xo',
#    '.'],
#   ['amazing', 'set', '!', 'top', 'is', 'indeed', 'gorgeous', ')', ')', '.'],
#   ['this',
#    'top',
#    'would',
#    'definitely',
#    'be',
#    'on',
#    'my',
#    'wishlist',
#    ',',
#    'too',
#    '!',
#    'love',
#    'the',
#    'entire',
#    'outfit',
#    '<',
#    '3',
#    'many',
#    'kisses',
#    ',',
#    'dear',
#    'rikka',
#    '!'],
#   ['wooow', 'dear', '...', 'fab', ',', 'i', 'love', 'this', 'outfit', '.'],
#   ['this', 'is', 'soo', 'beautiful', ',', 'love', 'the', 'outfit', '.'],
#   ['well', 'styled', ',', 'dear', '!', 'very', 'chic', '!']],
#  ('211449266', '208671281'): [['perfection', 'with', 'pineapples', '.']],
#  ('211449266',
#   '213621429'): [['fantastic', 'set', ',', 'love', 'the', 'shoes', '.']],
#  ('169266178', '167351781'): [['so', 'brilliant', '.'],
#   ['beautiful', 'outfit', '!', 'so', 'urban', '!'],
#   ['adore',
#    'this',
#    'kind',
#    'of',
#    'it',
#    'girl',
#    'style',
#    'fab',
#    'this',
#    'jacket',
#    'too',
#    '!']],
#  ('169266178',
#   '169236728'): [['wow',
#    '!',
#    'what',
#    'a',
#    'dynamic',
#    'evening',
#    'look',
#    '.'], ['obrigada', '!', 'bjs', '.'], ['so',
#    'astonishing',
#    'design',
#    'x',
#    '.'], ['splendid', 'set', 'xx', '.'], ['gorgeous',
#    'geometric',
#    'glam',
#    '!'], ['so', 'striking', '.'], ['fabulous',
#    'look',
#    'darling',
#    '!'], ['very', 'elegant', ':', ')', '.'], ['this',
#    'is',
#    'a',
#    'fabulous',
#    'black',
#    'and',
#    'white',
#    'set',
#    '!'], ['outstanding', 'set', '!', 'perfect', 'layout', '.'], ['on',
#    'point',
#    '!',
#    'everything',
#    'is',
#    'perfect',
#    '!'], ['fantastic', 'sassy', 'style', '!']],
#  ('169266178',
#   '179664787'): [['bold', 'statement', 'pieces', '!', 'fab', '!']],
#  ('19403971',
#   '18422780'): [['wow',
#    ',',
#    'amazing',
#    'doll',
#    '.',
#    'thank',
#    'you',
#    'for',
#    'the',
#    'tag',
#    'xx',
#    '.'], ['wow..gorgeous', 'dear', '!'], ['i',
#    'love',
#    'paper',
#    'dolls',
#    '!'], ['awesome',
#    '!',
#    'thanks',
#    'for',
#    'the',
#    'challenge',
#    ':',
#    ')',
#    '.'], ['so', 'fab', 'dear^^', '.'], ['that',
#    'one',
#    'stylish',
#    'doll',
#    ':',
#    ')',
#    '.'], ['wow', '...', '.stunning', '!'], ['<UNK>',
#    'doll',
#    '!'], ['outrageous', 'doll', '!', 'love', 'it', '!'], ['pretty',
#    'pretty',
#    'doll',
#    '!'], ['sooo', 'creative', ':', ')', ')', '.'], ['wow',
#    '!',
#    'amazing',
#    '!',
#    'superb',
#    'doll',
#    '!']],
#  ('19403971', '21898461'): [['well', 'done', '.']],
#  ('19403971',
#   '46686022'): [['thank',
#    'you',
#    'so',
#    'much',
#    'dear',
#    '!',
#    ':',
#    ')',
#    'same',
#    'to',
#    'you',
#    '<',
#    '3',
#    'kisses',
#    '.'], ['congrats', 'on', 'your', 'win', ':', ')', ')', ')', '.'], ['thank',
#    'you',
#    'so',
#    'much',
#    'ladies',
#    '!',
#    '<',
#    '3',
#    '.'], ['thank',
#    'you',
#    'so',
#    'much',
#    'for',
#    'all',
#    'your',
#    'comments',
#    '!',
#    '<',
#    '3',
#    '.'], ['~this',
#    'looks',
#    'amazing',
#    'sweetheart',
#    '>',
#    '>',
#    'wish',
#    'you',
#    'a',
#    'wonderful',
#    'week',
#    '!',
#    'kisses',
#    '.']],
#  ('167110308', '159200988'): [['very', 'chic', 'and', 'edgy', '.']],
#  ('167110308', '166246517'): [['very', 'chic', 'and', 'edgy', '.']],
#  ('167110308', '166277011'): [['incredible', '...', '.so', 'chic', '.'],
#   ['oh',
#    ',',
#    'good',
#    'golly',
#    ',',
#    'i',
#    'love',
#    'your',
#    'style',
#    '!',
#    '<',
#    '3',
#    '<',
#    '3',
#    '<',
#    '3',
#    '.'],
#   ['beautifully', 'done', '!']],
#  ...}

# %%
beamsearch = True
print(time.localtime())
checkpoint = 'checkpoint3/trained_model.ckpt-3'
test_graph = tf.Graph()
with tf.Session(graph=test_graph,config=config) as sess:
    loader = tf.train.import_meta_graph(checkpoint+'.meta')
    loader.restore(sess,checkpoint)
    img1 = test_graph.get_tensor_by_name('inputs/img1:0')
    img2 = test_graph.get_tensor_by_name('inputs/img2:0')
    img1id = test_graph.get_tensor_by_name('inputs/img1id:0')
    img2id = test_graph.get_tensor_by_name('inputs/img2id:0')
    sequence_length = test_graph.get_tensor_by_name('inputs/sequence_length:0')
    max_sequence_length = test_graph.get_tensor_by_name('inputs/max_sequence_length:0')
    batch_size = test_graph.get_tensor_by_name('inputs/batch_size:0')
    keep_prob = test_graph.get_tensor_by_name('inputs/keep_prob:0')
    flag = test_graph.get_tensor_by_name('inputs/flag:0')
    prediction = test_graph.get_tensor_by_name('prediction/prediction:0')
    greedysearch_sequence = test_graph.get_tensor_by_name('generation/greedysearch_sequence:0')
    beamsearch_sequence = test_graph.get_tensor_by_name('generation/beamsearch_sequence:0')
    
    print(time.localtime())
    print('Top-Down:')
    b_s = 64
    max_seq_len = 30
    system_tops_comments = {}
#     tops_trec = {}
    query_number = 0
    step = 0
    for top in tops_orderlist:
        downsoftop = test_tops_data[top]
#         probabilitylist = {}
        for batch_i in range(len(downsoftop)//b_s+1):
            start_i = batch_i*b_s
            downs = downsoftop[start_i:start_i+b_s]
            x_i1,x_i2,x_id1,x_id2 = build_evaluation_batch(top,downs,0,topidlist,downidlist)
            seq_len = [30]*len(x_i1)
            gred_seq,beam_seq = sess.run([greedysearch_sequence,beamsearch_sequence],{img1:get_img(x_i1),img2:get_img(x_i2),img1id:x_id1,img2id:x_id2,sequence_length:seq_len,max_sequence_length:max_seq_len,batch_size:len(x_i1),keep_prob:1.0,flag:True})
            j = 0
            for down in downs:
#                 probabilitylist[down] = prob[j][1]
                if model_tops_comments.get((top,down)) != None:
                    if beamsearch:
                        system_tops_comments[(top,down)] = [(id_seq_to_word_seq(beam_seq[j][:,index],int_to_word,word_to_int['<EOS>'])).split()[:-1] for index in range(3)]
                    else:
                        system_tops_comments[(top,down)] = (id_seq_to_word_seq(gred_seq[j],int_to_word,word_to_int['<EOS>'])).split()[:-1]
                j += 1 
            step += 1
            if step%1000 == 0:
                print('pass!')
#         tops_trec[query_number] = sorted(probabilitylist.items(),key=lambda item:item[1],reverse=True)
#         del probabilitylist,downsoftop
        query_number += 1
    _,select_tops = bleu_evalaution(model_tops_comments,system_tops_comments,beamsearch)
#     auc_evaluation(tops_labellist,tops_trec)
#     trec_evaluation(tops_qrel_file_path,tops_trec_file_path,tops_trec)
#     del tops_trec

    print(time.localtime())
    print('Down-Top:')
    system_downs_comments = {}
#     downs_trec = {}
    query_number = 0
    step = 0
    for down in downs_orderlist:
        topsofdown = test_downs_data[down]
#         probabilitylist = {}
        for batch_i in range(len(topsofdown)//b_s+1):
            start_i = batch_i*b_s
            tops = topsofdown[start_i:start_i+b_s]
            x_i1,x_i2,x_id1,x_id2 = build_evaluation_batch(down,tops,1,topidlist,downidlist)
            seq_len = [30]*len(x_i1)
            gred_seq,beam_seq = sess.run([greedysearch_sequence,beamsearch_sequence],{img1:get_img(x_i1),img2:get_img(x_i2),img1id:x_id1,img2id:x_id2,sequence_length:seq_len,max_sequence_length:max_seq_len,batch_size:len(x_i1),keep_prob:1.0,flag:True})
            j = 0
            for top in tops:
#                 probabilitylist[top] = prob[j][1]
                if model_downs_comments.get((down,top)) != None:
                    if beamsearch:
                        system_downs_comments[(down,top)] = [(id_seq_to_word_seq(beam_seq[j][:,index],int_to_word,word_to_int['<EOS>'])).split()[:-1] for index in range(3)]
                    else:
                        system_downs_comments[(down,top)] = (id_seq_to_word_seq(gred_seq[j],int_to_word,word_to_int['<EOS>'])).split()[:-1]
                j += 1
            step += 1
            if step%1000 == 0:
                print('pass!')
#         downs_trec[query_number] = sorted(probabilitylist.items(),key=lambda item:item[1],reverse=True)
#         del probabilitylist,topsofdown
        query_number += 1
    _,select_downs = bleu_evalaution(model_downs_comments,system_downs_comments,beamsearch)
#     auc_evaluation(downs_labellist,downs_trec)
#     trec_evaluation(downs_qrel_file_path,downs_trec_file_path,downs_trec)
#     del downs_trec
print(time.localtime())
# Out:
# time.struct_time(tm_year=2019, tm_mon=5, tm_mday=22, tm_hour=17, tm_min=45, tm_sec=15, tm_wday=2, tm_yday=142, tm_isdst=0)
# INFO:tensorflow:Restoring parameters from checkpoint3/trained_model.ckpt-3
# time.struct_time(tm_year=2019, tm_mon=5, tm_mday=22, tm_hour=17, tm_min=45, tm_sec=18, tm_wday=2, tm_yday=142, tm_isdst=0)
# Top-Down:
# pass!
# pass!
# pass!
# pass!
# 0.3259455329609304
# time.struct_time(tm_year=2019, tm_mon=5, tm_mday=22, tm_hour=18, tm_min=29, tm_sec=34, tm_wday=2, tm_yday=142, tm_isdst=0)
# Down-Top:
# pass!
# pass!
# pass!
# pass!
# 0.3242810944094186
# time.struct_time(tm_year=2019, tm_mon=5, tm_mday=22, tm_hour=19, tm_min=13, tm_sec=25, tm_wday=2, tm_yday=142, tm_isdst=0)

# %%
with open('system_comments/system_tops_comments.dat','w') as f:
    if beamsearch:
        for combination,commentlist in system_tops_comments.items():
            comment = ' '.join(commentlist[select_tops[combination]])
            f.write(combination[0]+'\t'+combination[1]+'\t'+comment+'\n')
    else:
        for combination,comment in system_downs_comments.items():
            comment = ' '.join(comment)
            f.write(combination[0]+'\t'+combination[1]+'\t'+comment+'\n')

# %%
with open('system_comments/system_downs_comments.dat','w') as f:
    if beamsearch:
        for combination,commentlist in system_downs_comments.items():
            comment = ' '.join(commentlist[select_downs[combination]])
            f.write(combination[0]+'\t'+combination[1]+'\t'+comment+'\n')
    else:
        for combination,comment in system_downs_comments.items():
            comment = ' '.join(comment)
            f.write(combination[0]+'\t'+combination[1]+'\t'+comment+'\n')
